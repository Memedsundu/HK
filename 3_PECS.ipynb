# %% [markdown]
# 1- Table 1: Census Main Form

# %%
CENSUS_MAIN_FORM_MAPPING = {
    # Universal columns (exist in all 10 countries)
    "formdef_version": {
        "Burkina Faso": "formdef_version",
        "Cameroon": "formdef_version",
        "Côte d'Ivoire": "formdef_version",
        "Guinea": "formdef_version",
        "Kenya": "formdef_version",
        "Madagascar": "formdef_version",
        "Mali": "formdef_version",
        "Niger": "formdef_version",
        "Nigeria": "formdef_version",
        "RDC": "formdef_version"
    },
    
    "submission_date": {
        "Burkina Faso": "SubmissionDate",
        "Cameroon": "SubmissionDate",
        "Côte d'Ivoire": "SubmissionDate",
        "Guinea": "SubmissionDate",
        "Kenya": "SubmissionDate",
        "Madagascar": "SubmissionDate",
        "Mali": "SubmissionDate",
        "Niger": "SubmissionDate",
        "Nigeria": "SubmissionDate",
        "RDC": "SubmissionDate"
    },
    
    "end_time": {
        "Burkina Faso": "end_time",
        "Cameroon": "end_time",
        "Côte d'Ivoire": "end_time",
        "Guinea": "end_time",
        "Kenya": "end_time",
        "Madagascar": "end_time",
        "Mali": "end_time",
        "Niger": "end_time",
        "Nigeria": "end_time",
        "RDC": "end_time"
    },
    
    "device_info": {
        "Burkina Faso": "device_info",
        "Cameroon": "device_info",
        "Côte d'Ivoire": "device_info",
        "Guinea": "device_info",
        "Kenya": "device_info",
        "Madagascar": "device_info",
        "Mali": "device_info",
        "Niger": "device_info",
        "Nigeria": "device_info",
        "RDC": "device_info"
    },
    
    "start_time": {
        "Burkina Faso": "start_time",
        "Cameroon": "start_time",
        "Côte d'Ivoire": "start_time",
        "Guinea": "start_time",
        "Kenya": "start_time",
        "Madagascar": "start_time",
        "Mali": "start_time",
        "Niger": "start_time",
        "Nigeria": "start_time",
        "RDC": "start_time"
    },
    
    "review_quality": {
        "Burkina Faso": "review_quality",
        "Cameroon": "review_quality",
        "Côte d'Ivoire": "review_quality",
        "Guinea": "review_quality",
        "Kenya": "review_quality",
        "Madagascar": "review_quality",
        "Mali": "review_quality",
        "Niger": "review_quality",
        "Nigeria": "review_quality",
        "RDC": "review_quality"
    },
    
    "case_id": {
        "Burkina Faso": "caseid",
        "Cameroon": "caseid",
        "Côte d'Ivoire": "caseid",
        "Guinea": "caseid",
        "Kenya": "caseid",
        "Madagascar": "caseid",
        "Mali": "caseid",
        "Niger": "caseid",
        "Nigeria": "caseid",
        "RDC": "caseid"
    },
    
    "duration_interview": {
        "Burkina Faso": "duration_interview",
        "Cameroon": "duration_interview",
        "Côte d'Ivoire": "duration_interview",
        "Guinea": "duration_interview",
        "Kenya": "duration_interview",
        "Madagascar": "duration_interview",
        "Mali": "duration_interview",
        "Niger": "duration_interview",
        "Nigeria": "duration_interview",
        "RDC": "duration_interview"
    },
    
    "text_audit": {
        "Burkina Faso": "text_audit",
        "Cameroon": "text_audit",
        "Côte d'Ivoire": "text_audit",
        "Guinea": "text_audit",
        "Kenya": "text_audit",
        "Madagascar": "text_audit",
        "Mali": "text_audit",
        "Niger": "text_audit",
        "Nigeria": "text_audit",
        "RDC": "text_audit"
    },
    
    "audio_audit": {
        "Burkina Faso": "audio_audit",
        "Cameroon": "audio_audit",
        "Côte d'Ivoire": "audio_audit",
        "Guinea": "audio_audit",
        "Kenya": "audio_audit",
        "Madagascar": "audio_audit",
        "Mali": "audio_audit",
        "Niger": "audio_audit",
        "Nigeria": "audio_audit",
        "RDC": "audio_audit"
    },
    
    "duration": {
        "Burkina Faso": "duration",
        "Cameroon": "duration",
        "Côte d'Ivoire": "duration",
        "Guinea": "duration",
        "Kenya": "duration",
        "Madagascar": "duration",
        "Mali": "duration",
        "Niger": "duration",
        "Nigeria": "duration",
        "RDC": "duration"
    },
    
    "n_denombre": {
        "Burkina Faso": "n_denombre",
        "Cameroon": "n_denombre",
        "Côte d'Ivoire": "n_denombre",
        "Guinea": "n_denombre",
        "Kenya": "n_denombre",
        "Madagascar": "n_denombre",
        "Mali": "n_denombre",
        "Niger": "n_denombre",
        "Nigeria": "n_denombre",
        "RDC": "n_denombre"
    },
    
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": "KEY",
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",
        "Nigeria": "KEY",
        "RDC": "KEY"
    },
    
    "tot_menage_eligible": {
        "Burkina Faso": "tot_menage_eligible",
        "Cameroon": "tot_menage_eligible",
        "Côte d'Ivoire": "tot_menage_eligible",
        "Guinea": "tot_menage_eligible",
        "Kenya": "tot_menage_eligible",
        "Madagascar": "tot_menage_eligible",
        "Mali": "tot_menage_eligible",
        "Niger": "tot_menage_eligible",
        "Nigeria": "tot_menage_eligible",
        "RDC": "tot_menage_eligible"
    },
    
    # Columns in 9 countries (missing in 1)
    "tot_hh_size": {
        "Burkina Faso": "tot_hh_size",
        "Cameroon": "tot_hh_size",
        "Côte d'Ivoire": "tot_hh_size",
        "Guinea": "tot_hh_size",
        "Kenya": "tot_HH_size",  # Note: different capitalization
        "Madagascar": "tot_hh_size",
        "Mali": "tot_hh_size",
        "Niger": "tot_hh_size",
        "Nigeria": "tot_hh_size",
        "RDC": "tot_hh_size"
    },
    
    "set_of_menage": {
        "Burkina Faso": "SET-OF-menage",
        "Cameroon": "SET-OF-menage",
        "Côte d'Ivoire": "SET-OF-menage",
        "Guinea": "SET-OF-consent_oui-menage",  # Different naming pattern
        "Kenya": "SET-OF-menage",
        "Madagascar": "SET-OF-menage",
        "Mali": "SET-OF-menage",
        "Niger": "SET-OF-menage",
        "Nigeria": "SET-OF-menage",
        "RDC": "SET-OF-menage"
    },
    
    # Columns in 8 countries
    "all_household": {
        "Burkina Faso": "all_household",
        "Cameroon": "all_household",
        "Côte d'Ivoire": "all_household",
        "Kenya": "all_household",
        "Mali": "all_household",
        "Niger": "all_household",
        "Nigeria": "all_household",
        "RDC": "all_household"
    },
    
    "enumerator_name": {
        "Burkina Faso": "enumerator_name",
        "Cameroon": "enumerator_name",
        "Côte d'Ivoire": "enumerator_name",
        "Kenya": "enumerator_name",
        "Mali": "enumerator_name",
        "Niger": "enumerator_name",
        "Nigeria": "enumerator_name",
        "RDC": "enumerator_name"
    },
    
    "enumerator": {
        "Burkina Faso": "enumerator",
        "Cameroon": "enumerator",
        "Côte d'Ivoire": "enumerator",
        "Guinea": "enqueteur",  # French variation
        "Madagascar": "enumerator",
        "Mali": "enumerator",
        "Niger": "enumerator",
        "Nigeria": "enumerator",
        "RDC": "enumerator"
    },
    
    "cluster": {
        "Burkina Faso": "cluster",
        "Cameroon": "cluster",
        "Côte d'Ivoire": "cluster",
        "Guinea": "cluster",
        "Madagascar": "cluster",
        "Mali": "cluster",
        "Niger": "cluster",
        "Nigeria": "cluster"
    },
    
    "num_household": {
        "Burkina Faso": "num_household",
        "Cameroon": "num_household",
        "Côte d'Ivoire": "num_household",
        "Kenya": "num_household",
        "Mali": "num_household",
        "Niger": "num_household",
        "Nigeria": "num_household",
        "RDC": "num_household"
    },
    
    "hh_start_time": {
        "Burkina Faso": "hh_start_time",
        "Cameroon": "hh_start_time",
        "Côte d'Ivoire": "hh_start_time",
        "Guinea": "consent_oui-hh_start_time",  # Different naming pattern
        "Madagascar": "hh_start_time",
        "Mali": "hh_start_time",
        "Niger": "hh_start_time",
        "Nigeria": "hh_start_time",
        "RDC": "hh_start_time"
    },
    
    # Columns in 7 countries
    "starttime": {
        "Burkina Faso": "starttime",
        "Cameroon": "starttime",
        "Côte d'Ivoire": "starttime",
        "Kenya": "starttime",
        "Niger": "starttime",
        "Nigeria": "starttime",
        "RDC": "starttime"
    },
    
    "area": {
        "Burkina Faso": "area",
        "Cameroon": "area",
        "Côte d'Ivoire": "area",
        "Kenya": "area",
        "Madagascar": "area",
        "Mali": "area",
        "Niger": "area"
    },
    
    "h14_maj": {
        "Burkina Faso": "h14_maj",
        "Cameroon": "h14_maj",
        "Côte d'Ivoire": "h14_maj",
        "Mali": "h14_maj",
        "Niger": "h14_maj",
        "Nigeria": "h14_maj",
        "RDC": "h14_maj"
    },
    
    "region": {
        "Burkina Faso": "region",
        "Cameroon": "region",
        "Côte d'Ivoire": "region",
        "Guinea": "region",
        "Madagascar": "region",
        "Mali": "region",
        "Niger": "region"
    },
    
    "join_eligible": {
        "Burkina Faso": "join_eligible",
        "Cameroon": "join_eligible",
        "Côte d'Ivoire": "join_eligible",
        "Mali": "join_eligible",
        "Niger": "join_eligible",
        "Nigeria": "join_eligible",
        "RDC": "join_eligible"
    },
    
    "endtime": {
        "Burkina Faso": "endtime",
        "Cameroon": "endtime",
        "Côte d'Ivoire": "endtime",
        "Kenya": "endtime",
        "Niger": "endtime",
        "Nigeria": "endtime",
        "RDC": "endtime"
    },
    
    # Columns in 6 countries
    "devicephonenum": {
        "Cameroon": "devicephonenum",
        "Côte d'Ivoire": "devicephonenum",
        "Kenya": "devicephonenum",
        "Niger": "devicephonenum",
        "Nigeria": "devicephonenum",
        "RDC": "devicephonenum"
    },
    
    "deviceid": {
        "Cameroon": "deviceid",
        "Côte d'Ivoire": "deviceid",
        "Kenya": "deviceid",
        "Niger": "deviceid",
        "Nigeria": "deviceid",
        "RDC": "deviceid"
    },
    
    "team_lead": {
        "Burkina Faso": "team_lead",
        "Cameroon": "team_lead",
        "Côte d'Ivoire": "team_lead",
        "Kenya": "team_lead",
        "Mali": "team_lead",
        "Niger": "team_lead",
        "RDC": "teamlead"  # Different spelling
    },
    
    "username": {
        "Cameroon": "username",
        "Côte d'Ivoire": "username",
        "Kenya": "username",
        "Niger": "username",
        "Nigeria": "username",
        "RDC": "username"
    },
    
    "commune_name": {
        "Burkina Faso": "commune_name",
        "Cameroon": "commune_name",
        "Côte d'Ivoire": "commune_name",
        "Mali": "commune_name",
        "Niger": "commune_name",
        "RDC": "commune_name"
    },
    
    "commune": {
        "Burkina Faso": "commune",
        "Côte d'Ivoire": "commune",
        "Madagascar": "commune",
        "Mali": "commune",
        "Niger": "commune",
        "RDC": "commune"
    },
    
    "set_of_random_selected_hh_rep": {
        "Burkina Faso": "SET-OF-random_selected-hh_rep",
        "Cameroon": "SET-OF-random_selected-hh_rep",
        "Côte d'Ivoire": "SET-OF-random_selected-hh_rep",
        "Guinea": "SET-OF-random_selected-hh_rep",
        "Kenya": "SET-OF-hh_rep",  # Shorter naming
        "Mali": "SET-OF-random_selected-hh_rep",
        "Nigeria": "SET-OF-random_selected-hh_rep"
    },
    
    "meta_instance_id": {
        "Cameroon": "meta-instanceID",
        "Côte d'Ivoire": "meta-instanceID",
        "Kenya": "meta-instanceID",
        "Niger": "meta-instanceID",
        "Nigeria": "meta-instanceID",
        "RDC": "meta-instanceID"
    },
    
    "hh_select": {
        "Burkina Faso": "hh_select",
        "Cameroon": "hh_select",
        "Côte d'Ivoire": "hh_select",
        "Mali": "hh_select",
        "Nigeria": "hh_select",
        "RDC": "hh_select"
    },
    
    "set_of_random_selected_random_draws": {
        "Burkina Faso": "SET-OF-random_selected-random_draws",
        "Cameroon": "SET-OF-random_selected-random_draws",
        "Côte d'Ivoire": "SET-OF-random_selected-random_draws",
        "Guinea": "SET-OF-random_selected-random_draws",
        "Kenya": "SET-OF-random_draws",  # Shorter naming
        "Mali": "SET-OF-random_selected-random_draws",
        "Nigeria": "SET-OF-random_selected-random_draws"
    },
    
    # Columns in 5 countries
    "region_name": {
        "Burkina Faso": "region_name",
        "Cameroon": "region_name",
        "Côte d'Ivoire": "region_name",
        "Mali": "region_name",
        "Niger": "region_name"
    },
    
    "random_selected_selected_phone": {
        "Burkina Faso": "random_selected-selected_phone",
        "Cameroon": "random_selected-selected_phone",
        "Côte d'Ivoire": "random_selected-selected_phone",
        "Mali": "random_selected-selected_phone",
        "Nigeria": "random_selected-selected_phone"
    },
    
    "random_selected_unique_draws": {
        "Burkina Faso": "random_selected-unique_draws",
        "Cameroon": "random_selected-unique_draws",
        "Côte d'Ivoire": "random_selected-unique_draws",
        "Kenya": "unique_draws",  # Without prefix
        "Mali": "random_selected-unique_draws",
        "Nigeria": "random_selected-unique_draws"
    },
    
    "random_selected_num_hh": {
        "Burkina Faso": "random_selected-num_hh",
        "Cameroon": "random_selected-num_hh",
        "Côte d'Ivoire": "random_selected-num_hh",
        "Kenya": "num_hh",  # Without prefix
        "Mali": "random_selected-num_hh",
        "Nigeria": "random_selected-num_hh"
    },
    
    "random_selected_selected_household": {
        "Burkina Faso": "random_selected-selected_household",
        "Cameroon": "random_selected-selected_household",
        "Côte d'Ivoire": "random_selected-selected_household",
        "Kenya": "selected_household",  # Without prefix
        "Mali": "random_selected-selected_household",
        "Nigeria": "random_selected-selected_household"
    },
    
    "random_selected_selected_des": {
        "Burkina Faso": "random_selected-selected_des",
        "Cameroon": "random_selected-selected_des",
        "Côte d'Ivoire": "random_selected-selected_des",
        "Mali": "random_selected-selected_des",
        "Nigeria": "random_selected-selected_des"
    },
    
    "random_selected_selected_nom": {
        "Burkina Faso": "random_selected-selected_nom",
        "Cameroon": "random_selected-selected_nom",
        "Côte d'Ivoire": "random_selected-selected_nom",
        "Mali": "random_selected-selected_nom",
        "Nigeria": "random_selected-selected_nom"
    },
    
    "random_selected_num_hh_sample": {
        "Burkina Faso": "random_selected-num_hh_sample",
        "Cameroon": "random_selected-num_hh_sample",
        "Côte d'Ivoire": "random_selected-num_hh_sample",
        "Guinea": "random_selected-num_hh_sample",
        "Kenya": "num_hh_sample",  # Without prefix
        "Mali": "random_selected-num_hh_sample"
    },
    
    "supervisor": {
        "Burkina Faso": "supervisor",
        "Guinea": "superviseur",  # French variation
        "Madagascar": "supervisor",
        "Mali": "supervisor",
        "Nigeria": "supervisor",
        "RDC": "supervisor"
    },
    
    # Columns in 4 countries
    "district": {
        "Burkina Faso": "district",
        "Côte d'Ivoire": "district",
        "Madagascar": "district",
        "Mali": "district"
    },
    
    "localite": {
        "Burkina Faso": "localite",
        "Côte d'Ivoire": "localite",
        "Mali": "localite",
        "Niger": "localite"
    },
    
    "team_name": {
        "Burkina Faso": "team_name",
        "Cameroon": "team_name",
        "Côte d'Ivoire": "team_name",
        "Mali": "team_name"
    },
    
    # Columns in 3 countries
    "localite_name": {
        "Burkina Faso": "localite_name",
        "Côte d'Ivoire": "localite_name",
        "Mali": "localite_name"
    },
    
    "district_name": {
        "Burkina Faso": "district_name",
        "Côte d'Ivoire": "district_name",
        "Mali": "district_name"
    },
    
    "random_selected_hh_rep_count": {
        "Cameroon": "random_selected-hh_rep_count",
        "Côte d'Ivoire": "random_selected-hh_rep_count",
        "Kenya": "hh_rep_count",  # Without prefix
        "Nigeria": "random_selected-hh_rep_count"
    },
    
    "random_selected_random_draws_count": {
        "Cameroon": "random_selected-random_draws_count",
        "Côte d'Ivoire": "random_selected-random_draws_count",
        "Kenya": "random_draws_count",  # Without prefix
        "Nigeria": "random_selected-random_draws_count"
    },
    
    "meta_instance_name": {
        "Cameroon": "meta-instanceName",
        "Côte d'Ivoire": "meta-instanceName",
        "Niger": "meta-instanceName"
    },
    
    "tot_enfant": {
        "Cameroon": "tot_enfant",
        "Niger": "tot_enfant",
        "Nigeria": "tot_enfant"
    },
    
    "tot_femme": {
        "Cameroon": "tot_femme",
        "Niger": "tot_femme",
        "Nigeria": "tot_femme"
    },
    
    # Columns in 2 countries
    "departement_name": {
        "Cameroon": "departement_name",
        "Niger": "departement_name"
    },
    
    "departement": {
        "Cameroon": "departement",
        "Niger": "departement"
    },
    
    "location": {
        "Kenya": "location",
        "Nigeria": "location"
    },
    
    "cercle_name": {
        "Côte d'Ivoire": "cercle_name",
        "Mali": "cercle_name"
    },
    
    # Single country columns
    "ra": {
        "Nigeria": "ra"
    },
    
    "province_name": {
        "RDC": "province_name"
    },
    
    "province": {
        "RDC": "province"
    },
    
    "eac": {
        "Nigeria": "EAC"
    },
    
    "strate": {
        "Cameroon": "strate"
    },
    
    "sousprefecture": {
        "Guinea": "sousprefecture"
    },
    
    "state": {
        "Nigeria": "state"
    },
    
    "sub_county_1": {
        "Kenya": "sub_county_1"
    },
    
    "sub_location_1": {
        "Kenya": "sub_location_1"
    },
    
    "team_sup": {
        "Kenya": "team_sup"
    },
    
    "ville": {
        "RDC": "ville"
    },
    
    "prefecture": {
        "Guinea": "prefecture"
    },
    
    "hh_end_time": {
        "Madagascar": "hh_end_time"
    },
    
    "arrondissement": {
        "Cameroon": "arrondissement"
    },
    
    "division": {
        "Kenya": "division"
    },
    
    "day_of_dc": {
        "Kenya": "day_of_dc"
    },
    
    "county": {
        "Kenya": "county"
    },
    
    "consent": {
        "Guinea": "consent"
    },
    
    "cluster_number": {
        "Cameroon": "cluster_number"
    },
    
    "cercle": {
        "Mali": "cercle"
    },
    
    "arrondissement_name": {
        "Cameroon": "arrondissement_name"
    },
    
    "zd": {
        "Niger": "ZD"
    },
    
    "typecluster": {
        "Cameroon": "Typecluster"
    },
    
    "ploc": {
        "Nigeria": "PLOC"
    },
    
    "locn": {
        "Nigeria": "LOCN"
    },
    
    "lclass": {
        "Nigeria": "LCLASS"
    },
    
    "ecode": {
        "Nigeria": "ECODE"
    },
    
    "ea_code_label": {
        "Kenya": "ea_code_label"
    },
    
    "ea_name": {
        "Niger": "ea_name"
    },
    
    "enquete": {
        "Côte d'Ivoire": "enquete"
    },
    
    "milieu_name": {
        "RDC": "milieu_name"
    },
    
    "milieu": {
        "RDC": "milieu"
    },
    
    "locality_name": {
        "RDC": "locality_name"
    },
    
    "locality": {
        "RDC": "locality"
    },
    
    "lga": {
        "Nigeria": "lga"
    },
    
    "hstatus": {
        "Nigeria": "hstatus"
    },
    
    "ean": {
        "Nigeria": "EAN"
    },
    
    "hh_duration_interview": {
        "Madagascar": "hh_duration_interview"
    },
    
    "grappe_name": {
        "RDC": "grappe_name"
    },
    
    "grappe": {
        "RDC": "grappe"
    },
    
    "enumerator_name_id": {
        "Kenya": "enumerator_name_id"
    },
    
    "enumerator_name_2": {
        "Kenya": "enumerator_name_2"
    },
    
    "enumerator_id": {
        "Niger": "enumerator_id"
    },
    
    "enumeration_area_id": {
        "Kenya": "enumeration_area_id"
    },
    
    "enumeration_area_1": {
        "Kenya": "enumeration_area_1"
    },
    
    "enumeration_area": {
        "Kenya": "enumeration_area"
    },
    
    "ville_name": {
        "RDC": "ville_name"
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Census Main Form
CENSUS_MAIN_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs_census",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_census",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_census_r2",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_census_r1",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_census_r2_collect",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_denombrement",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs_census",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_census_v2",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_censusform",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_census_r2"
}

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply CENSUS_MAIN_FORM_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in CENSUS_MAIN_FORM_MAPPING.items():
        if country in country_mapping:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_census_main_harmonized():
    """Create harmonized Census Main Form table"""
    
    print("CREATING CENSUS MAIN FORM - HARMONIZED TABLE")
    print("=" * 50)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in CENSUS_MAIN_ENDPOINTS.items():
        print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 50)
    print("CENSUS MAIN FORM - HARMONIZED SUMMARY")
    print("=" * 50)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in CENSUS_MAIN_FORM_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping
        country_count = len(CENSUS_MAIN_FORM_MAPPING[col])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:30} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    census_main_combined = create_census_main_harmonized()
    
    # Display sample data
    if census_main_combined is not None:
        print(f"\n🎉 Table 1 (Census Main) is ready!")
        print(f"Shape: {census_main_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(census_main_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(census_main_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(census_main_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING CENSUS MAIN FORM - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 108 rows loaded
#   → Burkina Faso: 48 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 933 rows loaded
#   → Cameroon: 58 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 307 rows loaded
#   → Côte d'Ivoire: 56 columns harmonized
# Loading Guinea...
# ✓ Guinea: 145 rows loaded
#   → Guinea: 27 columns harmonized
# Loading Kenya...
# ✓ Kenya: 456 rows loaded
#   → Kenya: 48 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 1459 rows loaded
#   → Madagascar: 26 columns harmonized
# Loading Mali...
# ✓ Mali: 115 rows loaded
#   → Mali: 48 columns harmonized
# Loading Niger...
# ✓ Niger: 311 rows loaded
#   → Niger: 45 columns harmonized
# Loading Nigeria...
# ✓ Nigeria: 174 rows loaded
#   → Nigeria: 55 columns harmonized
# Loading RDC...
# ✓ RDC: 355 rows loaded
#   → RDC: 44 columns harmonized
#
# Combining data from 10 countries...
#
# ...

# %% [markdown]
# Table 2: Census Menage Repeat Group

# %%
CENSUS_MENAGE_MAPPING = {
    # Universal columns (exist in all 10 countries)
    "set_of_menage": {
        "Burkina Faso": "SET-OF-menage",
        "Cameroon": "SET-OF-menage",
        "Côte d'Ivoire": "SET-OF-menage",
        "Guinea": "SET-OF-menage",
        "Kenya": "SET-OF-menage",
        "Madagascar": "SET-OF-menage",
        "Mali": "SET-OF-menage",
        "Niger": "SET-OF-menage",
        "Nigeria": "SET-OF-menage",
        "RDC": "SET-OF-menage"
    },
    
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": "KEY",
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",
        "Nigeria": "KEY",
        "RDC": "KEY"
    },
    
    "parent_key": {
        "Burkina Faso": "PARENT_KEY",
        "Cameroon": "PARENT_KEY",
        "Côte d'Ivoire": "PARENT_KEY",
        "Guinea": "PARENT_KEY",
        "Kenya": "PARENT_KEY",
        "Madagascar": "PARENT_KEY",
        "Mali": "PARENT_KEY",
        "Niger": "PARENT_KEY",
        "Nigeria": "PARENT_KEY",
        "RDC": "PARENT_KEY"
    },
    
    # Columns in 9 countries (missing Guinea mostly)
    "consent": {
        "Burkina Faso": "consent",
        "Cameroon": "consent",
        "Côte d'Ivoire": "consent",
        "Guinea": "consent",  # Guinea has this column separately
        "Kenya": "consent",
        "Madagascar": "consent",
        "Mali": "consent",
        "Niger": "consent",
        "Nigeria": "consent",
        "RDC": "consent"
    },
    
    "men_id_men": {
        "Burkina Faso": "consent_oui-men-id_men",
        "Cameroon": "consent_oui-men-id_men",
        "Côte d'Ivoire": "consent_oui-men-id_men",
        "Guinea": "men-id_men",  # Without consent_oui prefix
        "Kenya": "consent_oui-men-id_men",
        "Madagascar": "consent_oui-men-id_men",
        "Mali": "consent_oui-men-id_men",
        "Niger": "consent_oui-men-id_men",
        "Nigeria": "consent_oui-men-id_men",
        "RDC": "consent_oui-men-id_men"
    },
    
    "hh_status": {
        "Burkina Faso": "consent_oui-hh_status",
        "Cameroon": "consent_oui-hh_status",
        "Côte d'Ivoire": "consent_oui-hh_status",
        "Guinea": "hh_status",  # Without consent_oui prefix
        "Kenya": "consent_oui-hh_status",
        "Madagascar": "consent_oui-hh_status",
        "Mali": "consent_oui-hh_status",
        "Niger": "consent_oui-hh_status",
        "Nigeria": "consent_oui-hh_status",
        "RDC": "consent_oui-hh_status"
    },
    
    "enfant_6_59": {
        "Burkina Faso": "consent_oui-enfant_6_59",
        "Cameroon": "consent_oui-enfant_6_59",
        "Côte d'Ivoire": "consent_oui-enfant_6_59",
        "Guinea": "enfant_6_59",  # Without consent_oui prefix
        "Kenya": "consent_oui-enfant_6_59",
        "Madagascar": "consent_oui-enfant_6_59",
        "Mali": "consent_oui-enfant_6_59",
        "Niger": "consent_oui-enfant_6_59",
        "Nigeria": "consent_oui-enfant_6_59",
        "RDC": "consent_oui-enfant_6_59"
    },
    
    # Columns in 8 countries
    "hh_size": {
        "Burkina Faso": "consent_oui-hh_size",
        "Cameroon": "consent_oui-hh_size",
        "Côte d'Ivoire": "consent_oui-hh_size",
        "Guinea": "hh_size",  # Without consent_oui prefix
        "Kenya": "GPS-HH_size",  # Different naming pattern
        "Madagascar": "consent_oui-hh_size",
        "Mali": "consent_oui-hh_size",
        "Niger": "consent_oui-hh_size",
        "Nigeria": "consent_oui-hh_size",
        "RDC": "consent_oui-hh_size"
    },
    
    "men_num_men": {
        "Burkina Faso": "consent_oui-men-num_men",
        "Cameroon": "consent_oui-men-num_men",
        "Côte d'Ivoire": "consent_oui-men-num_men",
        "Kenya": "consent_oui-men-num_men",
        "Mali": "consent_oui-men-num_men",
        "Niger": "consent_oui-men-num_men",
        "Nigeria": "consent_oui-men-num_men",
        "RDC": "consent_oui-men-num_men"
    },
    
    "nb_6_59": {
        "Burkina Faso": "consent_oui-nb_6_59",
        "Cameroon": "consent_oui-nb_6_59",
        "Côte d'Ivoire": "consent_oui-nb_6_59",
        "Guinea": "nb_6_59",  # Without consent_oui prefix
        "Madagascar": "consent_oui-nb_6_59",
        "Mali": "consent_oui-nb_6_59",
        "Niger": "consent_oui-nb_6_59",
        "Nigeria": "consent_oui-nb_6_59",
        "RDC": "consent_oui-nb_6_59"
    },
    
    "menage_eligible": {
        "Burkina Faso": "consent_oui-men-rec-menage_eligible",
        "Cameroon": "consent_oui-men-rec-menage_eligible",
        "Côte d'Ivoire": "consent_oui-men-rec-menage_eligible",
        "Guinea": "men-rec-menage_eligible",  # Without consent_oui prefix
        "Kenya": "consent_oui-men-rec-menage_eligible",
        "Madagascar": "consent_oui-men-menage_eligible",  # Different structure
        "Mali": "consent_oui-men-rec-menage_eligible",
        "Niger": "consent_oui-men-rec-menage_eligible",
        "Nigeria": "consent_oui-men-rec-menage_eligible",
        "RDC": "consent_oui-men-rec-menage_eligible"
    },
    
    "household_phone_permit": {
        "Burkina Faso": "consent_oui-men-rec-household-phone_permit",
        "Cameroon": "consent_oui-men-rec-household-phone_permit",
        "Côte d'Ivoire": "consent_oui-men-rec-household-phone_permit",
        "Guinea": "men-rec-household-phone_permit",  # Without consent_oui prefix
        "Madagascar": "consent_oui-men-rec-household-phone_permit",
        "Mali": "consent_oui-men-rec-household-phone_permit",
        "Niger": "consent_oui-men-rec-household-phone_permit",
        "Nigeria": "consent_oui-men-rec-household-phone_permit",
        "RDC": "consent_oui-men-rec-household-phone_permit"
    },
    
    "household_info": {
        "Burkina Faso": "consent_oui-men-rec-household-info",
        "Cameroon": "consent_oui-men-rec-household-info",
        "Côte d'Ivoire": "consent_oui-men-rec-household-info",
        "Guinea": "men-rec-household-info",  # Without consent_oui prefix
        "Kenya": "consent_oui-men-rec-d-info",  # Different structure
        "Madagascar": "consent_oui-men-rec-household-info",
        "Mali": "consent_oui-men-rec-household-info",
        "Niger": "consent_oui-men-rec-household-info",
        "Nigeria": "consent_oui-men-rec-household-info",
        "RDC": "consent_oui-men-rec-household-info"
    },
    
    # Columns in 7 countries
    "household_description": {
        "Burkina Faso": "consent_oui-men-rec-household-description",
        "Cameroon": "consent_oui-men-rec-household-description",
        "Côte d'Ivoire": "consent_oui-men-rec-household-description",
        "Kenya": "consent_oui-men-rec-d-description",  # Different structure
        "Mali": "consent_oui-men-rec-household-description",
        "Niger": "consent_oui-men-rec-household-description",
        "Nigeria": "consent_oui-men-rec-household-description",
        "RDC": "consent_oui-men-rec-household-description"
    },
    
    "men_new_id": {
        "Burkina Faso": "consent_oui-men-new_id",
        "Cameroon": "consent_oui-men-new_id",
        "Côte d'Ivoire": "consent_oui-men-new_id",
        "Mali": "consent_oui-men-new_id",
        "Niger": "consent_oui-men-new_id",
        "Nigeria": "consent_oui-men-new_id",
        "RDC": "consent_oui-men-new_id"
    },
    
    "hh_index": {
        "Burkina Faso": "consent_oui-hh_index",
        "Cameroon": "consent_oui-hh_index",
        "Côte d'Ivoire": "consent_oui-hh_index",
        "Kenya": "hh_index",  # Without consent_oui prefix
        "Mali": "consent_oui-hh_index",
        "Niger": "consent_oui-hh_index",
        "Nigeria": "consent_oui-hh_index",
        "RDC": "consent_oui-hh_index"
    },
    
    "num_menage": {
        "Burkina Faso": "consent_oui-num_menage",
        "Cameroon": "consent_oui-num_menage",
        "Côte d'Ivoire": "consent_oui-num_menage",
        "Mali": "consent_oui-num_menage",
        "Niger": "consent_oui-num_menage",
        "Nigeria": "consent_oui-num_menage",
        "RDC": "consent_oui-num_menage"
    },
    
    "join_eligible2": {
        "Burkina Faso": "consent_oui-join_eligible2",
        "Cameroon": "consent_oui-join_eligible2",
        "Côte d'Ivoire": "consent_oui-join_eligible2",
        "Mali": "consent_oui-join_eligible2",
        "Niger": "consent_oui-join_eligible2",
        "Nigeria": "consent_oui-join_eligible2",
        "RDC": "consent_oui-join_eligible2"
    },
    
    "last_id": {
        "Burkina Faso": "consent_oui-last_id",
        "Cameroon": "consent_oui-last_id",
        "Côte d'Ivoire": "consent_oui-last_id",
        "Mali": "consent_oui-last_id",
        "Niger": "consent_oui-last_id",
        "Nigeria": "consent_oui-last_id",
        "RDC": "consent_oui-last_id"
    },
    
    "men_last_id1": {
        "Burkina Faso": "consent_oui-men-last_id1",
        "Cameroon": "consent_oui-men-last_id1",
        "Côte d'Ivoire": "consent_oui-men-last_id1",
        "Mali": "consent_oui-men-last_id1",
        "Niger": "consent_oui-men-last_id1",
        "Nigeria": "consent_oui-men-last_id1",
        "RDC": "consent_oui-men-last_id1"
    },
    
    "num_ordre_menage": {
        "Burkina Faso": "consent_oui-num_ordre_menage",
        "Cameroon": "consent_oui-num_ordre_menage",
        "Côte d'Ivoire": "consent_oui-num_ordre_menage",
        "Mali": "consent_oui-num_ordre_menage",
        "Niger": "consent_oui-num_ordre_menage",
        "Nigeria": "consent_oui-num_ordre_menage",
        "RDC": "consent_oui-num_ordre_menage"
    },
    
    "household_nom": {
        "Burkina Faso": "consent_oui-men-rec-household-nom",
        "Cameroon": "consent_oui-men-rec-household-nom",
        "Côte d'Ivoire": "consent_oui-men-rec-household-nom",
        "Kenya": "consent_oui-men-rec-d-nom",  # Different structure
        "Mali": "consent_oui-men-rec-household-nom",
        "Niger": "consent_oui-men-rec-household-nom",
        "Nigeria": "consent_oui-men-rec-household-nom",
        "RDC": "consent_oui-men-rec-household-nom"
    },
    
    # Location columns (6 countries)
    "location_longitude": {
        "Burkina Faso": "consent_oui-location-Longitude",
        "Cameroon": "consent_oui-location-Longitude",
        "Côte d'Ivoire": "consent_oui-location-Longitude",
        "Guinea": "location-Longitude",  # Without consent_oui prefix
        "Kenya": "GPS-location_2-Longitude",  # GPS prefix
        "Madagascar": "consent_oui-location-Longitude",
        "Mali": "consent_oui-location-Longitude",
        "Niger": "location-Longitude",  # Without consent_oui prefix
        "Nigeria": "consent_oui-location_gps-Longitude",  # location_gps instead of location
        "RDC": "consent_oui-location-Longitude"
    },
    
    "location_accuracy": {
        "Burkina Faso": "consent_oui-location-Accuracy",
        "Cameroon": "consent_oui-location-Accuracy",
        "Côte d'Ivoire": "consent_oui-location-Accuracy",
        "Guinea": "location-Accuracy",  # Without consent_oui prefix
        "Kenya": "GPS-location_2-Accuracy",  # GPS prefix
        "Madagascar": "consent_oui-location-Accuracy",
        "Mali": "consent_oui-location-Accuracy",
        "Niger": "location-Accuracy",  # Without consent_oui prefix
        "Nigeria": "consent_oui-location_gps-Accuracy",  # location_gps instead of location
        "RDC": "consent_oui-location-Accuracy"
    },
    
    "location_latitude": {
        "Burkina Faso": "consent_oui-location-Latitude",
        "Cameroon": "consent_oui-location-Latitude",
        "Côte d'Ivoire": "consent_oui-location-Latitude",
        "Guinea": "location-Latitude",  # Without consent_oui prefix
        "Kenya": "GPS-location_2-Latitude",  # GPS prefix
        "Madagascar": "consent_oui-location-Latitude",
        "Mali": "consent_oui-location-Latitude",
        "Niger": "location-Latitude",  # Without consent_oui prefix
        "Nigeria": "consent_oui-location_gps-Latitude",  # location_gps instead of location
        "RDC": "consent_oui-location-Latitude"
    },
    
    "location_altitude": {
        "Burkina Faso": "consent_oui-location-Altitude",
        "Cameroon": "consent_oui-location-Altitude",
        "Côte d'Ivoire": "consent_oui-location-Altitude",
        "Guinea": "location-Altitude",  # Without consent_oui prefix
        "Kenya": "GPS-location_2-Altitude",  # GPS prefix
        "Madagascar": "consent_oui-location-Altitude",
        "Mali": "consent_oui-location-Altitude",
        "Niger": "location-Altitude",  # Without consent_oui prefix
        "Nigeria": "consent_oui-location_gps-Altitude",  # location_gps instead of location
        "RDC": "consent_oui-location-Altitude"
    },
    
    "household_phone": {
        "Burkina Faso": "consent_oui-men-rec-household-phone",
        "Cameroon": "consent_oui-men-rec-phone",  # Different structure
        "Côte d'Ivoire": "consent_oui-men-rec-household-phone",
        "Kenya": "consent_oui-men-rec-d-phone",  # Different structure
        "Mali": "consent_oui-men-rec-household-phone",
        "Niger": "consent_oui-men-rec-household-phone",
        "Nigeria": "consent_oui-men-rec-household-phone",
        "RDC": "consent_oui-men-rec-household-phone"
    },
    
    "nb_femme": {
        "Burkina Faso": "consent_oui-nb_femme",
        "Cameroon": "consent_oui-nb_femme",
        "Côte d'Ivoire": "consent_oui-nb_femme",
        "Niger": "consent_oui-nb_femme",
        "Nigeria": "consent_oui-nb_femme",
        "RDC": "consent_oui-nb_femme"
    },
    
    "hh_end_time": {
        "Burkina Faso": "consent_oui-hh_end_time",
        "Cameroon": "consent_oui-hh_end_time",
        "Côte d'Ivoire": "consent_oui-hh_end_time",
        "Guinea": "hh_end_time",  # Without consent_oui prefix
        "Mali": "consent_oui-hh_end_time",
        "Niger": "hh_end_time",  # Without consent_oui prefix
        "Nigeria": "consent_oui-hh_end_time",
        "RDC": "consent_oui-hh_end_time"
    },
    
    "hh_duration_interview": {
        "Burkina Faso": "consent_oui-hh_duration_interview",
        "Cameroon": "consent_oui-hh_duration_interview",
        "Côte d'Ivoire": "consent_oui-hh_duration_interview",
        "Guinea": "hh_duration_interview",  # Without consent_oui prefix
        "Mali": "consent_oui-hh_duration_interview",
        "Niger": "hh_duration_interview",  # Without consent_oui prefix
        "Nigeria": "consent_oui-hh_duration_interview",
        "RDC": "consent_oui-hh_duration_interview"
    },
    
    # Columns in 4 countries
    "id_men_1": {
        "Cameroon": "id_men_1",
        "Kenya": "id_men_1",
        "Niger": "id_men_1",
        "Nigeria": "id_men_1"
    },
    
    "qe1": {
        "Cameroon": "QE1",
        "Kenya": "QE1",
        "Niger": "QE1",
        "Nigeria": "QE1"
    },
    
    "qe2": {
        "Cameroon": "QE2",
        "Kenya": "QE2",
        "Niger": "QE2",
        "Nigeria": "QE2"
    },
    
    # Columns in 3 countries
    "qe2_raison": {
        "Cameroon": "QE2_raison",
        "Niger": "QE2_raison",
        "Nigeria": "QE2_raison"
    },
    
    # Single country columns
    "reason_autre": {
        "Burkina Faso": "reason_autre"
    },
    
    "consent_oui_men_rec_d_nb_0_59": {
        "Kenya": "consent_oui-men-rec-d-nb_0_59"
    },
    
    "consentr": {
        "Côte d'Ivoire": "consentr"
    },
    
    "reason_consent_no": {
        "Burkina Faso": "reason_consent_no"
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Census Menage Repeat Group
CENSUS_MENAGE_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs_census/menage",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_census/menage",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_census_r2/menage",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_census_r1/menage",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_census_r2_collect/menage",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_denombrement/menage",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs_census/menage",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_census_v2/menage",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_censusform/menage",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_census_r2/menage"
}

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply CENSUS_MENAGE_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in CENSUS_MENAGE_MAPPING.items():
        if country in country_mapping:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_census_menage_harmonized():
    """Create harmonized Census Menage Repeat Group table"""
    
    print("CREATING CENSUS MENAGE REPEAT GROUP - HARMONIZED TABLE")
    print("=" * 60)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in CENSUS_MENAGE_ENDPOINTS.items():
        print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 60)
    print("CENSUS MENAGE REPEAT GROUP - HARMONIZED SUMMARY")
    print("=" * 60)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in CENSUS_MENAGE_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping
        country_count = len(CENSUS_MENAGE_MAPPING[col])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:30} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    census_menage_combined = create_census_menage_harmonized()
    
    # Display sample data
    if census_menage_combined is not None:
        print(f"\n🎉 Table 2 (Census Menage) is ready!")
        print(f"Shape: {census_menage_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(census_menage_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(census_menage_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(census_menage_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING CENSUS MENAGE REPEAT GROUP - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 19121 rows loaded
#   → Burkina Faso: 32 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 51878 rows loaded
#   → Cameroon: 34 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 55966 rows loaded
#   → Côte d'Ivoire: 31 columns harmonized
# Loading Guinea...
# ✓ Guinea: 23180 rows loaded
#   → Guinea: 17 columns harmonized
# Loading Kenya...
# ✓ Kenya: 10701 rows loaded
#   → Kenya: 23 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 60020 rows loaded
#   → Madagascar: 16 columns harmonized
# Loading Mali...
# ✓ Mali: 8603 rows loaded
#   → Mali: 29 columns harmonized
# Loading Niger...
# ✓ Niger: 12352 rows loaded
#   → Niger: 34 columns harmonized
# Loading Nigeria...
# ✓ Nigeria: 7916 rows loaded
#   → Nigeria: 34 columns harmonized
# Loading RDC...
# ✓ RDC: 30946 rows loaded
#   → RDC: 30 columns harmonized
#
# Combining data from 10 countries...
#
# ...

# %% [markdown]
# Table 3: Census Random Draws Repeat Group

# %%
CENSUS_RANDOM_DRAWS_MAPPING = {
    # Universal columns (exist in all 7 countries with data)
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": "KEY",
        "Mali": "KEY",
        "Nigeria": "KEY"
        # Note: Madagascar, Niger, and RDC not shown in CSV data
    },
    
    "parent_key": {
        "Burkina Faso": "PARENT_KEY",
        "Cameroon": "PARENT_KEY",
        "Côte d'Ivoire": "PARENT_KEY",
        "Guinea": "PARENT_KEY",
        "Kenya": "PARENT_KEY",
        "Mali": "PARENT_KEY",
        "Nigeria": "PARENT_KEY"
        # Note: Madagascar, Niger, and RDC not shown in CSV data
    },
    
    "set_of_random_draws": {
        "Burkina Faso": "SET-OF-random_draws",
        "Cameroon": "SET-OF-random_draws",
        "Côte d'Ivoire": "SET-OF-random_draws",
        "Guinea": "SET-OF-random_draws",
        "Kenya": "SET-OF-random_draws",
        "Mali": "SET-OF-random_draws",
        "Nigeria": "SET-OF-random_draws"
        # Note: Madagascar, Niger, and RDC not shown in CSV data
    },
    
    # Columns in 6 countries (missing Guinea)
    "random_draw": {
        "Burkina Faso": "random_draw",
        "Cameroon": "random_draw",
        "Côte d'Ivoire": "random_draw",
        # Guinea: Not present
        "Kenya": "random_draw",
        "Mali": "random_draw",
        "Nigeria": "random_draw"
    },
    
    "scaled_draw": {
        "Burkina Faso": "scaled_draw",
        "Cameroon": "scaled_draw",
        "Côte d'Ivoire": "scaled_draw",
        # Guinea: Not present
        "Kenya": "scaled_draw",
        "Mali": "scaled_draw",
        "Nigeria": "scaled_draw"
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Census Random Draws Repeat Group
# Note: Madagascar, Niger, RDC are marked as MISSING since they don't exist as separate endpoints
CENSUS_RANDOM_DRAWS_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs_census/random_draws",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_census/random_draws",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_census_r2/random_draws",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_census_r1/random_draws",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_census_r2_collect/random_draws",
    "Madagascar": "MISSING",  # Doesn't exist as separate endpoint
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs_census/random_draws",
    "Niger": "MISSING",       # Doesn't exist as separate endpoint
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_censusform/random_draws",
    "RDC": "MISSING"          # Doesn't exist as separate endpoint
}

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply CENSUS_RANDOM_DRAWS_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in CENSUS_RANDOM_DRAWS_MAPPING.items():
        if country in country_mapping:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_census_random_draws_harmonized():
    """Create harmonized Census Random Draws Repeat Group table"""
    
    print("CREATING CENSUS RANDOM DRAWS REPEAT GROUP - HARMONIZED TABLE")
    print("=" * 65)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in CENSUS_RANDOM_DRAWS_ENDPOINTS.items():
        if url == "MISSING":
            print(f"{country}: MISSING - No separate endpoint exists")
            continue
            
        print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 65)
    print("CENSUS RANDOM DRAWS REPEAT GROUP - HARMONIZED SUMMARY")
    print("=" * 65)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in CENSUS_RANDOM_DRAWS_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping
        country_count = len(CENSUS_RANDOM_DRAWS_MAPPING[col])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:25} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Note about missing countries
    missing_countries = [country for country, url in CENSUS_RANDOM_DRAWS_ENDPOINTS.items() if url == "MISSING"]
    if missing_countries:
        print(f"\nNote: {len(missing_countries)} countries have no separate random_draws endpoint:")
        for country in missing_countries:
            print(f"  - {country}")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    census_random_draws_combined = create_census_random_draws_harmonized()
    
    # Display sample data
    if census_random_draws_combined is not None:
        print(f"\n🎉 Table 3 (Census Random Draws) is ready!")
        print(f"Shape: {census_random_draws_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(census_random_draws_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(census_random_draws_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(census_random_draws_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING CENSUS RANDOM DRAWS REPEAT GROUP - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 1168 rows loaded
#   → Burkina Faso: 5 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 4980 rows loaded
#   → Cameroon: 5 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 5570 rows loaded
#   → Côte d'Ivoire: 5 columns harmonized
# Loading Guinea...
# ✓ Guinea: 3066 rows loaded
#   → Guinea: 3 columns harmonized
# Loading Kenya...
# ✓ Kenya: 6347 rows loaded
#   → Kenya: 5 columns harmonized
# Madagascar: MISSING - No separate endpoint exists
# Loading Mali...
# ✓ Mali: 1483 rows loaded
#   → Mali: 5 columns harmonized
# Niger: MISSING - No separate endpoint exists
# Loading Nigeria...
# ✓ Nigeria: 4514 rows loaded
#   → Nigeria: 5 columns harmonized
# RDC: MISSING - No separate endpoint exists
#
# Combining data from 7 countries...
#
# ...
# CENSUS RANDOM DRAWS REPEAT GROUP - HARMONIZED SUMMARY
# ...
# Total rows: 27,128
# Total columns: 6
# Countries: 7
# ...

# %% [markdown]
# Table 4: Census HH Rep Repeat Group

# %%
CENSUS_HH_REP_MAPPING = {
    # Universal columns (exist in all 7 countries with data)
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": "KEY",
        "Mali": "KEY",
        "Nigeria": "KEY"
        # Note: Madagascar, Niger, and RDC not shown in CSV data
    },
    
    "parent_key": {
        "Burkina Faso": "PARENT_KEY",
        "Cameroon": "PARENT_KEY",
        "Côte d'Ivoire": "PARENT_KEY",
        "Guinea": "PARENT_KEY",
        "Kenya": "PARENT_KEY",
        "Mali": "PARENT_KEY",
        "Nigeria": "PARENT_KEY"
        # Note: Madagascar, Niger, and RDC not shown in CSV data
    },
    
    "set_of_hh_rep": {
        "Burkina Faso": "SET-OF-hh_rep",
        "Cameroon": "SET-OF-hh_rep",
        "Côte d'Ivoire": "SET-OF-hh_rep",
        "Guinea": "SET-OF-hh_rep",
        "Kenya": "SET-OF-hh_rep",
        "Mali": "SET-OF-hh_rep",
        "Nigeria": "SET-OF-hh_rep"
        # Note: Madagascar, Niger, and RDC not shown in CSV data
    },
    
    # Columns in 6 countries (missing Guinea)
    "hh_name": {
        "Burkina Faso": "hh_name",
        "Cameroon": "hh_name",
        "Côte d'Ivoire": "hh_name",
        # Guinea: Not present
        "Kenya": "hh_name",
        "Mali": "hh_name",
        "Nigeria": "hh_name"
    },
    
    "rand_hh": {
        "Burkina Faso": "rand_hh",
        "Cameroon": "rand_hh",
        "Côte d'Ivoire": "rand_hh",
        # Guinea: Not present
        "Kenya": "rand_hh",
        "Mali": "rand_hh",
        "Nigeria": "rand_hh"
    },
    
    "rand_index": {
        "Burkina Faso": "rand_index",
        "Cameroon": "rand_index",
        "Côte d'Ivoire": "rand_index",
        # Guinea: Not present
        "Kenya": "rand_index",
        "Mali": "rand_index",
        "Nigeria": "rand_index"
    },
    
    "rand_int": {
        "Burkina Faso": "rand_int",
        "Cameroon": "rand_int",
        "Côte d'Ivoire": "rand_int",
        # Guinea: Not present
        "Kenya": "rand_int",
        "Mali": "rand_int",
        "Nigeria": "rand_int"
    },
    
    # Columns in 5 countries (missing Guinea and Kenya)
    "hh_des": {
        "Burkina Faso": "hh_des",
        "Cameroon": "hh_des",
        "Côte d'Ivoire": "hh_des",
        # Guinea: Not present
        # Kenya: Not present
        "Mali": "hh_des",
        "Nigeria": "hh_des"
    },
    
    "hh_nom": {
        "Burkina Faso": "hh_nom",
        "Cameroon": "hh_nom",
        "Côte d'Ivoire": "hh_nom",
        # Guinea: Not present
        # Kenya: Not present
        "Mali": "hh_nom",
        "Nigeria": "hh_nom"
    },
    
    "hh_phone": {
        "Burkina Faso": "hh_phone",
        "Cameroon": "hh_phone",
        "Côte d'Ivoire": "hh_phone",
        # Guinea: Not present
        # Kenya: Not present
        "Mali": "hh_phone",
        "Nigeria": "hh_phone"
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Census HH Rep Repeat Group
# Note: Madagascar, Niger, RDC are marked as MISSING since they don't exist as separate endpoints
CENSUS_HH_REP_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs_census/hh_rep",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_census/hh_rep",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_census_r2/hh_rep",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_census_r1/hh_rep",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_census_r2_collect/hh_rep",
    "Madagascar": "MISSING",  # Doesn't exist as separate endpoint
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs_census/hh_rep",
    "Niger": "MISSING",       # Doesn't exist as separate endpoint
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_censusform/hh_rep",
    "RDC": "MISSING"          # Doesn't exist as separate endpoint
}

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply CENSUS_HH_REP_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in CENSUS_HH_REP_MAPPING.items():
        if country in country_mapping:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_census_hh_rep_harmonized():
    """Create harmonized Census HH Rep Repeat Group table"""
    
    print("CREATING CENSUS HH REP REPEAT GROUP - HARMONIZED TABLE")
    print("=" * 60)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in CENSUS_HH_REP_ENDPOINTS.items():
        if url == "MISSING":
            print(f"{country}: MISSING - No separate endpoint exists")
            continue
            
        print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 60)
    print("CENSUS HH REP REPEAT GROUP - HARMONIZED SUMMARY")
    print("=" * 60)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in CENSUS_HH_REP_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping
        country_count = len(CENSUS_HH_REP_MAPPING[col])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:20} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Note about missing countries and data patterns
    missing_countries = [country for country, url in CENSUS_HH_REP_ENDPOINTS.items() if url == "MISSING"]
    if missing_countries:
        print(f"\nNote: {len(missing_countries)} countries have no separate hh_rep endpoint:")
        for country in missing_countries:
            print(f"  - {country}")
    
    # Show data patterns
    print(f"\nData pattern notes:")
    print(f"  - Guinea: Only has basic structure columns (KEY, PARENT_KEY, SET-OF-hh_rep)")
    print(f"  - Kenya: Missing household description fields (hh_des, hh_nom, hh_phone)")
    print(f"  - Other countries: Have all available columns")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    census_hh_rep_combined = create_census_hh_rep_harmonized()
    
    # Display sample data
    if census_hh_rep_combined is not None:
        print(f"\n🎉 Table 4 (Census HH Rep) is ready!")
        print(f"Shape: {census_hh_rep_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(census_hh_rep_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(census_hh_rep_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(census_hh_rep_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING CENSUS HH REP REPEAT GROUP - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 1071 rows loaded
#   → Burkina Faso: 10 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 2095 rows loaded
#   → Cameroon: 10 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 4183 rows loaded
#   → Côte d'Ivoire: 10 columns harmonized
# Loading Guinea...
# ✓ Guinea: 1919 rows loaded
#   → Guinea: 3 columns harmonized
# Loading Kenya...
# ✓ Kenya: 2598 rows loaded
#   → Kenya: 7 columns harmonized
# Madagascar: MISSING - No separate endpoint exists
# Loading Mali...
# ✓ Mali: 1265 rows loaded
#   → Mali: 10 columns harmonized
# Niger: MISSING - No separate endpoint exists
# Loading Nigeria...
# ✓ Nigeria: 2146 rows loaded
#   → Nigeria: 10 columns harmonized
# RDC: MISSING - No separate endpoint exists
#
# Combining data from 7 countries...
#
# ...
# CENSUS HH REP REPEAT GROUP - HARMONIZED SUMMARY
# ...
# Total rows: 15,277
# Total columns: 11
# Countries: 7
# ...

# %% [markdown]
# Table 5: Household Main Form

# %%
HOUSEHOLD_MAIN_MAPPING = {
    # Universal columns (exist in all 10 countries)
    "submission_date": {
        "Burkina Faso": "SubmissionDate",
        "Cameroon": "SubmissionDate",
        "Côte d'Ivoire": "SubmissionDate",
        "Guinea": "SubmissionDate",
        "Kenya": "SubmissionDate",
        "Madagascar": "SubmissionDate",
        "Mali": "SubmissionDate",
        "Niger": "SubmissionDate",
        "Nigeria": "SubmissionDate",
        "RDC": "SubmissionDate"
    },
    
    "text_audit": {
        "Burkina Faso": "text_audit",
        "Cameroon": "text_audit",
        "Côte d'Ivoire": "text_audit",
        "Guinea": "text_audit",
        "Kenya": "text_audit",
        "Madagascar": "text_audit",
        "Mali": "text_audit",
        "Niger": "text_audit",
        "Nigeria": "text_audit",
        "RDC": "text_audit"
    },
    
    "audio_audit": {
        "Burkina Faso": "audio_audit",
        "Cameroon": "audio_audit",
        "Côte d'Ivoire": "audio_audit",
        "Guinea": "audio_audit",
        "Kenya": "audio_audit",
        "Madagascar": "audio_audit",
        "Mali": "audio_audit",
        "Niger": "audio_audit",
        "Nigeria": "audio_audit",
        "RDC": "audio_audit"
    },
    
    "review_quality": {
        "Burkina Faso": "review_quality",
        "Cameroon": "review_quality",
        "Côte d'Ivoire": "review_quality",
        "Guinea": "review_quality",
        "Kenya": "review_quality",
        "Madagascar": "review_quality",
        "Mali": "review_quality",
        "Niger": "review_quality",
        "Nigeria": "review_quality",
        "RDC": "review_quality"
    },
    
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": "KEY",
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",
        "Nigeria": "KEY",
        "RDC": "KEY"
    },
    
    "formdef_version": {
        "Burkina Faso": "formdef_version",
        "Cameroon": "formdef_version",
        "Côte d'Ivoire": "formdef_version",
        "Guinea": "formdef_version",
        "Kenya": "formdef_version",
        "Madagascar": "formdef_version",
        "Mali": "formdef_version",
        "Niger": "formdef_version",
        "Nigeria": "formdef_version",
        "RDC": "formdef_version"
    },
    
    # Columns in 9 countries (missing Guinea mostly)
    "consent": {
        "Burkina Faso": "consent",
        "Cameroon": "consent",
        "Côte d'Ivoire": "consent",
        "Kenya": "consent",
        "Madagascar": "consent",
        "Mali": "consent",
        "Niger": "consent",
        "Nigeria": "consent",
        "RDC": "consent"
    },
    
    "duration": {
        "Burkina Faso": "duration",
        "Cameroon": "duration",
        "Côte d'Ivoire": "duration",
        "Kenya": "duration",
        "Madagascar": "duration",
        "Mali": "duration",
        "Niger": "duration",
        "Nigeria": "duration",
        "RDC": "duration"
    },
    
    "reason_consent_no": {
        "Burkina Faso": "reason_consent_no",
        "Cameroon": "reason_consent_no",
        "Côte d'Ivoire": "reason_consent_no",
        "Kenya": "reason_consent_no",
        "Madagascar": "reason_consent_no",
        "Mali": "reason_consent_no",
        "Niger": "reason_consent_no",
        "Nigeria": "reason_consent_no",
        "RDC": "reason_consent_no"
    },
    
    "device_info": {
        "Burkina Faso": "device_info",
        "Cameroon": "device_info",
        "Côte d'Ivoire": "device_info",
        "Kenya": "device_info",
        "Madagascar": "device_info",
        "Mali": "device_info",
        "Niger": "device_info",
        "Nigeria": "device_info",
        "RDC": "device_info"
    },
    
    "heure_debut": {
        "Burkina Faso": "heure_debut",
        "Cameroon": "heure_debut",
        "Côte d'Ivoire": "heure_debut",
        "Kenya": "heure_debut",
        "Madagascar": "heure_debut",
        "Mali": "heure_debut",
        "Niger": "heure_debut",
        "Nigeria": "heure_debut",
        "RDC": "heure_debut"
    },
    
    "today": {
        "Burkina Faso": "today",
        "Cameroon": "today",
        "Côte d'Ivoire": "today",
        "Kenya": "today",
        "Madagascar": "today",
        "Mali": "today",
        "Niger": "today",
        "Nigeria": "today",
        "RDC": "today"
    },
    
    # Columns in 8 countries
    "signature": {
        "Burkina Faso": "signature",
        "Cameroon": "signature",
        "Côte d'Ivoire": "signature",
        "Kenya": "signature",
        "Madagascar": "signature",
        "Mali": "signature",
        "Niger": "signature",
        "Nigeria": "signature"
    },
    
    "cluster": {
        "Burkina Faso": "cluster",
        "Cameroon": "cluster",
        "Côte d'Ivoire": "cluster",
        "Guinea": "cluster",
        "Madagascar": "cluster",
        "Mali": "cluster",
        "Niger": "cluster",
        "Nigeria": "cluster"
    },
    
    "q13": {
        "Burkina Faso": "q13",
        "Cameroon": "con-q13",
        "Côte d'Ivoire": "con-q13",
        "Guinea": "con-q13",
        "Kenya": "consent_oui-q13",  # Different prefix
        "Madagascar": "con-q13",
        "Mali": "con-q13",
        "Niger": "con-q13",
        "Nigeria": "con-q13",
        "RDC": "con-q13"
    },
    
    "q11": {
        "Burkina Faso": "q11",
        "Cameroon": "con-q11",
        "Côte d'Ivoire": "con-q11",
        "Guinea": "con-q11",
        "Kenya": "consent_oui-q11",  # Different prefix
        "Madagascar": "con-q11",
        "Mali": "con-q11",
        "Niger": "con-q11", 
        "Nigeria": "con-q11",
        "RDC": "con-q11"
    },
    
    "num_men": {
        "Burkina Faso": "num_men",
        "Cameroon": "con-num_men",
        "Côte d'Ivoire": "con-num_men",
        "Guinea": "con-num_men",
        "Kenya": "consent_oui-num_men",  # Different prefix
        "Madagascar": "con-num_men",
        "Mali": "con-num_men",
        "Niger": "con-num_men",
        "Nigeria": "con-num_men",
        "RDC": "con-num_men"
    },
    
    "nb_femme": {
        "Burkina Faso": "nb_femme",
        "Cameroon": "con-nb_femme",
        "Côte d'Ivoire": "con-nb_femme",
        "Guinea": "con-nb_femme",
        "Kenya": "consent_oui-nb_femme",  # Different prefix
        "Madagascar": "con-nb_femme",
        "Mali": "con-nb_femme",
        "Niger": "con-nb_femme",
        "Nigeria": "con-nb_femme",
        "RDC": "con-nb_femme"
    },
    
    "nb_6_59": {
        "Burkina Faso": "nb_6_59",
        "Cameroon": "con-nb_6_59",
        "Côte d'Ivoire": "con-nb_6_59r",  # Note: 'r' suffix
        "Guinea": "con-nb_6_59",
        "Kenya": "consent_oui-nb_6_59",  # Different prefix
        "Madagascar": "con-nb_6_23",  # Different age range
        "Mali": "con-nb_6_59",
        "Niger": "con-nb_6_59",
        "Nigeria": "con-nb_6_59",
        "RDC": "con-nb_6_59"
    },
    
    "q12": {
        "Burkina Faso": "q12",
        "Cameroon": "con-q12",
        "Côte d'Ivoire": "con-q12",
        "Guinea": "con-q12",
        "Kenya": "consent_oui-q12",  # Different prefix
        "Madagascar": "con-q12",
        "Mali": "con-q12",
        "Niger": "con-q12",
        "Nigeria": "con-q12",
        "RDC": "con-q12"
    },
    
    "q15": {
        "Burkina Faso": "q15",
        "Cameroon": "con-q15",
        "Côte d'Ivoire": "con-q15",
        "Guinea": "con-q15",
        "Kenya": "consent_oui-q15",  # Different prefix
        "Madagascar": "con-q15",
        "Mali": "con-q15",
        "Niger": "con-q15",
        "Nigeria": "con-q15",
        "RDC": "con-q15"
    },
    
    "duree_entretien": {
        "Burkina Faso": "duree_entretien",
        "Cameroon": "con-duree_entretien",
        "Côte d'Ivoire": "con-duree_entretien",
        "Guinea": "con-duree_entretien",
        "Kenya": "consent_oui-duree_entretien",  # Different prefix
        "Madagascar": "con-duree_entretien",
        "Mali": "con-duree_entretien",
        "Niger": "con-duree_entretien",
        "Nigeria": "con-duree_entretien",
        "RDC": "con-duree_entretien"
    },
    
    "q14": {
        "Burkina Faso": "q14",
        "Cameroon": "con-q14",
        "Côte d'Ivoire": "con-q14",
        "Guinea": "con-q14",
        "Kenya": "consent_oui-q14",  # Different prefix
        "Madagascar": "con-q14",
        "Mali": "con-q14",
        "Niger": "con-q14",
        "Nigeria": "con-q14",
        "RDC": "con-q14"
    },
    
    "check_eligible": {
        "Burkina Faso": "check_eligible",
        "Cameroon": "con-check_eligible",
        "Côte d'Ivoire": "con-check_eligible",
        "Guinea": "con-check_eligible",
        "Kenya": "consent_oui-check_eligible",  # Different prefix
        "Madagascar": "con-check_eligible",
        "Mali": "con-check_eligible",
        "Niger": "con-check_eligible",
        "Nigeria": "con-check_eligible",
        "RDC": "con-check_eligible"
    },
    
    "id_men": {
        "Burkina Faso": "id_men",
        "Cameroon": "con-id_men",
        "Côte d'Ivoire": "con-id_men",
        "Guinea": "con-id_men",
        "Madagascar": "con-id_men",
        "Mali": "con-id_men",
        "Niger": "con-id_men",
        "Nigeria": "con-id_men",
        "RDC": "con-id_men"
    },
    
    "heure_fin": {
        "Burkina Faso": "heure_fin",
        "Cameroon": "con-heure_fin",
        "Côte d'Ivoire": "con-heure_fin",
        "Guinea": "con-heure_fin",
        "Kenya": "consent_oui-heure_fin",  # Different prefix
        "Madagascar": "con-heure_fin",
        "Mali": "con-heure_fin",
        "Niger": "con-heure_fin",
        "Nigeria": "con-heure_fin",
        "RDC": "con-heure_fin"
    },
    
    "endtime": {
        "Burkina Faso": "endtime",
        "Cameroon": "endtime",
        "Côte d'Ivoire": "endtime",
        "Kenya": "endtime",
        "Madagascar": "endtime",
        "Niger": "endtime",
        "Nigeria": "endtime",
        "RDC": "endtime"
    },
    
    "area": {
        "Burkina Faso": "area",
        "Cameroon": "area",
        "Côte d'Ivoire": "area",
        "Guinea": "area",
        "Kenya": "area",
        "Madagascar": "area",
        "Mali": "area",
        "Niger": "area"
    },
    
    "enumerator_name": {
        "Burkina Faso": "enumerator_name",
        "Cameroon": "enumerator_name",
        "Côte d'Ivoire": "enumerator_name",
        "Guinea": "enumerator_name",
        "Madagascar": "enumerator_name",
        "Mali": "enumerator_name",
        "Niger": "enumerator_name",
        "Nigeria": "enumerator_name"
    },
    
    "starttime": {
        "Burkina Faso": "starttime",
        "Cameroon": "starttime",
        "Côte d'Ivoire": "starttime",
        "Kenya": "starttime",
        "Madagascar": "starttime",
        "Niger": "starttime",
        "Nigeria": "starttime",
        "RDC": "starttime"
    },
    
    # Columns in 7 countries
    "q22": {
        "Burkina Faso": "q22",
        "Cameroon": "con-ELIGIBLE-q22",
        "Côte d'Ivoire": "con-ELIGIBLE-q22",
        "Guinea": "con-ELIGIBLE-q22",
        "Madagascar": "con-ELIGIBLE-q22",
        "Mali": "con-ELIGIBLE-q22",
        "Niger": "con-ELIGIBLE-q22",
        "Nigeria": "con-eligible-q22",  # lowercase eligible
        "RDC": "con-ELIGIBLE-q22"
    },
    
    "username": {
        "Cameroon": "username",
        "Côte d'Ivoire": "username",
        "Kenya": "username",
        "Madagascar": "username",
        "Niger": "username",
        "Nigeria": "username",
        "RDC": "username"
    },
    
    "set_of_mothers_repeat": {
        "Burkina Faso": "SET-OF-mothers_repeat",
        "Cameroon": "SET-OF-con-ELIGIBLE-mothers_repeat",
        "Côte d'Ivoire": "SET-OF-con-ELIGIBLE-mothers_repeat",
        "Guinea": "SET-OF-con-ELIGIBLE-mothers_repeat",
        "Madagascar": "SET-OF-con-ELIGIBLE-mothers_repeat",
        "Mali": "SET-OF-con-ELIGIBLE-mothers_repeat",
        "Niger": "SET-OF-con-ELIGIBLE-mothers_repeat",
        "Nigeria": "SET-OF-con-eligible-mothers_repeat",  # lowercase eligible
        "RDC": "SET-OF-con-ELIGIBLE-mothers_repeat"
    },
    
    "q23_autre": {
        "Burkina Faso": "q23_autre",
        "Cameroon": "con-ELIGIBLE-q23_autre",
        "Côte d'Ivoire": "con-ELIGIBLE-q23_autre",
        "Guinea": "con-ELIGIBLE-q23_autre",
        "Madagascar": "con-ELIGIBLE-q23_autre",
        "Mali": "con-ELIGIBLE-q23_autre",
        "Niger": "con-ELIGIBLE-q23_autre",
        "Nigeria": "con-eligible-q23_Others",  # "Others" instead of "autre"
        "RDC": "con-ELIGIBLE-q23_autre"
    },
    
    "q22_autre": {
        "Burkina Faso": "q22_autre",
        "Cameroon": "con-ELIGIBLE-q22_autre",
        "Côte d'Ivoire": "con-ELIGIBLE-q22_autre",
        "Guinea": "con-ELIGIBLE-q22_autre",
        "Madagascar": "con-ELIGIBLE-q22_autre",
        "Mali": "con-ELIGIBLE-q22_autre",
        "Niger": "con-ELIGIBLE-q22_autre",
        "Nigeria": "con-eligible-q22_Others",  # "Others" instead of "autre"
        "RDC": "con-ELIGIBLE-q22_autre"
    },
    
    "q15_autre": {
        "Burkina Faso": "q15_autre",
        "Cameroon": "con-q15_autre",
        "Côte d'Ivoire": "con-q15_autre",
        "Guinea": "con-q15_autre",
        "Kenya": "consent_oui-q15_autre",  # Different prefix
        "Madagascar": "con-q15_autre",
        "Mali": "con-q15_autre",
        "Niger": "con-q15_autre",
        "Nigeria": "con-q15_Others",  # "Others" instead of "autre"
        "RDC": "con-q15_autre"
    },
    
    "devicephonenum": {
        "Cameroon": "devicephonenum",
        "Côte d'Ivoire": "devicephonenum",
        "Kenya": "devicephonenum",
        "Madagascar": "devicephonenum",
        "Niger": "devicephonenum",
        "Nigeria": "devicephonenum",
        "RDC": "devicephonenum"
    },
    
    "q23": {
        "Burkina Faso": "q23",
        "Cameroon": "con-ELIGIBLE-q23",
        "Côte d'Ivoire": "con-ELIGIBLE-q23",
        "Guinea": "con-ELIGIBLE-q23",
        "Madagascar": "con-ELIGIBLE-q23",
        "Mali": "con-ELIGIBLE-q23",
        "Niger": "con-ELIGIBLE-q23",
        "Nigeria": "con-eligible-q23",  # lowercase eligible
        "RDC": "con-ELIGIBLE-q23"
    },
    
    "team_lead": {
        "Burkina Faso": "team_lead",
        "Cameroon": "team_lead",
        "Côte d'Ivoire": "team_lead",
        "Kenya": "team_lead",
        "Madagascar": "team_lead",
        "Mali": "team_lead",
        "Niger": "team_lead",
        "RDC": "teamlead"  # Different spelling
    },
    
    "location_accuracy": {
        "Burkina Faso": "location-Accuracy",
        "Cameroon": "con-location-Accuracy",
        "Côte d'Ivoire": "con-location-Accuracy",
        "Guinea": "con-location-Accuracy",
        "Kenya": "consent_oui-location-Accuracy",  # Different prefix
        "Madagascar": "con-location-Accuracy",
        "Mali": "con-location-Accuracy",
        "Niger": "con-location-Accuracy",
        "Nigeria": "con-location_gps-Accuracy",  # location_gps instead of location
        "RDC": "con-location-Accuracy"
    },
    
    "enumerator": {
        "Burkina Faso": "enumerator",
        "Cameroon": "enumerator",
        "Côte d'Ivoire": "con-enumerator",
        "Guinea": "enumerator",
        "Kenya": "enumerator",
        "Mali": "con-enumerator",
        "Niger": "enumerator",
        "Nigeria": "enumerator",
        "RDC": "enumerator"
    },
    
    "obs": {
        "Burkina Faso": "obs",
        "Cameroon": "con-obs",
        "Côte d'Ivoire": "con-obs",
        "Madagascar": "con-obs",
        "Mali": "con-obs",
        "Niger": "con-obs",
        "Nigeria": "con-obs",
        "RDC": "con-obs"
    },
    
    "q24": {
        "Burkina Faso": "q24",
        "Cameroon": "con-ELIGIBLE-q24",
        "Côte d'Ivoire": "con-ELIGIBLE-q24",
        "Guinea": "con-ELIGIBLE-q24",
        "Madagascar": "con-ELIGIBLE-q24",
        "Mali": "con-ELIGIBLE-q24",
        "Niger": "con-ELIGIBLE-q24",
        "Nigeria": "con-eligible-q24",  # lowercase eligible
        "RDC": "con-ELIGIBLE-q24"
    },
    
    "location_latitude": {
        "Burkina Faso": "location-Latitude",
        "Cameroon": "con-location-Latitude",
        "Côte d'Ivoire": "con-location-Latitude",
        "Guinea": "con-location-Latitude",
        "Kenya": "consent_oui-location-Latitude",  # Different prefix
        "Madagascar": "con-location-Latitude",
        "Mali": "con-location-Latitude",
        "Niger": "con-location-Latitude",
        "Nigeria": "con-location_gps-Latitude",  # location_gps instead of location
        "RDC": "con-location-Latitude"
    },
    
    "hh_size": {
        "Burkina Faso": "hh_size",
        "Cameroon": "con-hh_size",
        "Côte d'Ivoire": "con-hh_size",
        "Madagascar": "con-hh_size",
        "Mali": "con-hh_size",
        "Niger": "con-hh_size",
        "Nigeria": "con-hh_size",
        "RDC": "con-hh_size"
    },
    
    "region": {
        "Burkina Faso": "region",
        "Cameroon": "region",
        "Côte d'Ivoire": "region",
        "Guinea": "region",
        "Madagascar": "region",
        "Mali": "region",
        "Niger": "region"
    },
    
    "reason_autre": {
        "Burkina Faso": "reason_autre",
        "Cameroon": "reason_autre",
        "Côte d'Ivoire": "reason_autre",
        "Madagascar": "reason_autre",
        "Mali": "reason_autre",
        "Niger": "reason_autre",
        "Nigeria": "reason_Others",  # "Others" instead of "autre"
        "RDC": "reason_autre"
    },
    
    "location_altitude": {
        "Burkina Faso": "location-Altitude",
        "Cameroon": "con-location-Altitude",
        "Côte d'Ivoire": "con-location-Altitude",
        "Guinea": "con-location-Altitude",
        "Kenya": "consent_oui-location-Altitude",  # Different prefix
        "Madagascar": "con-location-Altitude",
        "Mali": "con-location-Altitude",
        "Niger": "con-location-Altitude",
        "Nigeria": "con-location_gps-Altitude",  # location_gps instead of location
        "RDC": "con-location-Altitude"
    },
    
    "q14_autre": {
        "Burkina Faso": "q14_autre",
        "Cameroon": "con-q14_autre",
        "Côte d'Ivoire": "con-q14_autre",
        "Guinea": "con-q14_autre",
        "Kenya": "consent_oui-q14_autre",  # Different prefix
        "Madagascar": "con-q14_autre",
        "Mali": "con-q14_autre",
        "Niger": "con-q14_autre",
        "Nigeria": "con-q14_Others",  # "Others" instead of "autre"
        "RDC": "con-q14_autre"
    },
    
    "location_longitude": {
        "Burkina Faso": "location-Longitude",
        "Cameroon": "con-location-Longitude",
        "Côte d'Ivoire": "con-location-Longitude",
        "Guinea": "con-location-Longitude",
        "Kenya": "consent_oui-location-Longitude",  # Different prefix
        "Madagascar": "con-location-Longitude",
        "Mali": "con-location-Longitude",
        "Niger": "con-location-Longitude",
        "Nigeria": "con-location_gps-Longitude",  # location_gps instead of location
        "RDC": "con-location-Longitude"
    },
    
    "q24_autre": {
        "Burkina Faso": "q24_autre",
        "Cameroon": "con-ELIGIBLE-q24_autre",
        "Côte d'Ivoire": "con-ELIGIBLE-q24_autre",
        "Guinea": "con-ELIGIBLE-q24_autre",
        "Madagascar": "con-ELIGIBLE-q24_autre",
        "Mali": "con-ELIGIBLE-q24_autre",
        "Niger": "con-ELIGIBLE-q24_autre",
        "Nigeria": "con-eligible-q24_Others",  # "Others" instead of "autre"
        "RDC": "con-ELIGIBLE-q24_autre"
    },
    
    "deviceid": {
        "Cameroon": "deviceid",
        "Côte d'Ivoire": "deviceid",
        "Kenya": "deviceid",
        "Madagascar": "deviceid",
        "Niger": "deviceid",
        "Nigeria": "deviceid",
        "RDC": "deviceid"
    },
    
    # Columns in 6 countries
    "commune": {
        "Burkina Faso": "commune",
        "Côte d'Ivoire": "commune",
        "Madagascar": "commune",
        "Mali": "commune",
        "Niger": "commune",
        "RDC": "commune"
    },
    
    "commune_name": {
        "Burkina Faso": "commune_name",
        "Cameroon": "commune_name",
        "Côte d'Ivoire": "commune_name",
        "Mali": "commune_name",
        "Niger": "commune_name",
        "RDC": "commune_name"
    },
    
    "supervisor": {
        "Burkina Faso": "supervisor",
        "Guinea": "supervisor",
        "Madagascar": "supervisor",
        "Mali": "supervisor",
        "Nigeria": "supervisor",
        "RDC": "supervisor"
    },
    
    "q225": {
        "Burkina Faso": "q225",
        "Cameroon": "con-ELIGIBLE-q225",
        "Côte d'Ivoire": "con-ELIGIBLE-q225",
        "Guinea": "con-ELIGIBLE-q225",
        "Madagascar": "con-ELIGIBLE-q225",
        "Mali": "con-ELIGIBLE-q225",
        "Niger": "con-ELIGIBLE-q225",
        "Nigeria": "con-eligible-qqh-q225"  # Different structure
    },
    
    "q224": {
        "Burkina Faso": "q224",
        "Cameroon": "con-ELIGIBLE-q224",
        "Côte d'Ivoire": "con-ELIGIBLE-q224",
        "Guinea": "con-ELIGIBLE-q224",
        "Madagascar": "con-ELIGIBLE-q224",
        "Mali": "con-ELIGIBLE-q224",
        "Nigeria": "con-eligible-qqh-q224",  # Different structure
        "RDC": "con-ELIGIBLE-q224"
    },
    
    "q213": {
        "Burkina Faso": "q213",
        "Cameroon": "con-ELIGIBLE-q213",
        "Côte d'Ivoire": "con-ELIGIBLE-q213",
        "Guinea": "con-ELIGIBLE-q213",
        "Madagascar": "con-ELIGIBLE-q213",
        "Mali": "con-ELIGIBLE-q213",
        "Nigeria": "con-eligible-q213",  # lowercase eligible
        "RDC": "con-ELIGIBLE-q213"
    },
    
    "q228": {
        "Burkina Faso": "q228",
        "Cameroon": "con-ELIGIBLE-q228",
        "Côte d'Ivoire": "con-ELIGIBLE-q228",
        "Guinea": "con-ELIGIBLE-q228",
        "Mali": "con-ELIGIBLE-q228",
        "Niger": "con-ELIGIBLE-q228",
        "Nigeria": "con-eligible-qqh-q228",  # Different structure
        "RDC": "con-ELIGIBLE-q228"
    },
    
    # Columns in 5 countries
    "q29_autre": {
        "Burkina Faso": "q29_autre",
        "Cameroon": "con-ELIGIBLE-q29_autre",
        "Guinea": "con-ELIGIBLE-q29_autre",
        "Madagascar": "con-ELIGIBLE-q29_autre",
        "Mali": "con-ELIGIBLE-q29_autre",
        "Niger": "con-ELIGIBLE-q29_autre",
        "Nigeria": "con-eligible-q29_Others"  # "Others" instead of "autre"
    },
    
    "q29": {
        "Burkina Faso": "q29",
        "Cameroon": "con-ELIGIBLE-q29",
        "Guinea": "con-ELIGIBLE-q29",
        "Madagascar": "con-ELIGIBLE-q29",
        "Mali": "con-ELIGIBLE-q29",
        "Niger": "con-ELIGIBLE-q29",
        "Nigeria": "con-eligible-q29"  # lowercase eligible
    },
    
    "q21a_autre": {
        "Burkina Faso": "q21a_autre",
        "Cameroon": "con-ELIGIBLE-q21a_autre",
        "Madagascar": "con-ELIGIBLE-q21a_autre",
        "Mali": "con-ELIGIBLE-q21a_autre",
        "Niger": "con-ELIGIBLE-q21a_autre",
        "Nigeria": "con-eligible-q21a_Others",  # "Others" instead of "autre"
        "RDC": "con-ELIGIBLE-q21a_autre"
    },
    
    "q21_autre": {
        "Burkina Faso": "q21_autre",
        "Cameroon": "con-ELIGIBLE-q21_autre",
        "Guinea": "con-ELIGIBLE-q21_autre",
        "Madagascar": "con-ELIGIBLE-q21_autre",
        "Mali": "con-ELIGIBLE-q21_autre",
        "Nigeria": "con-eligible-q21_Others",  # "Others" instead of "autre"
        "RDC": "con-ELIGIBLE-q21_autre"
    },
    
    "q21a": {
        "Burkina Faso": "q21a",
        "Cameroon": "con-ELIGIBLE-q21a",
        "Madagascar": "con-ELIGIBLE-q21a",
        "Mali": "con-ELIGIBLE-q21a",
        "Niger": "con-ELIGIBLE-q21a",
        "Nigeria": "con-eligible-q21a",  # lowercase eligible
        "RDC": "con-ELIGIBLE-q21a"
    },
    
    "tel_menage": {
        "Burkina Faso": "Tel_menage",
        "Cameroon": "con-ELIGIBLE-Tel_menage",
        "Côte d'Ivoire": "con-ELIGIBLE-Tel_menage",
        "Mali": "con-ELIGIBLE-Tel_menage",
        "Niger": "con-ELIGIBLE-Tel_menage",
        "Nigeria": "con-eligible-Tel_menage",  # lowercase eligible
        "RDC": "con-ELIGIBLE-Tel_menage"
    },
    
    "nom_chef": {
        "Burkina Faso": "nom_chef",
        "Cameroon": "con-ELIGIBLE-nom_chef",
        "Côte d'Ivoire": "con-ELIGIBLE-nom_chef",
        "Mali": "con-ELIGIBLE-nom_chef",
        "Niger": "con-ELIGIBLE-nom_chef",
        "Nigeria": "con-eligible-nom_chef",  # lowercase eligible
        "RDC": "con-ELIGIBLE-nom_chef"
    },
    
    "region_name": {
        "Burkina Faso": "region_name",
        "Cameroon": "region_name",
        "Côte d'Ivoire": "region_name",
        "Mali": "region_name",
        "Niger": "region_name"
    },
    
    "q21": {
        "Burkina Faso": "q21",
        "Cameroon": "con-ELIGIBLE-q21",
        "Guinea": "con-ELIGIBLE-q21",
        "Madagascar": "con-ELIGIBLE-q21",
        "Mali": "con-ELIGIBLE-q21",
        "Nigeria": "con-eligible-q21",  # lowercase eligible
        "RDC": "con-ELIGIBLE-q21"
    },
    
    # Columns in 4 countries
    "localite": {
        "Burkina Faso": "localite",
        "Côte d'Ivoire": "localite",
        "Mali": "localite",
        "Niger": "localite"
    },
    
    "q220": {
        "Burkina Faso": "q220",
        "Cameroon": "con-ELIGIBLE-q220",
        "Madagascar": "con-ELIGIBLE-q220",
        "Mali": "con-ELIGIBLE-q220",
        "Niger": "con-ELIGIBLE-q220",
        "Nigeria": "con-eligible-qqh-q220"  # Different structure
    },
    
    "meta_instance_id": {
        "Cameroon": "meta-instanceID",
        "Kenya": "meta-instanceID",
        "Niger": "meta-instanceID",
        "Nigeria": "meta-instanceID"
    },
    
    "district": {
        "Burkina Faso": "district",
        "Côte d'Ivoire": "district",
        "Madagascar": "district",
        "Mali": "district"
    },
    
    "typecluster": {
        "Burkina Faso": "Typecluster",
        "Cameroon": "Typecluster",
        "Côte d'Ivoire": "Typecluster",
        "Mali": "Typecluster"
    },
    
    "q215": {
        "Cameroon": "con-ELIGIBLE-q215",
        "Côte d'Ivoire": "con-ELIGIBLE-q215",
        "Madagascar": "con-ELIGIBLE-q215",
        "Nigeria": "con-eligible-q215",  # lowercase eligible
        "RDC": "con-ELIGIBLE-q215"
    },
    
    "q229": {
        "Burkina Faso": "q229",
        "Cameroon": "con-ELIGIBLE-q229",
        "Guinea": "con-ELIGIBLE-q229",
        "Mali": "con-ELIGIBLE-q229",
        "Niger": "con-ELIGIBLE-q229",
        "Nigeria": "con-eligible-qqh-q229"  # Different structure
    },
    
    "q214": {
        "Cameroon": "con-ELIGIBLE-q214",
        "Madagascar": "con-ELIGIBLE-q214",
        "Niger": "con-ELIGIBLE-q214",
        "Nigeria": "con-eligible-q214",  # lowercase eligible
        "RDC": "con-ELIGIBLE-q214"
    },
    
    "case_id": {
        "Cameroon": "caseid",
        "Kenya": "caseid",
        "Niger": "caseid",
        "Nigeria": "caseid"
    },
    
    "team_name": {
        "Burkina Faso": "team_name",
        "Cameroon": "team_name",
        "Côte d'Ivoire": "team_name",
        "Mali": "team_name"
    },
    
    # Columns in 3 countries
    "q223": {
        "Cameroon": "con-ELIGIBLE-q223",
        "Côte d'Ivoire": "con-ELIGIBLE-q223",
        "Mali": "con-ELIGIBLE-q223",
        "Nigeria": "con-eligible-qqh-q223"  # Different structure
    },
    
    "q211": {
        "Burkina Faso": "q211",
        "Cameroon": "con-ELIGIBLE-q211",
        "Madagascar": "con-ELIGIBLE-q211",
        "Mali": "con-ELIGIBLE-q211",
        "Nigeria": "con-eligible-q211"  # lowercase eligible
    },
    
    "q211_autre": {
        "Burkina Faso": "q211_autre",
        "Cameroon": "con-ELIGIBLE-q211_autre",
        "Madagascar": "con-ELIGIBLE-q211_autre",
        "Mali": "con-ELIGIBLE-q211_autre",
        "Nigeria": "con-eligible-q211_Others"  # "Others" instead of "autre"
    },
    
    "meta_instance_name": {
        "Cameroon": "meta-instanceName",
        "Niger": "meta-instanceName",
        "Nigeria": "meta-instanceName"
    },
    
    "localite_name": {
        "Burkina Faso": "localite_name",
        "Côte d'Ivoire": "localite_name",
        "Mali": "localite_name"
    },
    
    "district_name": {
        "Burkina Faso": "district_name",
        "Côte d'Ivoire": "district_name",
        "Mali": "district_name"
    },
    
    "enqueteur": {
        "Côte d'Ivoire": "enqueteur",
        "Guinea": "enumerator",  # English version
        "Madagascar": "enqueteur",
        "Mali": "enqueteur"
    },
    
    "q217": {
        "Cameroon": "con-ELIGIBLE-q217",
        "Côte d'Ivoire": "con-ELIGIBLE-q217",
        "Mali": "con-ELIGIBLE-q217",
        "Nigeria": "con-eligible-q217"  # lowercase eligible
    },
    
    "q230": {
        "Burkina Faso": "q230",
        "Cameroon": "con-ELIGIBLE-q230",
        "Madagascar": "con-ELIGIBLE-q230",
        "Nigeria": "con-eligible-qqh-q230",  # Different structure
        "RDC": "con-ELIGIBLE-q230"
    },
    
    "enumerator1": {
        "Cameroon": "con-enumerator1",
        "Nigeria": "con-enumerator1",
        "RDC": "con-enumerator1"
    },
    
    # Columns in 2 countries
    "q236": {
        "Burkina Faso": "q236",
        "Cameroon": "con-ELIGIBLE-q236",
        "Mali": "con-ELIGIBLE-q236",
        "Nigeria": "con-eligible-qqh-q236"  # Different structure
    },
    
    "q212e": {
        "Burkina Faso": "q212e",
        "Cameroon": "con-ELIGIBLE-q212e",
        "Mali": "con-ELIGIBLE-q212e",
        "Nigeria": "con-eligible-q212e"  # lowercase eligible
    },
    
    "q212f": {
        "Burkina Faso": "q212f",
        "Cameroon": "con-ELIGIBLE-q212f",
        "Mali": "con-ELIGIBLE-q212f",
        "Nigeria": "con-eligible-q212f"  # lowercase eligible
    },
    
    "ea_name": {
        "Guinea": "ea_name",
        "Niger": "ea_name"
    },
    
    "q234": {
        "Burkina Faso": "q234",
        "Cameroon": "con-ELIGIBLE-q234",
        "Mali": "con-ELIGIBLE-q234",
        "Nigeria": "con-eligible-qqh-q234"  # Different structure
    },
    
    "q26": {
        "Cameroon": "con-ELIGIBLE-q26",
        "Côte d'Ivoire": "con-ELIGIBLE-q26",
        "Nigeria": "con-eligible-q26"  # lowercase eligible
    },
    
    "departement_name": {
        "Cameroon": "departement_name",
        "Niger": "departement_name"
    },
    
    "departement": {
        "Cameroon": "departement",
        "Niger": "departement"
    },
    
    "enumerator_name1": {
        "Cameroon": "con-enumerator_name1",
        "Nigeria": "con-enumerator_name1"
    },
    
    "con_enumerator": {
        "Côte d'Ivoire": "con-enumerator",
        "Mali": "con-enumerator"
    },
    
    "q235": {
        "Cameroon": "con-ELIGIBLE-q235",
        "Mali": "con-ELIGIBLE-q235",
        "Nigeria": "con-eligible-qqh-q235"  # Different structure
    },
    
    "q233": {
        "Burkina Faso": "q233",
        "Cameroon": "con-ELIGIBLE-q233",
        "Mali": "con-ELIGIBLE-q233",
        "Nigeria": "con-eligible-qqh-q233"  # Different structure
    },
    
    "q212b": {
        "Burkina Faso": "q212b",
        "Cameroon": "con-ELIGIBLE-q212b",
        "Mali": "con-ELIGIBLE-q212b",
        "Nigeria": "con-eligible-q212b"  # lowercase eligible
    },
    
    "q226": {
        "Cameroon": "con-ELIGIBLE-q226",
        "Madagascar": "con-ELIGIBLE-q226",
        "Nigeria": "con-eligible-qqh-q226"  # Different structure
    },
    
    "q218": {
        "Cameroon": "con-ELIGIBLE-q218",
        "Madagascar": "con-ELIGIBLE-q218",
        "Nigeria": "con-eligible-q218"  # lowercase eligible
    },
    
    "q216": {
        "Cameroon": "con-ELIGIBLE-q216",
        "Côte d'Ivoire": "con-ELIGIBLE-q216",
        "Nigeria": "con-eligible-q216"  # lowercase eligible
    },
    
    "q212d": {
        "Burkina Faso": "q212d",
        "Cameroon": "con-ELIGIBLE-q212d",
        "Mali": "con-ELIGIBLE-q212d",
        "Nigeria": "con-eligible-q212d"  # lowercase eligible
    },
    
    "q212a": {
        "Burkina Faso": "q212a",
        "Cameroon": "con-ELIGIBLE-q212a",
        "Mali": "con-ELIGIBLE-q212a",
        "Nigeria": "con-eligible-q212a"  # lowercase eligible
    },
    
    "q212k": {
        "Burkina Faso": "q212k",
        "Cameroon": "con-ELIGIBLE-q212k",
        "Mali": "con-ELIGIBLE-q212k",
        "Nigeria": "con-eligible-q212k"  # lowercase eligible
    },
    
    "q212": {
        "Cameroon": "con-ELIGIBLE-q212",
        "Madagascar": "con-ELIGIBLE-q212",
        "Nigeria": "con-eligible-q212"  # lowercase eligible
    },
    
    "mothers_repeat_count": {
        "Cameroon": "con-ELIGIBLE-mothers_repeat_count",
        "Niger": "con-ELIGIBLE-mothers_repeat_count",
        "Nigeria": "con-eligible-mothers_repeat_count"  # lowercase eligible
    },
    
    "q212c": {
        "Burkina Faso": "q212c",
        "Cameroon": "con-ELIGIBLE-q212c",
        "Mali": "con-ELIGIBLE-q212c",
        "Nigeria": "con-eligible-q212c"  # lowercase eligible
    },
    
    "q227": {
        "Cameroon": "con-ELIGIBLE-q227",
        "Madagascar": "con-ELIGIBLE-q227",
        "Nigeria": "con-eligible-qqh-q227"  # Different structure
    },
    
    "q212i": {
        "Burkina Faso": "q212i",
        "Cameroon": "con-ELIGIBLE-q212i",
        "Mali": "con-ELIGIBLE-q212i",
        "Nigeria": "con-eligible-q212i"  # lowercase eligible
    },
    
    "q212h": {
        "Burkina Faso": "q212h",
        "Cameroon": "con-ELIGIBLE-q212h",
        "Mali": "con-ELIGIBLE-q212h",
        "Nigeria": "con-eligible-q212h"  # lowercase eligible
    },
    
    "cercle_name": {
        "Côte d'Ivoire": "cercle_name",
        "Mali": "cercle_name"
    },
    
    "q231": {
        "Cameroon": "con-ELIGIBLE-q231",
        "Côte d'Ivoire": "con-ELIGIBLE-q231",
        "Nigeria": "con-eligible-qqh-q231"  # Different structure
    },
    
    "q212g": {
        "Burkina Faso": "q212g",
        "Cameroon": "con-ELIGIBLE-q212g",
        "Mali": "con-ELIGIBLE-q212g",
        "Nigeria": "con-eligible-q212g"  # lowercase eligible
    },
    
    "location": {
        "Kenya": "location_1",  # Different naming
        "Nigeria": "location"
    },
    
    # Single country columns
    "consentr": {
        "Côte d'Ivoire": "consentr"
    },
    
    "province_name": {
        "RDC": "province_name"
    },
    
    "province": {
        "RDC": "province"
    },
    
    "prefecture": {
        "Guinea": "prefecture"
    },
    
    "q237": {
        "Burkina Faso": "q237",
        "Cameroon": "con-ELIGIBLE-q237",
        "Nigeria": "con-eligible-qqh-q237"  # Different structure
    },
    
    "q238": {
        "Burkina Faso": "q238",
        "Cameroon": "con-ELIGIBLE-q238",
        "Nigeria": "con-eligible-qqh-q238"  # Different structure
    },
    
    "q239": {
        "Burkina Faso": "q239",
        "Cameroon": "con-ELIGIBLE-q239",
        "Nigeria": "con-eligible-qqh-q239"  # Different structure
    },
    
    "ville_name": {
        "RDC": "ville_name"
    },
    
    "ville": {
        "RDC": "ville"
    },
    
    "team_sup": {
        "Kenya": "team_sup"
    },
    
    "sublocation": {
        "Kenya": "sublocation"
    },
    
    "subcounty": {
        "Kenya": "subcounty"
    },
    
    "strate": {
        "Cameroon": "strate"
    },
    
    "state": {
        "Nigeria": "state"
    },
    
    "sousprefecture": {
        "Guinea": "sousprefecture"
    },
    
    "round": {
        "Madagascar": "round"
    },
    
    "ra": {
        "Nigeria": "ra"
    },
    
    "enumerator111": {
        "Burkina Faso": "enumerator111"
    },
    
    "eac": {
        "Nigeria": "EAC"
    },
    
    "milieu_name": {
        "RDC": "milieu_name"
    },
    
    "milieu": {
        "RDC": "milieu"
    },
    
    "locality_name": {
        "RDC": "locality_name"
    },
    
    "locality": {
        "RDC": "locality"
    },
    
    "lga": {
        "Nigeria": "lga"
    },
    
    "hstatus": {
        "Nigeria": "hstatus"
    },
    
    "grappe_name": {
        "RDC": "grappe_name"
    },
    
    "grappe": {
        "RDC": "grappe"
    },
    
    "enumerator_id": {
        "Niger": "enumerator_id"
    },
    
    "enumeration_area": {
        "Kenya": "enumeration_area"
    },
    
    "division": {
        "Kenya": "division"
    },
    
    "day_of_dc": {
        "Kenya": "day_of_dc"
    },
    
    "county": {
        "Kenya": "county"
    },
    
    "country": {
        "Madagascar": "country"
    },
    
    "ecode": {
        "Nigeria": "ECODE"
    },
    
    "lclass": {
        "Nigeria": "LCLASS"
    },
    
    "locn": {
        "Nigeria": "LOCN"
    },
    
    "ploc": {
        "Nigeria": "PLOC"
    },
    
    "ean": {
        "Nigeria": "EAN"
    },
    
    "zd": {
        "Niger": "ZD"
    },
    
    "arrondissement": {
        "Cameroon": "arrondissement"
    },
    
    "arrondissement_name": {
        "Cameroon": "arrondissement_name"
    },
    
    "q27": {
        "Cameroon": "con-ELIGIBLE-q27",
        "Nigeria": "con-eligible-q27"  # lowercase eligible
    },
    
    "q28": {
        "Cameroon": "con-ELIGIBLE-q28",
        "Nigeria": "con-eligible-q28"  # lowercase eligible
    },
    
    "q28_autre": {
        "Cameroon": "con-ELIGIBLE-q28_autre",
        "Nigeria": "con-eligible-q28_Others"  # "Others" instead of "autre"
    },
    
    "q25": {
        "Cameroon": "con-ELIGIBLE-q25",
        "Nigeria": "con-eligible-q25"  # lowercase eligible
    },
    
    "q25_autre": {
        "Cameroon": "con-ELIGIBLE-q25_autre",
        "Nigeria": "con-eligible-q25_Others"  # "Others" instead of "autre"
    },
    
    "q243": {
        "Niger": "con-ELIGIBLE-q243"
    },
    
    "cercle": {
        "Mali": "cercle"
    },
    
    "q219": {
        "Cameroon": "con-ELIGIBLE-q219",
        "Nigeria": "con-eligible-qqh-q219"  # Different structure
    },
    
    "cluster_number": {
        "Cameroon": "cluster_number"
    },
    
    "nb_an": {
        "Cameroon": "con-ELIGIBLE-Nb_AN"
    },
    
    "q210": {
        "Cameroon": "con-ELIGIBLE-q210",
        "Nigeria": "con-eligible-q210"  # lowercase eligible
    },
    
    "q217a": {
        "Côte d'Ivoire": "con-ELIGIBLE-q217a"
    },
    
    "q218a": {
        "Cameroon": "con-ELIGIBLE-q218a",
        "Nigeria": "con-eligible-q218a"  # lowercase eligible
    },
    
    "q221": {
        "Cameroon": "con-ELIGIBLE-q221",
        "Nigeria": "con-eligible-qqh-q221"  # Different structure
    },
    
    "q242": {
        "Niger": "con-ELIGIBLE-q242"
    },
    
    "q222": {
        "Cameroon": "con-ELIGIBLE-q222",
        "Nigeria": "con-eligible-qqh-q222"  # Different structure
    },
    
    "q232": {
        "RDC": "con-ELIGIBLE-q232"
    },
    
    "q240": {
        "Niger": "con-ELIGIBLE-q240"
    },
    
    "q241": {
        "Niger": "con-ELIGIBLE-q241"
    },
    
    "year": {
        "Madagascar": "year"
    },
    
    # Audio columns for Nigeria
    "audio_q53": {
        "Nigeria": "audio_q53"
    },
    
    "audio_q42": {
        "Nigeria": "audio_q42"
    },
    
    "audio_q46": {
        "Nigeria": "audio_q46"
    },
    
    "audio_q47": {
        "Nigeria": "audio_q47"
    },
    
    "audio_q51": {
        "Nigeria": "audio_q51"
    },
    
    "audio_q51r": {
        "Nigeria": "audio_q51r"
    },
    
    "audio_q52a": {
        "Nigeria": "audio_q52a"
    },
    
    "audio_q67": {
        "Nigeria": "audio_q67"
    },
    
    "audio_q123": {
        "Nigeria": "audio_q123"
    },
    
    "audio_q81": {
        "Nigeria": "audio_q81"
    },
    
    "audio_q812": {
        "Nigeria": "audio_q812"
    },
    
    "audio_q819": {
        "Nigeria": "audio_q819"
    },
    
    "audio_q82": {
        "Nigeria": "audio_q82"
    },
    
    "audio_q84": {
        "Nigeria": "audio_q84"
    },
    
    "audio_q84a": {
        "Nigeria": "audio_q84a"
    },
    
    "audio_q41": {
        "Nigeria": "audio_q41"
    },
    
    "audio_q122": {
        "Nigeria": "audio_q122"
    },
    
    "audio_q92": {
        "Nigeria": "audio_q92"
    },
    
    "audio_q121": {
        "Nigeria": "audio_q121"
    },
    
    "audio_q111": {
        "Nigeria": "audio_q111"
    },
    
    "audio_q112": {
        "Nigeria": "audio_q112"
    },
    
    "audio_q113": {
        "Nigeria": "audio_q113"
    },
    
    "audio_q91": {
        "Nigeria": "audio_q91"
    },
    
    "audio_q93": {
        "Nigeria": "audio_q93"
    },
    
    "audio_hh_size": {
        "Nigeria": "con-audio_hh_size"
    },
    
    "audio_nb_6_59": {
        "Nigeria": "con-audio_nb_6-59"
    },
    
    "audio_nb_femme": {
        "Nigeria": "con-audio_nb_femme"
    },
    
    "audio_q214": {
        "Nigeria": "con-eligible-audio_q214"
    },
    
    "audio_q23": {
        "Nigeria": "con-eligible-audio_q23"
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO
import re

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Household Main Form
HOUSEHOLD_MAIN_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs__household",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_household",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_household_r2",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_household_r1",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_household_r2_collect",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_menage",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs__household",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_household_v2",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_hhform",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_household_r2"
}

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply HOUSEHOLD_MAIN_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in HOUSEHOLD_MAIN_MAPPING.items():
        if country in country_mapping:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def clean_num_men_column(df):
    """Clean the num_men column by extracting last number and standardizing format"""
    if 'num_men' not in df.columns:
        return df
    
    # Function to extract and standardize numbers
    def extract_and_standardize_number(value):
        if pd.isna(value):
            return value
        
        # Convert to string and strip whitespace
        value_str = str(value).strip()
        
        # Pattern 1: Check for dash followed by (optional spaces and) digits at the end
        # This handles cases like "EC-3241-36-  011"
        dash_pattern = r'-\s*(\d+)$'
        dash_match = re.search(dash_pattern, value_str)
        if dash_match:
            # Extract the digits after the last dash and convert to integer
            extracted_num = int(dash_match.group(1))
            # If the number is reasonable (1-999), return it, otherwise blank
            if 1 <= extracted_num <= 999:
                return extracted_num
            else:
                return pd.NA
        
        # Pattern 2: Check for underscore followed by digits at the end
        underscore_pattern = r'_(\d+)$'
        underscore_match = re.search(underscore_pattern, value_str)
        if underscore_match:
            # Extract the digits after the underscore and convert to integer
            extracted_num = int(underscore_match.group(1))
            # If the number is reasonable (1-999), return it, otherwise blank
            if 1 <= extracted_num <= 999:
                return extracted_num
            else:
                return pd.NA
        
        # Pattern 3: Try to convert to numeric
        try:
            num_value = pd.to_numeric(value_str)
            # Check if it's a reasonable household number (1-999)
            if pd.notna(num_value):
                # If it's a whole number, convert to integer
                if num_value == int(num_value):
                    num_value = int(num_value)
                # If the number is reasonable, return it, otherwise blank
                if 1 <= num_value <= 999:
                    return num_value
                else:
                    return pd.NA
        except:
            # If conversion fails (e.g., "EC"), return blank
            return pd.NA
        
        # If none of the above work, return blank
        return pd.NA
    
    # Apply the cleaning function
    df['num_men'] = df['num_men'].apply(extract_and_standardize_number)
    
    # Print some examples of cleaned values for verification
    print(f"  → Sample num_men values after cleaning:")
    sample_values = df['num_men'].dropna().head(10)
    for val in sample_values:
        print(f"    {val}")
    
    return df

def create_household_main_harmonized():
    """Create harmonized Household Main Form table"""
    
    print("CREATING HOUSEHOLD MAIN FORM - HARMONIZED TABLE")
    print("=" * 55)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in HOUSEHOLD_MAIN_ENDPOINTS.items():
        print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Clean num_men column
    print(f"\nCleaning num_men column...")
    combined_data = clean_num_men_column(combined_data)
    
    # Summary
    print(f"\n" + "=" * 55)
    print("HOUSEHOLD MAIN FORM - HARMONIZED SUMMARY")
    print("=" * 55)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in HOUSEHOLD_MAIN_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping
        country_count = len(HOUSEHOLD_MAIN_MAPPING[col])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:35} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Special notes about data patterns
    print(f"\nData pattern notes:")
    print(f"  - Kenya: Contains mothers data in main form (will be extracted separately)")
    print(f"  - Nigeria: Uses 'Others' instead of 'autre' in many fields")
    print(f"  - Nigeria: Uses lowercase 'eligible' vs uppercase 'ELIGIBLE' in other countries")
    print(f"  - Madagascar: Uses different age range (6-23 instead of 6-59)")
    print(f"  - Kenya-specific columns (consent_oui-Eligible-*) excluded from this mapping")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    household_main_combined = create_household_main_harmonized()
    
    # Display sample data
    if household_main_combined is not None:
        print(f"\n🎉 Table 5 (Household Main) is ready!")
        print(f"Shape: {household_main_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(household_main_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(household_main_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(household_main_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# /Users/mehmetsundu/anaconda3/envs/ml/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# CREATING HOUSEHOLD MAIN FORM - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 1091 rows loaded
#   → Burkina Faso: 93 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 2877 rows loaded
#   → Cameroon: 123 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 3324 rows loaded
#   → Côte d'Ivoire: 77 columns harmonized
# Loading Guinea...
# ✓ Guinea: 1718 rows loaded
#   → Guinea: 49 columns harmonized
# Loading Kenya...
# ✓ Kenya: 867 rows loaded
#   → Kenya: 48 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 2863 rows loaded
#   → Madagascar: 77 columns harmonized
# Loading Mali...
# ✓ Mali: 1267 rows loaded
#   → Mali: 92 columns harmonized
# Loading Niger...
# ✓ Niger: 1095 rows loaded
# ...

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO
from thefuzz import fuzz

# Credentials and endpoints
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"
HOUSEHOLD_MAIN_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs__household",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_household",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_household_r2",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_household_r1",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_household_r2_collect",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_menage",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs__household",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_household_v2",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_hhform",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_household_r2"
}

# Expanded list of possible region/locality columns (English and French)
possible_cols = [
    'region', 'region_name', 'localite', 'localite_name', 'commune', 'commune_name',
    'district', 'district_name', 'arrondissement', 'arrondissement_name',
    'cercle', 'cercle_name', 'province', 'province_name', 'ville', 'ville_name',
    'departement', 'departement_name', 'area', 'ea_name', 'county', 'subcounty', 'sublocation'
]

THRESHOLD = 80  # Minimum similarity score to consider a match

for country, url in HOUSEHOLD_MAIN_ENDPOINTS.items():
    print(f"\n--- {country} ---")
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        df = pd.read_csv(StringIO(response.text), low_memory=False)
        col_matches = []
        for possible in possible_cols:
            best_score = 0
            best_col = None
            for actual in df.columns:
                score = fuzz.ratio(possible.lower(), actual.lower())
                if score > best_score:
                    best_score = score
                    best_col = actual
            if best_score >= THRESHOLD:
                col_matches.append((possible, best_col, best_score))
        if col_matches:
            for possible, actual, score in col_matches:
                print(f"  Possible: '{possible}'  →  Matched: '{actual}' (score: {score})")
                print(f"    dtype: {df[actual].dtype}")
                print(f"    Sample unique values: {df[actual].unique()[:10]}")
        else:
            print("  No close region/localite/commune/etc. columns found.")
    except Exception as e:
        print(f"  Error loading data: {e}")
# Out:
# --- Burkina Faso ---
#   Possible: 'region'  →  Matched: 'region' (score: 100)
#     dtype: int64
#     Sample unique values: [ 4  9  7 13  6]
#   Possible: 'region_name'  →  Matched: 'region_name' (score: 100)
#     dtype: float64
#     Sample unique values: [nan]
#   Possible: 'localite'  →  Matched: 'localite' (score: 100)
#     dtype: object
#     Sample unique values: ['Niago' 'Niaogo' 'NIAOGO' 'PENI' 'SECTEUR 3' 'SECTEUR 5' 'SECTEUR 03'
#  'Secteur 03' 'BOUZIN' 'MOGDA']
#   Possible: 'localite_name'  →  Matched: 'localite_name' (score: 100)
#     dtype: float64
#     Sample unique values: [nan]
#   Possible: 'commune'  →  Matched: 'commune' (score: 100)
#     dtype: int64
#     Sample unique values: [ 412  414  979  964  763 1396  633 1395  760  419]
#   Possible: 'commune_name'  →  Matched: 'commune_name' (score: 100)
#     dtype: float64
#     Sample unique values: [nan]
#   Possible: 'district'  →  Matched: 'district' (score: 100)
#     dtype: int64
# ...

# %% [markdown]
# Table 6: Household Mothers Repeat Group

# %%
HOUSEHOLD_MOTHERS_REPEAT_MAPPING = {
    # Note: Kenya data is in main form but we include the mappings here
    # Kenya columns use "consent_oui-Eligible-" prefix
    
    # KEY and PARENT_KEY don't exist for Kenya as data is embedded in main form
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": "KEY",
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",
        "Nigeria": "KEY",
        "RDC": "KEY"
    },
    
    "parent_key": {
        "Burkina Faso": "PARENT_KEY",
        "Cameroon": "PARENT_KEY",
        "Côte d'Ivoire": "PARENT_KEY",
        "Guinea": "PARENT_KEY",
        "Kenya": "PARENT_KEY",
        "Madagascar": "PARENT_KEY",
        "Mali": "PARENT_KEY",
        "Niger": "PARENT_KEY",
        "Nigeria": "PARENT_KEY",
        "RDC": "PARENT_KEY"
    },
    
    "set_of_mothers_repeat": {
        "Burkina Faso": "SET-OF-mothers_repeat",
        "Cameroon": "SET-OF-mothers_repeat",
        "Côte d'Ivoire": "SET-OF-mothers_repeat",
        "Guinea": "SET-OF-mothers_repeat",
        # Kenya: No direct equivalent - data is in main form
        "Madagascar": "SET-OF-mothers_repeat",
        "Mali": "SET-OF-mothers_repeat",
        "Niger": "SET-OF-mothers_repeat",
        "Nigeria": "SET-OF-mothers_repeat",
        "RDC": "SET-OF-mothers_repeat"
    },
    
    # Mother identification questions
    "mum_position": {
        "Burkina Faso": "mum_position",
        "Cameroon": "mum_position",
        "Côte d'Ivoire": "mum_position",
        "Guinea": "mum_position",
        # Kenya: No direct equivalent in the main form data
        "Madagascar": "mum_position",
        "Mali": "mum_position",
        "Niger": "mum_position",
        "Nigeria": "mum_position",
        "RDC": "mum_position"
    },
    
    "mum1_position": {
        "Burkina Faso": "mum1_position",
        "Cameroon": "mum1_position",
        "Côte d'Ivoire": "mum1_position",
        "Guinea": "mum1_position",
        # Kenya: No direct equivalent in the main form data
        "Madagascar": "mum1_position",
        "Mali": "mum1_position",
        "Niger": "mum1_position",
        "Nigeria": "mum1_position",
        "RDC": "mum1_position"
    },
    
    "mum_guard": {
        "Burkina Faso": "mum_guard",
        "Cameroon": "mum_guard",
        "Côte d'Ivoire": "mum_guard",
        "Guinea": "mum_guard",
        "Kenya": "consent_oui-Eligible-mum_guard",
        "Madagascar": "mum_guard",
        "Mali": "mum_guard",
        "Niger": "mum_guard",
        "Nigeria": "mum_guard",
        "RDC": "mum_guard"
    },
    
    # Q30-Q39 series
    "q31": {
        "Burkina Faso": "q31",
        "Cameroon": "q31",
        "Côte d'Ivoire": "q31",
        "Guinea": "q31",
        "Kenya": "consent_oui-Eligible-q31",
        "Madagascar": "q31",
        "Mali": "q31",
        "Niger": "q31",
        "Nigeria": "q31",
        "RDC": "q31"
    },
    
    "q31_autre": {
        "Burkina Faso": "q31_autre",
        "Cameroon": "q31_autre",
        "Côte d'Ivoire": "q31_autre",
        "Guinea": "q31_autre",
        "Kenya": "consent_oui-Eligible-q31_autre",
        "Madagascar": "q31_autre",
        "Mali": "q31_autre",
        "Niger": "q31_autre",
        "Nigeria": "q31_Others",  # "Others" instead of "autre"
        "RDC": "q31_autre"
    },
    
    "q32": {
        "Burkina Faso": "q32",
        "Cameroon": "q32",
        "Côte d'Ivoire": "q32",
        "Guinea": "q32",
        "Kenya": "consent_oui-Eligible-q32",
        "Madagascar": "q32",
        "Mali": "q32",
        "Niger": "q32",
        "Nigeria": "q32",
        "RDC": "q32"
    },
    
    "q33": {
        "Burkina Faso": "q33",
        "Cameroon": "q33",
        "Côte d'Ivoire": "q33",
        "Guinea": "q33",
        "Kenya": "consent_oui-Eligible-q33",
        "Madagascar": "q33",
        "Mali": "q33",
        "Niger": "q33",
        "Nigeria": "q33",
        "RDC": "q33"
    },
    
    "q34": {
        "Burkina Faso": "q34",
        "Cameroon": "q34",
        "Côte d'Ivoire": "q34",
        "Guinea": "q34",
        "Kenya": "consent_oui-Eligible-q34",
        "Madagascar": "q34",
        "Mali": "q34",
        "Niger": "q34",
        "Nigeria": "q34",
        "RDC": "q34"
    },
    
    "q35": {
        "Burkina Faso": "q35",
        "Cameroon": "q35",
        "Côte d'Ivoire": "q35",
        "Guinea": "q35",
        "Kenya": "consent_oui-Eligible-q35",
        "Madagascar": "q35",
        "Mali": "q35",
        "Niger": "q35",
        "Nigeria": "q35",
        "RDC": "q35"
    },
    
    "q36": {
        "Burkina Faso": "q36",
        "Cameroon": "q36",
        "Côte d'Ivoire": "q36",
        "Guinea": "q36",
        "Kenya": "consent_oui-Eligible-q36",
        "Madagascar": "q36",
        "Mali": "q36",
        "Niger": "q36",
        "Nigeria": "q36",
        "RDC": "q36"
    },
    
    "q36_autre": {
        "Burkina Faso": "q36_autre",
        "Cameroon": "q36_autre",
        "Côte d'Ivoire": "q36_autre",
        "Guinea": "q36_autre",
        "Kenya": "consent_oui-Eligible-q36_autre",
        "Madagascar": "q36_autre",
        "Mali": "q36_autre",
        "Niger": "q36_autre",
        "Nigeria": "q36_Others",  # "Others" instead of "autre"
        "RDC": "q36_autre"
    },
    
    # Q40-Q49 series
    "q41": {
        "Burkina Faso": "q41",
        "Cameroon": "q41",
        "Côte d'Ivoire": "q41",
        "Guinea": "q41",
        "Kenya": "consent_oui-Eligible-q41",
        "Madagascar": "q41",
        "Mali": "q41",
        "Niger": "q41",
        "Nigeria": "q41",
        "RDC": "q41"
    },
    
    "q41_autre": {
        "Burkina Faso": "q41_autre",
        "Cameroon": "q41_autre",
        "Côte d'Ivoire": "q41_autre",
        "Guinea": "q41_autre",
        "Kenya": "consent_oui-Eligible-q41_autre",
        "Madagascar": "q41_autre",
        "Mali": "q41_autre",
        "Niger": "q41_autre",
        "Nigeria": "q41_Others",  # "Others" instead of "autre"
        "RDC": "q41_autre"
    },
    
    "q42": {
        "Burkina Faso": "q42",
        "Cameroon": "q42",
        "Côte d'Ivoire": "q42",
        "Guinea": "q42",
        "Kenya": "consent_oui-Eligible-q42",
        "Madagascar": "q42",
        "Mali": "q42",
        "Niger": "q42",
        "Nigeria": "q42",
        "RDC": "q42"
    },
    
    "q42_autre": {
        "Burkina Faso": "q42_autre",
        "Cameroon": "q42_autre",
        "Côte d'Ivoire": "q42_autre",
        "Guinea": "q42_autre",
        "Kenya": "consent_oui-Eligible-q42_autre",
        "Madagascar": "q42_autre",
        "Mali": "q42_autre",
        "Niger": "q42_autre",
        "Nigeria": "q42_Others",  # "Others" instead of "autre"
        "RDC": "q42_autre"
    },
    
    "q43": {
        "Burkina Faso": "q43",
        "Cameroon": "q43",
        "Côte d'Ivoire": "q43",
        "Guinea": "q43",
        "Kenya": "consent_oui-Eligible-q43",
        "Madagascar": "q43",
        "Mali": "q43",
        "Niger": "q43",
        "Nigeria": "q43",
        "RDC": "q43"
    },
    
    "q44": {
        "Burkina Faso": "q44",
        "Cameroon": "q44",
        "Côte d'Ivoire": "q44",
        "Guinea": "q44",
        "Kenya": "consent_oui-Eligible-q44",
        "Madagascar": "q44",
        "Mali": "q44",
        "Niger": "q44",
        "Nigeria": "q44",
        "RDC": "q44"
    },
    
    "q45": {
        "Burkina Faso": "q45",
        "Cameroon": "q45",
        "Côte d'Ivoire": "q45",
        "Guinea": "q45",
        "Kenya": "consent_oui-Eligible-q45",
        "Madagascar": "q45",
        "Mali": "q45",
        "Niger": "q45",
        "Nigeria": "q45",
        "RDC": "q45"
    },
    
    "q45_autre": {
        "Burkina Faso": "q45_autre",
        "Cameroon": "q45_autre",
        "Côte d'Ivoire": "q45_autre",
        "Guinea": "q45_autre",
        "Kenya": "consent_oui-Eligible-q45_autre",
        "Madagascar": "q45_autre",
        "Mali": "q45_autre",
        "Niger": "q45_autre",
        "Nigeria": "q45_Others",  # "Others" instead of "autre"
        "RDC": "q45_autre"
    },
    
    "q46": {
        "Burkina Faso": "q46",
        "Cameroon": "q46",
        "Côte d'Ivoire": "q46",
        "Guinea": "q46",
        "Kenya": "consent_oui-Eligible-q46",
        "Madagascar": "q46",
        "Mali": "q46",
        "Niger": "q46",
        "Nigeria": "q46",
        "RDC": "q46"
    },
    
    "q46_autre": {
        "Burkina Faso": "q46_autre",
        "Cameroon": "q46_autre",
        "Côte d'Ivoire": "q46_autre",
        "Guinea": "q46_autre",
        "Kenya": "consent_oui-Eligible-q46_autre",
        "Madagascar": "q46_autre",
        "Mali": "q46_autre",
        "Niger": "q46_autre",
        "Nigeria": "q46_Others",  # "Others" instead of "autre"
        "RDC": "q46_autre"
    },
    
    "q47": {
        "Burkina Faso": "q47",
        "Cameroon": "q47",
        "Côte d'Ivoire": "q47",
        "Guinea": "q47",
        "Kenya": "consent_oui-Eligible-q47",
        "Madagascar": "q47",
        "Mali": "q47",
        "Niger": "q47",
        "Nigeria": "q47",
        "RDC": "q47"
    },
    
    "q48": {
        "Burkina Faso": "q48",
        "Cameroon": "q48",
        "Côte d'Ivoire": "q48",
        "Guinea": "q48",
        "Kenya": "consent_oui-Eligible-q48",
        "Madagascar": "q48",
        "Mali": "q48",
        "Niger": "q48",
        "Nigeria": "q48",
        "RDC": "q48"
    },
    
    "q48_autre": {
        "Burkina Faso": "q48_autre",
        "Cameroon": "q48_autre",
        "Côte d'Ivoire": "q48_autre",
        "Guinea": "q48_autre",
        "Kenya": "consent_oui-Eligible-q48_autre",
        "Madagascar": "q48_autre",
        "Mali": "q48_autre",
        "Niger": "q48_autre",
        "Nigeria": "q48_Others",  # "Others" instead of "autre"
        "RDC": "q48_autre"
    },
    
    "q49": {
        "Burkina Faso": "q49",
        "Cameroon": "q49",
        "Côte d'Ivoire": "q49",
        "Guinea": "q49",
        "Kenya": "consent_oui-Eligible-q49",
        "Madagascar": "q49",
        "Mali": "q49",
        "Niger": "q49",
        "Nigeria": "q49",
        "RDC": "q49"
    },
    
    # Q410 group questions
    "q410_group_q410a": {
        "Burkina Faso": "q410_group-q410a",
        "Cameroon": "q410_group-q410a",
        "Côte d'Ivoire": "q410_group-q410a",
        "Guinea": "q410_group-q410a",
        "Kenya": "consent_oui-Eligible-q410_group-q410a",
        "Madagascar": "q410_group-q410a",
        "Mali": "q410_group-q410a",
        "Niger": "q410_group-q410a",
        "Nigeria": "q410_group-q410a",
        "RDC": "q410_group-q410a"
    },
    
    "q410_group_q410b": {
        "Burkina Faso": "q410_group-q410b",
        "Cameroon": "q410_group-q410b",
        "Côte d'Ivoire": "q410_group-q410b",
        "Guinea": "q410_group-q410b",
        "Kenya": "consent_oui-Eligible-q410_group-q410b",
        "Madagascar": "q410_group-q410b",
        "Mali": "q410_group-q410b",
        "Niger": "q410_group-q410b",
        "Nigeria": "q410_group-q410b",
        "RDC": "q410_group-q410b"
    },
    
    "q410_group_q410c": {
        "Burkina Faso": "q410_group-q410c",
        "Cameroon": "q410_group-q410c",
        "Côte d'Ivoire": "q410_group-q410c",
        "Guinea": "q410_group-q410c",
        "Kenya": "consent_oui-Eligible-q410_group-q410c",
        "Madagascar": "q410_group-q410c",
        "Mali": "q410_group-q410c",
        "Niger": "q410_group-q410c",
        "Nigeria": "q410_group-q410c",
        "RDC": "q410_group-q410c"
    },
    
    # Q411-Q422 series
    "q411": {
        "Burkina Faso": "q411",
        "Cameroon": "q411",
        "Côte d'Ivoire": "q411",
        "Guinea": "q411",
        "Kenya": "consent_oui-Eligible-q411",
        "Madagascar": "q411",
        "Mali": "q411",
        "Niger": "q411",
        "Nigeria": "q411",
        "RDC": "q411"
    },
    
    "q412": {
        "Burkina Faso": "q412",
        "Cameroon": "q412",
        "Côte d'Ivoire": "q412",
        "Guinea": "q412",
        "Kenya": "consent_oui-Eligible-q412",
        "Madagascar": "q412",
        "Mali": "q412",
        "Niger": "q412",
        "Nigeria": "q412",
        "RDC": "q412"
    },
    
    "q412_autre": {
        "Burkina Faso": "q412_autre",
        "Cameroon": "q412_autre",
        "Côte d'Ivoire": "q412_autre",
        "Guinea": "q412_autre",
        "Kenya": "consent_oui-Eligible-q412_autre",
        "Madagascar": "q412_autre",
        "Mali": "q412_autre",
        "Niger": "q412_autre",
        "Nigeria": "q412_Others",  # "Others" instead of "autre"
        "RDC": "q412_autre"
    },
    
    "q413": {
        "Burkina Faso": "q413",
        "Cameroon": "q413",
        "Côte d'Ivoire": "q413",
        "Guinea": "q413",
        "Kenya": "consent_oui-Eligible-q413",
        "Madagascar": "q413",
        "Mali": "q413",
        "Niger": "q413",
        "Nigeria": "q413",
        "RDC": "q413"
    },
    
    "q414": {
        "Burkina Faso": "q414",
        "Cameroon": "q414",
        "Côte d'Ivoire": "q414",
        "Guinea": "q414",
        "Kenya": "consent_oui-Eligible-q414",
        "Madagascar": "q414",
        "Mali": "q414",
        "Niger": "q414",
        "Nigeria": "q414",
        "RDC": "q414"
    },
    
    "q415": {
        "Burkina Faso": "q415",
        "Cameroon": "q415",
        "Côte d'Ivoire": "q415",
        "Guinea": "q415",
        "Kenya": "consent_oui-Eligible-q415",
        "Madagascar": "q415",
        "Mali": "q415",
        "Niger": "q415",
        "Nigeria": "q415",
        "RDC": "q415"
    },
    
    "q415_autre": {
        "Burkina Faso": "q415_autre",
        "Cameroon": "q415_autre",
        "Côte d'Ivoire": "q415_autre",
        "Guinea": "q415_autre",
        "Kenya": "consent_oui-Eligible-q415_autre",
        "Madagascar": "q415_autre",
        "Mali": "q415_autre",
        "Niger": "q415_autre",
        "Nigeria": "q415_Others",  # "Others" instead of "autre"
        "RDC": "q415_autre"
    },
    
    "q416": {
        "Burkina Faso": "q416",
        "Cameroon": "q416",
        "Côte d'Ivoire": "q416",
        "Guinea": "q416",
        "Kenya": "consent_oui-Eligible-q416",
        "Madagascar": "q416",
        "Mali": "q416",
        "Niger": "q416",
        "Nigeria": "q416",
        "RDC": "q416"
    },
    
    "q417": {
        "Burkina Faso": "q417",
        "Cameroon": "q417",
        "Côte d'Ivoire": "q417",
        "Guinea": "q417",
        "Kenya": "consent_oui-Eligible-q417",
        "Madagascar": "q417",
        "Mali": "q417",
        "Niger": "q417",
        "Nigeria": "q417",
        "RDC": "q417"
    },
    
    "q417_autre": {
        "Burkina Faso": "q417_autre",
        "Cameroon": "q417_autre",
        "Côte d'Ivoire": "q417_autre",
        "Guinea": "q417_autre",
        "Kenya": "consent_oui-Eligible-q417_autre",
        "Madagascar": "q417_autre",
        "Mali": "q417_autre",
        "Niger": "q417_autre",
        "Nigeria": "q417_Others",  # "Others" instead of "autre"
        "RDC": "q417_autre"
    },
    
    "q418": {
        "Burkina Faso": "q418",
        "Cameroon": "q418",
        "Côte d'Ivoire": "q418",
        "Guinea": "q418",
        "Kenya": "consent_oui-Eligible-q418",
        "Madagascar": "q418",
        "Mali": "q418",
        "Niger": "q418",
        "Nigeria": "q418",
        "RDC": "q418"
    },
    
    "q419": {
        "Burkina Faso": "q419",
        "Cameroon": "q419",
        "Côte d'Ivoire": "q419",
        "Guinea": "q419",
        "Kenya": "consent_oui-Eligible-q419",
        "Madagascar": "q419",
        "Mali": "q419",
        "Niger": "q419",
        "Nigeria": "q419",
        "RDC": "q419"
    },
    
    "q420": {
        "Burkina Faso": "q420",
        "Cameroon": "q420",
        "Côte d'Ivoire": "q420",
        "Guinea": "q420",
        "Kenya": "consent_oui-Eligible-q420",
        "Madagascar": "q420",
        "Mali": "q420",
        "Niger": "q420",
        "Nigeria": "q420",
        "RDC": "q420"
    },
    
    "q421": {
        "Burkina Faso": "q421",
        "Cameroon": "q421",
        "Côte d'Ivoire": "q421",
        "Guinea": "q421",
        "Kenya": "consent_oui-Eligible-q421",
        "Madagascar": "q421",
        "Mali": "q421",
        "Niger": "q421",
        "Nigeria": "q421",
        "RDC": "q421"
    },
    
    "q422": {
        "Burkina Faso": "q422",
        "Cameroon": "q422",
        "Côte d'Ivoire": "q422",
        "Guinea": "q422",
        "Kenya": "consent_oui-Eligible-q422",
        "Madagascar": "q422",
        "Mali": "q422",
        "Niger": "q422",
        "Nigeria": "q422",
        "RDC": "q422"
    },
    
    "q422_autre": {
        "Burkina Faso": "q422_autre",
        "Cameroon": "q422_autre",
        "Côte d'Ivoire": "q422_autre",
        "Guinea": "q422_autre",
        "Kenya": "consent_oui-Eligible-q422_autre",
        "Madagascar": "q422_autre",
        "Mali": "q422_autre",
        "Niger": "q422_autre",
        "Nigeria": "q422_Others",  # "Others" instead of "autre"
        "RDC": "q422_autre"
    },
    
    # Q50-Q59 series
    "q51": {
        "Burkina Faso": "q51",
        "Cameroon": "q51",
        "Côte d'Ivoire": "q51",
        "Guinea": "q51",
        "Kenya": "consent_oui-Eligible-q51",
        "Madagascar": "q51",
        "Mali": "q51",
        "Niger": "q51",
        "Nigeria": "q51",
        "RDC": "q51"
    },
    
    "q52": {
        "Burkina Faso": "q52",
        "Cameroon": "q52",
        "Côte d'Ivoire": "q52",
        "Guinea": "q52",
        "Kenya": "consent_oui-Eligible-q52",
        "Madagascar": "q52",
        "Mali": "q52",
        "Niger": "q52",
        "Nigeria": "q52",
        "RDC": "q52"
    },
    
    "q52_autre": {
        "Burkina Faso": "q52_autre",
        "Cameroon": "q52_autre",
        "Côte d'Ivoire": "q52_autre",
        "Guinea": "q52_autre",
        "Kenya": "consent_oui-Eligible-q52_autre",
        "Madagascar": "q52_autre",
        "Mali": "q52_autre",
        "Niger": "q52_autre",
        "Nigeria": "q52_Others",  # "Others" instead of "autre"
        "RDC": "q52_autre"
    },
    
    "q52a": {
        "Burkina Faso": "q52a",
        "Cameroon": "q52a",
        "Côte d'Ivoire": "q52a",
        "Guinea": "q52a",
        "Kenya": "consent_oui-Eligible-q52a",
        "Mali": "q52a",
        "Niger": "q52a",
        "Nigeria": "q52a",
        "RDC": "q52a"
    },
    
    "q53": {
        "Burkina Faso": "q53",
        "Cameroon": "q53",
        "Côte d'Ivoire": "q53",
        "Guinea": "q53",
        "Kenya": "consent_oui-Eligible-q53",
        "Mali": "q53",
        "Niger": "q53",
        "Nigeria": "q53",
        "RDC": "q53"
    },
    
    "q53_autre": {
        "Burkina Faso": "q53_autre",
        "Cameroon": "q53_autre",
        "Côte d'Ivoire": "q53_autre",
        "Guinea": "q53_autre",
        "Kenya": "consent_oui-Eligible-q53_autre",
        "Mali": "q53_autre",
        "Niger": "q53_autre",
        "Nigeria": "q53_Others",  # "Others" instead of "autre"
        "RDC": "q53_autre"
    },
    
    "q54": {
        "Burkina Faso": "q54",
        "Cameroon": "q54",
        "Côte d'Ivoire": "q54",
        "Guinea": "q54",
        "Kenya": "consent_oui-Eligible-q54",
        "Mali": "q54",
        "Niger": "q54",
        "Nigeria": "q54",
        "RDC": "q54"
    },
    
    "q55": {
        "Burkina Faso": "q55",
        "Cameroon": "q55",
        "Côte d'Ivoire": "q55",
        "Guinea": "q55",
        "Kenya": "consent_oui-Eligible-q55",
        "Mali": "q55",
        "Niger": "q55",
        "Nigeria": "q55",
        "RDC": "q55"
    },
    
    "q55_autre": {
        "Burkina Faso": "q55_autre",
        "Cameroon": "q55_autre",
        "Côte d'Ivoire": "q55_autre",
        "Guinea": "q55_autre",
        # Kenya: No q55_autre found in main form
        "Mali": "q55_autre",
        "Niger": "q55_autre",
        "Nigeria": "q55_Others",  # "Others" instead of "autre"
        "RDC": "q55_autre"
    },
    
    # Q60-Q69 series
    "q61": {
        "Burkina Faso": "q61",
        "Cameroon": "q61",
        "Côte d'Ivoire": "q61",
        "Guinea": "q61",
        "Kenya": "consent_oui-Eligible-q61",
        "Madagascar": "q61",
        "Mali": "q61",
        "Niger": "q61",
        "Nigeria": "q61",
        "RDC": "q61"
    },
    
    "q61b": {
        "Burkina Faso": "q61b",
        "Cameroon": "q61b",
        "Côte d'Ivoire": "q61b",
        "Guinea": "q61b",
        "Kenya": "consent_oui-Eligible-q61b",
        "Madagascar": "q61b",
        "Mali": "q61b",
        "Niger": "q61b",
        "Nigeria": "q61b",
        "RDC": "q61b"
    },
    
    "q61b_autre": {
        "Burkina Faso": "q61b_autre",
        "Cameroon": "q61b_autre",
        "Côte d'Ivoire": "q61b_autre",
        # Kenya: No q61b_autre found in main form
        "Niger": "q61b_autre",
        "Nigeria": "q61b_Others",  # "Others" instead of "autre"
        "RDC": "q61b_autre"
    },
    
    "q61c": {
        "Burkina Faso": "q61c",
        "Cameroon": "q61c",
        "Côte d'Ivoire": "q61c",
        # Kenya: No q61c found in main form
        "Niger": "q61c",
        "Nigeria": "q61c",
        "RDC": "q61c"
    },
    
    "q62": {
        "Burkina Faso": "q62",
        "Cameroon": "q62",
        "Côte d'Ivoire": "q62",
        "Guinea": "q62",
        "Kenya": "consent_oui-Eligible-q62",
        "Madagascar": "q62",
        "Mali": "q62",
        "Niger": "q62",
        "Nigeria": "q62",
        "RDC": "q62"
    },
    
    "q62_autre": {
        "Burkina Faso": "q62_autre",
        "Cameroon": "q62_autre",
        "Côte d'Ivoire": "q62_autre",
        "Guinea": "q62_autre",
        "Kenya": "consent_oui-Eligible-q62_autre",
        "Madagascar": "q62_autre",
        "Mali": "q62_autre",
        "Niger": "q62_autre",
        "Nigeria": "q62_Others",  # "Others" instead of "autre"
        "RDC": "q62_autre"
    },
    
    "q63": {
        "Burkina Faso": "q63",
        "Cameroon": "q63",
        "Côte d'Ivoire": "q63",
        "Guinea": "q63",
        "Kenya": "consent_oui-Eligible-q63",
        "Madagascar": "q63",
        "Mali": "q63",
        "Niger": "q63",
        "Nigeria": "q63",
        "RDC": "q63"
    },
    
    "q63_autre": {
        "Burkina Faso": "q63_autre",
        "Cameroon": "q63_autre",
        "Côte d'Ivoire": "q63_autre",
        "Guinea": "q63_autre",
        "Kenya": "consent_oui-Eligible-q63_autre",
        "Madagascar": "q63_autre",
        "Mali": "q63_autre",
        "Niger": "q63_autre",
        "Nigeria": "q63_Others",  # "Others" instead of "autre"
        "RDC": "q63_autre"
    },
    
    "q64": {
        "Burkina Faso": "q64",
        "Cameroon": "q64",
        "Côte d'Ivoire": "q64",
        "Guinea": "q64",
        "Kenya": "consent_oui-Eligible-q64",
        "Madagascar": "q64",
        "Mali": "q64",
        "Niger": "q64",
        "Nigeria": "q64",
        "RDC": "q64"
    },
    
    "q64_autre": {
        "Burkina Faso": "q64_autre",
        "Cameroon": "q64_autre",
        "Côte d'Ivoire": "q64_autre",
        "Guinea": "q64_autre",
        "Kenya": "consent_oui-Eligible-q64_autre",
        "Madagascar": "q64_autre",
        "Mali": "q64_autre",
        "Niger": "q64_autre",
        "Nigeria": "q64_Others",  # "Others" instead of "autre"
        "RDC": "q64_autre"
    },
    
    "q65": {
        "Burkina Faso": "q65",
        "Cameroon": "q65",
        "Côte d'Ivoire": "q65",
        "Guinea": "q65",
        "Kenya": "consent_oui-Eligible-q65",
        "Madagascar": "q65",
        "Mali": "q65",
        "Niger": "q65",
        "Nigeria": "q65",
        "RDC": "q65"
    },
    
    "q65_autre": {
        "Burkina Faso": "q65_autre",
        "Cameroon": "q65_autre",
        "Côte d'Ivoire": "q65_autre",
        "Guinea": "q65_autre",
        "Kenya": "consent_oui-Eligible-q65_autre",
        "Madagascar": "q65_autre",
        "Mali": "q65_autre",
        "Niger": "q65_autre",
        "Nigeria": "q65_Others",  # "Others" instead of "autre"
        "RDC": "q65_autre"
    },
    
    "q66": {
        "Burkina Faso": "q66",
        "Cameroon": "q66",
        "Côte d'Ivoire": "q66",
        # Kenya: No q66 found in main form
        "Niger": "q66",
        "Nigeria": "q66",
        "RDC": "q66"
    },
    
    "q66_autre": {
        "Burkina Faso": "q66_autre",
        "Cameroon": "q66_autre",
        "Côte d'Ivoire": "q66_autre",
        # Kenya: No q66_autre found in main form
        "Niger": "q66_autre",
        "Nigeria": "q66_Others",  # "Others" instead of "autre"
        "RDC": "q66_autre"
    },
    
    "q67": {
        "Burkina Faso": "q67",
        "Cameroon": "q67",
        "Côte d'Ivoire": "q67",
        "Kenya": "consent_oui-Eligible-q67",
        "Madagascar": "q67",
        "Mali": "q67",
        "Niger": "q67",
        "Nigeria": "q67",
        "RDC": "q67"
    },
    
    "q68": {
        "Burkina Faso": "q68",
        "Cameroon": "q68",
        "Côte d'Ivoire": "q68",
        # Kenya: No q68 found in main form
        "Madagascar": "q68",
        "Niger": "q68",
        "Nigeria": "q68",
        "RDC": "q68"
    },
    
    "q69": {
        "Burkina Faso": "q69",
        "Cameroon": "q69",
        "Côte d'Ivoire": "q69",
        # Kenya: No q69 found in main form
        "Madagascar": "q69",
        "Niger": "q69",
        "Nigeria": "q69",
        "RDC": "q69"
    },
    
    # R-variant questions (review/repeat versions)
    "q51r": {
        "Burkina Faso": "q51r",
        "Cameroon": "q51r",
        # Kenya: No q51r found in main form
        "Madagascar": "q51r",
        "Niger": "q51r",
        "Nigeria": "q51r",
        "RDC": "q51r"
    },
    
    "q52r": {
        "Burkina Faso": "q52r",
        "Cameroon": "q52r",
        # Kenya: No q52r found in main form
        "Madagascar": "q52r",
        "Niger": "q52r",
        "Nigeria": "q52r",
        "RDC": "q52r"
    },
    
    "q52r_autre": {
        "Burkina Faso": "q52r_autre",
        "Cameroon": "q52r_autre",
        "Côte d'Ivoire": "q52r_autre",
        # Kenya: No q52r_autre found in main form
        "Madagascar": "q52r_autre",
        "Niger": "q52r_autre",
        "Nigeria": "q52r_Others",  # "Others" instead of "autre"
        "RDC": "q52r_autre"
    },
    
    # Children and health center related
    "nb_child": {
        "Burkina Faso": "nb_child",
        "Cameroon": "nb_child",
        "Côte d'Ivoire": "nb_child",
        "Guinea": "nb_child",
        "Kenya": "consent_oui-Eligible-nb_child",
        "Madagascar": "nb_child",
        "Mali": "nb_child",
        "Niger": "nb_child",
        "Nigeria": "nb_child",
        "RDC": "nb_child"
    },
    
    "set_of_children_repeat": {
        "Burkina Faso": "SET-OF-children_repeat",
        "Cameroon": "SET-OF-children_repeat",
        "Côte d'Ivoire": "SET-OF-children_repeat",
        "Guinea": "SET-OF-children_repeat",
        "Kenya": "SET-OF-consent_oui-Eligible-children_repeat",
        "Madagascar": "SET-OF-children_repeat",
        "Mali": "SET-OF-children_repeat",
        "Niger": "SET-OF-children_repeat",
        "Nigeria": "SET-OF-children_repeat",
        "RDC": "SET-OF-children_repeat"
    },
    
    "centre_sante": {
        "Burkina Faso": "centre_sante",
        "Cameroon": "centre_sante",
        "Côte d'Ivoire": "centre_sante",
        # Kenya: No centre_sante found in main form
        "Madagascar": "centre_sante",
        "Mali": "centre_sante",
        "Niger": "centre_sante",
        "Nigeria": "centre_sante",
        "RDC": "centre_sante"
    },
    
    "mum_bm": {
        "Burkina Faso": "mum_bm",
        "Cameroon": "mum_bm",
        "Côte d'Ivoire": "mum_bm",
        "Guinea": "mum_bm",
        "Kenya": "consent_oui-Eligible-mum_bm",
        "Mali": "mum_bm",
        "Niger": "mum_bm",
        "Nigeria": "mum_bm",
        "RDC": "mum_bm"
    },
    
    # Supplementary questions (qs series)
    "qs96": {
        "Cameroon": "qs96",
        "Côte d'Ivoire": "qs96",
        # Kenya: No qs96 found in main form
        "Niger": "qs96",
        "Nigeria": "qs96",
        "RDC": "qs96"
    },
    
    "qs97": {
        "Cameroon": "qs97",
        "Côte d'Ivoire": "qs97",
        # Kenya: No qs97 found in main form
        "Niger": "qs97",
        "Nigeria": "qs97",
        "RDC": "qs97"
    },
    
    "qs911": {
        "Cameroon": "qs911",
        "Côte d'Ivoire": "qs911",
        # Kenya: No qs911 found in main form
        "Niger": "qs911",
        "Nigeria": "qs911",
        "RDC": "qs911"
    },
    
    "qs912": {
        "Cameroon": "qs912",
        "Côte d'Ivoire": "qs912",
        # Kenya: No qs912 found in main form
        "Niger": "qs912",
        "Nigeria": "qs912",
        "RDC": "qs912"
    },
    
    # Count fields
    "children_repeat_count": {
        "Cameroon": "children_repeat_count",
        "Kenya": "consent_oui-Eligible-children_repeat_count",
        "Niger": "children_repeat_count",
        "Nigeria": "children_repeat_count"
    },
    
    # Côte d'Ivoire specific R-variant columns
    "q51r_1": {
        "Côte d'Ivoire": "q51r_1"
    },
    
    "q51r_2": {
        "Côte d'Ivoire": "q51r_2"
    },
    
    "q52ar": {
        "Côte d'Ivoire": "q52ar"
    },
    
    "q52r_1": {
        "Côte d'Ivoire": "q52r_1"
    },
    
    "q52r_2": {
        "Côte d'Ivoire": "q52r_2"
    },
    
    "q53ar": {
        "Côte d'Ivoire": "q53ar"
    },
    
    "q53br": {
        "Côte d'Ivoire": "q53br"
    },
    
    "q54r": {
        "Côte d'Ivoire": "q54r"
    },
    
    "q68r": {
        "Côte d'Ivoire": "q68r"
    },
    
    "q69r": {
        "Côte d'Ivoire": "q69r"
    },
    
    "qs96r": {
        "Côte d'Ivoire": "qs96r"
    },
    
    "qs97r": {
        "Côte d'Ivoire": "qs97r"
    },
    
    "nb_child_r": {
        "Côte d'Ivoire": "nb_child_r"
    },
    
    # Madagascar specific columns
    "q30": {
        "Madagascar": "q30"
    },
    
    "q56": {
        "Madagascar": "q56"
    },
    
    "q817a": {
        "Madagascar": "q817a"
    },
    
    "q818b": {
        "Madagascar": "q818b"
    },
    
    "q819c": {
        "Madagascar": "q819c"
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO
import re

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Household Mothers Repeat Group
# Note: Kenya uses main household form instead of separate repeat group
HOUSEHOLD_MOTHERS_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs__household/mothers_repeat",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_household/mothers_repeat",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_household_r2/mothers_repeat",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_household_r1/mothers_repeat",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_household_r2_collect",  # Main form
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_menage/mothers_repeat",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs__household/mothers_repeat",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_household_v2/mothers_repeat",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_hhform/mothers_repeat",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_household_r2/mothers_repeat"
}

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply HOUSEHOLD_MOTHERS_REPEAT_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in HOUSEHOLD_MOTHERS_REPEAT_MAPPING.items():
        if country in country_mapping:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def clean_q44_distance(df):
    """Clean q44 column (distance) to standardize as numeric kilometers"""
    if 'q44' not in df.columns:
        return df
    
    def standardize_distance(value):
        if pd.isna(value):
            return pd.NA
        
        # Convert to string and clean
        value_str = str(value).strip().lower()
        
        # Handle "don't know" variations
        if any(x in value_str for x in ["don't know", "do not know", "dont know"]):
            return pd.NA
        
        # Handle special text cases
        if value_str in ["less than a kilometer", "less than 1km", "less 1km"]:
            return 0.5  # Assume half a kilometer
        
        # Try to extract numeric value with regex
        # Pattern to match numbers (including decimals) followed by optional units
        patterns = [
            r'(\d+\.?\d*)\s*(?:km|kilometer|kilometers|kilometre|kilometres|kms|kilimoter)',
            r'(\d+\.?\d*)\s*(?:m|meter|meters|metre|metres)',
            r'^(\d+\.?\d*)$',  # Just a number
            r',(\d+\.?\d*)',    # Comma as decimal separator
        ]
        
        for pattern in patterns:
            match = re.search(pattern, value_str.replace('•', '.'))  # Replace bullet with decimal
            if match:
                num_value = float(match.group(1).replace(',', '.'))
                
                # Convert meters to kilometers
                if any(x in value_str for x in ['meter', 'metre', 'm ']) or (pattern == patterns[1]):
                    num_value = num_value / 1000
                
                # Handle large values that might be meters
                elif num_value >= 100 and 'km' not in value_str and 'kilometer' not in value_str:
                    # Values like 600, 700, 800 are likely meters
                    num_value = num_value / 1000
                
                # Convert negative values to positive (except special codes)
                if num_value < 0 and num_value != -999:
                    num_value = abs(num_value)
                
                # Handle special codes as NA
                if num_value in [-999, 988, 998, 999, 9999, 99999]:
                    return pd.NA
                
                # Set reasonable bounds for distance (0-200 km)
                if 0 <= num_value <= 200:
                    return round(num_value, 2)
                else:
                    return pd.NA
        
        # If no pattern matches, return NA
        return pd.NA
    
    # Apply cleaning
    df['q44'] = df['q44'].apply(standardize_distance)
    
    # Print summary of cleaning
    print(f"\nCleaning q44 (distance) column:")
    print(f"  → Non-null values: {df['q44'].notna().sum()}")
    print(f"  → Null/invalid values: {df['q44'].isna().sum()}")
    if df['q44'].notna().sum() > 0:
        print(f"  → Range: {df['q44'].min():.2f} - {df['q44'].max():.2f} km")
        print(f"  → Mean distance: {df['q44'].mean():.2f} km")
    
    return df

def create_household_mothers_harmonized():
    """Create harmonized Household Mothers Repeat Group table"""
    
    print("CREATING HOUSEHOLD MOTHERS REPEAT GROUP - HARMONIZED TABLE")
    print("=" * 65)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in HOUSEHOLD_MOTHERS_ENDPOINTS.items():
        if country == "Kenya":
            print(f"Loading {country} (from main household form)...")
        else:
            print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Clean q44 distance column
    combined_data = clean_q44_distance(combined_data)
    
    # Summary
    print(f"\n" + "=" * 65)
    print("HOUSEHOLD MOTHERS REPEAT GROUP - HARMONIZED SUMMARY")
    print("=" * 65)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in HOUSEHOLD_MOTHERS_REPEAT_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping
        country_count = len(HOUSEHOLD_MOTHERS_REPEAT_MAPPING[col])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:35} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Special notes about data patterns
    print(f"\nData pattern notes:")
    print(f"  - Kenya: Data extracted from main household form (consent_oui-Eligible- prefix)")
    print(f"  - Nigeria: Uses 'Others' instead of 'autre' in all _autre columns")
    print(f"  - Côte d'Ivoire: Has extensive r-variant columns (q51r_1, q52r_2, etc.)")
    print(f"  - Madagascar: Has unique questions (q30, q56, q817a, q818b, q819c)")
    print(f"  - qs series: Questions (qs96, qs97, qs911, qs912) in 5 countries")
    print(f"  - Some Kenya questions missing from main form (see documentation)")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    household_mothers_combined = create_household_mothers_harmonized()
    
    # Display sample data
    if household_mothers_combined is not None:
        print(f"\n🎉 Table 6 (Household Mothers) is ready!")
        print(f"Shape: {household_mothers_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(household_mothers_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(household_mothers_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(household_mothers_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING HOUSEHOLD MOTHERS REPEAT GROUP - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 1229 rows loaded
#   → Burkina Faso: 80 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 3002 rows loaded
#   → Cameroon: 85 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 3590 rows loaded
#   → Côte d'Ivoire: 95 columns harmonized
# Loading Guinea...
# ✓ Guinea: 1921 rows loaded
#   → Guinea: 69 columns harmonized
# Loading Kenya (from main household form)...
# ✓ Kenya: 867 rows loaded
#   → Kenya: 66 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 2875 rows loaded
#   → Madagascar: 74 columns harmonized
# Loading Mali...
# ✓ Mali: 2333 rows loaded
#   → Mali: 71 columns harmonized
# Loading Niger...
# ✓ Niger: 1251 rows loaded
#   → Niger: 85 columns harmonized
# Loading Nigeria...
# ✓ Nigeria: 1365 rows loaded
#   → Nigeria: 85 columns harmonized
# Loading RDC...
# ✓ RDC: 1318 rows loaded
#   → RDC: 84 columns harmonized
#
# ...

# %% [markdown]
# Table 7: Household Children Repeat Group

# %%
HOUSEHOLD_CHILDREN_REPEAT_MAPPING = {
    # Core identification columns (present in all 10 countries)
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": "KEY",
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",
        "Nigeria": "KEY",
        "RDC": "KEY"
    },
    "parent_key": {
        "Burkina Faso": "PARENT_KEY",
        "Cameroon": "PARENT_KEY",
        "Côte d'Ivoire": "PARENT_KEY",
        "Guinea": "PARENT_KEY",
        "Kenya": "PARENT_KEY",
        "Madagascar": "PARENT_KEY",
        "Mali": "PARENT_KEY",
        "Niger": "PARENT_KEY",
        "Nigeria": "PARENT_KEY",
        "RDC": "PARENT_KEY"
    },
    "set_of_children_repeat": {
        "Burkina Faso": "SET-OF-children_repeat",
        "Cameroon": "SET-OF-children_repeat",
        "Côte d'Ivoire": "SET-OF-children_repeat",
        "Guinea": "SET-OF-children_repeat",
        "Kenya": "SET-OF-children_repeat",
        "Madagascar": "SET-OF-children_repeat",
        "Mali": "SET-OF-children_repeat",
        "Niger": "SET-OF-children_repeat",
        "Nigeria": "SET-OF-children_repeat",
        "RDC": "SET-OF-children_repeat"
    },
    
    # Child identification
    "child_name": {
        "Burkina Faso": "nom",
        "Cameroon": "nom",
        "Côte d'Ivoire": "nom",
        "Guinea": "nom",
        "Kenya": "nom",
        "Madagascar": "nom",
        "Mali": "nom",
        "Niger": "nom",
        "Nigeria": "nom",
        "RDC": "nom"
    },
    "child_rank": {
        "Burkina Faso": "q7rang",
        "Cameroon": "q7rang",
        "Côte d'Ivoire": "q7rang",
        "Guinea": "q7rang",
        "Kenya": "q7rang",
        "Madagascar": "q7rang",
        "Mali": "q7rang",
        "Niger": "q7rang",
        "Nigeria": "q7rang",
        "RDC": "q7rang"
    },
    
    # Child demographics
    "child_sex": {
        "Burkina Faso": "q71",
        "Cameroon": "q71",
        "Côte d'Ivoire": "q71",
        "Guinea": "q71",
        "Kenya": "q71",
        "Madagascar": "q71",
        "Mali": "q71",
        "Niger": "q71",
        "Nigeria": "q71",
        "RDC": "q71"
    },
    "date_of_birth": {
        "Burkina Faso": "q72",
        "Cameroon": "q72",
        "Côte d'Ivoire": "q72",
        "Guinea": "q72",
        "Kenya": "q72",
        "Madagascar": "q72",
        "Mali": "q72",
        "Niger": "q72",
        "Nigeria": "q72",
        "RDC": "q72"
    },
    "dob_known": {
        "Burkina Faso": "dob_known",
        "Cameroon": "dob_known",
        "Côte d'Ivoire": "dob_known",
        "Guinea": "dob_known",
        "Kenya": "dob_known",
        "Madagascar": "dob_known",
        "Mali": "dob_known",
        "Niger": "dob_known",
        "Nigeria": "dob_known",
        "RDC": "dob_known"
    },
    "age_months": {
        "Burkina Faso": "q73",
        "Cameroon": "q73",
        "Côte d'Ivoire": "q73",
        "Guinea": "q73",
        "Kenya": "q73",
        "Madagascar": "q73",
        "Mali": "q73",
        "Niger": "q73",
        "Nigeria": "q73",
        "RDC": "q73"
    },
    "birth_certificate": {
        "Burkina Faso": "q74",
        "Cameroon": "q74",
        "Côte d'Ivoire": "q74",
        "Guinea": "q74",
        "Kenya": "q74",
        "Madagascar": "q74",
        "Mali": "q74",
        "Niger": "q74",
        "Nigeria": "q74",
        "RDC": "q74"
    },
    "birth_certificate_other": {
        "Burkina Faso": "q74_autre",
        "Cameroon": "q74_autre",
        "Côte d'Ivoire": "q74_autre",
        "Guinea": "q74_autre",
        "Kenya": "q74_autre",
        "Madagascar": "q74_autre",
        "Mali": "q74_autre",
        "Niger": "q74_autre",
        "Nigeria": "q74_Others",
        "RDC": "q74_autre"
    },
    
    # Health-related questions
    "vaccination_card": {
        "Burkina Faso": "q81",
        "Cameroon": "q81",
        "Côte d'Ivoire": "q81",
        "Guinea": "q81",
        "Kenya": "q81",
        "Madagascar": "q81",
        "Mali": "q81",
        "Niger": "q81",
        "Nigeria": "q81",
        "RDC": "q81"
    },
    "vitamin_a": {
        "Burkina Faso": "q82a",
        "Cameroon": "q82a",
        "Côte d'Ivoire": "q82a",
        "Guinea": "q82a",
        "Kenya": "q82a",
        "Madagascar": "q82a",
        "Mali": "q82a",
        "Niger": "q82a",
        "Nigeria": "q82a",
        "RDC": "q82a"
    },
    "vitamin_a_other": {
        "Burkina Faso": "q82a_autre",
        "Cameroon": "q82a_autre",
        "Côte d'Ivoire": "q82a_autre",
        "Guinea": "q82a_autre",
        "Kenya": "q82a_autre",
        "Madagascar": "q82a_autre",
        "Mali": "q82a_autre",
        "Niger": "q82a_autre",
        "Nigeria": "q82a_Others",
        "RDC": "q82a_autre"
    },
    "illness_2weeks": {
        "Burkina Faso": "q83",
        "Cameroon": "q83",
        "Côte d'Ivoire": "q83",
        "Guinea": "q83",
        "Kenya": "q83",
        "Madagascar": "q83",
        "Mali": "q83",
        "Niger": "q83",
        "Nigeria": "q83",
        "RDC": "q83"
    },
    "illness_2weeks_other": {
        "Burkina Faso": "q83_autre",
        "Cameroon": "q83_autre",
        "Côte d'Ivoire": "q83_autre",
        "Guinea": "q83_autre",
        "Kenya": "q83_autre",
        "Madagascar": "q83_autre",
        "Mali": "q83_autre",
        "Niger": "q83_autre",
        "Nigeria": "q83_Others",
        "RDC": "q83_autre"
    },
    "treatment_sought": {
        "Burkina Faso": "q84",
        "Cameroon": "q84",
        "Côte d'Ivoire": "q84",
        "Guinea": "q84",
        "Kenya": "q84",
        "Madagascar": "q84",
        "Mali": "q84",
        "Niger": "q84",
        "Nigeria": "q84",
        "RDC": "q84"
    },
    "treatment_sought_other": {
        "Burkina Faso": "q84_autre",
        "Cameroon": "q84_autre",
        "Côte d'Ivoire": "q84_autre",
        "Guinea": "q84_autre",
        "Kenya": "q84_autre",
        "Madagascar": "q84_autre",
        "Mali": "q84_autre",
        "Niger": "q84_autre",
        "Nigeria": "q84_Others",
        "RDC": "q84_autre"
    },
    "treatment_location": {
        "Burkina Faso": "q84a",
        "Cameroon": "q84a",
        "Côte d'Ivoire": "q84a",
        "Guinea": "q84a",
        "Kenya": "q84a",
        "Madagascar": "q84a",
        "Mali": "q84a",
        "Niger": "q84a",
        "Nigeria": "q84a",
        "RDC": "q84a"
    },
    "treatment_provider": {
        "Burkina Faso": "q84b",
        "Cameroon": "q84b",
        "Côte d'Ivoire": "q84b",
        "Guinea": "q84b",
        "Kenya": "q84b",
        "Madagascar": "q84b",
        "Mali": "q84b",
        "Niger": "q84b",
        "Nigeria": "q84b",
        "RDC": "q84b"
    },
    "treatment_provider_other": {
        "Burkina Faso": "q84b_autre",
        "Cameroon": "q84b_autre",
        "Côte d'Ivoire": "q84b_autre",
        "Guinea": "q84b_autre",
        "Kenya": "q84b_autre",
        "Madagascar": "q84b_autre",
        "Mali": "q84b_autre",
        "Niger": "q84b_autre",
        "Nigeria": "q84b_Others",
        "RDC": "q84b_autre"
    },
    "diarrhea_treatment": {
        "Burkina Faso": "q85",
        "Cameroon": "q85",
        "Côte d'Ivoire": "q85",
        "Guinea": "q85",
        "Kenya": "q85",
        "Madagascar": "q85",
        "Mali": "q85",
        "Niger": "q85",
        "Nigeria": "q85",
        "RDC": "q85"
    },
    "diarrhea_treatment_other": {
        "Burkina Faso": "q85_autre",
        "Cameroon": "q85_autre",
        "Côte d'Ivoire": "q85_autre",
        "Guinea": "q85_autre",
        "Kenya": "q85_autre",
        "Madagascar": "q85_autre",
        "Mali": "q85_autre",
        "Niger": "q85_autre",
        "Nigeria": "q85_Others",
        "RDC": "q85_autre"
    },
    "deworming": {
        "Burkina Faso": "q86",
        "Cameroon": "q86",
        "Côte d'Ivoire": "q86",
        "Guinea": "q86",
        "Kenya": "q86",
        "Madagascar": "q86",
        "Mali": "q86",
        "Niger": "q86",
        "Nigeria": "q86",
        "RDC": "q86"
    },
    "mosquito_net": {
        "Burkina Faso": "q87",
        "Cameroon": "q87",
        "Côte d'Ivoire": "q87",
        "Guinea": "q87",
        "Kenya": "q87",
        "Madagascar": "q87",
        "Mali": "q87",
        "Niger": "q87",
        "Nigeria": "q87",
        "RDC": "q87"
    },
    
    # Additional health questions
    "q812": {
        "Burkina Faso": "q812",
        "Cameroon": "q812",
        "Côte d'Ivoire": "q812",
        "Guinea": "q812",
        "Kenya": "q812",
        "Madagascar": "q812",
        "Mali": "q812",
        "Niger": "q812",
        "Nigeria": "q812",
        "RDC": "q812"
    },
    "q817": {
        "Burkina Faso": "q817",
        "Cameroon": "q817",
        "Côte d'Ivoire": "q817",
        "Guinea": "q817",
        "Kenya": "q817",
        "Madagascar": "q817",
        "Mali": "q817",
        "Niger": "q817",
        "Nigeria": "q817",
        "RDC": "q817"
    },
    "q817_other": {
        "Burkina Faso": "q817_autre",
        "Cameroon": "q817_autre",
        "Côte d'Ivoire": "q817_autre",
        "Guinea": "q817_autre",
        "Kenya": "q817_autre",
        "Madagascar": "q817_autre",
        "Mali": "q817_autre",
        "Niger": "q817_autre",
        "Nigeria": "q817_Others",
        "RDC": "q817_autre"
    },
    "q819": {
        "Burkina Faso": "q819",
        "Cameroon": "q819",
        "Côte d'Ivoire": "q819",
        "Guinea": "q819",
        "Kenya": "q819",
        "Madagascar": "q819",
        "Mali": "q819",
        "Niger": "q819",
        "Nigeria": "q819",
        "RDC": "q819"
    },
    "q820": {
        "Burkina Faso": "q820",
        "Cameroon": "q820",
        "Côte d'Ivoire": "q820",
        "Guinea": "q820",
        "Kenya": "q820",
        "Madagascar": "q820",
        "Mali": "q820",
        "Niger": "q820",
        "Nigeria": "q820",
        "RDC": "q820"
    },
    "q821": {
        "Burkina Faso": "q821",
        "Cameroon": "q821",
        "Côte d'Ivoire": "q821",
        "Guinea": "q821",
        "Kenya": "q821",
        "Madagascar": "q821",
        "Mali": "q821",
        "Niger": "q821",
        "Nigeria": "q821",
        "RDC": "q821"
    },
    
    # Departure-related questions (9 countries - Madagascar excluded)
    "departure_filter": {
        "Burkina Faso": "filtre_dep",
        "Cameroon": "filtre_dep",
        "Côte d'Ivoire": "filtre_dep",
        "Guinea": "filtre_dep",
        "Kenya": "filtre_dep",
        "Madagascar": None,
        "Mali": "filtre_dep",
        "Niger": "filtre_dep",
        "Nigeria": "filtre_dep",
        "RDC": "filtre_dep"
    },
    "departure_q91": {
        "Burkina Faso": "dep-q91",
        "Cameroon": "dep-q91",
        "Côte d'Ivoire": "dep-q91",
        "Guinea": "dep-q91",
        "Kenya": "dep-q91",
        "Madagascar": None,
        "Mali": "dep-q91",
        "Niger": "dep-q91",
        "Nigeria": "dep-q91",
        "RDC": "dep-q91"
    },
    "departure_q92": {
        "Burkina Faso": "dep-q92",
        "Cameroon": "dep-q92",
        "Côte d'Ivoire": "dep-q92",
        "Guinea": "dep-q92",
        "Kenya": "dep-q92",
        "Madagascar": None,
        "Mali": "dep-q92",
        "Niger": "dep-q92",
        "Nigeria": "dep-q92",
        "RDC": "dep-q92"
    },
    "departure_q93": {
        "Burkina Faso": "dep-q93",
        "Cameroon": "dep-q93",
        "Côte d'Ivoire": "dep-q93",
        "Guinea": "dep-q93",
        "Kenya": "dep-q93",
        "Madagascar": None,
        "Mali": "dep-q93",
        "Niger": "dep-q93",
        "Nigeria": "dep-q93",
        "RDC": "dep-q93"
    },
    "departure_q93_other": {
        "Burkina Faso": "dep-q93_autre",
        "Cameroon": "dep-q93_autre",
        "Côte d'Ivoire": "dep-q93_autre",
        "Guinea": "dep-q93_autre",
        "Kenya": "dep-q93_autre",
        "Madagascar": None,
        "Mali": "dep-q93_autre",
        "Niger": "dep-q93_autre",
        "Nigeria": "dep-q93_Others",
        "RDC": "dep-q93_autre"
    },
    "departure_q94": {
        "Burkina Faso": "dep-q94",
        "Cameroon": "dep-q94",
        "Côte d'Ivoire": "dep-q94",
        "Guinea": "dep-q94",
        "Kenya": "dep-q94",
        "Madagascar": None,
        "Mali": "dep-q94",
        "Niger": "dep-q94",
        "Nigeria": "dep-q94",
        "RDC": "dep-q94"
    },
    "departure_q94_other": {
        "Burkina Faso": "dep-q94_autre",
        "Cameroon": "dep-q94_autre",
        "Côte d'Ivoire": "dep-q94_autre",
        "Guinea": "dep-q94_autre",
        "Kenya": "dep-q94_autre",
        "Madagascar": None,
        "Mali": "dep-q94_autre",
        "Niger": "dep-q94_autre",
        "Nigeria": "dep-q94_Others",
        "RDC": "dep-q94_autre"
    },
    
    # Age calculation fields (9 countries - Kenya excluded)
    "child_age_months_calculated": {
        "Burkina Faso": "Child_age_month",
        "Cameroon": "Child_age_month",
        "Côte d'Ivoire": "Child_age_month",
        "Guinea": "Child_age_month",
        "Kenya": None,
        "Madagascar": "Child_age_month",
        "Mali": "Child_age_month",
        "Niger": "Child_age_month",
        "Nigeria": "Child_age_month",
        "RDC": "Child_age_month"
    },
    "child_age_months_collection_day": {
        "Burkina Faso": "Child_age_month_collect_day",
        "Cameroon": "Child_age_month_collect_day",
        "Côte d'Ivoire": "Child_age_month_collect_day",
        "Guinea": "Child_age_month_collect_day",
        "Kenya": None,
        "Madagascar": "Child_age_month_collect_day",
        "Mali": "Child_age_month_collect_day",
        "Niger": "Child_age_month_collect_day",
        "Nigeria": "Child_age_month_collect_day",
        "RDC": "Child_age_month_collect_day"
    },
    "younger_age_months": {
        "Burkina Faso": "Youger_age_month",
        "Cameroon": "Youger_age_month",
        "Côte d'Ivoire": "Youger_age_month",
        "Guinea": "Youger_age_month",
        "Kenya": None,
        "Madagascar": "Youger_age_month",
        "Mali": "Youger_age_month",
        "Niger": "Youger_age_month",
        "Nigeria": "Youger_age_month",
        "RDC": "Youger_age_month"
    },
    "confirm_age": {
        "Burkina Faso": "confirm_age",
        "Cameroon": "confirm_age",
        "Côte d'Ivoire": "confirm_age",
        "Guinea": "confirm_age",
        "Kenya": None,
        "Madagascar": "confirm_age",
        "Mali": "confirm_age",
        "Niger": "confirm_age",
        "Nigeria": "confirm_age",
        "RDC": "confirm_age"
    },
    "q71_rank": {
        "Burkina Faso": "q71rang",
        "Cameroon": "q71rang",
        "Côte d'Ivoire": "q71rang",
        "Guinea": "q71rang",
        "Kenya": None,
        "Madagascar": "q71rang",
        "Mali": "q71rang",
        "Niger": "q71rang",
        "Nigeria": "q71rang",
        "RDC": "q71rang"
    },
    
    # Group8b and Group8c references (8 countries - Guinea and Kenya have embedded data instead)
    "set_of_group8b": {
        "Burkina Faso": "SET-OF-group8b",
        "Cameroon": "SET-OF-group8b",
        "Côte d'Ivoire": "SET-OF-group8b",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "SET-OF-group8b",
        "Mali": "SET-OF-group8b",
        "Niger": "SET-OF-group8b",
        "Nigeria": "SET-OF-group8b",
        "RDC": "SET-OF-group8b"
    },
    "set_of_group8c": {
        "Burkina Faso": "SET-OF-group8c",
        "Cameroon": "SET-OF-group8c",
        "Côte d'Ivoire": "SET-OF-group8c",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "SET-OF-group8c",
        "Mali": "SET-OF-group8c",
        "Niger": "SET-OF-group8c",
        "Nigeria": "SET-OF-group8c",
        "RDC": "SET-OF-group8c"
    },
    "mother_position": {
        "Burkina Faso": "mum_position1",
        "Cameroon": "mum_position1",
        "Côte d'Ivoire": "mum_position1",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "mum_position1",
        "Mali": "mum_position1",
        "Niger": "mum_position1",
        "Nigeria": "mum_position1",
        "RDC": "mum_position1"
    },
    
    # Additional fields present in fewer countries
    "q82": {
        "Burkina Faso": "q82",
        "Cameroon": None,
        "Côte d'Ivoire": "q82",
        "Guinea": "q82",
        "Kenya": "q82",
        "Madagascar": "q82",
        "Mali": "q82",
        "Niger": None,
        "Nigeria": "q82",
        "RDC": None
    },
    "confirm_q86": {
        "Burkina Faso": "confir_q86",
        "Cameroon": "confir_q86",
        "Côte d'Ivoire": "confir_q86",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": "confir_q86",
        "Niger": "confir_q86",
        "Nigeria": "confir_q86",
        "RDC": "confir_q86"
    },
    "q84x": {
        "Burkina Faso": "q84x",
        "Cameroon": "q84x",
        "Côte d'Ivoire": "q84x",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "q84x",
        "Nigeria": "q84x",
        "RDC": "q84x"
    },
    "q84x_other": {
        "Burkina Faso": "q84x_autre",
        "Cameroon": "q84x_autre",
        "Côte d'Ivoire": "q84x_autre",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "q84x_autre",
        "Nigeria": "q84x_Others",
        "RDC": "q84x_autre"
    },
    "q852": {
        "Burkina Faso": "q852",
        "Cameroon": "q852",
        "Côte d'Ivoire": "q852",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "q852",
        "Nigeria": "q852",
        "RDC": "q852"
    },
    "q83a": {
        "Burkina Faso": "q83a",
        "Cameroon": "q83a",
        "Côte d'Ivoire": "q83a",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "q83a",
        "Nigeria": "q83a",
        "RDC": "q83a"
    },
    "q83a_other": {
        "Burkina Faso": "q83a_autre",
        "Cameroon": "q83a_autre",
        "Côte d'Ivoire": "q83a_autre",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "q83a_autre",
        "Nigeria": "q83a_Others",
        "RDC": "q83a_autre"
    },
    "q71a": {
        "Burkina Faso": "q71a",
        "Cameroon": "q71a",
        "Côte d'Ivoire": "q71a",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "q71a",
        "Nigeria": "q71a",
        "RDC": None
    },
    "q72f": {
        "Burkina Faso": "q72f",
        "Cameroon": "q72f",
        "Côte d'Ivoire": "q72f",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "q72f",
        "Nigeria": "q72f",
        "RDC": None
    },
    
    # Group count fields (4 countries only)
    "group8b_count": {
        "Burkina Faso": None,
        "Cameroon": "group8b_count",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "group8b_count",
        "Madagascar": None,
        "Mali": None,
        "Niger": "group8b_count",
        "Nigeria": "group8b_count",
        "RDC": None
    },
    "group8c_count": {
        "Burkina Faso": None,
        "Cameroon": "group8c_count",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "group8c_count",
        "Madagascar": None,
        "Mali": None,
        "Niger": "group8c_count",
        "Nigeria": "group8c_count",
        "RDC": None
    },
    
    # Country-specific fields
    "current_region": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "current_region_1",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q8_rank": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "q8rang",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "departure_count": {
        "Burkina Faso": None,
        "Cameroon": "depar_effectif",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "polio_filter": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "filtre_polio",
        "RDC": None
    },
    "azithro_filter": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "filtre_azitro",
        "RDC": None
    },
    "azithro_q111": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "azitro-q111",
        "RDC": None
    },
    "azithro_q112": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "azitro-q112",
        "RDC": None
    },
    "azithro_q113": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "azitro-q113",
        "RDC": None
    },
    "azithro_q113_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "azitro-q113_Others",
        "RDC": None
    },
    "azithro_q114": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "azitro-q114",
        "RDC": None
    },
    "azithro_q114_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "azitro-q114_Others",
        "RDC": None
    },
    "screening_q100": {
        "Burkina Faso": "depistage-q100",
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "screening_q101": {
        "Burkina Faso": "depistage-q101",
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Côte d'Ivoire specific fields
    "q73_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "q73r",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q81_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "q81r",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q82_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "q82r",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q87_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "q87r",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "departure_q91_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "dep-q91r",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "departure_q94_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "dep-q94r",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "child_age_month_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "Child_age_month_routine",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "child_age_month_routine_start": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "Child_age_month_routine_start",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "child_age_month_collect_day_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "Child_age_month_collect_day_routine",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "younger_age_month_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "Youger_age_month_routine",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "confirm_age_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "confirm_age_routine",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Madagascar specific fields
    "q75": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "q75",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q76": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "q76",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q76_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "q76_autre",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q80": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "q80",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q81a": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "q81a",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q85a": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "q85a",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q86_nw": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "q86_nw",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q86_nw_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "q86_nw_autre",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q2_9": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "q2_9",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q2_10": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "q2_10",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Household Children Repeat Group
HOUSEHOLD_CHILDREN_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs__household/children_repeat",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_household/children_repeat",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_household_r2/children_repeat",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_household_r1/children_repeat",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_household_r2_collect/children_repeat",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_menage/children_repeat",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs__household/children_repeat",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_household_v2/children_repeat",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_hhform/children_repeat",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_household_r2/children_repeat"
}

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply HOUSEHOLD_CHILDREN_REPEAT_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in HOUSEHOLD_CHILDREN_REPEAT_MAPPING.items():
        if country in country_mapping and country_mapping[country] is not None:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_household_children_harmonized():
    """Create harmonized Household Children Repeat Group table"""
    
    print("CREATING HOUSEHOLD CHILDREN REPEAT GROUP - HARMONIZED TABLE")
    print("=" * 70)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in HOUSEHOLD_CHILDREN_ENDPOINTS.items():
        print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 70)
    print("HOUSEHOLD CHILDREN REPEAT GROUP - HARMONIZED SUMMARY")
    print("=" * 70)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in HOUSEHOLD_CHILDREN_REPEAT_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping (exclude None values)
        country_count = len([c for c in HOUSEHOLD_CHILDREN_REPEAT_MAPPING[col].values() if c is not None])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:40} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Special notes about data patterns
    print(f"\nData pattern notes:")
    print(f"  - All countries: Core child data (name, age, health) available")
    print(f"  - Nigeria: Uses 'Others' instead of 'autre' in all _autre columns")
    print(f"  - Madagascar: Excluded from departure-related questions (9 countries only)")
    print(f"  - Kenya: Excluded from calculated age fields (9 countries only)")
    print(f"  - Guinea & Kenya: Group8b/8c data embedded in children_repeat")
    print(f"  - Nigeria: Has unique azithromycin (azitro) questions")
    print(f"  - Côte d'Ivoire: Has extensive routine variant questions (q*r)")
    print(f"  - Madagascar: Has unique questions (q75, q76, q80, etc.)")
    print(f"  - Burkina Faso: Has unique screening (depistage) questions")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    household_children_combined = create_household_children_harmonized()
    
    # Display sample data
    if household_children_combined is not None:
        print(f"\n🎉 Table 7 (Household Children) is ready!")
        print(f"Shape: {household_children_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(household_children_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(household_children_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(household_children_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING HOUSEHOLD CHILDREN REPEAT GROUP - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 1466 rows loaded
#   → Burkina Faso: 57 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 4107 rows loaded
#   → Cameroon: 57 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 4141 rows loaded
#   → Côte d'Ivoire: 66 columns harmonized
# Loading Guinea...
# ✓ Guinea: 2559 rows loaded
#   → Guinea: 44 columns harmonized
# Loading Kenya...
# ✓ Kenya: 1008 rows loaded
#   → Kenya: 43 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 3301 rows loaded
#   → Madagascar: 50 columns harmonized
# Loading Mali...
# ✓ Mali: 3198 rows loaded
#   → Mali: 48 columns harmonized
# Loading Niger...
# ✓ Niger: 1748 rows loaded
#   → Niger: 56 columns harmonized
# Loading Nigeria...
# ✓ Nigeria: 1682 rows loaded
#   → Nigeria: 65 columns harmonized
# Loading RDC...
# ✓ RDC: 1758 rows loaded
#   → RDC: 52 columns harmonized
#
# Combining data from 10 countries...
#
# ...

# %% [markdown]
# Table 8: Household Group8b Repeat Group

# %%
HOUSEHOLD_GROUP8B_MAPPING = {
    # Core identification columns
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",  # Will need special extraction from children_repeat
        "Kenya": "KEY",   # Will need special extraction from children_repeat
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",
        "Nigeria": "KEY",
        "RDC": "KEY"
    },
    "parent_key": {
        "Burkina Faso": "PARENT_KEY",
        "Cameroon": "PARENT_KEY",
        "Côte d'Ivoire": "PARENT_KEY",
        "Guinea": "PARENT_KEY",  # Will need special extraction from children_repeat
        "Kenya": "PARENT_KEY",   # Will need special extraction from children_repeat
        "Madagascar": "PARENT_KEY",
        "Mali": "PARENT_KEY",
        "Niger": "PARENT_KEY",
        "Nigeria": "PARENT_KEY",
        "RDC": "PARENT_KEY"
    },
    "set_of_group8b": {
        "Burkina Faso": "SET-OF-group8b",
        "Cameroon": "SET-OF-group8b",
        "Côte d'Ivoire": "SET-OF-group8b",
        "Guinea": "SET-OF-group8b",  # Will need special extraction from children_repeat
        "Kenya": "SET-OF-group8b",   # Will need special extraction from children_repeat
        "Madagascar": "SET-OF-group8b",
        "Mali": "SET-OF-group8b",
        "Niger": "SET-OF-group8b",
        "Nigeria": "SET-OF-group8b",
        "RDC": "SET-OF-group8b"
    },
    
    # Vaccination questions
    "vaccination_type": {
        "Burkina Faso": "q88",
        "Cameroon": "q88",
        "Côte d'Ivoire": "q88",
        "Guinea": "group8b-q88",  # From children_repeat
        "Kenya": "group8b-q88",   # From children_repeat
        "Madagascar": "q88",
        "Mali": "q88",
        "Niger": "q88",
        "Nigeria": "q88",
        "RDC": "q88"
    },
    "vaccination_source": {
        "Burkina Faso": "q88a",
        "Cameroon": "q88a",
        "Côte d'Ivoire": "q88a",
        "Guinea": "group8b-q88a",  # From children_repeat
        "Kenya": "group8b-q88a",   # From children_repeat
        "Madagascar": "q88a",
        "Mali": "q88a",
        "Niger": "q88a",
        "Nigeria": "q88a",
        "RDC": "q88a"
    },
    "vaccination_source_other": {
        "Burkina Faso": "q88a_autre",
        "Cameroon": "q88a_autre",
        "Côte d'Ivoire": "q88a_autre",
        "Guinea": "group8b-q88a_autre",  # From children_repeat
        "Kenya": "group8b-q88a_autre",   # From children_repeat
        "Madagascar": "q88a_autre",
        "Mali": "q88a_autre",
        "Niger": "q88a_autre",
        "Nigeria": "q88a_Others",
        "RDC": "q88a_autre"
    },
    "vaccination_date": {
        "Burkina Faso": "q89",
        "Cameroon": "q89",
        "Côte d'Ivoire": "q89",
        "Guinea": "group8b-q89",  # From children_repeat
        "Kenya": "group8b-q89",   # From children_repeat
        "Madagascar": "q89",
        "Mali": "q89",
        "Niger": "q89",
        "Nigeria": "q89",
        "RDC": "q89"
    },
    
    # Additional vaccination questions
    "q810": {
        "Burkina Faso": "q810",
        "Cameroon": "q810",
        "Côte d'Ivoire": "q810",
        "Guinea": "group8b-q810",  # From children_repeat
        "Kenya": "group8b-q810",   # From children_repeat
        "Madagascar": "q810",
        "Mali": "q810",
        "Niger": "q810",
        "Nigeria": "q810",
        "RDC": "q810"
    },
    "q810_other": {
        "Burkina Faso": "q810_autre",
        "Cameroon": "q810_autre",
        "Côte d'Ivoire": "q810_autre",
        "Guinea": "group8b-q810_autre",  # From children_repeat
        "Kenya": "group8b-q810_autre",   # From children_repeat
        "Madagascar": "q810_autre",
        "Mali": "q810_autre",
        "Niger": "q810_autre",
        "Nigeria": "q810_Others",
        "RDC": "q810_autre"
    },
    "q811": {
        "Burkina Faso": "q811",
        "Cameroon": "q811",
        "Côte d'Ivoire": "q811",
        "Guinea": "group8b-q811",  # From children_repeat
        "Kenya": "group8b-q811",   # From children_repeat
        "Madagascar": "q811",
        "Mali": "q811",
        "Niger": "q811",
        "Nigeria": "q811",
        "RDC": "q811"
    },
    "q811_other": {
        "Burkina Faso": "q811_autre",
        "Cameroon": "q811_autre",
        "Côte d'Ivoire": "q811_autre",
        "Guinea": "group8b-q811_autre",  # From children_repeat
        "Kenya": "group8b-q811_autre",   # From children_repeat
        "Madagascar": "q811_autre",
        "Mali": "q811_autre",
        "Niger": "q811_autre",
        "Nigeria": "q811_Others",
        "RDC": "q811_autre"
    },
    
    # q811a and q811b (not present in Mali, not in Guinea/Kenya embedded data)
    "q811a": {
        "Burkina Faso": "q811a",
        "Cameroon": "q811a",
        "Côte d'Ivoire": "q811a",
        "Guinea": None,  # Not in embedded data
        "Kenya": None,   # Not in embedded data
        "Madagascar": "q811a",
        "Mali": None,
        "Niger": "q811a",
        "Nigeria": "q811a",
        "RDC": "q811a"
    },
    "q811a_other": {
        "Burkina Faso": "q811a_autre",
        "Cameroon": "q811a_autre",
        "Côte d'Ivoire": "q811a_autre",
        "Guinea": None,  # Not in embedded data
        "Kenya": None,   # Not in embedded data
        "Madagascar": "q811a_autre",
        "Mali": None,
        "Niger": "q811a_autre",
        "Nigeria": "q811a_Others",
        "RDC": "q811a_autre"
    },
    "q811b": {
        "Burkina Faso": "q811b",
        "Cameroon": "q811b",
        "Côte d'Ivoire": "q811b",
        "Guinea": None,  # Not in embedded data
        "Kenya": None,   # Not in embedded data
        "Madagascar": "q811b",
        "Mali": None,
        "Niger": "q811b",
        "Nigeria": "q811b",
        "RDC": "q811b"
    },
    "q811b_other": {
        "Burkina Faso": "q811b_autre",
        "Cameroon": "q811b_autre",
        "Côte d'Ivoire": "q811b_autre",
        "Guinea": None,  # Not in embedded data
        "Kenya": None,   # Not in embedded data
        "Madagascar": "q811b_autre",
        "Mali": None,
        "Niger": "q811b_autre",
        "Nigeria": "q811b_Others",
        "RDC": "q811b_autre"
    },
    
    # q818
    "q818": {
        "Burkina Faso": "q818",
        "Cameroon": "q818",
        "Côte d'Ivoire": "q818",
        "Guinea": "group8b-q818",  # From children_repeat
        "Kenya": "group8b-q818",   # From children_repeat
        "Madagascar": "q818",
        "Mali": "q818",
        "Niger": "q818",
        "Nigeria": "q818",
        "RDC": "q818"
    },
    "q818_other": {
        "Burkina Faso": "q818_autre",
        "Cameroon": "q818_autre",
        "Côte d'Ivoire": "q818_autre",
        "Guinea": "group8b-q818_autre",  # From children_repeat
        "Kenya": None,   # Not in Kenya's embedded data
        "Madagascar": "q818_autre",
        "Mali": "q818_autre",
        "Niger": "q818_autre",
        "Nigeria": "q818_Others",
        "RDC": "q818_autre"
    },
    
    # Côte d'Ivoire specific routine fields
    "q89_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "q89r",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q810_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "q810r",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q818_routine": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "q818r",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Madagascar specific field
    "ption": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "ption",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Household Group8b Repeat Group
# Note: Guinea and Kenya use children_repeat, mapping will handle the extraction
HOUSEHOLD_GROUP8B_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs__household/group8b",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_household/group8b",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_household_r2/group8b",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_household_r1/children_repeat",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_household_r2_collect/children_repeat",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_menage/group8b",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs__household/group8b",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_household_v2/group8b",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_hhform/group8b",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_household_r2/group8b"
}

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply HOUSEHOLD_GROUP8B_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in HOUSEHOLD_GROUP8B_MAPPING.items():
        if country in country_mapping and country_mapping[country] is not None:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_household_group8b_harmonized():
    """Create harmonized Household Group8b Repeat Group table"""
    
    print("CREATING HOUSEHOLD GROUP8B REPEAT GROUP - HARMONIZED TABLE")
    print("=" * 65)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in HOUSEHOLD_GROUP8B_ENDPOINTS.items():
        if country in ["Guinea", "Kenya"]:
            print(f"Loading {country} (from children_repeat - mapping will handle extraction)...")
        else:
            print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 65)
    print("HOUSEHOLD GROUP8B REPEAT GROUP - HARMONIZED SUMMARY")
    print("=" * 65)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in HOUSEHOLD_GROUP8B_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping (exclude None values)
        country_count = len([c for c in HOUSEHOLD_GROUP8B_MAPPING[col].values() if c is not None])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:35} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Special notes about data patterns
    print(f"\nData pattern notes:")
    print(f"  - Guinea & Kenya: Data extracted from children_repeat with 'group8b-' prefix")
    print(f"  - Nigeria: Uses 'Others' instead of 'autre' in all _autre columns")
    print(f"  - Burkina Faso: Uses 'group8b' endpoint (not 'group8b_repeat')")
    print(f"  - Mali: Missing q811a and q811b questions")
    print(f"  - Guinea & Kenya: Missing q811a, q811b in embedded data")
    print(f"  - Kenya: Missing q818_autre in embedded data")
    print(f"  - Côte d'Ivoire: Has routine variant questions (q*r)")
    print(f"  - Madagascar: Has unique 'ption' field")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    household_group8b_combined = create_household_group8b_harmonized()
    
    # Display sample data
    if household_group8b_combined is not None:
        print(f"\n🎉 Table 8 (Household Group8b) is ready!")
        print(f"Shape: {household_group8b_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(household_group8b_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(household_group8b_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(household_group8b_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING HOUSEHOLD GROUP8B REPEAT GROUP - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 402 rows loaded
#   → Burkina Faso: 17 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 1826 rows loaded
#   → Cameroon: 17 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 3101 rows loaded
#   → Côte d'Ivoire: 20 columns harmonized
# Loading Guinea (from children_repeat - mapping will handle extraction)...
# ✓ Guinea: 2559 rows loaded
#   → Guinea: 12 columns harmonized
# Loading Kenya (from children_repeat - mapping will handle extraction)...
# ✓ Kenya: 1008 rows loaded
#   → Kenya: 11 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 1426 rows loaded
#   → Madagascar: 18 columns harmonized
# Loading Mali...
# ✓ Mali: 554 rows loaded
#   → Mali: 13 columns harmonized
# Loading Niger...
# ✓ Niger: 992 rows loaded
#   → Niger: 17 columns harmonized
# Loading Nigeria...
# ✓ Nigeria: 1200 rows loaded
#   → Nigeria: 17 columns harmonized
# Loading RDC...
# ...

# %% [markdown]
# Table 9: Household Group8c Repeat Group

# %%
HOUSEHOLD_GROUP8C_MAPPING = {
    # ────────────────────────────
    # Core identification columns
    # ────────────────────────────
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",            # from children_repeat
        "Kenya": "KEY",             # from children_repeat
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",
        "Nigeria": "KEY",
        "RDC": "KEY"
    },
    "parent_key": {
        "Burkina Faso": "PARENT_KEY",
        "Cameroon": "PARENT_KEY",
        "Côte d'Ivoire": "PARENT_KEY",
        "Guinea": "PARENT_KEY",     # from children_repeat
        "Kenya": "PARENT_KEY",      # from children_repeat
        "Madagascar": "PARENT_KEY",
        "Mali": "PARENT_KEY",
        "Niger": "PARENT_KEY",
        "Nigeria": "PARENT_KEY",
        "RDC": "PARENT_KEY"
    },
    "set_of_group8c": {
        "Burkina Faso": "SET-OF-group8c_repeat",  # note “_repeat” suffix
        "Cameroon": "SET-OF-group8c",
        "Côte d'Ivoire": "SET-OF-group8c",
        "Guinea": "SET-OF-group8c",               # from children_repeat
        "Kenya": "SET-OF-group8c",                # from children_repeat
        "Madagascar": "SET-OF-group8c",
        "Mali": "SET-OF-group8c",
        "Niger": "SET-OF-group8c",
        "Nigeria": "SET-OF-group8c",
        "RDC": "SET-OF-group8c"
    },

    # ────────────────────────────
    # Group-8c fields
    # (programme-specific wording)
    # ────────────────────────────
    "rang_visite": {
        "Burkina Faso": "rang_visite",
        "Cameroon": "rang_visite",
        "Côte d'Ivoire": "rang_visite",
        "Guinea": None,             # not captured in embedded data
        "Kenya": None,              # not captured in embedded data
        "Madagascar": "rang_visite",
        "Mali": "rang_visite",
        "Niger": "rang_visite",
        "Nigeria": "rang_visite",
        "RDC": "rang_visite"
    },

    # Main question set (q813 – q816) and “other” write-ins
    "q813": {
        "Burkina Faso": "q813",
        "Cameroon": "q813",
        "Côte d'Ivoire": "q813",
        "Guinea": "group8c-q813",   # from children_repeat
        "Kenya": "group8c-q813",    # from children_repeat
        "Madagascar": "q813",
        "Mali": "q813",
        "Niger": "q813",
        "Nigeria": "q813",
        "RDC": "q813"
    },
    "q813_other": {
        "Burkina Faso": "q813_autre",
        "Cameroon": "q813_autre",
        "Côte d'Ivoire": "q813_autre",
        "Guinea": "group8c-q813_autre",
        "Kenya": "group8c-q813_autre",
        "Madagascar": "q813_autre",
        "Mali": "q813_autre",
        "Niger": "q813_autre",
        "Nigeria": "q813_Others",   # English label
        "RDC": "q813_autre"
    },

    "q814": {
        "Burkina Faso": "q814",
        "Cameroon": "q814",
        "Côte d'Ivoire": "q814",
        "Guinea": "group8c-q814",
        "Kenya": "group8c-q814",
        "Madagascar": "q814",
        "Mali": "q814",
        "Niger": "q814",
        "Nigeria": "q814",
        "RDC": "q814"
    },
    "q814_other": {
        "Burkina Faso": "q814_autre",
        "Cameroon": "q814_autre",
        "Côte d'Ivoire": "q814_autre",
        "Guinea": "group8c-q814_autre",
        "Kenya": "group8c-q814_autre",
        "Madagascar": "q814_autre",
        "Mali": "q814_autre",
        "Niger": "q814_autre",
        "Nigeria": "q814_Others",
        "RDC": "q814_autre"
    },

    "q815": {
        "Burkina Faso": "q815",
        "Cameroon": "q815",
        "Côte d'Ivoire": "q815",
        "Guinea": "group8c-q815",
        "Kenya": "group8c-q815",
        "Madagascar": "q815",
        "Mali": "q815",
        "Niger": "q815",
        "Nigeria": "q815",
        "RDC": "q815"
    },
    "q815_other": {
        "Burkina Faso": "q815_autre",
        "Cameroon": "q815_autre",
        "Côte d'Ivoire": "q815_autre",
        "Guinea": "group8c-q815_autre",
        "Kenya": "group8c-q815_autre",
        "Madagascar": "q815_autre",
        "Mali": "q815_autre",
        "Niger": "q815_autre",
        "Nigeria": "q815_Others",
        "RDC": "q815_autre"
    },

    "q816": {
        "Burkina Faso": "q816",
        "Cameroon": "q816",
        "Côte d'Ivoire": "q816",
        "Guinea": "group8c-q816",
        "Kenya": "group8c-q816",
        "Madagascar": "q816",
        "Mali": "q816",
        "Niger": "q816",
        "Nigeria": "q816",
        "RDC": "q816"
    },
    "q816_other": {
        "Burkina Faso": "q816_autre",
        "Cameroon": "q816_autre",
        "Côte d'Ivoire": "q816_autre",
        "Guinea": "group8c-q816_autre",
        "Kenya": "group8c-q816_autre",
        "Madagascar": "q816_autre",
        "Mali": "q816_autre",
        "Niger": "q816_autre",
        "Nigeria": "q816_Others",
        "RDC": "q816_autre"
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Household Group8c Repeat Group
# Note: Guinea and Kenya use children_repeat, mapping will handle the extraction
HOUSEHOLD_GROUP8C_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs__household/group8c_repeat",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_household/group8c",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_household_r2/group8c",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_household_r1/children_repeat",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_household_r2_collect/children_repeat",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_menage/group8c",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs__household/group8c",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_household_v2/group8c",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_hhform/group8c",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_household_r2/group8c"
}

# Mapping dictionary for Household Group8c

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply HOUSEHOLD_GROUP8C_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in HOUSEHOLD_GROUP8C_MAPPING.items():
        if country in country_mapping and country_mapping[country] is not None:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_household_group8c_harmonized():
    """Create harmonized Household Group8c Repeat Group table"""
    
    print("CREATING HOUSEHOLD GROUP8C REPEAT GROUP - HARMONIZED TABLE")
    print("=" * 65)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in HOUSEHOLD_GROUP8C_ENDPOINTS.items():
        if country in ["Guinea", "Kenya"]:
            print(f"Loading {country} (from children_repeat - mapping will handle extraction)...")
        else:
            print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 65)
    print("HOUSEHOLD GROUP8C REPEAT GROUP - HARMONIZED SUMMARY")
    print("=" * 65)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in HOUSEHOLD_GROUP8C_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping (exclude None values)
        country_count = len([c for c in HOUSEHOLD_GROUP8C_MAPPING[col].values() if c is not None])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:35} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Special notes about data patterns
    print(f"\nData pattern notes:")
    print(f"  - Guinea & Kenya: Data extracted from children_repeat with 'group8c-' prefix")
    print(f"  - Nigeria: Uses 'Others' instead of 'autre' in all _autre columns")
    print(f"  - Burkina Faso: Uses 'group8c_repeat' endpoint with SET-OF-group8c_repeat")
    print(f"  - Guinea & Kenya: Missing rang_visite in embedded data")
    print(f"  - Main questions: q813-q816 with corresponding _autre/_Others fields")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    household_group8c_combined = create_household_group8c_harmonized()
    
    # Display sample data
    if household_group8c_combined is not None:
        print(f"\n🎉 Table 9 (Household Group8c) is ready!")
        print(f"Shape: {household_group8c_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(household_group8c_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(household_group8c_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(household_group8c_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING HOUSEHOLD GROUP8C REPEAT GROUP - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✗ Burkina Faso: Error - 400 Client Error: 400 for url: https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs__household/group8c_repeat
# Loading Cameroon...
# ✓ Cameroon: 2644 rows loaded
#   → Cameroon: 12 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 3578 rows loaded
#   → Côte d'Ivoire: 12 columns harmonized
# Loading Guinea (from children_repeat - mapping will handle extraction)...
# ✓ Guinea: 2559 rows loaded
#   → Guinea: 9 columns harmonized
# Loading Kenya (from children_repeat - mapping will handle extraction)...
# ✓ Kenya: 1008 rows loaded
#   → Kenya: 9 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 2361 rows loaded
#   → Madagascar: 12 columns harmonized
# Loading Mali...
# ✓ Mali: 3385 rows loaded
#   → Mali: 12 columns harmonized
# Loading Niger...
# ✓ Niger: 1907 rows loaded
#   → Niger: 12 columns harmonized
# Loading Nigeria...
# ...

# %% [markdown]
# Table 10: Quality Control Main Form

# %%
QUALITY_CONTROL_MAIN_MAPPING = {
    # Core identification columns (present in all 10 countries)
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": "KEY",
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",
        "Nigeria": "KEY",
        "RDC": "KEY"
    },
    "formdef_version": {
        "Burkina Faso": "formdef_version",
        "Cameroon": "formdef_version",
        "Côte d'Ivoire": "formdef_version",
        "Guinea": "formdef_version",
        "Kenya": "formdef_version",
        "Madagascar": "formdef_version",
        "Mali": "formdef_version",
        "Niger": "formdef_version",
        "Nigeria": "formdef_version",
        "RDC": "formdef_version"
    },
    "submission_date": {
        "Burkina Faso": "SubmissionDate",
        "Cameroon": "SubmissionDate",
        "Côte d'Ivoire": "SubmissionDate",
        "Guinea": "SubmissionDate",
        "Kenya": "SubmissionDate",
        "Madagascar": "SubmissionDate",
        "Mali": "SubmissionDate",
        "Niger": "SubmissionDate",
        "Nigeria": "SubmissionDate",
        "RDC": "SubmissionDate"
    },
    "audio_audit": {
        "Burkina Faso": "audio_audit",
        "Cameroon": "audio_audit",
        "Côte d'Ivoire": "audio_audit",
        "Guinea": "audio_audit",
        "Kenya": "audio_audit",
        "Madagascar": "audio_audit",
        "Mali": "audio_audit",
        "Niger": "audio_audit",
        "Nigeria": "audio_audit",
        "RDC": "audio_audit"
    },
    "text_audit": {
        "Burkina Faso": "text_audit",
        "Cameroon": "text_audit",
        "Côte d'Ivoire": "text_audit",
        "Guinea": "text_audit",
        "Kenya": "text_audit",
        "Madagascar": "text_audit",
        "Mali": "text_audit",
        "Niger": "text_audit",
        "Nigeria": "text_audit",
        "RDC": "text_audit"
    },
    "consent": {
        "Burkina Faso": "consent",
        "Cameroon": "consent",
        "Côte d'Ivoire": "consent",
        "Guinea": "consent",
        "Kenya": "consent",
        "Madagascar": "consent",
        "Mali": "consent",
        "Niger": "consent",
        "Nigeria": "consent",
        "RDC": "consent"
    },
    "review_quality": {
        "Burkina Faso": "review_quality",
        "Cameroon": "review_quality",
        "Côte d'Ivoire": "review_quality",
        "Guinea": "review_quality",
        "Kenya": "review_quality",
        "Madagascar": "review_quality",
        "Mali": "review_quality",
        "Niger": "review_quality",
        "Nigeria": "review_quality",
        "RDC": "review_quality"
    },
    
    # Time-related fields (9 countries - Kenya excluded)
    "start_time": {
        "Burkina Faso": "heure_debut",
        "Cameroon": "heure_debut",
        "Côte d'Ivoire": "heure_debut",
        "Guinea": "heure_debut",
        "Kenya": None,
        "Madagascar": "heure_debut",
        "Mali": "heure_debut",
        "Niger": "heure_debut",
        "Nigeria": "heure_debut",
        "RDC": "heure_debut"
    },
    
    # Household identification (9 countries - Niger excluded)
    "household_number": {
        "Burkina Faso": "con-num_men",
        "Cameroon": "con-num_men",
        "Côte d'Ivoire": "con-num_men",
        "Guinea": "con-num_men",
        "Kenya": "con-num_men",
        "Madagascar": "con-num_men",
        "Mali": "con-num_men",
        "Niger": None,
        "Nigeria": "con-num_men",
        "RDC": "con-num_men"
    },
    
    # Geographic/location fields (8 countries)
    "area": {
        "Burkina Faso": "area",
        "Cameroon": "area",
        "Côte d'Ivoire": "area",
        "Guinea": "area",
        "Kenya": "area",
        "Madagascar": "area",
        "Mali": "area",
        "Niger": "area",
        "Nigeria": None,
        "RDC": None
    },
    "cluster": {
        "Burkina Faso": "cluster",
        "Cameroon": "cluster",
        "Côte d'Ivoire": "cluster",
        "Guinea": "cluster",
        "Kenya": None,
        "Madagascar": "cluster",
        "Mali": "cluster",
        "Niger": "cluster",
        "Nigeria": "cluster",
        "RDC": None
    },
    
    # Consent-related questions (8 countries - Cameroon and Niger excluded)
    "q32": {
        "Burkina Faso": "con-q32",
        "Cameroon": None,
        "Côte d'Ivoire": "con-q32",
        "Guinea": "con-q32",
        "Kenya": "con-q32",
        "Madagascar": "con-q32",
        "Mali": "con-q32",
        "Niger": None,
        "Nigeria": "con-q32",
        "RDC": "con-q32"
    },
    "q34": {
        "Burkina Faso": "con-q34",
        "Cameroon": None,
        "Côte d'Ivoire": "con-q34",
        "Guinea": "con-q34",
        "Kenya": "con-q34",
        "Madagascar": "con-q34",
        "Mali": "con-q34",
        "Niger": None,
        "Nigeria": "con-q34",
        "RDC": "con-q34"
    },
    "q35": {
        "Burkina Faso": "con-q35",
        "Cameroon": None,
        "Côte d'Ivoire": "con-q35",
        "Guinea": "con-q35",
        "Kenya": "con-q35",
        "Madagascar": "con-q35",
        "Mali": "con-q35",
        "Niger": None,
        "Nigeria": "con-q35",
        "RDC": "con-q35"
    },
    
    # Reason for no consent (8 countries - Guinea and Niger excluded)
    "reason_consent_no": {
        "Burkina Faso": "reason_consent_no",
        "Cameroon": "reason_consent_no",
        "Côte d'Ivoire": "reason_consent_no",
        "Guinea": None,
        "Kenya": "reason_consent_no",
        "Madagascar": "reason_consent_no",
        "Mali": "reason_consent_no",
        "Niger": None,
        "Nigeria": "reason_consent_no",
        "RDC": "reason_consent_no"
    },
    "reason_consent_no_other": {
        "Burkina Faso": None,
        "Cameroon": "reason_autre",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "reason_others",
        "RDC": "reason_autre"
    },
    
    # Household ID (8 countries - Kenya and Niger excluded)
    "household_id": {
        "Burkina Faso": "con-id_men",
        "Cameroon": "con-id_men",
        "Côte d'Ivoire": "con-id_men",
        "Guinea": "con-id_men",
        "Kenya": None,
        "Madagascar": "con-id_men",
        "Mali": "con-id_men",
        "Niger": None,
        "Nigeria": "con-id_men",
        "RDC": "con-id_men"
    },
    
    # Enumerator information (8 countries)
    "enumerator_name": {
        "Burkina Faso": "enumerator_name",
        "Cameroon": "enumerator_name",
        "Côte d'Ivoire": "enumerator_name",
        "Guinea": "enumerator_name",
        "Kenya": None,
        "Madagascar": "enumerator_name",
        "Mali": "enumerator_name",
        "Niger": "enumerator_name",
        "Nigeria": "enumerator_name",
        "RDC": None
    },
    "enumerator": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "enumerator",
        "Guinea": "enumerator",
        "Kenya": None,
        "Madagascar": "enumerator",
        "Mali": "enumerator",
        "Niger": "enumerator",
        "Nigeria": "enumerator",
        "RDC": "enumerator"
    },
    
    # Mother benchmark (8 countries - Cameroon and Niger excluded)
    "mother_benchmark": {
        "Burkina Faso": "con-mum_bm",
        "Cameroon": None,
        "Côte d'Ivoire": "con-mum_bm",
        "Guinea": "con-mum_bm",
        "Kenya": "con-mum_bm",
        "Madagascar": "con-mum_bm",
        "Mali": "con-mum_bm",
        "Niger": None,
        "Nigeria": "con-mum_bm",
        "RDC": "con-mum_bm"
    },
    
    # Device information (7 countries)
    "device_info": {
        "Burkina Faso": "device_info",
        "Cameroon": "device_info",
        "Côte d'Ivoire": "device_info",
        "Guinea": None,
        "Kenya": "device_info",
        "Madagascar": None,
        "Mali": None,
        "Niger": "device_info",
        "Nigeria": "device_info",
        "RDC": "device_info"
    },
    "device_id": {
        "Burkina Faso": "deviceid",
        "Cameroon": "deviceid",
        "Côte d'Ivoire": "deviceid",
        "Guinea": None,
        "Kenya": "deviceid",
        "Madagascar": None,
        "Mali": None,
        "Niger": "deviceid",
        "Nigeria": "deviceid",
        "RDC": "deviceid"
    },
    "duration": {
        "Burkina Faso": "duration",
        "Cameroon": "duration",
        "Côte d'Ivoire": "duration",
        "Guinea": None,
        "Kenya": "duration",
        "Madagascar": None,
        "Mali": None,
        "Niger": "duration",
        "Nigeria": "duration",
        "RDC": "duration"
    },
    "today": {
        "Burkina Faso": "today",
        "Cameroon": "today",
        "Côte d'Ivoire": "today",
        "Guinea": None,
        "Kenya": "today",
        "Madagascar": None,
        "Mali": None,
        "Niger": "today",
        "Nigeria": "today",
        "RDC": "today"
    },
    "username": {
        "Burkina Faso": "username",
        "Cameroon": "username",
        "Côte d'Ivoire": "username",
        "Guinea": None,
        "Kenya": "username",
        "Madagascar": None,
        "Mali": None,
        "Niger": "username",
        "Nigeria": "username",
        "RDC": "username"
    },
    
    # Regional information (7 countries)
    "region": {
        "Burkina Faso": "region",
        "Cameroon": "region",
        "Côte d'Ivoire": "region",
        "Guinea": "region",
        "Kenya": None,
        "Madagascar": "region",
        "Mali": "region",
        "Niger": "region",
        "Nigeria": None,
        "RDC": None
    },
    
    # Number of children (7 countries - Niger and Nigeria excluded)
    "number_of_children": {
        "Burkina Faso": "con-nb_child",
        "Cameroon": None,
        "Côte d'Ivoire": "con-nb_child",
        "Guinea": "con-nb_child",
        "Kenya": "con-nb_child",
        "Madagascar": "con-nb_child",
        "Mali": "con-nb_child",
        "Niger": None,
        "Nigeria": None,
        "RDC": "con-nb_child"
    },
    
    # Team lead (7 countries)
    "team_lead": {
        "Burkina Faso": "team_lead",
        "Cameroon": "team_lead",
        "Côte d'Ivoire": "team_lead",
        "Guinea": None,
        "Kenya": "team_lead",
        "Madagascar": "team_lead",
        "Mali": "team_lead",
        "Niger": "team_lead",
        "Nigeria": None,
        "RDC": "teamlead"  # Note: different spelling
    },
    
    # SET-OF fields for repeat groups (7 countries)
    "set_of_mothers": {
        "Burkina Faso": "SET-OF-con-mothers",
        "Cameroon": None,
        "Côte d'Ivoire": "SET-OF-con-mothers",
        "Guinea": "SET-OF-con-mothers",
        "Kenya": None,  # Mothers in main
        "Madagascar": "SET-OF-con-mothers",
        "Mali": "SET-OF-con-mothers",
        "Niger": None,  # Mothers in main
        "Nigeria": "SET-OF-con-mothers",
        "RDC": "SET-OF-con-mothers"
    },
    "set_of_children_repeat": {
        "Burkina Faso": "SET-OF-con-children_repeat",
        "Cameroon": None,
        "Côte d'Ivoire": "SET-OF-con-children_repeat",
        "Guinea": "SET-OF-con-children_repeat",
        "Kenya": "SET-OF-con-children_repeat",
        "Madagascar": "SET-OF-con-children_repeat",
        "Mali": "SET-OF-con-children_repeat",
        "Niger": None,  # Children in main
        "Nigeria": None,  # Children in main
        "RDC": "SET-OF-con-children_repeat"
    },
    
    # GPS coordinates (6 countries)
    "gps_longitude": {
        "Burkina Faso": "con-gps-Longitude",
        "Cameroon": None,
        "Côte d'Ivoire": "con-gps-Longitude",
        "Guinea": "con-gps-Longitude",
        "Kenya": "con-gps-Longitude",
        "Madagascar": "con-gps-Longitude",
        "Mali": "con-gps-Longitude",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "gps_latitude": {
        "Burkina Faso": "con-gps-Latitude",
        "Cameroon": None,
        "Côte d'Ivoire": "con-gps-Latitude",
        "Guinea": "con-gps-Latitude",
        "Kenya": "con-gps-Latitude",
        "Madagascar": "con-gps-Latitude",
        "Mali": "con-gps-Latitude",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "gps_altitude": {
        "Burkina Faso": "con-gps-Altitude",
        "Cameroon": None,
        "Côte d'Ivoire": "con-gps-Altitude",
        "Guinea": "con-gps-Altitude",
        "Kenya": "con-gps-Altitude",
        "Madagascar": "con-gps-Altitude",
        "Mali": "con-gps-Altitude",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "gps_accuracy": {
        "Burkina Faso": "con-gps-Accuracy",
        "Cameroon": None,
        "Côte d'Ivoire": "con-gps-Accuracy",
        "Guinea": "con-gps-Accuracy",
        "Kenya": "con-gps-Accuracy",
        "Madagascar": "con-gps-Accuracy",
        "Mali": "con-gps-Accuracy",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Number of mothers (6 countries)
    "number_of_mothers": {
        "Burkina Faso": "con-nb_mother",
        "Cameroon": None,
        "Côte d'Ivoire": "con-nb_mother",
        "Guinea": "con-nb_mother",
        "Kenya": None,
        "Madagascar": "con-nb_mother",
        "Mali": "con-nb_mother",
        "Niger": None,
        "Nigeria": "con-nb_mother",
        "RDC": None
    },
    
    # Meta instance ID (6 countries)
    "meta_instance_id": {
        "Burkina Faso": "meta-instanceID",
        "Cameroon": "meta-instanceID",
        "Côte d'Ivoire": "meta-instanceID",
        "Guinea": None,
        "Kenya": "meta-instanceID",
        "Madagascar": None,
        "Mali": None,
        "Niger": "meta-instanceID",
        "Nigeria": "meta-instanceID",
        "RDC": None
    },
    
    # EA name (6 countries)
    "ea_name": {
        "Burkina Faso": "ea_name",
        "Cameroon": None,
        "Côte d'Ivoire": "ea_name",
        "Guinea": "ea_name",
        "Kenya": None,
        "Madagascar": "ea_name",
        "Mali": "ea_name",
        "Niger": "ea_name",
        "Nigeria": None,
        "RDC": None
    },
    
    # Observations (6 countries)
    "observations": {
        "Burkina Faso": "con-obs",
        "Cameroon": "con-obs",
        "Côte d'Ivoire": "con-obs",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": "con-obs",
        "Niger": None,
        "Nigeria": "con-obs",
        "RDC": "con-obs"
    },
    
    # Signature (6 countries)
    "signature": {
        "Burkina Faso": "signature",
        "Cameroon": "signature",
        "Côte d'Ivoire": "signature",
        "Guinea": None,
        "Kenya": "signature",
        "Madagascar": None,
        "Mali": "signature",
        "Niger": None,
        "Nigeria": "signature",
        "RDC": None
    },
    
    # Commune (6 countries)
    "commune": {
        "Burkina Faso": "commune",
        "Cameroon": None,
        "Côte d'Ivoire": "commune",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "commune",
        "Mali": "commune",
        "Niger": "commune",
        "Nigeria": None,
        "RDC": "commune"
    },
    
    # Case ID (6 countries)
    "case_id": {
        "Burkina Faso": "caseid",
        "Cameroon": "caseid",
        "Côte d'Ivoire": "caseid",
        "Guinea": None,
        "Kenya": "caseid",
        "Madagascar": None,
        "Mali": None,
        "Niger": "caseid",
        "Nigeria": "caseid",
        "RDC": None
    },
    
    # Time fields (5 countries)
    "end_time": {
        "Burkina Faso": "endtime",
        "Cameroon": "endtime",
        "Côte d'Ivoire": "endtime",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "endtime",
        "RDC": "endtime"
    },
    "start_time_full": {
        "Burkina Faso": "starttime",
        "Cameroon": "starttime",
        "Côte d'Ivoire": "starttime",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "starttime",
        "RDC": "starttime"
    },
    
    # Supervisor (5 countries)
    "supervisor": {
        "Burkina Faso": "supervisor",
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "supervisor",
        "Mali": "supervisor",
        "Niger": None,
        "Nigeria": "supervisor",
        "RDC": "supervisor"
    },
    
    # Device phone number (5 countries)
    "device_phone_number": {
        "Burkina Faso": "devicephonenum",
        "Cameroon": "devicephonenum",
        "Côte d'Ivoire": "devicephonenum",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "devicephonenum",
        "RDC": "devicephonenum"
    },
    
    # Selected child fields (4 countries)
    "selected_child": {
        "Burkina Faso": "con-selected_child",
        "Cameroon": None,
        "Côte d'Ivoire": "con-selected_child",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": "con-selected_child",
        "Niger": None,
        "Nigeria": "con-selected_child",
        "RDC": None
    },
    "selected_position": {
        "Burkina Faso": "con-selected_position",
        "Cameroon": None,
        "Côte d'Ivoire": "con-selected_position",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": "con-selected_position",
        "Niger": None,
        "Nigeria": "con-selected_position",
        "RDC": None
    },
    "selected_name": {
        "Burkina Faso": "con-selected_name",
        "Cameroon": None,
        "Côte d'Ivoire": "con-selected_name",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": "con-selected_name",
        "Niger": None,
        "Nigeria": "con-selected_name",
        "RDC": None
    },
    
    # Supervisor name (4 countries)
    "supervisor_name": {
        "Burkina Faso": "supervisor_name",
        "Cameroon": None,
        "Côte d'Ivoire": "supervisor_name",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "supervisor_name",
        "Mali": "supervisor_name",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Mother (4 countries)
    "mother": {
        "Burkina Faso": "con-mother",
        "Cameroon": None,
        "Côte d'Ivoire": "con-mother",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": "con-mother",
        "Niger": None,
        "Nigeria": "con-mother",
        "RDC": None
    },
    
    # District (4 countries)
    "district": {
        "Burkina Faso": "district",
        "Cameroon": None,
        "Côte d'Ivoire": "district",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "district",
        "Mali": "district",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Meta instance name (4 countries)
    "meta_instance_name": {
        "Burkina Faso": "meta-instanceName",
        "Cameroon": "meta-instanceName",
        "Côte d'Ivoire": "meta-instanceName",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "meta-instanceName",
        "Nigeria": None,
        "RDC": None
    },
    
    # Random number list (4 countries)
    "list_random_number": {
        "Burkina Faso": "con-list_randnum",
        "Cameroon": None,
        "Côte d'Ivoire": "con-list_randnum",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": "con-list_randnum",
        "Niger": None,
        "Nigeria": "con-list_randnum",
        "RDC": None
    },
    
    # End time fields (3 countries)
    "end_time_hour": {
        "Burkina Faso": None,
        "Cameroon": "con-heure_fin",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-heure_fin",
        "RDC": "con-heure_fin"
    },
    "interview_duration": {
        "Burkina Faso": None,
        "Cameroon": "con-duree_entretien",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-duree_entretien",
        "RDC": "con-duree_entretien"
    },
    
    # Commune name (3 countries)
    "commune_name": {
        "Burkina Faso": None,
        "Cameroon": "commune_name",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "commune_name",
        "Nigeria": None,
        "RDC": "commune_name"
    },
    
    # Mothers count (3 countries)
    "mothers_count": {
        "Burkina Faso": "con-mothers_count",
        "Cameroon": None,
        "Côte d'Ivoire": "con-mothers_count",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-mothers_count",
        "RDC": None
    },
    
    # Locality (3 countries)
    "locality": {
        "Burkina Faso": "localite",
        "Cameroon": None,
        "Côte d'Ivoire": "localite",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "localite",
        "Nigeria": None,
        "RDC": "locality"
    },
    
    # Children repeat count (3 countries)
    "children_repeat_count": {
        "Burkina Faso": "con-children_repeat_count",
        "Cameroon": None,
        "Côte d'Ivoire": "con-children_repeat_count",
        "Guinea": None,
        "Kenya": "con-children_repeat_count",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Location coordinates (for Cameroon and RDC)
    "location_longitude": {
        "Burkina Faso": None,
        "Cameroon": "con-location-Longitude",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "con-location-Longitude"
    },
    "location_latitude": {
        "Burkina Faso": None,
        "Cameroon": "con-location-Latitude",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "con-location-Latitude"
    },
    "location_altitude": {
        "Burkina Faso": None,
        "Cameroon": "con-location-Altitude",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "con-location-Altitude"
    },
    "location_accuracy": {
        "Burkina Faso": None,
        "Cameroon": "con-location-Accuracy",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "con-location-Accuracy"
    },
    
    # Q31, Q33, Q36 (Kenya and Nigeria only)
    "q31": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "con-q31",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-q31",
        "RDC": None
    },
    "q31_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "con-q31_autre",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-q31_others",
        "RDC": None
    },
    "q33": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "con-q33",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-q33",
        "RDC": None
    },
    "q36": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "con-q36",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-q36",
        "RDC": None
    },
    "q36_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "con-q36_autre",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-q36_others",
        "RDC": None
    },
    
    # Department fields (2 countries)
    "department": {
        "Burkina Faso": None,
        "Cameroon": "departement",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "departement",
        "Nigeria": None,
        "RDC": None
    },
    "department_name": {
        "Burkina Faso": None,
        "Cameroon": "departement_name",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "departement_name",
        "Nigeria": None,
        "RDC": None
    },
    
    # Start/End fields (2 countries)
    "end": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "end",
        "Madagascar": None,
        "Mali": None,
        "Niger": "end",
        "Nigeria": None,
        "RDC": None
    },
    "start": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "start",
        "Madagascar": None,
        "Mali": None,
        "Niger": "start",
        "Nigeria": None,
        "RDC": None
    },
    
    # Location field (2 countries)
    "location": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "location",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "location",
        "RDC": None
    },
    
    # Phone number (2 countries)
    "phone_number": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "phonenumber",
        "Madagascar": None,
        "Mali": None,
        "Niger": "phonenumber",
        "Nigeria": None,
        "RDC": None
    },
    
    # Type cluster (2 countries)
    "type_cluster": {
        "Burkina Faso": "typecluster",
        "Cameroon": "Typecluster",
        "Côte d'Ivoire": "typecluster",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Region name (2 countries)
    "region_name": {
        "Burkina Faso": None,
        "Cameroon": "region_name",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "region_name",
        "Nigeria": None,
        "RDC": None
    },
    
    # Mother position (2 countries)
    "mother_position": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "con-mum_position",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "con-mum_position"
    },
    
    # Enumerator1 (2 countries)
    "enumerator1": {
        "Burkina Faso": None,
        "Cameroon": "con-enumerator1",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "con-enumerator1"
    },
    
    # Country-specific fields
    "country": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "country",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "year": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "year",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "round": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "round",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "state": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "state",
        "RDC": None
    },
    "lga": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "lga",
        "RDC": None
    },
    "prefecture": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": "prefecture",
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "sub_prefecture": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": "sousprefecture",
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "county": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "county",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "subcounty": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "subcounty",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "division": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "division",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "sublocation": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "sublocation",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "enumeration_area": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "enumeration_area",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Quality Control Main Form
QUALITY_CONTROL_MAIN_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs_quality_control",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_quality_control",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_quality_control_r2",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_quality_controle_r1",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_quality_control_r2_collect",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_controle_qualite",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs_quality_control",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_quality_control",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_qualitycontrolform",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_quality_control_r2"
}

# Mapping dictionary for Quality Control Main Form

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply QUALITY_CONTROL_MAIN_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in QUALITY_CONTROL_MAIN_MAPPING.items():
        if country in country_mapping and country_mapping[country] is not None:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_quality_control_main_harmonized():
    """Create harmonized Quality Control Main Form table"""
    
    print("CREATING QUALITY CONTROL MAIN FORM - HARMONIZED TABLE")
    print("=" * 60)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in QUALITY_CONTROL_MAIN_ENDPOINTS.items():
        print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 60)
    print("QUALITY CONTROL MAIN FORM - HARMONIZED SUMMARY")
    print("=" * 60)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in QUALITY_CONTROL_MAIN_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping (exclude None values)
        country_count = len([c for c in QUALITY_CONTROL_MAIN_MAPPING[col].values() if c is not None])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:35} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Special notes about data patterns
    print(f"\nData pattern notes:")
    print(f"  - Kenya: Mothers data embedded in main form")
    print(f"  - Niger: Mothers & Children data embedded in main form")
    print(f"  - Nigeria: Children data embedded in main form")
    print(f"  - All countries: Core fields like KEY, consent, review_quality present")
    print(f"  - Geographic variations: Different location field structures")
    print(f"  - RDC: Uses 'teamlead' instead of 'team_lead'")
    print(f"  - Nigeria: Uses '_others' instead of '_autre' fields")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    quality_control_main_combined = create_quality_control_main_harmonized()
    
    # Display sample data
    if quality_control_main_combined is not None:
        print(f"\n🎉 Table 10 (Quality Control Main Form) is ready!")
        print(f"Shape: {quality_control_main_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(quality_control_main_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(quality_control_main_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(quality_control_main_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING QUALITY CONTROL MAIN FORM - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 108 rows loaded
#   → Burkina Faso: 55 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 463 rows loaded
#   → Cameroon: 42 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 370 rows loaded
#   → Côte d'Ivoire: 55 columns harmonized
# Loading Guinea...
# ✓ Guinea: 272 rows loaded
#   → Guinea: 30 columns harmonized
# Loading Kenya...
# ✓ Kenya: 117 rows loaded
#   → Kenya: 45 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 376 rows loaded
#   → Madagascar: 37 columns harmonized
# Loading Mali...
# ✓ Mali: 365 rows loaded
#   → Mali: 41 columns harmonized
# Loading Niger...
# ✓ Niger: 98 rows loaded
#   → Niger: 32 columns harmonized
# Loading Nigeria...
# ✓ Nigeria: 194 rows loaded
#   → Nigeria: 50 columns harmonized
# Loading RDC...
# ✓ RDC: 222 rows loaded
#   → RDC: 42 columns harmonized
#
# Combining data from 10 countries...
#
# ...

# %% [markdown]
# Table 11: Quality Control Mothers Repeat Group

# %%
QUALITY_CONTROL_MOTHERS_MAPPING = {
    # Core identification columns
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",  # Assuming standard structure
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": "KEY",  # From main form
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",  # From main form
        "Nigeria": "KEY",
        "RDC": "KEY"
    },
    "parent_key": {
        "Burkina Faso": "PARENT_KEY",
        "Cameroon": "PARENT_KEY",  # Assuming standard structure
        "Côte d'Ivoire": "PARENT_KEY",
        "Guinea": "PARENT_KEY",
        "Kenya": "KEY",  # Parent would be main form KEY
        "Madagascar": "PARENT_KEY",
        "Mali": "PARENT_KEY",
        "Niger": "KEY",  # Parent would be main form KEY
        "Nigeria": "PARENT_KEY",
        "RDC": "PARENT_KEY"
    },
    "set_of_mothers": {
        "Burkina Faso": "SET-OF-mothers",
        "Cameroon": "SET-OF-mothers",  # Assuming standard structure
        "Côte d'Ivoire": "SET-OF-mothers",
        "Guinea": "SET-OF-mothers",
        "Kenya": None,  # Not applicable for embedded data
        "Madagascar": "SET-OF-mothers",
        "Mali": "SET-OF-mothers",
        "Niger": None,  # Not applicable for embedded data
        "Nigeria": "SET-OF-mothers",
        "RDC": "SET-OF-mothers"
    },
    
    # Mother position and information
    "mother_position_1": {
        "Burkina Faso": "mum1_position",
        "Cameroon": None,
        "Côte d'Ivoire": "mum1_position",
        "Guinea": "mum1_position",
        "Kenya": "con-mum_position",  # From main form
        "Madagascar": "mum1_position",
        "Mali": "mum1_position",
        "Niger": None,  # Not found in main form
        "Nigeria": "mum1_position",
        "RDC": None
    },
    "mother_guardian": {
        "Burkina Faso": "mum_guard",
        "Cameroon": None,
        "Côte d'Ivoire": "mum_guard",
        "Guinea": "mum_guard",
        "Kenya": "con-mum_guard",  # From main form
        "Madagascar": "mum_guard",
        "Mali": "mum_guard",
        "Niger": None,  # Not found in main form
        "Nigeria": "mum_guard",
        "RDC": None
    },
    "mother_guardian_name": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "con-mum_guard_nam"  # From main form
    },
    "number_of_mother_children": {
        "Burkina Faso": "nb_mother_child",
        "Cameroon": None,
        "Côte d'Ivoire": "nb_mother_child",
        "Guinea": "nb_mother_child",
        "Kenya": None,  # Not found in main form
        "Madagascar": "nb_mother_child",
        "Mali": "nb_mother_child",
        "Niger": None,  # Not found in main form
        "Nigeria": "nb_mother_child",
        "RDC": None
    },
    
    # Random number fields (4 countries)
    "keep_position": {
        "Burkina Faso": "keep_position",
        "Cameroon": None,
        "Côte d'Ivoire": "keep_position",
        "Guinea": None,
        "Kenya": None,  # Not found in main form
        "Madagascar": None,
        "Mali": "keep_position",
        "Niger": None,  # Not found in main form
        "Nigeria": "keep_position",
        "RDC": None
    },
    "random_number": {
        "Burkina Faso": "randnum",
        "Cameroon": None,
        "Côte d'Ivoire": "randnum",
        "Guinea": None,
        "Kenya": None,  # Not found in main form
        "Madagascar": None,
        "Mali": "randnum",
        "Niger": None,  # Not found in main form
        "Nigeria": "randnum",
        "RDC": None
    },
    "random_number_rank": {
        "Burkina Faso": "randnum_rank",
        "Cameroon": None,
        "Côte d'Ivoire": "randnum_rank",
        "Guinea": None,
        "Kenya": None,  # Not found in main form
        "Madagascar": None,
        "Mali": "randnum_rank",
        "Niger": None,  # Not found in main form
        "Nigeria": "randnum_rank",
        "RDC": None
    },
    "random_number_relevant": {
        "Burkina Faso": "randnum_relevant",
        "Cameroon": None,
        "Côte d'Ivoire": "randnum_relevant",
        "Guinea": None,
        "Kenya": None,  # Not found in main form
        "Madagascar": None,
        "Mali": "randnum_relevant",
        "Niger": None,  # Not found in main form
        "Nigeria": "randnum_relevant",
        "RDC": None
    },
    
    # Position field
    "position": {
        "Burkina Faso": "position",
        "Cameroon": None,
        "Côte d'Ivoire": "position",
        "Guinea": None,
        "Kenya": None,  # Not found in main form
        "Madagascar": None,
        "Mali": "position",
        "Niger": None,  # Not found in main form
        "Nigeria": "mum_position",  # Nigeria uses different field name
        "RDC": None
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Quality Control Mothers Repeat Group
# Note: Kenya and Niger use main form, mapping will handle the extraction
QUALITY_CONTROL_MOTHERS_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs_quality_control/mothers",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_quality_control/mothers",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_quality_control_r2/mothers",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_quality_controle_r1/mothers",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_quality_control_r2_collect",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_controle_qualite/mothers",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs_quality_control/mothers",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_quality_control",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_qualitycontrolform/mothers",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_quality_control_r2/mothers"
}

# Mapping dictionary for Quality Control Mothers Repeat Group

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply QUALITY_CONTROL_MOTHERS_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in QUALITY_CONTROL_MOTHERS_MAPPING.items():
        if country in country_mapping and country_mapping[country] is not None:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_quality_control_mothers_harmonized():
    """Create harmonized Quality Control Mothers Repeat Group table"""
    
    print("CREATING QUALITY CONTROL MOTHERS REPEAT GROUP - HARMONIZED TABLE")
    print("=" * 67)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in QUALITY_CONTROL_MOTHERS_ENDPOINTS.items():
        if country in ["Kenya", "Niger"]:
            print(f"Loading {country} (from main form - mapping will handle extraction)...")
        else:
            print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 67)
    print("QUALITY CONTROL MOTHERS REPEAT GROUP - HARMONIZED SUMMARY")
    print("=" * 67)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in QUALITY_CONTROL_MOTHERS_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping (exclude None values)
        country_count = len([c for c in QUALITY_CONTROL_MOTHERS_MAPPING[col].values() if c is not None])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:35} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Special notes about data patterns
    print(f"\nData pattern notes:")
    print(f"  - Kenya: Mothers data extracted from main form (con-mum_guard, con-mum_position)")
    print(f"  - Niger: Mothers data extracted from main form")
    print(f"  - RDC: Has con-mum_guard_nam field in main form")
    print(f"  - Cameroon: Assumed standard structure (endpoint exists)")
    print(f"  - Random number fields: Available in 4 countries (BF, CI, ML, NG)")
    print(f"  - Nigeria: Uses 'mum_position' instead of 'position'")
    print(f"  - Core fields: mother_position_1, mother_guardian, number_of_mother_children")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    quality_control_mothers_combined = create_quality_control_mothers_harmonized()
    
    # Display sample data
    if quality_control_mothers_combined is not None:
        print(f"\n🎉 Table 11 (Quality Control Mothers) is ready!")
        print(f"Shape: {quality_control_mothers_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(quality_control_mothers_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(quality_control_mothers_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(quality_control_mothers_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING QUALITY CONTROL MOTHERS REPEAT GROUP - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 124 rows loaded
#   → Burkina Faso: 11 columns harmonized
# Loading Cameroon...
# ✗ Cameroon: Error - 400 Client Error: 400 for url: https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_quality_control/mothers
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 407 rows loaded
#   → Côte d'Ivoire: 11 columns harmonized
# Loading Guinea...
# ✓ Guinea: 299 rows loaded
#   → Guinea: 6 columns harmonized
# Loading Kenya (from main form - mapping will handle extraction)...
# ✓ Kenya: 117 rows loaded
#   → Kenya: 3 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 384 rows loaded
#   → Madagascar: 6 columns harmonized
# Loading Mali...
# ✓ Mali: 654 rows loaded
#   → Mali: 11 columns harmonized
# Loading Niger (from main form - mapping will handle extraction)...
# ✓ Niger: 98 rows loaded
#   → Niger: 1 columns harmonized
# Loading Nigeria...
# ...

# %% [markdown]
# Table 12: Quality Control Children Repeat Group

# %%
QUALITY_CONTROL_CHILDREN_MAPPING = {
    # Core identification columns
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": "KEY",
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",  # From main form
        "Nigeria": "KEY",  # From main form
        "RDC": "KEY"
    },
    "parent_key": {
        "Burkina Faso": "PARENT_KEY",
        "Cameroon": "PARENT_KEY",
        "Côte d'Ivoire": "PARENT_KEY",
        "Guinea": "PARENT_KEY",
        "Kenya": "PARENT_KEY",
        "Madagascar": "PARENT_KEY",
        "Mali": "PARENT_KEY",
        "Niger": "KEY",  # Parent would be main form KEY
        "Nigeria": "KEY",  # Parent would be main form KEY
        "RDC": "PARENT_KEY"
    },
    "set_of_children_repeat": {
        "Burkina Faso": "SET-OF-children_repeat",
        "Cameroon": "SET-OF-children_repeat",
        "Côte d'Ivoire": "SET-OF-children_repeat",
        "Guinea": "SET-OF-children_repeat",
        "Kenya": "SET-OF-children_repeat",
        "Madagascar": "SET-OF-children_repeat",
        "Mali": "SET-OF-children_repeat",
        "Niger": None,  # Not applicable for embedded data
        "Nigeria": None,  # Not applicable for embedded data
        "RDC": "SET-OF-children_repeat"
    },
    
    # Child identification
    "child_name": {
        "Burkina Faso": "nom",
        "Cameroon": "nom",
        "Côte d'Ivoire": "nom",
        "Guinea": None,
        "Kenya": "nom",
        "Madagascar": "nom",
        "Mali": "nom",
        "Niger": "consent_oui-c-nom",  # From main form
        "Nigeria": "con-children_survey-nom",  # From main form
        "RDC": "nom"
    },
    "child_rank": {
        "Burkina Faso": "q7rang",
        "Cameroon": "q7rang",
        "Côte d'Ivoire": "q7rang",
        "Guinea": "q7rang",
        "Kenya": "q7rang",
        "Madagascar": "q7rang",
        "Mali": "q7rang",
        "Niger": "consent_oui-c-q8rang",  # From main form (note: q8rang)
        "Nigeria": "con-children_survey-q71rang",  # From main form (note: q71rang)
        "RDC": "q7rang"
    },
    
    # Child demographics
    "child_sex": {
        "Burkina Faso": "q71",
        "Cameroon": "q71",
        "Côte d'Ivoire": "q71",
        "Guinea": "q71",
        "Kenya": "q71",
        "Madagascar": "q71",
        "Mali": "q71",
        "Niger": "consent_oui-c-sex",  # From main form
        "Nigeria": "con-children_survey-q71",  # From main form
        "RDC": "q71"
    },
    "date_of_birth": {
        "Burkina Faso": "q72",
        "Cameroon": "q72",
        "Côte d'Ivoire": "q72",
        "Guinea": "q72",
        "Kenya": "q72",
        "Madagascar": "q72",
        "Mali": "q72",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q72",  # From main form
        "RDC": "q72"
    },
    "dob_known": {
        "Burkina Faso": "dob_known",
        "Cameroon": "dob_known",
        "Côte d'Ivoire": "dob_known",
        "Guinea": "dob_known",
        "Kenya": "dob_known",
        "Madagascar": "dob_known",
        "Mali": "dob_known",
        "Niger": "consent_oui-c-dob_known",  # From main form
        "Nigeria": "con-children_survey-dob_known",  # From main form
        "RDC": "dob_known"
    },
    "age_months": {
        "Burkina Faso": "q73",
        "Cameroon": "q73",
        "Côte d'Ivoire": "q73",
        "Guinea": "q73",
        "Kenya": "q73",
        "Madagascar": "q73",
        "Mali": "q73",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q73",  # From main form
        "RDC": "q73"
    },
    "birth_certificate": {
        "Burkina Faso": "q74",
        "Cameroon": "q74",
        "Côte d'Ivoire": "q74",
        "Guinea": "q74",
        "Kenya": "q74",
        "Madagascar": "q74",
        "Mali": "q74",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q74",  # From main form
        "RDC": "q74"
    },
    "birth_certificate_other": {
        "Burkina Faso": "q74_autre",
        "Cameroon": "q74_autre",
        "Côte d'Ivoire": "q74_autre",
        "Guinea": "q74_autre",
        "Kenya": "q74_autre",
        "Madagascar": "q74_autre",
        "Mali": "q74_autre",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q74_others",  # From main form
        "RDC": "q74_autre"
    },
    
    # Health-related questions
    "vaccination_card": {
        "Burkina Faso": "q81",
        "Cameroon": "q81",
        "Côte d'Ivoire": "q81",
        "Guinea": "q81",
        "Kenya": "q81",
        "Madagascar": "q81",
        "Mali": "q81",
        "Niger": "consent_oui-c-q81",  # From main form
        "Nigeria": "con-children_survey-q81",  # From main form
        "RDC": "q81"
    },
    "q82": {
        "Burkina Faso": "q82",
        "Cameroon": "q82",
        "Côte d'Ivoire": "q82",
        "Guinea": "q82",
        "Kenya": "q82",
        "Madagascar": "q82",
        "Mali": "q82",
        "Niger": "consent_oui-c-q82",  # From main form
        "Nigeria": None,  # Not found in main form
        "RDC": "q82"
    },
    "vitamin_a": {
        "Burkina Faso": "q82a",
        "Cameroon": "q82a",
        "Côte d'Ivoire": "q82a",
        "Guinea": "q82a",
        "Kenya": "q82a",
        "Madagascar": "q82a",
        "Mali": "q82a",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q82a",  # From main form
        "RDC": "q82a"
    },
    "vitamin_a_other": {
        "Burkina Faso": "q82a_autre",
        "Cameroon": "q82a_autre",
        "Côte d'Ivoire": "q82a_autre",
        "Guinea": "q82a_autre",
        "Kenya": "q82a_autre",
        "Madagascar": "q82a_autre",
        "Mali": "q82a_autre",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q82a_others",  # From main form
        "RDC": "q82a_autre"
    },
    "illness_2weeks": {
        "Burkina Faso": "q83",
        "Cameroon": "q83",
        "Côte d'Ivoire": "q83",
        "Guinea": "q83",
        "Kenya": "q83",
        "Madagascar": "q83",
        "Mali": "q83",
        "Niger": "consent_oui-c-q83",  # From main form
        "Nigeria": "con-children_survey-q83",  # From main form
        "RDC": "q83"
    },
    "illness_2weeks_other": {
        "Burkina Faso": "q83_autre",
        "Cameroon": "q83_autre",
        "Côte d'Ivoire": "q83_autre",
        "Guinea": "q83_autre",
        "Kenya": "q83_autre",
        "Madagascar": "q83_autre",
        "Mali": "q83_autre",
        "Niger": "consent_oui-c-q83_autre",  # From main form
        "Nigeria": "con-children_survey-q83_others",  # From main form
        "RDC": "q83_autre"
    },
    "treatment_sought": {
        "Burkina Faso": "q84",
        "Cameroon": "q84",
        "Côte d'Ivoire": "q84",
        "Guinea": "q84",
        "Kenya": "q84",
        "Madagascar": "q84",
        "Mali": "q84",
        "Niger": "consent_oui-c-q84",  # From main form
        "Nigeria": "con-children_survey-q84",  # From main form
        "RDC": "q84"
    },
    "treatment_sought_other": {
        "Burkina Faso": "q84_autre",
        "Cameroon": "q84_autre",
        "Côte d'Ivoire": "q84_autre",
        "Guinea": "q84_autre",
        "Kenya": "q84_autre",
        "Madagascar": "q84_autre",
        "Mali": "q84_autre",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q84_others",  # From main form
        "RDC": "q84_autre"
    },
    "treatment_location": {
        "Burkina Faso": "q84a",
        "Cameroon": "q84a",
        "Côte d'Ivoire": "q84a",
        "Guinea": "q84a",
        "Kenya": "q84a",
        "Madagascar": "q84a",
        "Mali": "q84a",
        "Niger": "consent_oui-c-q84a",  # From main form
        "Nigeria": "con-children_survey-q84a",  # From main form
        "RDC": "q84a"
    },
    "treatment_provider": {
        "Burkina Faso": "q84b",
        "Cameroon": "q84b",
        "Côte d'Ivoire": "q84b",
        "Guinea": "q84b",
        "Kenya": "q84b",
        "Madagascar": "q84b",
        "Mali": "q84b",
        "Niger": "consent_oui-c-q84b",  # From main form
        "Nigeria": "con-children_survey-q84b",  # From main form
        "RDC": "q84b"
    },
    "treatment_provider_other": {
        "Burkina Faso": "q84b_autre",
        "Cameroon": "q84b_autre",
        "Côte d'Ivoire": "q84b_autre",
        "Guinea": "q84b_autre",
        "Kenya": "q84b_autre",
        "Madagascar": "q84b_autre",
        "Mali": "q84b_autre",
        "Niger": "consent_oui-c-q84b_autre",  # From main form
        "Nigeria": "con-children_survey-q84b_others",  # From main form
        "RDC": "q84b_autre"
    },
    "diarrhea_treatment": {
        "Burkina Faso": "q85",
        "Cameroon": "q85",
        "Côte d'Ivoire": "q85",
        "Guinea": "q85",
        "Kenya": "q85",
        "Madagascar": "q85",
        "Mali": "q85",
        "Niger": "consent_oui-c-q85",  # From main form
        "Nigeria": "con-children_survey-q85",  # From main form
        "RDC": "q85"
    },
    "diarrhea_treatment_other": {
        "Burkina Faso": "q85_autre",
        "Cameroon": "q85_autre",
        "Côte d'Ivoire": "q85_autre",
        "Guinea": "q85_autre",
        "Kenya": "q85_autre",
        "Madagascar": "q85_autre",
        "Mali": "q85_autre",
        "Niger": "consent_oui-c-q85_autre",  # From main form
        "Nigeria": "con-children_survey-q85_others",  # From main form
        "RDC": "q85_autre"
    },
    "deworming": {
        "Burkina Faso": "q86",
        "Cameroon": "q86",
        "Côte d'Ivoire": "q86",
        "Guinea": "q86",
        "Kenya": "q86",
        "Madagascar": "q86",
        "Mali": "q86",
        "Niger": "consent_oui-c-q86",  # From main form
        "Nigeria": "con-children_survey-q86",  # From main form
        "RDC": "q86"
    },
    "deworming_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-q86_autre",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "mosquito_net": {
        "Burkina Faso": "q87",
        "Cameroon": "q87",
        "Côte d'Ivoire": "q87",
        "Guinea": "q87",
        "Kenya": "q87",
        "Madagascar": "q87",
        "Mali": "q87",
        "Niger": "consent_oui-c-q87",  # From main form
        "Nigeria": "con-children_survey-q87",  # From main form
        "RDC": "q87"
    },
    
    # Additional health questions
    "q812": {
        "Burkina Faso": "q812",
        "Cameroon": "q812",
        "Côte d'Ivoire": "q812",
        "Guinea": "q812",
        "Kenya": "q812",
        "Madagascar": "q812",
        "Mali": "q812",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q812",  # From main form
        "RDC": "q812"
    },
    "q817": {
        "Burkina Faso": "q817",
        "Cameroon": "q817",
        "Côte d'Ivoire": "q817",
        "Guinea": "q817",
        "Kenya": "q817",
        "Madagascar": "q817",
        "Mali": "q817",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q817",  # From main form
        "RDC": "q817"
    },
    "q817_other": {
        "Burkina Faso": "q817_autre",
        "Cameroon": "q817_autre",
        "Côte d'Ivoire": "q817_autre",
        "Guinea": "q817_autre",
        "Kenya": "q817_autre",
        "Madagascar": "q817_autre",
        "Mali": "q817_autre",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q817_others",  # From main form
        "RDC": "q817_autre"
    },
    "q819": {
        "Burkina Faso": "q819",
        "Cameroon": "q819",
        "Côte d'Ivoire": "q819",
        "Guinea": "q819",
        "Kenya": "q819",
        "Madagascar": "q819",
        "Mali": "q819",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q819",  # From main form
        "RDC": "q819"
    },
    "q820": {
        "Burkina Faso": "q820",
        "Cameroon": "q820",
        "Côte d'Ivoire": "q820",
        "Guinea": "q820",
        "Kenya": "q820",
        "Madagascar": "q820",
        "Mali": "q820",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-q820",  # From main form
        "RDC": "q820"
    },
    "q821": {
        "Burkina Faso": "q821",
        "Cameroon": "q821",
        "Côte d'Ivoire": "q821",
        "Guinea": "q821",
        "Kenya": "q821",
        "Madagascar": "q821",
        "Mali": "q821",
        "Niger": "consent_oui-c-q821",  # From main form
        "Nigeria": "con-children_survey-q821",  # From main form
        "RDC": "q821"
    },
    
    # Age calculation fields (7 countries - excluding Kenya, Niger, Nigeria)
    "q71_rank": {
        "Burkina Faso": "q71rang",
        "Cameroon": "q71rang",
        "Côte d'Ivoire": "q71rang",
        "Guinea": "q71rang",
        "Kenya": None,
        "Madagascar": "q71rang",
        "Mali": "q71rang",
        "Niger": None,  # Not found in main form
        "Nigeria": None,  # Uses con-children_survey-q71rang
        "RDC": "q71rang"
    },
    "child_age_months_calculated": {
        "Burkina Faso": "Child_age_month",
        "Cameroon": "Child_age_month",
        "Côte d'Ivoire": "Child_age_month",
        "Guinea": "Child_age_month",
        "Kenya": None,
        "Madagascar": "Child_age_month",
        "Mali": "Child_age_month",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-Child_age_month",  # From main form
        "RDC": "Child_age_month"
    },
    "child_age_months_collection_day": {
        "Burkina Faso": "Child_age_month_collect_day",
        "Cameroon": "Child_age_month_collect_day",
        "Côte d'Ivoire": "Child_age_month_collect_day",
        "Guinea": "Child_age_month_collect_day",
        "Kenya": None,
        "Madagascar": "Child_age_month_collect_day",
        "Mali": "Child_age_month_collect_day",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-Child_age_month_collect_day",  # From main form
        "RDC": "Child_age_month_collect_day"
    },
    "younger_age_months": {
        "Burkina Faso": "Youger_age_month",
        "Cameroon": "Youger_age_month",
        "Côte d'Ivoire": "Youger_age_month",
        "Guinea": "Youger_age_month",
        "Kenya": None,
        "Madagascar": "Youger_age_month",
        "Mali": "Youger_age_month",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-Youger_age_month",  # From main form
        "RDC": "Youger_age_month"
    },
    "confirm_age": {
        "Burkina Faso": "confirm_age",
        "Cameroon": "confirm_age",
        "Côte d'Ivoire": "confirm_age",
        "Guinea": "confirm_age",
        "Kenya": None,
        "Madagascar": "confirm_age",
        "Mali": "confirm_age",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-confirm_age",  # From main form
        "RDC": "confirm_age"
    },
    
    # Departure-related questions (6 countries)
    "departure_filter": {
        "Burkina Faso": "filtre_dep",
        "Cameroon": "filtre_dep",
        "Côte d'Ivoire": None,
        "Guinea": "filtre_dep",
        "Kenya": "filtre_dep",
        "Madagascar": None,
        "Mali": "filtre_dep",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-filtre_dep",  # From main form
        "RDC": "filtre_dep"
    },
    "departure_q91": {
        "Burkina Faso": "dep-q91",
        "Cameroon": "dep-q91",
        "Côte d'Ivoire": None,
        "Guinea": "dep-q91",
        "Kenya": "dep-q91",
        "Madagascar": None,
        "Mali": "dep-q91",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-dep-q91",  # From main form
        "RDC": "dep-q91"
    },
    "departure_q92": {
        "Burkina Faso": "dep-q92",
        "Cameroon": "dep-q92",
        "Côte d'Ivoire": None,
        "Guinea": "dep-q92",
        "Kenya": "dep-q92",
        "Madagascar": None,
        "Mali": "dep-q92",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-dep-q92",  # From main form
        "RDC": "dep-q92"
    },
    "departure_q93": {
        "Burkina Faso": "dep-q93",
        "Cameroon": "dep-q93",
        "Côte d'Ivoire": None,
        "Guinea": "dep-q93",
        "Kenya": "dep-q93",
        "Madagascar": None,
        "Mali": "dep-q93",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-dep-q93",  # From main form
        "RDC": "dep-q93"
    },
    "departure_q93_other": {
        "Burkina Faso": "dep-q93_autre",
        "Cameroon": "dep-q93_autre",
        "Côte d'Ivoire": None,
        "Guinea": "dep-q93_autre",
        "Kenya": "dep-q93_autre",
        "Madagascar": None,
        "Mali": "dep-q93_autre",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-dep-q93_others",  # From main form
        "RDC": "dep-q93_autre"
    },
    "departure_q94": {
        "Burkina Faso": "dep-q94",
        "Cameroon": "dep-q94",
        "Côte d'Ivoire": None,
        "Guinea": "dep-q94",
        "Kenya": "dep-q94",
        "Madagascar": None,
        "Mali": "dep-q94",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-dep-q94",  # From main form
        "RDC": "dep-q94"
    },
    "departure_q94_other": {
        "Burkina Faso": "dep-q94_autre",
        "Cameroon": "dep-q94_autre",
        "Côte d'Ivoire": None,
        "Guinea": "dep-q94_autre",
        "Kenya": "dep-q94_autre",
        "Madagascar": None,
        "Mali": "dep-q94_autre",
        "Niger": None,  # Not found in main form
        "Nigeria": "con-children_survey-dep-q94_others",  # From main form
        "RDC": "dep-q94_autre"
    },
    
    # End time field (5 countries)
    "end_time_hour": {
        "Burkina Faso": "heure_fin",
        "Cameroon": None,
        "Côte d'Ivoire": "heure_fin",
        "Guinea": "heure_fin",
        "Kenya": None,
        "Madagascar": "heure_fin",
        "Mali": "heure_fin",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Group8b and Group8c fields (5 countries - embedded)
    # Note: These are embedded in children_repeat for these countries
    "group8b_vaccination_type": {
        "Burkina Faso": "group8b-q88",
        "Cameroon": None,
        "Côte d'Ivoire": "group8b-q88",
        "Guinea": "group8b-q88",
        "Kenya": "group8b-q88",
        "Madagascar": None,
        "Mali": "group8b-q88",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "group8b_vaccination_source": {
        "Burkina Faso": "group8b-q88a",
        "Cameroon": None,
        "Côte d'Ivoire": "group8b-q88a",
        "Guinea": "group8b-q88a",
        "Kenya": "group8b-q88a",
        "Madagascar": None,
        "Mali": "group8b-q88a",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Count fields
    "group8b_count": {
        "Burkina Faso": "group8b_count",
        "Cameroon": "group8b_count",
        "Côte d'Ivoire": "group8b_count",
        "Guinea": None,
        "Kenya": "group8b_count",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-children_survey-group8b_count",  # From main form
        "RDC": None
    },
    "group8c_count": {
        "Burkina Faso": "group8c_count",
        "Cameroon": "group8c_count",
        "Côte d'Ivoire": "group8c_count",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-children_survey-group8c_count",  # From main form
        "RDC": None
    },
    
    # SET-OF fields for group8b/group8c (3 countries)
    "set_of_group8b": {
        "Burkina Faso": None,
        "Cameroon": "SET-OF-group8b",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "SET-OF-group8b",
        "Mali": None,
        "Niger": None,
        "Nigeria": "SET-OF-con-children_survey-group8b",  # From main form
        "RDC": "SET-OF-group8b"
    },
    "set_of_group8c": {
        "Burkina Faso": None,
        "Cameroon": "SET-OF-group8c",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": "SET-OF-group8c",
        "Mali": None,
        "Niger": None,
        "Nigeria": "SET-OF-con-children_survey-group8c",  # From main form
        "RDC": "SET-OF-group8c"
    },
    
    # Mother position (2 countries)
    "mother_position": {
        "Burkina Faso": None,
        "Cameroon": "mum_position1",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-mum_position",  # From main form
        "Nigeria": None,
        "RDC": "mum_position1"
    },
    
    # Additional fields present in fewer countries
    "q852": {
        "Burkina Faso": None,
        "Cameroon": "q852",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-children_survey-q852",  # From main form
        "RDC": "q852"
    },
    "q83a": {
        "Burkina Faso": None,
        "Cameroon": "q83a",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-children_survey-q83a",  # From main form
        "RDC": "q83a"
    },
    "q83a_other": {
        "Burkina Faso": None,
        "Cameroon": "q83a_autre",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-children_survey-q83a_others",  # From main form
        "RDC": "q83a_autre"
    },
    "confirm_q86": {
        "Burkina Faso": None,
        "Cameroon": "confir_q86",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-children_survey-confir_q86",  # From main form
        "RDC": "confir_q86"
    },
    "q84x": {
        "Burkina Faso": None,
        "Cameroon": "q84x",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-children_survey-q84x",  # From main form
        "RDC": "q84x"
    },
    "q84x_other": {
        "Burkina Faso": None,
        "Cameroon": "q84x_autre",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-children_survey-q84x_others",  # From main form
        "RDC": "q84x_autre"
    },
    "q71a": {
        "Burkina Faso": None,
        "Cameroon": "q71a",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-children_survey-q71a",  # From main form
        "RDC": None
    },
    "q72f": {
        "Burkina Faso": None,
        "Cameroon": "q72f",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "con-children_survey-q72f",  # From main form
        "RDC": None
    },
    "departure_count": {
        "Burkina Faso": None,
        "Cameroon": "depar_effectif",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Kenya-specific field
    "q8_rank": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": "q8rang",
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Niger-specific fields from main form
    "mother_guardian": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-mum_guard",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "guardian_education": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-educ_gard",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "guardian_age": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-age_gard",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "guardian_activity": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-activ_gard",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "guardian_activity_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-activ_autre",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "child_status": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-status",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "child_relationship": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-relation",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "child_relationship_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-relat_autre",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "q87a": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-q87a",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "q88": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-q88",  # From main form
        "Nigeria": None,
        "RDC": None
    },
    "q88_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": "consent_oui-c-q88_autre",  # From main form
        "Nigeria": None,
        "RDC": None
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Quality Control Children Repeat Group
# Note: Niger and Nigeria use main form, mapping will handle the extraction
QUALITY_CONTROL_CHILDREN_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs_quality_control/children_repeat",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_quality_control/children_repeat",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_quality_control_r2/children_repeat",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_quality_controle_r1/children_repeat",
    "Kenya": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ke2024_pecs_quality_control_r2_collect/children_repeat",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_controle_qualite/children_repeat",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs_quality_control/children_repeat",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_quality_control",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_qualitycontrolform",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_quality_control_r2/children_repeat"
}

# Mapping dictionary for Quality Control Children Repeat Group

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply QUALITY_CONTROL_CHILDREN_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in QUALITY_CONTROL_CHILDREN_MAPPING.items():
        if country in country_mapping and country_mapping[country] is not None:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_quality_control_children_harmonized():
    """Create harmonized Quality Control Children Repeat Group table"""
    
    print("CREATING QUALITY CONTROL CHILDREN REPEAT GROUP - HARMONIZED TABLE")
    print("=" * 68)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in QUALITY_CONTROL_CHILDREN_ENDPOINTS.items():
        if country in ["Niger", "Nigeria"]:
            print(f"Loading {country} (from main form - mapping will handle extraction)...")
        else:
            print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 68)
    print("QUALITY CONTROL CHILDREN REPEAT GROUP - HARMONIZED SUMMARY")
    print("=" * 68)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in QUALITY_CONTROL_CHILDREN_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping (exclude None values)
        country_count = len([c for c in QUALITY_CONTROL_CHILDREN_MAPPING[col].values() if c is not None])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:35} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Special notes about data patterns
    print(f"\nData pattern notes:")
    print(f"  - Niger & Nigeria: Children data extracted from main form")
    print(f"  - Nigeria: Uses '_others' instead of '_autre' for write-in fields")
    print(f"  - Core health questions: q81-q87 (vaccination, illness, treatment)")
    print(f"  - Age calculation fields: Available in 7-8 countries")
    print(f"  - Departure questions: Available in 6 countries")
    print(f"  - Group8b/Group8c: Embedded in children_repeat for some countries")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    quality_control_children_combined = create_quality_control_children_harmonized()
    
    # Display sample data
    if quality_control_children_combined is not None:
        print(f"\n🎉 Table 12 (Quality Control Children) is ready!")
        print(f"Shape: {quality_control_children_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(quality_control_children_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(quality_control_children_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(quality_control_children_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING QUALITY CONTROL CHILDREN REPEAT GROUP - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 132 rows loaded
#   → Burkina Faso: 49 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 601 rows loaded
#   → Cameroon: 58 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 447 rows loaded
#   → Côte d'Ivoire: 42 columns harmonized
# Loading Guinea...
# ✓ Guinea: 336 rows loaded
#   → Guinea: 46 columns harmonized
# Loading Kenya...
# ✓ Kenya: 150 rows loaded
#   → Kenya: 43 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 441 rows loaded
#   → Madagascar: 40 columns harmonized
# Loading Mali...
# ✓ Mali: 492 rows loaded
#   → Mali: 47 columns harmonized
# Loading Niger (from main form - mapping will handle extraction)...
# ✓ Niger: 98 rows loaded
#   → Niger: 31 columns harmonized
# Loading Nigeria (from main form - mapping will handle extraction)...
# ✓ Nigeria: 194 rows loaded
#   → Nigeria: 52 columns harmonized
# Loading RDC...
# ...

# %% [markdown]
# Table 13: Health Workers Main Form

# %%
HEALTH_WORKERS_MAIN_MAPPING = {
    # Core identification columns (present in all 9 countries)
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": None,  # No data available
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",
        "Nigeria": "KEY",
        "RDC": "KEY"
    },
    "formdef_version": {
        "Burkina Faso": "formdef_version",
        "Cameroon": "formdef_version",
        "Côte d'Ivoire": "formdef_version",
        "Guinea": "formdef_version",
        "Kenya": None,  # No data available
        "Madagascar": "formdef_version",
        "Mali": "formdef_version",
        "Niger": "formdef_version",
        "Nigeria": "formdef_version",
        "RDC": "formdef_version"
    },
    "submission_date": {
        "Burkina Faso": "SubmissionDate",
        "Cameroon": "SubmissionDate",
        "Côte d'Ivoire": "SubmissionDate",
        "Guinea": "SubmissionDate",
        "Kenya": None,  # No data available
        "Madagascar": "SubmissionDate",
        "Mali": "SubmissionDate",
        "Niger": "SubmissionDate",
        "Nigeria": "SubmissionDate",
        "RDC": "SubmissionDate"
    },
    "text_audit": {
        "Burkina Faso": "text_audit",
        "Cameroon": "text_audit",
        "Côte d'Ivoire": "text_audit",
        "Guinea": "text_audit",
        "Kenya": None,  # No data available
        "Madagascar": "text_audit",
        "Mali": "text_audit",
        "Niger": "text_audit",
        "Nigeria": "text_audit",
        "RDC": "text_audit"
    },
    "review_quality": {
        "Burkina Faso": "review_quality",
        "Cameroon": "review_quality",
        "Côte d'Ivoire": "review_quality",
        "Guinea": "review_quality",
        "Kenya": None,  # No data available
        "Madagascar": "review_quality",
        "Mali": "review_quality",
        "Niger": "review_quality",
        "Nigeria": "review_quality",
        "RDC": "review_quality"
    },
    "consent": {
        "Burkina Faso": "consent",
        "Cameroon": "consent",
        "Côte d'Ivoire": "consent",
        "Guinea": "consent",
        "Kenya": None,  # No data available
        "Madagascar": "consent",
        "Mali": "consent",
        "Niger": "consent",
        "Nigeria": "consent",
        "RDC": "consent"
    },
    "today": {
        "Burkina Faso": "today",
        "Cameroon": "today",
        "Côte d'Ivoire": "today",
        "Guinea": "today",
        "Kenya": None,  # No data available
        "Madagascar": "today",
        "Mali": "today",
        "Niger": "today",
        "Nigeria": "today",
        "RDC": "today"
    },
    "type": {
        "Burkina Faso": "type",
        "Cameroon": "type",
        "Côte d'Ivoire": "type",
        "Guinea": "type",
        "Kenya": None,  # No data available
        "Madagascar": "type",
        "Mali": "type",
        "Niger": "type",
        "Nigeria": "type",
        "RDC": "type"
    },
    "type_other": {
        "Burkina Faso": "type_autre",
        "Cameroon": "type_autre",
        "Côte d'Ivoire": "type_autre",
        "Guinea": "type_autre",
        "Kenya": None,  # No data available
        "Madagascar": "type_autre",
        "Mali": "type_autre",
        "Niger": "type_autre",
        "Nigeria": "type_others",
        "RDC": "type_autre"
    },
    
    # Personal information questions
    "q21": {
        "Burkina Faso": "q21",
        "Cameroon": "q21",
        "Côte d'Ivoire": "q21",
        "Guinea": "q21",
        "Kenya": None,  # No data available
        "Madagascar": "q21",
        "Mali": "q21",
        "Niger": "q21",
        "Nigeria": "q21",
        "RDC": "q21"
    },
    "q21a": {
        "Burkina Faso": "q21a",
        "Cameroon": "q21a",
        "Côte d'Ivoire": "q21a",
        "Guinea": "q21a",
        "Kenya": None,  # No data available
        "Madagascar": "q21a",
        "Mali": "q21a",
        "Niger": "q21a",
        "Nigeria": "q21a",
        "RDC": "q21a"
    },
    "q21b": {
        "Burkina Faso": "q21b",
        "Cameroon": "q21b",
        "Côte d'Ivoire": "q21b",
        "Guinea": "q21b",
        "Kenya": None,  # No data available
        "Madagascar": "q21b",
        "Mali": "q21b",
        "Niger": "q21b",
        "Nigeria": None,
        "RDC": "q21b"
    },
    "q21b_other": {
        "Burkina Faso": "q21b_autre",
        "Cameroon": "q21b_autre",
        "Côte d'Ivoire": "q21b_autre",
        "Guinea": "q21b_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q21b_autre",
        "Mali": "q21b_autre",
        "Niger": "q21b_autre",
        "Nigeria": None,
        "RDC": "q21b_autre"
    },
    "q22": {
        "Burkina Faso": "q22",
        "Cameroon": "q22",
        "Côte d'Ivoire": "q22",
        "Guinea": "q22",
        "Kenya": None,  # No data available
        "Madagascar": "q22",
        "Mali": "q22",
        "Niger": "q22",
        "Nigeria": "q22",
        "RDC": "q22"
    },
    "q22_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "q22_others",
        "RDC": None
    },
    "q23": {
        "Burkina Faso": "q23",
        "Cameroon": "q23",
        "Côte d'Ivoire": "q23",
        "Guinea": "q23",
        "Kenya": None,  # No data available
        "Madagascar": "q23",
        "Mali": "q23",
        "Niger": "q23",
        "Nigeria": "q23",
        "RDC": "q23"
    },
    
    # Core survey questions (present in all 9 countries)
    "q31": {
        "Burkina Faso": "q31",
        "Cameroon": "q31",
        "Côte d'Ivoire": "q31",
        "Guinea": "q31",
        "Kenya": None,  # No data available
        "Madagascar": "q31",
        "Mali": "q31",
        "Niger": "q31",
        "Nigeria": "q31",
        "RDC": "q31"
    },
    "q31_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "q31_others",
        "RDC": None
    },
    "q32": {
        "Burkina Faso": "q32",
        "Cameroon": "q32",
        "Côte d'Ivoire": "q32",
        "Guinea": "q32",
        "Kenya": None,  # No data available
        "Madagascar": "q32",
        "Mali": "q32",
        "Niger": "q32",
        "Nigeria": "q32",
        "RDC": "q32"
    },
    "q33": {
        "Burkina Faso": "q33",
        "Cameroon": "q33",
        "Côte d'Ivoire": "q33",
        "Guinea": "q33",
        "Kenya": None,  # No data available
        "Madagascar": "q33",
        "Mali": "q33",
        "Niger": "q33",
        "Nigeria": "q33",
        "RDC": "q33"
    },
    "q33_other": {
        "Burkina Faso": "q33_autre",
        "Cameroon": "q33_autre",
        "Côte d'Ivoire": "q33_autre",
        "Guinea": "q33_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q33_autre",
        "Mali": "q33_autre",
        "Niger": "q33_autre",
        "Nigeria": None,
        "RDC": "q33_autre"
    },
    "q34": {
        "Burkina Faso": "q34",
        "Cameroon": "q34",
        "Côte d'Ivoire": "q34",
        "Guinea": "q34",
        "Kenya": None,  # No data available
        "Madagascar": "q34",
        "Mali": "q34",
        "Niger": "q34",
        "Nigeria": "q34",
        "RDC": "q34"
    },
    "q35": {
        "Burkina Faso": "q35",
        "Cameroon": "q35",
        "Côte d'Ivoire": "q35",
        "Guinea": "q35",
        "Kenya": None,  # No data available
        "Madagascar": "q35",
        "Mali": "q35",
        "Niger": "q35",
        "Nigeria": "q35",
        "RDC": "q35"
    },
    "q36": {
        "Burkina Faso": "q36",
        "Cameroon": "q36",
        "Côte d'Ivoire": "q36",
        "Guinea": "q36",
        "Kenya": None,  # No data available
        "Madagascar": "q36",
        "Mali": "q36",
        "Niger": "q36",
        "Nigeria": "q36",
        "RDC": "q36"
    },
    "q36_other": {
        "Burkina Faso": "q36_autre",
        "Cameroon": "q36_autre",
        "Côte d'Ivoire": "q36_autre",
        "Guinea": "q36_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q36_autre",
        "Mali": "q36_autre",
        "Niger": "q36_autre",
        "Nigeria": None,
        "RDC": "q36_autre"
    },
    "q37": {
        "Burkina Faso": "q37",
        "Cameroon": "q37",
        "Côte d'Ivoire": "q37",
        "Guinea": "q37",
        "Kenya": None,  # No data available
        "Madagascar": "q37",
        "Mali": "q37",
        "Niger": "q37",
        "Nigeria": "q37",
        "RDC": "q37"
    },
    "q37_other": {
        "Burkina Faso": "q37_autre",
        "Cameroon": "q37_autre",
        "Côte d'Ivoire": "q37_autre",
        "Guinea": "q37_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q37_autre",
        "Mali": "q37_autre",
        "Niger": "q37_autre",
        "Nigeria": "q37_others",
        "RDC": "q37_autre"
    },
    "q38": {
        "Burkina Faso": "q38",
        "Cameroon": "q38",
        "Côte d'Ivoire": "q38",
        "Guinea": "q38",
        "Kenya": None,  # No data available
        "Madagascar": "q38",
        "Mali": "q38",
        "Niger": "q38",
        "Nigeria": "q38",
        "RDC": "q38"
    },
    "q38_other": {
        "Burkina Faso": "q38_autre",
        "Cameroon": "q38_autre",
        "Côte d'Ivoire": "q38_autre",
        "Guinea": "q38_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q38_autre",
        "Mali": "q38_autre",
        "Niger": "q38_autre",
        "Nigeria": "q38_others",
        "RDC": "q38_autre"
    },
    "q39": {
        "Burkina Faso": "q39",
        "Cameroon": "q39",
        "Côte d'Ivoire": "q39",
        "Guinea": "q39",
        "Kenya": None,  # No data available
        "Madagascar": "q39",
        "Mali": "q39",
        "Niger": "q39",
        "Nigeria": "q39",
        "RDC": "q39"
    },
    "q39_other": {
        "Burkina Faso": "q39_autre",
        "Cameroon": "q39_autre",
        "Côte d'Ivoire": "q39_autre",
        "Guinea": "q39_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q39_autre",
        "Mali": "q39_autre",
        "Niger": "q39_autre",
        "Nigeria": "q39_others",
        "RDC": "q39_autre"
    },
    "q310": {
        "Burkina Faso": "q310",
        "Cameroon": "q310",
        "Côte d'Ivoire": "q310",
        "Guinea": "q310",
        "Kenya": None,  # No data available
        "Madagascar": "q310",
        "Mali": "q310",
        "Niger": "q310",
        "Nigeria": "q310",
        "RDC": "q310"
    },
    "q310_other": {
        "Burkina Faso": "q310_autre",
        "Cameroon": "q310_autre",
        "Côte d'Ivoire": "q310_autre",
        "Guinea": "q310_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q310_autre",
        "Mali": "q310_autre",
        "Niger": "q310_autre",
        "Nigeria": "q310_others",
        "RDC": "q310_autre"
    },
    "q311": {
        "Burkina Faso": "q311",
        "Cameroon": "q311",
        "Côte d'Ivoire": "q311",
        "Guinea": "q311",
        "Kenya": None,  # No data available
        "Madagascar": "q311",
        "Mali": "q311",
        "Niger": "q311",
        "Nigeria": "q311",
        "RDC": "q311"
    },
    "q311_other": {
        "Burkina Faso": "q311_autre",
        "Cameroon": "q311_autre",
        "Côte d'Ivoire": "q311_autre",
        "Guinea": "q311_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q311_autre",
        "Mali": "q311_autre",
        "Niger": "q311_autre",
        "Nigeria": "q311_others",
        "RDC": "q311_autre"
    },
    
    # Section 4 questions (present in 7 countries)
    "q41": {
        "Burkina Faso": "q41",
        "Cameroon": "q41",
        "Côte d'Ivoire": None,
        "Guinea": "q41",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q41",
        "Niger": "q41",
        "Nigeria": "q41",
        "RDC": "q41"
    },
    "q41_other": {
        "Burkina Faso": "q41_autre",
        "Cameroon": "q41_autre",
        "Côte d'Ivoire": None,
        "Guinea": "q41_autre",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q41_autre",
        "Niger": "q41_autre",
        "Nigeria": "q41_others",
        "RDC": "q41_autre"
    },
    "q42": {
        "Burkina Faso": "q42",
        "Cameroon": "q42",
        "Côte d'Ivoire": None,
        "Guinea": "q42",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q42",
        "Niger": "q42",
        "Nigeria": "q42",
        "RDC": "q42"
    },
    "q42_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "q42_others",
        "RDC": None
    },
    "q43": {
        "Burkina Faso": "q43",
        "Cameroon": "q43",
        "Côte d'Ivoire": None,
        "Guinea": "q43",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q43",
        "Niger": "q43",
        "Nigeria": "q43",
        "RDC": "q43"
    },
    "q43_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "q43_others",
        "RDC": None
    },
    "q44": {
        "Burkina Faso": "q44",
        "Cameroon": "q44",
        "Côte d'Ivoire": None,
        "Guinea": "q44",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q44",
        "Niger": "q44",
        "Nigeria": "q44",
        "RDC": "q44"
    },
    "q44_other": {
        "Burkina Faso": "q44_autre",
        "Cameroon": "q44_autre",
        "Côte d'Ivoire": None,
        "Guinea": "q44_autre",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q44_autre",
        "Niger": "q44_autre",
        "Nigeria": "q44_others",
        "RDC": "q44_autre"
    },
    "q45": {
        "Burkina Faso": "q45",
        "Cameroon": "q45",
        "Côte d'Ivoire": None,
        "Guinea": "q45",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q45",
        "Niger": "q45",
        "Nigeria": "q45",
        "RDC": "q45"
    },
    "q45_other": {
        "Burkina Faso": "q45_autre",
        "Cameroon": "q45_autre",
        "Côte d'Ivoire": None,
        "Guinea": "q45_autre",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q45_autre",
        "Niger": "q45_autre",
        "Nigeria": "q45_others",
        "RDC": "q45_autre"
    },
    "q46": {
        "Burkina Faso": "q46",
        "Cameroon": "q46",
        "Côte d'Ivoire": None,
        "Guinea": "q46",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q46",
        "Niger": "q46",
        "Nigeria": "q46",
        "RDC": "q46"
    },
    "q46_other": {
        "Burkina Faso": "q46_autre",
        "Cameroon": "q46_autre",
        "Côte d'Ivoire": None,
        "Guinea": "q46_autre",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q46_autre",
        "Niger": "q46_autre",
        "Nigeria": None,
        "RDC": "q46_autre"
    },
    
    # Section 5 questions (present in all 9 countries)
    "q51": {
        "Burkina Faso": "q51",
        "Cameroon": "q51",
        "Côte d'Ivoire": "q51",
        "Guinea": "q51",
        "Kenya": None,  # No data available
        "Madagascar": "q51",
        "Mali": "q51",
        "Niger": "q51",
        "Nigeria": "q51",
        "RDC": "q51"
    },
    "q52": {
        "Burkina Faso": "q52",
        "Cameroon": "q52",
        "Côte d'Ivoire": "q52",
        "Guinea": "q52",
        "Kenya": None,  # No data available
        "Madagascar": "q52",
        "Mali": "q52",
        "Niger": "q52",
        "Nigeria": "q52",
        "RDC": "q52"
    },
    "q52_other": {
        "Burkina Faso": "q52_autre",
        "Cameroon": "q52_autre",
        "Côte d'Ivoire": "q52_autre",
        "Guinea": "q52_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q52_autre",
        "Mali": "q52_autre",
        "Niger": "q52_autre",
        "Nigeria": "q52_others",
        "RDC": "q52_autre"
    },
    "q53": {
        "Burkina Faso": "q53",
        "Cameroon": "q53",
        "Côte d'Ivoire": "q53",
        "Guinea": "q53",
        "Kenya": None,  # No data available
        "Madagascar": "q53",
        "Mali": "q53",
        "Niger": "q53",
        "Nigeria": "q53",
        "RDC": "q53"
    },
    "q53_other": {
        "Burkina Faso": "q53_autre",
        "Cameroon": "q53_autre",
        "Côte d'Ivoire": "q53_autre",
        "Guinea": "q53_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q53_autre",
        "Mali": "q53_autre",
        "Niger": "q53_autre",
        "Nigeria": "q53_others",
        "RDC": "q53_autre"
    },
    "q54": {
        "Burkina Faso": "q54",
        "Cameroon": "q54",
        "Côte d'Ivoire": "q54",
        "Guinea": "q54",
        "Kenya": None,  # No data available
        "Madagascar": "q54",
        "Mali": "q54",
        "Niger": "q54",
        "Nigeria": "q54",
        "RDC": "q54"
    },
    "q55": {
        "Burkina Faso": "q55",
        "Cameroon": "q55",
        "Côte d'Ivoire": "q55",
        "Guinea": "q55",
        "Kenya": None,  # No data available
        "Madagascar": "q55",
        "Mali": "q55",
        "Niger": "q55",
        "Nigeria": "q55",
        "RDC": "q55"
    },
    "q55_other": {
        "Burkina Faso": "q55_autre",
        "Cameroon": "q55_autre",
        "Côte d'Ivoire": "q55_autre",
        "Guinea": "q55_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q55_autre",
        "Mali": "q55_autre",
        "Niger": "q55_autre",
        "Nigeria": None,
        "RDC": "q55_autre"
    },
    "q56": {
        "Burkina Faso": "q56",
        "Cameroon": "q56",
        "Côte d'Ivoire": "q56",
        "Guinea": "q56",
        "Kenya": None,  # No data available
        "Madagascar": "q56",
        "Mali": "q56",
        "Niger": "q56",
        "Nigeria": "q56",
        "RDC": "q56"
    },
    "q56_other": {
        "Burkina Faso": "q56_autre",
        "Cameroon": "q56_autre",
        "Côte d'Ivoire": "q56_autre",
        "Guinea": "q56_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q56_autre",
        "Mali": "q56_autre",
        "Niger": "q56_autre",
        "Nigeria": None,
        "RDC": "q56_autre"
    },
    "q57": {
        "Burkina Faso": "q57",
        "Cameroon": "q57",
        "Côte d'Ivoire": "q57",
        "Guinea": "q57",
        "Kenya": None,  # No data available
        "Madagascar": "q57",
        "Mali": "q57",
        "Niger": "q57",
        "Nigeria": "q57",
        "RDC": "q57"
    },
    "q58": {
        "Burkina Faso": "q58",
        "Cameroon": "q58",
        "Côte d'Ivoire": "q58",
        "Guinea": "q58",
        "Kenya": None,  # No data available
        "Madagascar": "q58",
        "Mali": "q58",
        "Niger": "q58",
        "Nigeria": "q58",
        "RDC": "q58"
    },
    "q59": {
        "Burkina Faso": "q59",
        "Cameroon": "q59",
        "Côte d'Ivoire": None,
        "Guinea": "q59",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q59",
        "Niger": "q59",
        "Nigeria": "q59",
        "RDC": "q59"
    },
    "q59_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "q59_others",
        "RDC": None
    },
    "q510": {
        "Burkina Faso": "q510",
        "Cameroon": "q510",
        "Côte d'Ivoire": None,
        "Guinea": "q510",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q510",
        "Niger": "q510",
        "Nigeria": None,
        "RDC": "q510"
    },
    "q511": {
        "Burkina Faso": "q511",
        "Cameroon": "q511",
        "Côte d'Ivoire": "q511",
        "Guinea": "q511",
        "Kenya": None,  # No data available
        "Madagascar": "q511",
        "Mali": "q511",
        "Niger": "q511",
        "Nigeria": None,
        "RDC": "q511"
    },
    "q512": {
        "Burkina Faso": "q512",
        "Cameroon": "q512",
        "Côte d'Ivoire": "q512",
        "Guinea": "q512",
        "Kenya": None,  # No data available
        "Madagascar": "q512",
        "Mali": "q512",
        "Niger": "q512",
        "Nigeria": None,
        "RDC": "q512"
    },
    "q512_other": {
        "Burkina Faso": "q512_autre",
        "Cameroon": "q512_autre",
        "Côte d'Ivoire": "q512_autre",
        "Guinea": "q512_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q512_autre",
        "Mali": "q512_autre",
        "Niger": "q512_autre",
        "Nigeria": None,
        "RDC": "q512_autre"
    },
    "q513": {
        "Burkina Faso": "q513",
        "Cameroon": "q513",
        "Côte d'Ivoire": "q513",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q513",
        "Niger": "q513",
        "Nigeria": None,
        "RDC": "q513"
    },
    "q514": {
        "Burkina Faso": "q514",
        "Cameroon": "q514",
        "Côte d'Ivoire": "q514",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q514",
        "Niger": "q514",
        "Nigeria": None,
        "RDC": "q514"
    },
    
    # Section 7 questions (present in all 9 countries)
    "q71": {
        "Burkina Faso": "q71",
        "Cameroon": "q71",
        "Côte d'Ivoire": "q71",
        "Guinea": "q71",
        "Kenya": None,  # No data available
        "Madagascar": "q71",
        "Mali": "q71",
        "Niger": "q71",
        "Nigeria": "q71",
        "RDC": "q71"
    },
    "q72": {
        "Burkina Faso": "q72",
        "Cameroon": "q72",
        "Côte d'Ivoire": "q72",
        "Guinea": "q72",
        "Kenya": None,  # No data available
        "Madagascar": "q72",
        "Mali": "q72",
        "Niger": "q72",
        "Nigeria": "q72",
        "RDC": "q72"
    },
    "q73": {
        "Burkina Faso": "q73",
        "Cameroon": "q73",
        "Côte d'Ivoire": "q73",
        "Guinea": "q73",
        "Kenya": None,  # No data available
        "Madagascar": "q73",
        "Mali": "q73",
        "Niger": "q73",
        "Nigeria": "q73",
        "RDC": "q73"
    },
    "q73_other": {
        "Burkina Faso": "q73_autre",
        "Cameroon": "q73_autre",
        "Côte d'Ivoire": "q73_autre",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "q73_autre",
        "Mali": "q73_autre",
        "Niger": "q73_autre",
        "Nigeria": "q73_others",
        "RDC": "q73_autre"
    },
    "q74": {
        "Burkina Faso": "q74",
        "Cameroon": "q74",
        "Côte d'Ivoire": "q74",
        "Guinea": "q74",
        "Kenya": None,  # No data available
        "Madagascar": "q74",
        "Mali": "q74",
        "Niger": "q74",
        "Nigeria": "q74",
        "RDC": "q74"
    },
    "q75": {
        "Burkina Faso": "q75",
        "Cameroon": "q75",
        "Côte d'Ivoire": "q75",
        "Guinea": "q75",
        "Kenya": None,  # No data available
        "Madagascar": "q75",
        "Mali": "q75",
        "Niger": "q75",
        "Nigeria": "q75",
        "RDC": "q75"
    },
    "q76": {
        "Burkina Faso": "q76",
        "Cameroon": "q76",
        "Côte d'Ivoire": "q76",
        "Guinea": "q76",
        "Kenya": None,  # No data available
        "Madagascar": "q76",
        "Mali": "q76",
        "Niger": "q76",
        "Nigeria": "q76",
        "RDC": "q76"
    },
    "q77": {
        "Burkina Faso": "q77",
        "Cameroon": "q77",
        "Côte d'Ivoire": "q77",
        "Guinea": "q77",
        "Kenya": None,  # No data available
        "Madagascar": "q77",
        "Mali": "q77",
        "Niger": "q77",
        "Nigeria": "q77",
        "RDC": "q77"
    },
    "q78": {
        "Burkina Faso": "q78",
        "Cameroon": "q78",
        "Côte d'Ivoire": "q78",
        "Guinea": "q78",
        "Kenya": None,  # No data available
        "Madagascar": "q78",
        "Mali": "q78",
        "Niger": "q78",
        "Nigeria": "q78",
        "RDC": "q78"
    },
    "q79": {
        "Burkina Faso": "q79",
        "Cameroon": "q79",
        "Côte d'Ivoire": "q79",
        "Guinea": "q79",
        "Kenya": None,  # No data available
        "Madagascar": "q79",
        "Mali": "q79",
        "Niger": "q79",
        "Nigeria": "q79",
        "RDC": "q79"
    },
    "q79_other": {
        "Burkina Faso": "q79_autre",
        "Cameroon": "q79_autre",
        "Côte d'Ivoire": "q79_autre",
        "Guinea": "q79_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q79_autre",
        "Mali": "q79_autre",
        "Niger": "q79_autre",
        "Nigeria": "q79_others",
        "RDC": "q79_autre"
    },
    "q710": {
        "Burkina Faso": "q710",
        "Cameroon": "q710",
        "Côte d'Ivoire": "q710",
        "Guinea": "q710",
        "Kenya": None,  # No data available
        "Madagascar": "q710",
        "Mali": "q710",
        "Niger": "q710",
        "Nigeria": "q710",
        "RDC": "q710"
    },
    "q711": {
        "Burkina Faso": "q711",
        "Cameroon": "q711",
        "Côte d'Ivoire": "q711",
        "Guinea": "q711",
        "Kenya": None,  # No data available
        "Madagascar": "q711",
        "Mali": "q711",
        "Niger": "q711",
        "Nigeria": "q711",
        "RDC": "q711"
    },
    "q711_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": "q711_autre",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q712": {
        "Burkina Faso": "q712",
        "Cameroon": "q712",
        "Côte d'Ivoire": "q712",
        "Guinea": "q712",
        "Kenya": None,  # No data available
        "Madagascar": "q712",
        "Mali": "q712",
        "Niger": "q712",
        "Nigeria": "q712",
        "RDC": "q712"
    },
    "q713": {
        "Burkina Faso": "q713",
        "Cameroon": "q713",
        "Côte d'Ivoire": "q713",
        "Guinea": "q713",
        "Kenya": None,  # No data available
        "Madagascar": "q713",
        "Mali": "q713",
        "Niger": "q713",
        "Nigeria": "q713",
        "RDC": "q713"
    },
    "q713_non": {
        "Burkina Faso": "q713_non",
        "Cameroon": "q713_non",
        "Côte d'Ivoire": "q713_non",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "q713_non",
        "Mali": "q713_non",
        "Niger": "q713_non",
        "Nigeria": None,
        "RDC": "q713_non"
    },
    "q713_other": {
        "Burkina Faso": "q713_autre",
        "Cameroon": "q713_autre",
        "Côte d'Ivoire": "q713_autre",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "q713_autre",
        "Mali": "q713_autre",
        "Niger": "q713_autre",
        "Nigeria": None,
        "RDC": "q713_autre"
    },
    "q714": {
        "Burkina Faso": "q714",
        "Cameroon": "q714",
        "Côte d'Ivoire": "q714",
        "Guinea": "q714",
        "Kenya": None,  # No data available
        "Madagascar": "q714",
        "Mali": "q714",
        "Niger": "q714",
        "Nigeria": "q714",
        "RDC": "q714"
    },
    "q715": {
        "Burkina Faso": "q715",
        "Cameroon": "q715",
        "Côte d'Ivoire": "q715",
        "Guinea": "q715",
        "Kenya": None,  # No data available
        "Madagascar": "q715",
        "Mali": "q715",
        "Niger": "q715",
        "Nigeria": "q715",
        "RDC": "q715"
    },
    "q716": {
        "Burkina Faso": "q716",
        "Cameroon": "q716",
        "Côte d'Ivoire": "q716",
        "Guinea": "q716",
        "Kenya": None,  # No data available
        "Madagascar": "q716",
        "Mali": "q716",
        "Niger": "q716",
        "Nigeria": "q716",
        "RDC": "q716"
    },
    "q717": {
        "Burkina Faso": "q717",
        "Cameroon": "q717",
        "Côte d'Ivoire": "q717",
        "Guinea": "q717",
        "Kenya": None,  # No data available
        "Madagascar": "q717",
        "Mali": "q717",
        "Niger": "q717",
        "Nigeria": "q717",
        "RDC": "q717"
    },
    "q717_other": {
        "Burkina Faso": "q717_autre",
        "Cameroon": "q717_autre",
        "Côte d'Ivoire": "q717_autre",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "q717_autre",
        "Mali": "q717_autre",
        "Niger": "q717_autre",
        "Nigeria": "q717_others",
        "RDC": "q717_autre"
    },
    "q718": {
        "Burkina Faso": "q718",
        "Cameroon": "q718",
        "Côte d'Ivoire": "q718",
        "Guinea": "q718",
        "Kenya": None,  # No data available
        "Madagascar": "q718",
        "Mali": "q718",
        "Niger": "q718",
        "Nigeria": "q718",
        "RDC": "q718"
    },
    "q718_other": {
        "Burkina Faso": "q718_autre",
        "Cameroon": "q718_autre",
        "Côte d'Ivoire": "q718_autre",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "q718_autre",
        "Mali": "q718_autre",
        "Niger": "q718_autre",
        "Nigeria": "q718_others",
        "RDC": "q718_autre"
    },
    
    # Section 8 questions (present in all 9 countries)
    "q84": {
        "Burkina Faso": "q84",
        "Cameroon": "q84",
        "Côte d'Ivoire": "q84",
        "Guinea": "q84",
        "Kenya": None,  # No data available
        "Madagascar": "q84",
        "Mali": "q84",
        "Niger": "q84",
        "Nigeria": "q84",
        "RDC": "q84"
    },
    "q85": {
        "Burkina Faso": "q85",
        "Cameroon": "q85",
        "Côte d'Ivoire": "q85",
        "Guinea": "q85",
        "Kenya": None,  # No data available
        "Madagascar": "q85",
        "Mali": "q85",
        "Niger": "q85",
        "Nigeria": "q85",
        "RDC": "q85"
    },
    "q85_other": {
        "Burkina Faso": "q85_autre",
        "Cameroon": "q85_autre",
        "Côte d'Ivoire": "q85_autre",
        "Guinea": "q85_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q85_autre",
        "Mali": "q85_autre",
        "Niger": "q85_autre",
        "Nigeria": "q85_others",
        "RDC": "q85_autre"
    },
    "q86": {
        "Burkina Faso": "q86",
        "Cameroon": "q86",
        "Côte d'Ivoire": "q86",
        "Guinea": "q86",
        "Kenya": None,  # No data available
        "Madagascar": "q86",
        "Mali": "q86",
        "Niger": "q86",
        "Nigeria": "q86",
        "RDC": "q86"
    },
    "q87": {
        "Burkina Faso": "q87",
        "Cameroon": "q87",
        "Côte d'Ivoire": None,
        "Guinea": "q87",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q87",
        "Niger": "q87",
        "Nigeria": "q87",
        "RDC": "q87"
    },
    "q88": {
        "Burkina Faso": "q88",
        "Cameroon": "q88",
        "Côte d'Ivoire": None,
        "Guinea": "q88",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q88",
        "Niger": "q88",
        "Nigeria": "q88",
        "RDC": "q88"
    },
    "q88_other": {
        "Burkina Faso": "q88_autre",
        "Cameroon": "q88_autre",
        "Côte d'Ivoire": None,
        "Guinea": "q88_autre",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q88_autre",
        "Niger": "q88_autre",
        "Nigeria": "q88_others",
        "RDC": "q88_autre"
    },
    "q89": {
        "Burkina Faso": "q89",
        "Cameroon": "q89",
        "Côte d'Ivoire": None,
        "Guinea": "q89",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q89",
        "Niger": "q89",
        "Nigeria": "q89",
        "RDC": "q89"
    },
    "q810": {
        "Burkina Faso": "q810",
        "Cameroon": "q810",
        "Côte d'Ivoire": "q810",
        "Guinea": "q810",
        "Kenya": None,  # No data available
        "Madagascar": "q810",
        "Mali": "q810",
        "Niger": "q810",
        "Nigeria": "q810",
        "RDC": "q810"
    },
    "q810_other": {
        "Burkina Faso": "q810_autre",
        "Cameroon": "q810_autre",
        "Côte d'Ivoire": "q810_autre",
        "Guinea": "q810_autre",
        "Kenya": None,  # No data available
        "Madagascar": "q810_autre",
        "Mali": "q810_autre",
        "Niger": "q810_autre",
        "Nigeria": "q810_others",
        "RDC": "q810_autre"
    },
    "q811": {
        "Burkina Faso": "q811",
        "Cameroon": "q811",
        "Côte d'Ivoire": None,
        "Guinea": "q811",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q811",
        "Niger": "q811",
        "Nigeria": "q811",
        "RDC": "q811"
    },
    "q811_other": {
        "Burkina Faso": "q811_autre",
        "Cameroon": "q811_autre",
        "Côte d'Ivoire": None,
        "Guinea": "q811_autre",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q811_autre",
        "Niger": "q811_autre",
        "Nigeria": "q811_others",
        "RDC": "q811_autre"
    },
    "q812": {
        "Burkina Faso": "q812",
        "Cameroon": "q812",
        "Côte d'Ivoire": "q812",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q812",
        "Niger": None,
        "Nigeria": "q812",
        "RDC": "q812"
    },
    "q813": {
        "Burkina Faso": "q813",
        "Cameroon": "q813",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q813",
        "Niger": None,
        "Nigeria": "q813",
        "RDC": "q813"
    },
    "q814": {
        "Burkina Faso": "q814",
        "Cameroon": "q814",
        "Côte d'Ivoire": "q814",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q814",
        "Niger": "q814",
        "Nigeria": "q814",
        "RDC": "q814"
    },
    "q815": {
        "Burkina Faso": "q815",
        "Cameroon": "q815",
        "Côte d'Ivoire": "q815",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q815",
        "Niger": "q815",
        "Nigeria": "q815",
        "RDC": "q815"
    },
    "q816": {
        "Burkina Faso": "q816",
        "Cameroon": "q816",
        "Côte d'Ivoire": "q816",
        "Guinea": "q816",
        "Kenya": None,  # No data available
        "Madagascar": "q816",
        "Mali": "q816",
        "Niger": "q816",
        "Nigeria": "q816",
        "RDC": "q816"
    },
    "q816_other": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "q816_others",
        "RDC": None
    },
    "q817": {
        "Burkina Faso": "q817",
        "Cameroon": "q817",
        "Côte d'Ivoire": "q817",
        "Guinea": "q817",
        "Kenya": None,  # No data available
        "Madagascar": "q817",
        "Mali": "q817",
        "Niger": "q817",
        "Nigeria": "q817",
        "RDC": "q817"
    },
    "q818": {
        "Burkina Faso": "q818",
        "Cameroon": "q818",
        "Côte d'Ivoire": "q818",
        "Guinea": "q818",
        "Kenya": None,  # No data available
        "Madagascar": "q818",
        "Mali": "q818",
        "Niger": "q818",
        "Nigeria": "q818",
        "RDC": "q818"
    },
    "q819": {
        "Burkina Faso": "q819",
        "Cameroon": "q819",
        "Côte d'Ivoire": "q819",
        "Guinea": "q819",
        "Kenya": None,  # No data available
        "Madagascar": "q819",
        "Mali": "q819",
        "Niger": "q819",
        "Nigeria": "q819",
        "RDC": "q819"
    },
    "q820": {
        "Burkina Faso": "q820",
        "Cameroon": "q820",
        "Côte d'Ivoire": "q820",
        "Guinea": "q820",
        "Kenya": None,  # No data available
        "Madagascar": "q820",
        "Mali": "q820",
        "Niger": "q820",
        "Nigeria": "q820",
        "RDC": "q820"
    },
    "q821": {
        "Burkina Faso": "q821",
        "Cameroon": "q821",
        "Côte d'Ivoire": "q821",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q821",
        "Niger": None,
        "Nigeria": "q821",
        "RDC": "q821"
    },
    "q821_other": {
        "Burkina Faso": "q821_autre",
        "Cameroon": "q821_autre",
        "Côte d'Ivoire": "q821_autre",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "q821_autre",
        "Niger": None,
        "Nigeria": "q821_others",
        "RDC": "q821_autre"
    },
    
    # Time and location fields (8 countries - Nigeria excluded)
    "start_time": {
        "Burkina Faso": "heure_debut",
        "Cameroon": "heure_debut",
        "Côte d'Ivoire": "heure_debut",
        "Guinea": "heure_debut",
        "Kenya": None,  # No data available
        "Madagascar": "heure_debut",
        "Mali": "heure_debut",
        "Niger": "heure_debut",
        "Nigeria": None,
        "RDC": "heure_debut"
    },
    "end_time": {
        "Burkina Faso": "heure_fin",
        "Cameroon": "heure_fin",
        "Côte d'Ivoire": "heure_fin",
        "Guinea": "heure_fin",
        "Kenya": None,  # No data available
        "Madagascar": "heure_fin",
        "Mali": "heure_fin",
        "Niger": "heure_fin",
        "Nigeria": None,
        "RDC": "heure_fin"
    },
    "location_longitude": {
        "Burkina Faso": "location-Longitude",
        "Cameroon": "location-Longitude",
        "Côte d'Ivoire": "location-Longitude",
        "Guinea": "location-Longitude",
        "Kenya": None,  # No data available
        "Madagascar": "location-Longitude",
        "Mali": "location-Longitude",
        "Niger": "location-Longitude",
        "Nigeria": None,
        "RDC": "location-Longitude"
    },
    "location_latitude": {
        "Burkina Faso": "location-Latitude",
        "Cameroon": "location-Latitude",
        "Côte d'Ivoire": "location-Latitude",
        "Guinea": "location-Latitude",
        "Kenya": None,  # No data available
        "Madagascar": "location-Latitude",
        "Mali": "location-Latitude",
        "Niger": "location-Latitude",
        "Nigeria": None,
        "RDC": "location-Latitude"
    },
    "location_altitude": {
        "Burkina Faso": "location-Altitude",
        "Cameroon": "location-Altitude",
        "Côte d'Ivoire": "location-Altitude",
        "Guinea": "location-Altitude",
        "Kenya": None,  # No data available
        "Madagascar": "location-Altitude",
        "Mali": "location-Altitude",
        "Niger": "location-Altitude",
        "Nigeria": None,
        "RDC": "location-Altitude"
    },
    "location_accuracy": {
        "Burkina Faso": "location-Accuracy",
        "Cameroon": "location-Accuracy",
        "Côte d'Ivoire": "location-Accuracy",
        "Guinea": "location-Accuracy",
        "Kenya": None,  # No data available
        "Madagascar": "location-Accuracy",
        "Mali": "location-Accuracy",
        "Niger": "location-Accuracy",
        "Nigeria": None,
        "RDC": "location-Accuracy"
    },
    "audio_audit": {
        "Burkina Faso": "audio_audit",
        "Cameroon": "audio_audit",
        "Côte d'Ivoire": "audio_audit",
        "Guinea": "audio_audit",
        "Kenya": None,  # No data available
        "Madagascar": "audio_audit",
        "Mali": "audio_audit",
        "Niger": "audio_audit",
        "Nigeria": None,
        "RDC": "audio_audit"
    },
    
    # Administrative area fields
    "health_area": {
        "Burkina Faso": "aire_sante",
        "Cameroon": "aire_sante",
        "Côte d'Ivoire": "aire_sante",
        "Guinea": "aire_sante",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "aire_sante",
        "Niger": "aire_sante",
        "Nigeria": "aire_sante",
        "RDC": "aire_sante"
    },
    "reason_consent_no": {
        "Burkina Faso": "reason_consent_no",
        "Cameroon": "reason_consent_no",
        "Côte d'Ivoire": "reason_consent_no",
        "Guinea": "reason_consent_no",
        "Kenya": None,  # No data available
        "Madagascar": "reason_consent_no",
        "Mali": "reason_consent_no",
        "Niger": "reason_consent_no",
        "Nigeria": "reason_consent_no",
        "RDC": None
    },
    
    # Geographic/location fields (7 countries)
    "region": {
        "Burkina Faso": "region",
        "Cameroon": "region",
        "Côte d'Ivoire": "region",
        "Guinea": "region",
        "Kenya": None,  # No data available
        "Madagascar": "region",
        "Mali": "region",
        "Niger": "region",
        "Nigeria": None,
        "RDC": None
    },
    "cluster": {
        "Burkina Faso": "cluster",
        "Cameroon": "cluster",
        "Côte d'Ivoire": "cluster",
        "Guinea": "cluster",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "cluster",
        "Niger": "cluster",
        "Nigeria": "cluster",
        "RDC": None
    },
    "duration": {
        "Burkina Faso": "duration",
        "Cameroon": "duration",
        "Côte d'Ivoire": "duration",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "duration",
        "Niger": "duration",
        "Nigeria": "duration",
        "RDC": "duration"
    },
    "device_info": {
        "Burkina Faso": "device_info",
        "Cameroon": "device_info",
        "Côte d'Ivoire": "device_info",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "device_info",
        "Niger": "device_info",
        "Nigeria": "device_info",
        "RDC": "device_info"
    },
    "signature": {
        "Burkina Faso": "signature",
        "Cameroon": "signature",
        "Côte d'Ivoire": "signature",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "signature",
        "Mali": "signature",
        "Niger": "signature",
        "Nigeria": "signature",
        "RDC": None
    },
    
    # Meta and system fields (6 countries)
    "device_id": {
        "Burkina Faso": "deviceid",
        "Cameroon": "deviceid",
        "Côte d'Ivoire": "deviceid",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "deviceid",
        "Nigeria": "deviceid",
        "RDC": "deviceid"
    },
    "end": {
        "Burkina Faso": "end",
        "Cameroon": "end",
        "Côte d'Ivoire": "end",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "end",
        "Nigeria": "end",
        "RDC": "end"
    },
    "commune": {
        "Burkina Faso": "commune",
        "Cameroon": None,
        "Côte d'Ivoire": "commune",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "commune",
        "Mali": "commune",
        "Niger": "commune",
        "Nigeria": None,
        "RDC": "commune"
    },
    "case_id": {
        "Burkina Faso": "caseid",
        "Cameroon": "caseid",
        "Côte d'Ivoire": "caseid",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "caseid",
        "Nigeria": "caseid",
        "RDC": "caseid"
    },
    "start": {
        "Burkina Faso": "start",
        "Cameroon": "start",
        "Côte d'Ivoire": "start",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "start",
        "Nigeria": "start",
        "RDC": "start"
    },
    "area": {
        "Burkina Faso": "area",
        "Cameroon": "area",
        "Côte d'Ivoire": "area",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "area",
        "Mali": "area",
        "Niger": "area",
        "Nigeria": None,
        "RDC": None
    },
    "supervisor": {
        "Burkina Faso": "supervisor",
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": "supervisor",
        "Kenya": None,  # No data available
        "Madagascar": "supervisor",
        "Mali": "supervisor",
        "Niger": None,
        "Nigeria": "supervisor",
        "RDC": "supervisor"
    },
    "username": {
        "Burkina Faso": "username",
        "Cameroon": "username",
        "Côte d'Ivoire": "username",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "username",
        "Nigeria": "username",
        "RDC": "username"
    },
    "phone_number": {
        "Burkina Faso": "phonenumber",
        "Cameroon": "phonenumber",
        "Côte d'Ivoire": "phonenumber",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "phonenumber",
        "Nigeria": "phonenumber",
        "RDC": "phonenumber"
    },
    "meta_instance_id": {
        "Burkina Faso": "meta-instanceID",
        "Cameroon": "meta-instanceID",
        "Côte d'Ivoire": "meta-instanceID",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "meta-instanceID",
        "Nigeria": "meta-instanceID",
        "RDC": "meta-instanceID"
    },
    "health_worker_number": {
        "Burkina Faso": "num_AC",
        "Cameroon": "num_AC",
        "Côte d'Ivoire": "num_AC",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "num_AC",
        "Niger": "num_AC",
        "Nigeria": None,
        "RDC": "num_AC"
    },
    
    # Meta instance name (5 countries)
    "meta_instance_name": {
        "Burkina Faso": "meta-instanceName",
        "Cameroon": "meta-instanceName",
        "Côte d'Ivoire": "meta-instanceName",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "meta-instanceName",
        "Nigeria": None,
        "RDC": "meta-instanceName"
    },
    "enumerator_name": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "enumerator_name",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "enumerator_name",
        "Niger": "enumerator_name",
        "Nigeria": "enumerator_name",
        "RDC": "enumerator_name"
    },
    "enumerator": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "enumerator",
        "Guinea": "enumerator",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "enumerator",
        "Niger": "enumerator",
        "Nigeria": None,
        "RDC": "enumerator"
    },
    
    # Section 9 questions (4 countries)
    "q91": {
        "Burkina Faso": None,
        "Cameroon": "q91",
        "Côte d'Ivoire": "q91",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q91",
        "Nigeria": None,
        "RDC": "q91"
    },
    "q92": {
        "Burkina Faso": None,
        "Cameroon": "q92",
        "Côte d'Ivoire": "q92",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q92",
        "Nigeria": None,
        "RDC": "q92"
    },
    "q93": {
        "Burkina Faso": None,
        "Cameroon": "q93",
        "Côte d'Ivoire": "q93",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q93",
        "Nigeria": None,
        "RDC": "q93"
    },
    "q94": {
        "Burkina Faso": None,
        "Cameroon": "q94",
        "Côte d'Ivoire": "q94",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q94",
        "Nigeria": None,
        "RDC": "q94"
    },
    "q94_other": {
        "Burkina Faso": None,
        "Cameroon": "q94_autre",
        "Côte d'Ivoire": "q94_autre",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q94_autre",
        "Nigeria": None,
        "RDC": "q94_autre"
    },
    "q95": {
        "Burkina Faso": None,
        "Cameroon": "q95",
        "Côte d'Ivoire": "q95",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q95",
        "Nigeria": None,
        "RDC": "q95"
    },
    "q96": {
        "Burkina Faso": None,
        "Cameroon": "q96",
        "Côte d'Ivoire": "q96",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q96",
        "Nigeria": None,
        "RDC": "q96"
    },
    "q97": {
        "Burkina Faso": None,
        "Cameroon": "q97",
        "Côte d'Ivoire": "q97",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q97",
        "Nigeria": None,
        "RDC": "q97"
    },
    "q911": {
        "Burkina Faso": None,
        "Cameroon": "q911",
        "Côte d'Ivoire": "q911",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q911",
        "Nigeria": None,
        "RDC": "q911"
    },
    "team_lead": {
        "Burkina Faso": "team_lead",
        "Cameroon": "team_lead",
        "Côte d'Ivoire": "team_lead",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "team_lead",
        "Niger": None,
        "Nigeria": None,
        "RDC": "teamlead"  # Note: different spelling
    },
    "locality": {
        "Burkina Faso": "localite",
        "Cameroon": None,
        "Côte d'Ivoire": "localite",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "localite",
        "Niger": "localite",
        "Nigeria": None,
        "RDC": "locality"
    },
    "district": {
        "Burkina Faso": "district",
        "Cameroon": None,
        "Côte d'Ivoire": "district",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "district",
        "Mali": "district",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Type cluster (3 countries)
    "type_cluster": {
        "Burkina Faso": "typecluster",
        "Cameroon": "Typecluster",
        "Côte d'Ivoire": "typecluster",
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": "typecluster",
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Department (2 countries)
    "department": {
        "Burkina Faso": None,
        "Cameroon": "departement",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "departement",
        "Nigeria": None,
        "RDC": None
    },
    "milieu": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": "milieu",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "milieu"
    },
    "milieu_name": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "milieu_name"
    },
    
    # Additional fields only in 2 countries
    "q98": {
        "Burkina Faso": None,
        "Cameroon": "q98",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q98",
        "Nigeria": None,
        "RDC": None
    },
    "q99": {
        "Burkina Faso": None,
        "Cameroon": "q99",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q99",
        "Nigeria": None,
        "RDC": None
    },
    "q99_other": {
        "Burkina Faso": None,
        "Cameroon": "q99_autre",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q99_autre",
        "Nigeria": None,
        "RDC": None
    },
    "q910": {
        "Burkina Faso": None,
        "Cameroon": "q910",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q910",
        "Nigeria": None,
        "RDC": None
    },
    "q910_other": {
        "Burkina Faso": None,
        "Cameroon": "q910_autre",
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": "q910_autre",
        "Nigeria": None,
        "RDC": None
    },
    
    # Country-specific fields
    "country": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "country",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "year": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "year",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "round": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": "round",
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "state": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "state",
        "RDC": None
    },
    "lga": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": "lga",
        "RDC": None
    },
    "prefecture": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": "prefecture",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "sub_prefecture": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": "sousprefecture",
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "province": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "province"
    },
    "province_name": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "province_name"
    },
    "locality_name": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "locality_name"
    },
    "city": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "ville"
    },
    "city_name": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "ville_name"
    },
    "grappe": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "grappe"
    },
    "grappe_name": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "grappe_name"
    },
    "commune_name": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": "commune_name"
    },
    
    # Burkina Faso specific
    "q101": {
        "Burkina Faso": "q101",
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    "q104": {
        "Burkina Faso": "q104",
        "Cameroon": None,
        "Côte d'Ivoire": None,
        "Guinea": None,
        "Kenya": None,  # No data available
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Health Workers Main Form
# Note: Kenya has no data available
HEALTH_WORKERS_MAIN_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs_hwc_r2",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cm2024_pecs_hwc_r2",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_hwc_r2",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_chw_r1",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_agent_communautaire",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs_agent_communautaire",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_hwc_v2",
    "Nigeria": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ng2025_pecs_chwform",
    "RDC": "https://keller2024.surveycto.com/api/v1/forms/data/csv/cd2024_pecs_hwc_r2"
}

# Mapping dictionary for Health Workers Main Form

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply HEALTH_WORKERS_MAIN_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in HEALTH_WORKERS_MAIN_MAPPING.items():
        if country in country_mapping and country_mapping[country] is not None:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_health_workers_main_harmonized():
    """Create harmonized Health Workers Main Form table"""
    
    print("CREATING HEALTH WORKERS MAIN FORM - HARMONIZED TABLE")
    print("=" * 55)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in HEALTH_WORKERS_MAIN_ENDPOINTS.items():
        print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 55)
    print("HEALTH WORKERS MAIN FORM - HARMONIZED SUMMARY")
    print("=" * 55)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in HEALTH_WORKERS_MAIN_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping (exclude None values)
        country_count = len([c for c in HEALTH_WORKERS_MAIN_MAPPING[col].values() if c is not None])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:35} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Special notes about data patterns
    print(f"\nData pattern notes:")
    print(f"  - Kenya: No data available")
    print(f"  - Nigeria: Uses '_others' instead of '_autre' for write-in fields")
    print(f"  - RDC: Uses 'teamlead' instead of 'team_lead'")
    print(f"  - Core survey sections: Personal info (q21-q23), Survey (q31-q311), Section 4-8")
    print(f"  - Time/location fields: Available in 8 countries")
    print(f"  - Geographic variations: Different administrative divisions by country")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    health_workers_main_combined = create_health_workers_main_harmonized()
    
    # Display sample data
    if health_workers_main_combined is not None:
        print(f"\n🎉 Table 13 (Health Workers Main Form) is ready!")
        print(f"Shape: {health_workers_main_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(health_workers_main_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(health_workers_main_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(health_workers_main_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING HEALTH WORKERS MAIN FORM - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 105 rows loaded
#   → Burkina Faso: 141 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 249 rows loaded
#   → Cameroon: 150 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 255 rows loaded
#   → Côte d'Ivoire: 130 columns harmonized
# Loading Guinea...
# ✓ Guinea: 116 rows loaded
#   → Guinea: 113 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 209 rows loaded
#   → Madagascar: 100 columns harmonized
# Loading Mali...
# ✓ Mali: 109 rows loaded
#   → Mali: 133 columns harmonized
# Loading Niger...
# ✓ Niger: 102 rows loaded
#   → Niger: 148 columns harmonized
# Loading Nigeria...
# ✓ Nigeria: 73 rows loaded
#   → Nigeria: 117 columns harmonized
# Loading RDC...
# ✓ RDC: 115 rows loaded
#   → RDC: 153 columns harmonized
#
# Combining data from 9 countries...
#
# ...
# HEALTH WORKERS MAIN FORM - HARMONIZED SUMMARY
# ...
# Total rows: 1,333
# Total columns: 249
# ...

# %% [markdown]
# Table 14: Minister Region District Main Form

# %%
MINISTER_REGION_DISTRICT_MAIN_MAPPING = {
    # Core identification columns (present in all 7 countries)
    "key": {
        "Burkina Faso": "KEY",
        "Cameroon": "KEY",
        "Côte d'Ivoire": "KEY",
        "Guinea": "KEY",
        "Kenya": None,  # No data available
        "Madagascar": "KEY",
        "Mali": "KEY",
        "Niger": "KEY",
        "Nigeria": None,  # No data available
        "RDC": None  # No data available
    },
    
    # Form metadata (present in all 7 countries)
    "formdef_version": {
        "Burkina Faso": "formdef_version",
        "Cameroon": "formdef_version",
        "Côte d'Ivoire": "formdef_version",
        "Guinea": "formdef_version",
        "Kenya": None,
        "Madagascar": "formdef_version",
        "Mali": "formdef_version",
        "Niger": "formdef_version",
        "Nigeria": None,
        "RDC": None
    },
    
    "submission_date": {
        "Burkina Faso": "SubmissionDate",
        "Cameroon": "SubmissionDate",
        "Côte d'Ivoire": "SubmissionDate",
        "Guinea": "SubmissionDate",
        "Kenya": None,
        "Madagascar": "SubmissionDate",
        "Mali": "SubmissionDate",
        "Niger": "SubmissionDate",
        "Nigeria": None,
        "RDC": None
    },
    
    "level": {
        "Burkina Faso": "level",
        "Cameroon": "level",
        "Côte d'Ivoire": "level",
        "Guinea": "level",
        "Kenya": None,
        "Madagascar": "level",
        "Mali": "level",
        "Niger": "level",
        "Nigeria": None,
        "RDC": None
    },
    
    "region": {
        "Burkina Faso": "region",
        "Cameroon": "region",
        "Côte d'Ivoire": "region",
        "Guinea": "region",
        "Kenya": None,
        "Madagascar": "region",
        "Mali": "region",
        "Niger": "region",
        "Nigeria": None,
        "RDC": None
    },
    
    # Audit fields (present in all 7 countries)
    "text_audit": {
        "Burkina Faso": "text_audit",
        "Cameroon": "text_audit",
        "Côte d'Ivoire": "text_audit",
        "Guinea": "text_audit",
        "Kenya": None,
        "Madagascar": "text_audit",
        "Mali": "text_audit",
        "Niger": "text_audit",
        "Nigeria": None,
        "RDC": None
    },
    
    "audio_audit": {
        "Burkina Faso": "audio_audit",
        "Cameroon": "audio_audit",
        "Côte d'Ivoire": "audio_audit",
        "Guinea": "audio_audit",
        "Kenya": None,
        "Madagascar": "audio_audit",
        "Mali": "audio_audit",
        "Niger": "audio_audit",
        "Nigeria": None,
        "RDC": None
    },
    
    "review_quality": {
        "Burkina Faso": "review_quality",
        "Cameroon": "review_quality",
        "Côte d'Ivoire": "review_quality",
        "Guinea": "review_quality",
        "Kenya": None,
        "Madagascar": "review_quality",
        "Mali": "review_quality",
        "Niger": "review_quality",
        "Nigeria": None,
        "RDC": None
    },
    
    # GPS coordinates (present in all 7 countries)
    "gps_latitude": {
        "Burkina Faso": "con-gps-Latitude",
        "Cameroon": "con-gps-Latitude",
        "Côte d'Ivoire": "con-gps-Latitude",
        "Guinea": "con-gps-Latitude",
        "Kenya": None,
        "Madagascar": "con-gps-Latitude",
        "Mali": "con-gps-Latitude",
        "Niger": "con-gps-Latitude",
        "Nigeria": None,
        "RDC": None
    },
    
    "gps_longitude": {
        "Burkina Faso": "con-gps-Longitude",
        "Cameroon": "con-gps-Longitude",
        "Côte d'Ivoire": "con-gps-Longitude",
        "Guinea": "con-gps-Longitude",
        "Kenya": None,
        "Madagascar": "con-gps-Longitude",
        "Mali": "con-gps-Longitude",
        "Niger": "con-gps-Longitude",
        "Nigeria": None,
        "RDC": None
    },
    
    "gps_altitude": {
        "Burkina Faso": "con-gps-Altitude",
        "Cameroon": "con-gps-Altitude",
        "Côte d'Ivoire": "con-gps-Altitude",
        "Guinea": "con-gps-Altitude",
        "Kenya": None,
        "Madagascar": "con-gps-Altitude",
        "Mali": "con-gps-Altitude",
        "Niger": "con-gps-Altitude",
        "Nigeria": None,
        "RDC": None
    },
    
    "gps_accuracy": {
        "Burkina Faso": "con-gps-Accuracy",
        "Cameroon": "con-gps-Accuracy",
        "Côte d'Ivoire": "con-gps-Accuracy",
        "Guinea": "con-gps-Accuracy",
        "Kenya": None,
        "Madagascar": "con-gps-Accuracy",
        "Mali": "con-gps-Accuracy",
        "Niger": "con-gps-Accuracy",
        "Nigeria": None,
        "RDC": None
    },
    
    # Interview timing (present in all 7 countries)
    "interview_end_time": {
        "Burkina Faso": "con-heure_fin",
        "Cameroon": "con-heure_fin",
        "Côte d'Ivoire": "con-heure_fin",
        "Guinea": "con-heure_fin",
        "Kenya": None,
        "Madagascar": "con-heure_fin",
        "Mali": "con-heure_fin",
        "Niger": "con-heure_fin",
        "Nigeria": None,
        "RDC": None
    },
    
    # Central level questions (all 7 countries)
    "central_q1": {
        "Burkina Faso": "con-central-q1",
        "Cameroon": "con-central-q1",
        "Côte d'Ivoire": "con-central-q1",
        "Guinea": "con-central-q1",
        "Kenya": None,
        "Madagascar": "con-central-q1",
        "Mali": "con-central-q1",
        "Niger": "con-central-q1",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q1_other": {
        "Burkina Faso": "con-central-q1_oth",
        "Cameroon": "con-central-q1_oth",
        "Côte d'Ivoire": "con-central-q1_oth",
        "Guinea": "con-central-q1_oth",
        "Kenya": None,
        "Madagascar": "con-central-q1_oth",
        "Mali": "con-central-q1_oth",
        "Niger": "con-central-q1_oth",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q2": {
        "Burkina Faso": "con-central-q2",
        "Cameroon": "con-central-q2",
        "Côte d'Ivoire": "con-central-q2",
        "Guinea": "con-central-q2",
        "Kenya": None,
        "Madagascar": "con-central-q2",
        "Mali": "con-central-q2",
        "Niger": "con-central-q2",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q2_other": {
        "Burkina Faso": "con-central-q2_oth",
        "Cameroon": "con-central-q2_oth",
        "Côte d'Ivoire": "con-central-q2_oth",
        "Guinea": "con-central-q2_oth",
        "Kenya": None,
        "Madagascar": "con-central-q2_oth",
        "Mali": "con-central-q2_oth",
        "Niger": "con-central-q2_oth",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q3": {
        "Burkina Faso": "con-central-q3",
        "Cameroon": "con-central-q3",
        "Côte d'Ivoire": "con-central-q3",
        "Guinea": "con-central-q3",
        "Kenya": None,
        "Madagascar": "con-central-q3",
        "Mali": "con-central-q3",
        "Niger": "con-central-q3",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q3_other": {
        "Burkina Faso": "con-central-q3_oth",
        "Cameroon": "con-central-q3_oth",
        "Côte d'Ivoire": "con-central-q3_oth",
        "Guinea": "con-central-q3_oth",
        "Kenya": None,
        "Madagascar": "con-central-q3_oth",
        "Mali": "con-central-q3_oth",
        "Niger": "con-central-q3_oth",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q4": {
        "Burkina Faso": "con-central-q4",
        "Cameroon": "con-central-q4",
        "Côte d'Ivoire": "con-central-q4",
        "Guinea": "con-central-q4",
        "Kenya": None,
        "Madagascar": "con-central-q4",
        "Mali": "con-central-q4",
        "Niger": "con-central-q4",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q5": {
        "Burkina Faso": "con-central-q5",
        "Cameroon": "con-central-q5",
        "Côte d'Ivoire": "con-central-q5",
        "Guinea": "con-central-q5",
        "Kenya": None,
        "Madagascar": "con-central-q5",
        "Mali": "con-central-q5",
        "Niger": "con-central-q5",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q5_other": {
        "Burkina Faso": "con-central-q5_oth",
        "Cameroon": "con-central-q5_oth",
        "Côte d'Ivoire": "con-central-q5_oth",
        "Guinea": "con-central-q5_oth",
        "Kenya": None,
        "Madagascar": "con-central-q5_oth",
        "Mali": "con-central-q5_oth",
        "Niger": "con-central-q5_oth",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q6": {
        "Burkina Faso": "con-central-q6",
        "Cameroon": "con-central-q6",
        "Côte d'Ivoire": "con-central-q6",
        "Guinea": "con-central-q6",
        "Kenya": None,
        "Madagascar": "con-central-q6",
        "Mali": "con-central-q6",
        "Niger": "con-central-q6",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q6_other": {
        "Burkina Faso": "con-central-q6_oth",
        "Cameroon": "con-central-q6_oth",
        "Côte d'Ivoire": "con-central-q6_oth",
        "Guinea": "con-central-q6_oth",
        "Kenya": None,
        "Madagascar": "con-central-q6_oth",
        "Mali": "con-central-q6_oth",
        "Niger": "con-central-q6_oth",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q7": {
        "Burkina Faso": "con-central-q7",
        "Cameroon": "con-central-q7",
        "Côte d'Ivoire": "con-central-q7",
        "Guinea": "con-central-q7",
        "Kenya": None,
        "Madagascar": "con-central-q7",
        "Mali": "con-central-q7",
        "Niger": "con-central-q7",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q7_other": {
        "Burkina Faso": "con-central-q7_oth",
        "Cameroon": "con-central-q7_oth",
        "Côte d'Ivoire": "con-central-q7_oth",
        "Guinea": "con-central-q7_oth",
        "Kenya": None,
        "Madagascar": "con-central-q7_oth",
        "Mali": "con-central-q7_oth",
        "Niger": "con-central-q7_oth",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q8": {
        "Burkina Faso": "con-central-q8",
        "Cameroon": "con-central-q8",
        "Côte d'Ivoire": "con-central-q8",
        "Guinea": "con-central-q8",
        "Kenya": None,
        "Madagascar": "con-central-q8",
        "Mali": "con-central-q8",
        "Niger": "con-central-q8",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q8a": {
        "Burkina Faso": "con-central-q8a",
        "Cameroon": "con-central-q8a",
        "Côte d'Ivoire": "con-central-q8a",
        "Guinea": "con-central-q8a",
        "Kenya": None,
        "Madagascar": "con-central-q8a",
        "Mali": "con-central-q8a",
        "Niger": "con-central-q8a",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q8b": {
        "Burkina Faso": "con-central-q8b",
        "Cameroon": "con-central-q8b",
        "Côte d'Ivoire": "con-central-q8b",
        "Guinea": "con-central-q8b",
        "Kenya": None,
        "Madagascar": "con-central-q8b",
        "Mali": "con-central-q8b",
        "Niger": "con-central-q8b",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q9": {
        "Burkina Faso": "con-central-q9",
        "Cameroon": "con-central-q9",
        "Côte d'Ivoire": "con-central-q9",
        "Guinea": "con-central-q9",
        "Kenya": None,
        "Madagascar": "con-central-q9",
        "Mali": "con-central-q9",
        "Niger": "con-central-q9",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q9a": {
        "Burkina Faso": "con-central-q9a",
        "Cameroon": "con-central-q9a",
        "Côte d'Ivoire": "con-central-q9a",
        "Guinea": "con-central-q9a",
        "Kenya": None,
        "Madagascar": "con-central-q9a",
        "Mali": "con-central-q9a",
        "Niger": "con-central-q9a",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q9b": {
        "Burkina Faso": "con-central-q9b",
        "Cameroon": "con-central-q9b",
        "Côte d'Ivoire": "con-central-q9b",
        "Guinea": "con-central-q9b",
        "Kenya": None,
        "Madagascar": "con-central-q9b",
        "Mali": "con-central-q9b",
        "Niger": "con-central-q9b",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q9_other": {
        "Burkina Faso": "con-central-q9_oth",
        "Cameroon": "con-central-q9_oth",
        "Côte d'Ivoire": "con-central-q9_oth",
        "Guinea": None,  # Not available in Guinea
        "Kenya": None,
        "Madagascar": "con-central-q9_oth",
        "Mali": "con-central-q9_oth",
        "Niger": "con-central-q9_oth",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q10": {
        "Burkina Faso": "con-central-q10",
        "Cameroon": "con-central-q10",
        "Côte d'Ivoire": "con-central-q10",
        "Guinea": "con-central-q10",
        "Kenya": None,
        "Madagascar": "con-central-q10",
        "Mali": "con-central-q10",
        "Niger": "con-central-q10",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q11": {
        "Burkina Faso": "con-central-q11",
        "Cameroon": "con-central-q11",
        "Côte d'Ivoire": "con-central-q11",
        "Guinea": "con-central-q11",
        "Kenya": None,
        "Madagascar": "con-central-q11",
        "Mali": "con-central-q11",
        "Niger": "con-central-q11",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q11_other": {
        "Burkina Faso": "con-central-q11_oth",
        "Cameroon": "con-central-q11_oth",
        "Côte d'Ivoire": "con-central-q11_oth",
        "Guinea": "con-central-q11_oth",
        "Kenya": None,
        "Madagascar": "con-central-q11_oth",
        "Mali": "con-central-q11_oth",
        "Niger": "con-central-q11_oth",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q12": {
        "Burkina Faso": "con-central-q12",
        "Cameroon": "con-central-q12",
        "Côte d'Ivoire": "con-central-q12",
        "Guinea": "con-central-q12",
        "Kenya": None,
        "Madagascar": "con-central-q12",
        "Mali": "con-central-q12",
        "Niger": "con-central-q12",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q13": {
        "Burkina Faso": "con-central-q13",
        "Cameroon": "con-central-q13",
        "Côte d'Ivoire": "con-central-q13",
        "Guinea": "con-central-q13",
        "Kenya": None,
        "Madagascar": "con-central-q13",
        "Mali": "con-central-q13",
        "Niger": "con-central-q13",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q14": {
        "Burkina Faso": "con-central-q14",
        "Cameroon": "con-central-q14",
        "Côte d'Ivoire": "con-central-q14",
        "Guinea": "con-central-q14",
        "Kenya": None,
        "Madagascar": "con-central-q14",
        "Mali": "con-central-q14",
        "Niger": "con-central-q14",
        "Nigeria": None,
        "RDC": None
    },
    
    "central_q15": {
        "Burkina Faso": None,  # Not available
        "Cameroon": "con-central-q15",
        "Côte d'Ivoire": "con-central-q15",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "con-central-q15",
        "Nigeria": None,
        "RDC": None
    },
    
    # All level questions (all 7 countries)
    "all_q50": {
        "Burkina Faso": "con-all-q50",
        "Cameroon": "con-all-q50",
        "Côte d'Ivoire": "con-all-q50",
        "Guinea": "con-all-q50",
        "Kenya": None,
        "Madagascar": "con-all-q50",
        "Mali": "con-all-q50",
        "Niger": "con-all-q50",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_q50a": {
        "Burkina Faso": "con-all-q50a",
        "Cameroon": "con-all-q50a",
        "Côte d'Ivoire": "con-all-q50a",
        "Guinea": "con-all-q50a",
        "Kenya": None,
        "Madagascar": "con-all-q50a",
        "Mali": "con-all-q50a",
        "Niger": "con-all-q50a",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_q51": {
        "Burkina Faso": "con-all-q51",
        "Cameroon": "con-all-q51",
        "Côte d'Ivoire": "con-all-q51",
        "Guinea": "con-all-q51",
        "Kenya": None,
        "Madagascar": "con-all-q51",
        "Mali": "con-all-q51",
        "Niger": "con-all-q51",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_q52": {
        "Burkina Faso": "con-all-q52",
        "Cameroon": "con-all-q52",
        "Côte d'Ivoire": "con-all-q52",
        "Guinea": "con-all-q52",
        "Kenya": None,
        "Madagascar": "con-all-q52",
        "Mali": "con-all-q52",
        "Niger": "con-all-q52",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_q53": {
        "Burkina Faso": "con-all-q53",
        "Cameroon": "con-all-q53",
        "Côte d'Ivoire": "con-all-q53",
        "Guinea": "con-all-q53",
        "Kenya": None,
        "Madagascar": "con-all-q53",
        "Mali": "con-all-q53",
        "Niger": "con-all-q53",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_q54": {
        "Burkina Faso": "con-all-q54",
        "Cameroon": "con-all-q54",
        "Côte d'Ivoire": "con-all-q54",
        "Guinea": "con-all-q54",
        "Kenya": None,
        "Madagascar": "con-all-q54",
        "Mali": "con-all-q54",
        "Niger": "con-all-q54",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_q54a": {
        "Burkina Faso": "con-all-q54a",
        "Cameroon": "con-all-q54a",
        "Côte d'Ivoire": "con-all-q54a",
        "Guinea": "con-all-q54a",
        "Kenya": None,
        "Madagascar": "con-all-q54a",
        "Mali": "con-all-q54a",
        "Niger": "con-all-q54a",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_q54b": {
        "Burkina Faso": "con-all-q54b",
        "Cameroon": "con-all-q54b",
        "Côte d'Ivoire": "con-all-q54b",
        "Guinea": "con-all-q54b",
        "Kenya": None,
        "Madagascar": "con-all-q54b",
        "Mali": "con-all-q54b",
        "Niger": "con-all-q54b",
        "Nigeria": None,
        "RDC": None
    },
    
    # District level questions (6 countries - excluding Guinea)
    "district_q30": {
        "Burkina Faso": None,  # Not available
        "Cameroon": "con-district_level-q30",
        "Côte d'Ivoire": "con-district_level-q30",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "con-district_level-q30",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q31": {
        "Burkina Faso": "con-district_level-q31",
        "Cameroon": "con-district_level-q31",
        "Côte d'Ivoire": "con-district_level-q31",
        "Guinea": "con-district-q31",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q31",
        "Mali": "con-district_level-q31",
        "Niger": "con-district_level-q31",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q32": {
        "Burkina Faso": "con-district_level-q32",
        "Cameroon": "con-district_level-q32",
        "Côte d'Ivoire": "con-district_level-q32",
        "Guinea": "con-district-q32",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q32",
        "Mali": "con-district_level-q32",
        "Niger": "con-district_level-q32",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q32_other": {
        "Burkina Faso": "con-district_level-q32_oth",
        "Cameroon": "con-district_level-q32_oth",
        "Côte d'Ivoire": "con-district_level-q32_oth",
        "Guinea": "con-district-q32_oth",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q32_oth",
        "Mali": "con-district_level-q32_oth",
        "Niger": "con-district_level-q32_oth",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q33": {
        "Burkina Faso": "con-district_level-q33",
        "Cameroon": "con-district_level-q33",
        "Côte d'Ivoire": "con-district_level-q33",
        "Guinea": "con-district-q33",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q33",
        "Mali": "con-district_level-q33",
        "Niger": "con-district_level-q33",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q34": {
        "Burkina Faso": "con-district_level-q34",
        "Cameroon": "con-district_level-q34",
        "Côte d'Ivoire": "con-district_level-q34",
        "Guinea": "con-district-q34",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q34",
        "Mali": "con-district_level-q34",
        "Niger": "con-district_level-q34",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q34a": {
        "Burkina Faso": "con-district_level-q34a",
        "Cameroon": "con-district_level-q34a",
        "Côte d'Ivoire": "con-district_level-q34a",
        "Guinea": "con-district-q34a",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q34a",
        "Mali": "con-district_level-q34a",
        "Niger": "con-district_level-q34a",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q34b": {
        "Burkina Faso": "con-district_level-q34b",
        "Cameroon": "con-district_level-q34b",
        "Côte d'Ivoire": "con-district_level-q34b",
        "Guinea": "con-district-q34b",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q34b",
        "Mali": "con-district_level-q34b",
        "Niger": "con-district_level-q34b",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q35": {
        "Burkina Faso": "con-district_level-q35",
        "Cameroon": "con-district_level-q35",
        "Côte d'Ivoire": "con-district_level-q35",
        "Guinea": "con-district-q35",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q35",
        "Mali": "con-district_level-q35",
        "Niger": "con-district_level-q35",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q35a": {
        "Burkina Faso": "con-district_level-q35a",
        "Cameroon": "con-district_level-q35a",
        "Côte d'Ivoire": "con-district_level-q35a",
        "Guinea": "con-district-q35a",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q35a",
        "Mali": "con-district_level-q35a",
        "Niger": "con-district_level-q35a",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q35a_other": {
        "Burkina Faso": "con-district_level-q35a_oth",
        "Cameroon": "con-district_level-q35a_oth",
        "Côte d'Ivoire": "con-district_level-q35a_oth",
        "Guinea": None,  # Not available in Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q35a_oth",
        "Mali": "con-district_level-q35a_oth",
        "Niger": "con-district_level-q35a_oth",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q36": {
        "Burkina Faso": "con-district_level-q36",
        "Cameroon": "con-district_level-q36",
        "Côte d'Ivoire": "con-district_level-q36",
        "Guinea": "con-district-q36",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q36",
        "Mali": "con-district_level-q36",
        "Niger": "con-district_level-q36",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q36a": {
        "Burkina Faso": "con-district_level-q36a",
        "Cameroon": "con-district_level-q36a",
        "Côte d'Ivoire": "con-district_level-q36a",
        "Guinea": "con-district-q36a",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q36a",
        "Mali": "con-district_level-q36a",
        "Niger": "con-district_level-q36a",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q36b": {
        "Burkina Faso": "con-district_level-q36b",
        "Cameroon": "con-district_level-q36b",
        "Côte d'Ivoire": "con-district_level-q36b",
        "Guinea": None,  # Not available in Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q36b",
        "Mali": "con-district_level-q36b",
        "Niger": "con-district_level-q36b",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q360": {
        "Burkina Faso": "con-district_level-q360",
        "Cameroon": "con-district_level-q360",
        "Côte d'Ivoire": "con-district_level-q360",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "con-district_level-q360",
        "Niger": "con-district_level-q360",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q37": {
        "Burkina Faso": "con-district_level-q37",
        "Cameroon": "con-district_level-q37",
        "Côte d'Ivoire": "con-district_level-q37",
        "Guinea": "con-district-q37",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q37",
        "Mali": "con-district_level-q37",
        "Niger": "con-district_level-q37",
        "Nigeria": None,
        "RDC": None
    },
    
    "district_q38": {
        "Burkina Faso": "con-district_level-q38",
        "Cameroon": "con-district_level-q38",
        "Côte d'Ivoire": "con-district_level-q38",
        "Guinea": "con-district-q38",  # Different pattern for Guinea
        "Kenya": None,
        "Madagascar": "con-district_level-q38",
        "Mali": "con-district_level-q38",
        "Niger": "con-district_level-q38",
        "Nigeria": None,
        "RDC": None
    },
    
    # Region level questions (5 countries - Burkina Faso, Cameroon, Guinea, Madagascar, Mali)
    "region_q21": {
        "Burkina Faso": "con-region_level-q21",
        "Cameroon": "con-region_level-q21",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q21",
        "Kenya": None,
        "Madagascar": "con-region_level-q21",
        "Mali": "con-region_level-q21",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q21_other": {
        "Burkina Faso": "con-region_level-q21_oth",
        "Cameroon": "con-region_level-q21_oth",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q21_oth",
        "Kenya": None,
        "Madagascar": "con-region_level-q21_oth",
        "Mali": "con-region_level-q21_oth",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q22": {
        "Burkina Faso": "con-region_level-q22",
        "Cameroon": "con-region_level-q22",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q22",
        "Kenya": None,
        "Madagascar": "con-region_level-q22",
        "Mali": "con-region_level-q22",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q23": {
        "Burkina Faso": "con-region_level-q23",
        "Cameroon": "con-region_level-q23",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q23",
        "Kenya": None,
        "Madagascar": "con-region_level-q23",
        "Mali": "con-region_level-q23",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q23a": {
        "Burkina Faso": "con-region_level-q23a",
        "Cameroon": "con-region_level-q23a",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q23a",
        "Kenya": None,
        "Madagascar": "con-region_level-q23a",
        "Mali": "con-region_level-q23a",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q23b": {
        "Burkina Faso": "con-region_level-q23b",
        "Cameroon": "con-region_level-q23b",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q23b",
        "Kenya": None,
        "Madagascar": "con-region_level-q23b",
        "Mali": "con-region_level-q23b",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q24": {
        "Burkina Faso": "con-region_level-q24",
        "Cameroon": "con-region_level-q24",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q24",
        "Kenya": None,
        "Madagascar": "con-region_level-q24",
        "Mali": "con-region_level-q24",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q24a": {
        "Burkina Faso": "con-region_level-q24a",
        "Cameroon": "con-region_level-q24a",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q24a",
        "Kenya": None,
        "Madagascar": "con-region_level-q24a",
        "Mali": "con-region_level-q24a",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q24a_other": {
        "Burkina Faso": "con-region_level-q24a_oth",
        "Cameroon": "con-region_level-q24a_oth",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": "con-region_level-q24a_oth",
        "Mali": "con-region_level-q24a_oth",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q25": {
        "Burkina Faso": "con-region_level-q25",
        "Cameroon": "con-region_level-q25",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q25",
        "Kenya": None,
        "Madagascar": "con-region_level-q25",
        "Mali": "con-region_level-q25",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q26": {
        "Burkina Faso": "con-region_level-q26",
        "Cameroon": "con-region_level-q26",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q26",
        "Kenya": None,
        "Madagascar": "con-region_level-q26",
        "Mali": "con-region_level-q26",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q26a": {
        "Burkina Faso": "con-region_level-q26a",
        "Cameroon": "con-region_level-q26a",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": "con-region_level-q26a",
        "Mali": "con-region_level-q26a",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q27": {
        "Burkina Faso": "con-region_level-q27",
        "Cameroon": "con-region_level-q27",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q27",
        "Kenya": None,
        "Madagascar": "con-region_level-q27",
        "Mali": "con-region_level-q27",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "region_q28": {
        "Burkina Faso": "con-region_level-q28",
        "Cameroon": "con-region_level-q28",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "con-region_level-q28",
        "Kenya": None,
        "Madagascar": "con-region_level-q28",
        "Mali": "con-region_level-q28",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    # Aire Sante level questions (5 countries - Burkina Faso, Côte d'Ivoire, Guinea, Madagascar, Mali)
    "aire_sante_q41": {
        "Burkina Faso": "con-aire_sante-q41",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q41",
        "Guinea": "con-aire_sante-q41",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q41",
        "Mali": "con-aire_sante-q41",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q42": {
        "Burkina Faso": "con-aire_sante-q42",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q42",
        "Guinea": "con-aire_sante-q42",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q42",
        "Mali": "con-aire_sante-q42",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q42_other": {
        "Burkina Faso": "con-aire_sante-q42_oth",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q42_oth",
        "Guinea": "con-aire_sante-q42_oth",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q42_oth",
        "Mali": "con-aire_sante-q42_oth",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q43": {
        "Burkina Faso": "con-aire_sante-q43",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q43",
        "Guinea": "con-aire_sante-q43",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q43",
        "Mali": "con-aire_sante-q43",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q43a": {
        "Burkina Faso": "con-aire_sante-q43a",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q43a",
        "Guinea": "con-aire_sante-q43a",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q43a",
        "Mali": "con-aire_sante-q43a",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q43b": {
        "Burkina Faso": "con-aire_sante-q43b",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q43b",
        "Guinea": "con-aire_sante-q43b",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q43b",
        "Mali": "con-aire_sante-q43b",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q44": {
        "Burkina Faso": "con-aire_sante-q44",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q44",
        "Guinea": "con-aire_sante-q44",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q44",
        "Mali": "con-aire_sante-q44",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q44a": {
        "Burkina Faso": "con-aire_sante-q44a",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q44a",
        "Guinea": "con-aire_sante-q44a",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q44a",
        "Mali": "con-aire_sante-q44a",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q45": {
        "Burkina Faso": "con-aire_sante-q45",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q45",
        "Guinea": "con-aire_sante-q45",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q45",
        "Mali": "con-aire_sante-q45",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q45a": {
        "Burkina Faso": "con-aire_sante-q45a",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q45a",
        "Guinea": "con-aire_sante-q45a",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q45a",
        "Mali": "con-aire_sante-q45a",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q45b": {
        "Burkina Faso": "con-aire_sante-q45b",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q45b",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": "con-aire_sante-q45b",
        "Mali": "con-aire_sante-q45b",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q46": {
        "Burkina Faso": "con-aire_sante-q46",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q46",
        "Guinea": "con-aire_sante-q46",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q46",
        "Mali": "con-aire_sante-q46",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q47": {
        "Burkina Faso": "con-aire_sante-q47",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "con-aire_sante-q47",
        "Guinea": "con-aire_sante-q47",
        "Kenya": None,
        "Madagascar": "con-aire_sante-q47",
        "Mali": "con-aire_sante-q47",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    # Additional Côte d'Ivoire specific questions
    "aire_sante_q91": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q91",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q92": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q92",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q93": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q93",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q94": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q94",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q94_autre": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q94_autre",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q95": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q95",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q96": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q96",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q97": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q97",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q98": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q98",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q99": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q99",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q99_autre": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q99_autre",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q910": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q910",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q910_autre": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q910_autre",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_sante_q911": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Côte d'Ivoire": "con-aire_sante-q911",
        "Guinea": None,
        "Kenya": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None,
        "Nigeria": None,
        "RDC": None
    },
    
    # Survey metadata fields (varying availability)
    "team_lead": {
        "Burkina Faso": "team_lead",
        "Cameroon": "team_lead",
        "Côte d'Ivoire": "team_lead",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": "team_lead",
        "Mali": "team_lead",
        "Niger": "team_lead",
        "Nigeria": None,
        "RDC": None
    },
    
    "signature": {
        "Burkina Faso": "signature",
        "Cameroon": "signature",
        "Côte d'Ivoire": "signature",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "signature",
        "Niger": "signature",
        "Nigeria": None,
        "RDC": None
    },
    
    "today": {
        "Burkina Faso": "today",
        "Cameroon": "today",
        "Côte d'Ivoire": "today",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "today",
        "Niger": "today",
        "Nigeria": None,
        "RDC": None
    },
    
    "cluster": {
        "Burkina Faso": "cluster",
        "Cameroon": "cluster",
        "Côte d'Ivoire": "cluster",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "cluster",
        "Niger": "cluster",
        "Nigeria": None,
        "RDC": None
    },
    
    "area": {
        "Burkina Faso": "area",
        "Cameroon": "area",
        "Côte d'Ivoire": "area",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "area",
        "Niger": "area",
        "Nigeria": None,
        "RDC": None
    },
    
    "commune": {
        "Burkina Faso": "commune",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "commune",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": "commune",
        "Mali": "commune",
        "Niger": "commune",
        "Nigeria": None,
        "RDC": None
    },
    
    "duration": {
        "Burkina Faso": "duration",
        "Cameroon": "duration",
        "Côte d'Ivoire": "duration",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "duration",
        "Niger": "duration",
        "Nigeria": None,
        "RDC": None
    },
    
    "enumerator": {
        "Burkina Faso": None,  # Not available
        "Cameroon": "enumerator",
        "Côte d'Ivoire": "enumerator",
        "Guinea": "enumerator",
        "Kenya": None,
        "Madagascar": "enumerator",
        "Mali": "enumerator",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "enumerator_name": {
        "Burkina Faso": None,  # Not available
        "Cameroon": "enumerator_name",
        "Côte d'Ivoire": "enumerator_name",
        "Guinea": "enumerator_name",
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "enumerator_name",
        "Niger": "enumerator_name",
        "Nigeria": None,
        "RDC": None
    },
    
    "device_info": {
        "Burkina Faso": "device_info",
        "Cameroon": "device_info",
        "Côte d'Ivoire": "device_info",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "device_info",
        "Niger": "device_info",
        "Nigeria": None,
        "RDC": None
    },
    
    "consent": {
        "Burkina Faso": "consent",
        "Cameroon": "consent",
        "Côte d'Ivoire": "consent",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "consent",
        "Niger": "consent",
        "Nigeria": None,
        "RDC": None
    },
    
    "interview_start_time": {
        "Burkina Faso": "heure_debut",
        "Cameroon": "heure_debut",
        "Côte d'Ivoire": "heure_debut",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "heure_debut",
        "Niger": "heure_debut",
        "Nigeria": None,
        "RDC": None
    },
    
    "reason_consent_no": {
        "Burkina Faso": "reason_consent_no",
        "Cameroon": "reason_consent_no",
        "Côte d'Ivoire": "reason_consent_no",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "reason_consent_no",
        "Niger": "reason_consent_no",
        "Nigeria": None,
        "RDC": None
    },
    
    "start_time": {
        "Burkina Faso": "start",
        "Cameroon": "start",
        "Côte d'Ivoire": "start",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "start",
        "Nigeria": None,
        "RDC": None
    },
    
    "end_time": {
        "Burkina Faso": "end",
        "Cameroon": "end",
        "Côte d'Ivoire": "end",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "end",
        "Nigeria": None,
        "RDC": None
    },
    
    "supervisor": {
        "Burkina Faso": "supervisor",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "supervisor",
        "Kenya": None,
        "Madagascar": "supervisor",
        "Mali": "supervisor",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "localite": {
        "Burkina Faso": "localite",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "localite",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "localite",
        "Niger": "localite",
        "Nigeria": None,
        "RDC": None
    },
    
    "meta_instance_id": {
        "Burkina Faso": "meta-instanceID",
        "Cameroon": "meta-instanceID",
        "Côte d'Ivoire": "meta-instanceID",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "meta-instanceID",
        "Nigeria": None,
        "RDC": None
    },
    
    "phone_number": {
        "Burkina Faso": "phonenumber",
        "Cameroon": "phonenumber",
        "Côte d'Ivoire": "phonenumber",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "phonenumber",
        "Nigeria": None,
        "RDC": None
    },
    
    "district": {
        "Burkina Faso": "district",
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "district",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": "district",
        "Mali": "district",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "device_id": {
        "Burkina Faso": "deviceid",
        "Cameroon": "deviceid",
        "Côte d'Ivoire": "deviceid",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "deviceid",
        "Nigeria": None,
        "RDC": None
    },
    
    "username": {
        "Burkina Faso": "username",
        "Cameroon": "username",
        "Côte d'Ivoire": "username",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "username",
        "Nigeria": None,
        "RDC": None
    },
    
    # All OK questions (4 countries - Burkina Faso, Cameroon, Côte d'Ivoire, Niger)
    "all_ok_q01": {
        "Burkina Faso": "con-all_ok-q01",
        "Cameroon": "con-all_ok-q01",
        "Côte d'Ivoire": "con-all_ok-q01",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "con-all_ok-q01",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_ok_q02": {
        "Burkina Faso": "con-all_ok-q02",
        "Cameroon": "con-all_ok-q02",
        "Côte d'Ivoire": "con-all_ok-q02",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "con-all_ok-q02",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_ok_q02_other": {
        "Burkina Faso": None,  # Not available
        "Cameroon": "con-all_ok-q02_oth",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "all_ok_q03": {
        "Burkina Faso": "con-all_ok-q03",
        "Cameroon": "con-all_ok-q03",
        "Côte d'Ivoire": "con-all_ok-q03",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "con-all_ok-q03",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_ok_q03_other": {
        "Burkina Faso": None,  # Not available
        "Cameroon": "con-all_ok-q03_oth",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "all_ok_q04": {
        "Burkina Faso": "con-all_ok-q04",
        "Cameroon": "con-all_ok-q04",
        "Côte d'Ivoire": "con-all_ok-q04",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "con-all_ok-q04",
        "Nigeria": None,
        "RDC": None
    },
    
    "all_ok_q04_other": {
        "Burkina Faso": None,  # Not available
        "Cameroon": "con-all_ok-q04_oth",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "aire_san": {
        "Burkina Faso": "aire_san",
        "Cameroon": "aire_san",
        "Côte d'Ivoire": "aire_san",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "aire_san",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "case_id": {
        "Burkina Faso": "caseid",
        "Cameroon": "caseid",
        "Côte d'Ivoire": "caseid",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "caseid",
        "Nigeria": None,
        "RDC": None
    },
    
    # Geographic divisions (country-specific)
    "departement": {
        "Burkina Faso": None,  # Not available
        "Cameroon": "departement",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "departement",
        "Nigeria": None,
        "RDC": None
    },
    
    "prefecture": {
        "Burkina Faso": None,  # Not available
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "prefecture",
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "cercle": {
        "Burkina Faso": None,  # Not available
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": "cercle",
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "sous_prefecture": {
        "Burkina Faso": None,  # Not available
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": None,  # Not available
        "Guinea": "sousprefecture",
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "census_enumerator": {
        "Burkina Faso": None,  # Not available
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "census_enumerator",
        "Nigeria": None,
        "RDC": None
    },
    
    "strate": {
        "Burkina Faso": None,  # Not available
        "Cameroon": "strate",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "arrondissement": {
        "Burkina Faso": None,  # Not available
        "Cameroon": "arrondissement",
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "zd": {
        "Burkina Faso": None,  # Not available
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "ZD",
        "Nigeria": None,
        "RDC": None
    },
    
    "enumerator_id": {
        "Burkina Faso": None,  # Not available
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "enumerator_id",
        "Nigeria": None,
        "RDC": None
    },
    
    "enquete": {
        "Burkina Faso": None,  # Not available
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "enquete",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    },
    
    "ea_name": {
        "Burkina Faso": None,  # Not available
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": None,  # Not available
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": "ea_name",
        "Nigeria": None,
        "RDC": None
    },
    
    "consentr": {
        "Burkina Faso": None,  # Not available
        "Cameroon": None,  # Not available
        "Côte d'Ivoire": "consentr",
        "Guinea": None,  # Not available
        "Kenya": None,
        "Madagascar": None,  # Not available
        "Mali": None,  # Not available
        "Niger": None,  # Not available
        "Nigeria": None,
        "RDC": None
    }
}

# %%
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth
from io import StringIO

# Configuration
SURVEYCTO_USERNAME = "camille@reliefapplications.org"
SURVEYCTO_PASSWORD = "HELENKELLER2025!"

# API endpoints for Minister Region District Main Form
# Note: Kenya, Nigeria, and RDC have no data available
MINISTER_REGION_DISTRICT_MAIN_ENDPOINTS = {
    "Burkina Faso": "https://keller2024.surveycto.com/api/v1/forms/data/csv/bf2024_pecs_minister_region_district_r2",
    "Cameroon": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gl2024_pecs_minister_region_district",
    "Côte d'Ivoire": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ci2024_pecs_minister_region_district_r2",
    "Guinea": "https://keller2024.surveycto.com/api/v1/forms/data/csv/gn2024_pecs_ministere_region_r1",
    "Madagascar": "https://keller2024.surveycto.com/api/v1/forms/data/csv/mg2024_pecs_ministere_region_district",
    "Mali": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ml2024_pecs_ministere_region_district",
    "Niger": "https://keller2024.surveycto.com/api/v1/forms/data/csv/ne2024_pecs_minister_region_district"
}

# Mapping dictionary for Minister Region District Main Form

def load_country_data(country, url):
    """Load data for a single country"""
    try:
        response = requests.get(url, auth=HTTPBasicAuth(SURVEYCTO_USERNAME, SURVEYCTO_PASSWORD))
        response.raise_for_status()
        data = pd.read_csv(StringIO(response.text), low_memory=False)
        
        # Add country column
        data['Country'] = country
        
        print(f"✓ {country}: {len(data)} rows loaded")
        return data
    
    except Exception as e:
        print(f"✗ {country}: Error - {str(e)}")
        return None

def harmonize_columns(data, country):
    """Apply MINISTER_REGION_DISTRICT_MAIN_MAPPING to harmonize column names"""
    harmonized_data = data.copy()
    
    # Create reverse mapping for this country
    column_mapping = {}
    for std_name, country_mapping in MINISTER_REGION_DISTRICT_MAIN_MAPPING.items():
        if country in country_mapping and country_mapping[country] is not None:
            original_col = country_mapping[country]
            if original_col in data.columns:
                column_mapping[original_col] = std_name
    
    # Rename columns
    harmonized_data = harmonized_data.rename(columns=column_mapping)
    
    print(f"  → {country}: {len(column_mapping)} columns harmonized")
    
    return harmonized_data

def create_minister_region_district_main_harmonized():
    """Create harmonized Minister Region District Main Form table"""
    
    print("CREATING MINISTER REGION DISTRICT MAIN FORM - HARMONIZED TABLE")
    print("=" * 63)
    
    all_country_data = []
    
    # Load data for each country
    for country, url in MINISTER_REGION_DISTRICT_MAIN_ENDPOINTS.items():
        print(f"Loading {country}...")
        
        # Load raw data
        raw_data = load_country_data(country, url)
        
        if raw_data is not None:
            # Apply harmonization mapping
            harmonized_data = harmonize_columns(raw_data, country)
            all_country_data.append(harmonized_data)
    
    if not all_country_data:
        print("No data loaded!")
        return None
    
    # Combine all countries
    print(f"\nCombining data from {len(all_country_data)} countries...")
    combined_data = pd.concat(all_country_data, ignore_index=True, sort=False)
    
    # Summary
    print(f"\n" + "=" * 63)
    print("MINISTER REGION DISTRICT MAIN FORM - HARMONIZED SUMMARY")
    print("=" * 63)
    print(f"Total rows: {len(combined_data):,}")
    print(f"Total columns: {len(combined_data.columns)}")
    print(f"Countries: {combined_data['Country'].nunique()}")
    
    # Show harmonized columns with country counts
    harmonized_cols = [col for col in MINISTER_REGION_DISTRICT_MAIN_MAPPING.keys() if col in combined_data.columns]
    print(f"Harmonized columns: {len(harmonized_cols)}")
    
    print(f"\nHarmonized columns with country coverage:")
    for col in sorted(harmonized_cols):
        # Count how many countries have this column in the mapping (exclude None values)
        country_count = len([c for c in MINISTER_REGION_DISTRICT_MAIN_MAPPING[col].values() if c is not None])
        # Check how many countries actually have data for this column
        actual_count = combined_data[col].notna().sum() if col in combined_data.columns else 0
        print(f"  {col:35} → {country_count} countries in mapping, {actual_count:6,} non-null values")
    
    print(f"\nSample harmonized columns: {harmonized_cols[:10]}")
    
    # Show country breakdown
    print(f"\nCountry breakdown:")
    country_counts = combined_data['Country'].value_counts().sort_index()
    for country, count in country_counts.items():
        print(f"  {country:15}: {count:6,} rows")
    
    # Special notes about data patterns
    print(f"\nData pattern notes:")
    print(f"  - Kenya, Nigeria, RDC: No data available")
    print(f"  - Cameroon: Uses 'gl' prefix instead of 'cm'")
    print(f"  - Guinea: Uses different field patterns for district questions")
    print(f"  - Multi-level survey: Central, District, Region, Aire Sante levels")
    print(f"  - GPS coordinates and timing data: Available in all 7 countries")
    print(f"  - Country-specific administrative divisions included")
    
    return combined_data

# Run the harmonization
if __name__ == "__main__":
    # Create harmonized table
    minister_region_district_main_combined = create_minister_region_district_main_harmonized()
    
    # Display sample data
    if minister_region_district_main_combined is not None:
        print(f"\n🎉 Table 14 (Minister Region District Main Form) is ready!")
        print(f"Shape: {minister_region_district_main_combined.shape}")
        
        print(f"\n" + "=" * 80)
        print("SAMPLE DATA (First 5 rows):")
        print("=" * 80)
        print(minister_region_district_main_combined.head())
        
        print(f"\n" + "=" * 50)
        print("COLUMN NAMES:")
        print("=" * 50)
        print(f"Total columns: {len(minister_region_district_main_combined.columns)}")
        print("Column list:")
        for i, col in enumerate(minister_region_district_main_combined.columns, 1):
            print(f"  {i:3d}. {col}")
# Out:
# CREATING MINISTER REGION DISTRICT MAIN FORM - HARMONIZED TABLE
# ...
# Loading Burkina Faso...
# ✓ Burkina Faso: 28 rows loaded
#   → Burkina Faso: 116 columns harmonized
# Loading Cameroon...
# ✓ Cameroon: 87 rows loaded
#   → Cameroon: 109 columns harmonized
# Loading Côte d'Ivoire...
# ✓ Côte d'Ivoire: 101 rows loaded
#   → Côte d'Ivoire: 121 columns harmonized
# Loading Guinea...
# ✓ Guinea: 38 rows loaded
#   → Guinea: 88 columns harmonized
# Loading Madagascar...
# ✓ Madagascar: 65 rows loaded
#   → Madagascar: 94 columns harmonized
# Loading Mali...
# ✓ Mali: 129 rows loaded
#   → Mali: 108 columns harmonized
# Loading Niger...
# ✓ Niger: 43 rows loaded
#   → Niger: 94 columns harmonized
#
# Combining data from 7 countries...
#
# ...
# MINISTER REGION DISTRICT MAIN FORM - HARMONIZED SUMMARY
# ...
# Total rows: 491
# Total columns: 150
# Countries: 7
# Harmonized columns: 149
#
# Harmonized columns with country coverage:
# ...

# %% [markdown]
# ## Dropping the non-harmonized columns

# %%
import pandas as pd

def drop_non_harmonized_columns(df, mapping_dict):
    """
    Drop non-harmonized columns from a dataframe, keeping only harmonized columns + Country column
    
    Parameters:
    df (pd.DataFrame): The dataframe to clean
    mapping_dict (dict): The mapping dictionary used for harmonization
    
    Returns:
    pd.DataFrame: Dataframe with only harmonized columns + Country column
    """
    if df is None or df.empty:
        return df
    
    # Get all harmonized column names from the mapping dictionary
    harmonized_columns = list(mapping_dict.keys())
    
    # Add 'Country' column to keep (this was added during harmonization)
    columns_to_keep = ['Country'] + harmonized_columns
    
    # Find which columns actually exist in the dataframe
    existing_columns = [col for col in columns_to_keep if col in df.columns]
    
    # Keep only the harmonized columns that exist
    cleaned_df = df[existing_columns].copy()
    
    dropped_count = len(df.columns) - len(existing_columns)
    print(f"Dropped {dropped_count} non-harmonized columns. Kept {len(existing_columns)} columns.")
    
    return cleaned_df

def clean_all_dataframes(dataframes_and_mappings):
    """
    Clean multiple dataframes at once
    
    Parameters:
    dataframes_and_mappings (list): List of tuples [(df_name, df, mapping_dict), ...]
    
    Returns:
    dict: Dictionary of cleaned dataframes {df_name: cleaned_df}
    """
    cleaned_dataframes = {}
    
    print("Cleaning all dataframes...")
    print("=" * 50)
    
    for df_name, df, mapping_dict in dataframes_and_mappings:
        print(f"\nCleaning {df_name}:")
        cleaned_df = drop_non_harmonized_columns(df, mapping_dict)
        cleaned_dataframes[df_name] = cleaned_df
        
        if cleaned_df is not None:
            print(f"  Original shape: {df.shape}")
            print(f"  Cleaned shape:  {cleaned_df.shape}")
    
    print(f"\n🎉 All {len(cleaned_dataframes)} dataframes cleaned!")
    return cleaned_dataframes

# Example usage for your 14 dataframes:
if __name__ == "__main__":
    # Single dataframe example:
    # cleaned_df = drop_non_harmonized_columns(your_dataframe, YOUR_MAPPING_DICT)
    
    # Multiple dataframes example:
    dataframes_to_clean = [
        # Format: (name, dataframe, mapping_dictionary)
        ("Census Main", census_main_combined, CENSUS_MAIN_FORM_MAPPING),
        ("Census Menage", census_menage_combined, CENSUS_MENAGE_MAPPING),
        ("Census Random Draws", census_random_draws_combined, CENSUS_RANDOM_DRAWS_MAPPING),
        ("Census HH Rep", census_hh_rep_combined, CENSUS_HH_REP_MAPPING),
        ("Household Main", household_main_combined, HOUSEHOLD_MAIN_MAPPING),
        ("Household Mothers", household_mothers_combined, HOUSEHOLD_MOTHERS_REPEAT_MAPPING),
        ("Household Children", household_children_combined, HOUSEHOLD_CHILDREN_REPEAT_MAPPING),
        ("Household Group8b", household_group8b_combined, HOUSEHOLD_GROUP8B_MAPPING),
        ("Household Group8c", household_group8c_combined, HOUSEHOLD_GROUP8C_MAPPING),
        ("Quality Control Main", quality_control_main_combined, QUALITY_CONTROL_MAIN_MAPPING),
        ("Quality Control Mothers", quality_control_mothers_combined, QUALITY_CONTROL_MOTHERS_MAPPING),
        ("Quality Control Children", quality_control_children_combined, QUALITY_CONTROL_CHILDREN_MAPPING),
        ("Health Workers Main", health_workers_main_combined, HEALTH_WORKERS_MAIN_MAPPING),
        ("Minister Region District", minister_region_district_main_combined, MINISTER_REGION_DISTRICT_MAIN_MAPPING),
    ]
    
    # Clean all dataframes
    cleaned_dfs = clean_all_dataframes(dataframes_to_clean)
    
    # Access cleaned dataframes
    # census_main_clean = cleaned_dfs["Census Main"]
    # household_main_clean = cleaned_dfs["Household Main"]
    # etc...
# Out:
# Cleaning all dataframes...
# ...
#
# Cleaning Census Main:
# Dropped 0 non-harmonized columns. Kept 109 columns.
#   Original shape: (4363, 109)
#   Cleaned shape:  (4363, 109)
#
# Cleaning Census Menage:
# Dropped 0 non-harmonized columns. Kept 39 columns.
#   Original shape: (280683, 39)
#   Cleaned shape:  (280683, 39)
#
# Cleaning Census Random Draws:
# Dropped 0 non-harmonized columns. Kept 6 columns.
#   Original shape: (27128, 6)
#   Cleaned shape:  (27128, 6)
#
# Cleaning Census HH Rep:
# Dropped 0 non-harmonized columns. Kept 11 columns.
#   Original shape: (15277, 11)
#   Cleaned shape:  (15277, 11)
#
# Cleaning Household Main:
# Dropped 302 non-harmonized columns. Kept 208 columns.
#   Original shape: (17728, 510)
#   Cleaned shape:  (17728, 208)
#
# Cleaning Household Mothers:
# Dropped 282 non-harmonized columns. Kept 104 columns.
#   Original shape: (19751, 386)
#   Cleaned shape:  (19751, 104)
#
# Cleaning Household Children:
# ...

# %% [markdown]
# ## Load data to sharepoint

# %%
import pandas as pd
from io import BytesIO
import datetime
from office365.runtime.auth.user_credential import UserCredential
from office365.sharepoint.client_context import ClientContext
import time
import csv

# SharePoint Configuration
sharepoint_username = "rAssaf@HKI.org"
sharepoint_password = "R@ch^2627"
sharepoint_site_url = "https://hkw.sharepoint.com/teams/PBI_MER_Data"
sharepoint_folder_name = "PECS_Harmonized_Data"

# Your dataframes using the actual variable names
def get_dataframe_safely(df_var, name):
    """Safely get dataframe and handle potential errors"""
    try:
        if df_var is not None and not df_var.empty:
            return df_var
        else:
            print(f"⚠️ {name}: DataFrame is None or empty")
            return None
    except NameError:
        print(f"❌ {name}: Variable not found")
        return None
    except Exception as e:
        print(f"❌ {name}: Error accessing dataframe - {str(e)}")
        return None

# Map your actual dataframes
upload_dfs = {
    "Census_Main": get_dataframe_safely(census_main_combined, "Census Main"),
    "Census_Menage": get_dataframe_safely(census_menage_combined, "Census Menage"),
    "Census_Random_Draws": get_dataframe_safely(census_random_draws_combined, "Census Random Draws"),
    "Census_HH_Rep": get_dataframe_safely(census_hh_rep_combined, "Census HH Rep"),
    "Household_Main": get_dataframe_safely(household_main_combined, "Household Main"),
    "Household_Mothers": get_dataframe_safely(household_mothers_combined, "Household Mothers"),
    "Household_Children": get_dataframe_safely(household_children_combined, "Household Children"),
    "Household_Group8b": get_dataframe_safely(household_group8b_combined, "Household Group8b"),
    "Household_Group8c": get_dataframe_safely(household_group8c_combined, "Household Group8c"),
    "Quality_Control_Main": get_dataframe_safely(quality_control_main_combined, "Quality Control Main"),
    "Quality_Control_Mothers": get_dataframe_safely(quality_control_mothers_combined, "Quality Control Mothers"),
    "Quality_Control_Children": get_dataframe_safely(quality_control_children_combined, "Quality Control Children"),
    "Health_Workers_Main": get_dataframe_safely(health_workers_main_combined, "Health Workers Main"),
    "Minister_Region_District": get_dataframe_safely(minister_region_district_main_combined, "Minister Region District")
}

# Filter out None values
upload_dfs = {k: v for k, v in upload_dfs.items() if v is not None}

print(f"📊 Found {len(upload_dfs)} dataframes ready for upload:")
for name, df in upload_dfs.items():
    if df is not None and not df.empty:
        print(f"  ✅ {name}: {df.shape[0]:,} rows × {df.shape[1]} columns")
    else:
        print(f"  ⚠️ {name}: Empty or None")
print()

def test_sharepoint_connection():
    """Test SharePoint connection and explore site structure"""
    try:
        print("🔍 Testing SharePoint connection...")
        
        # Connect to SharePoint
        ctx = ClientContext(sharepoint_site_url).with_credentials(
            UserCredential(sharepoint_username, sharepoint_password)
        )
        
        # Test connection by getting site info
        web = ctx.web
        ctx.load(web)
        ctx.execute_query()
        print(f"✅ Connected to site: {web.title}")
        
        # List all document libraries
        print("📚 Available document libraries:")
        lists = ctx.web.lists
        ctx.load(lists)
        ctx.execute_query()
        
        doc_libraries = []
        for lst in lists:
            if lst.base_type == 1:  # Document library
                doc_libraries.append(lst.title)
                print(f"  - {lst.title}")
        
        return doc_libraries
        
    except Exception as e:
        print(f"❌ Connection failed: {str(e)}")
        return None

def upload_to_sharepoint(file_content, filename, doc_lib_name="Documents"):
    """Upload file to SharePoint with multiple library options"""
    library_names = [doc_lib_name, "Shared Documents", "Documents", "Shared%20Documents"]
    
    for lib_name in library_names:
        try:
            print(f"  📤 Trying library '{lib_name}' for {filename}...")
            
            # Connect to SharePoint
            ctx = ClientContext(sharepoint_site_url).with_credentials(
                UserCredential(sharepoint_username, sharepoint_password)
            )
            
            # Get document library
            doc_lib = ctx.web.lists.get_by_title(lib_name)
            ctx.load(doc_lib)
            ctx.execute_query()
            
            root_folder = doc_lib.root_folder
            ctx.load(root_folder)
            ctx.execute_query()
            
            # Create or access folder
            try:
                target_folder = root_folder.folders.get_by_url(sharepoint_folder_name)
                ctx.load(target_folder)
                ctx.execute_query()
            except:
                target_folder = root_folder.folders.add(sharepoint_folder_name)
                ctx.execute_query()
                print(f"  📁 Created folder: {sharepoint_folder_name}")
            
            # Delete existing file (refresh functionality)
            try:
                existing_file = target_folder.files.get_by_url(filename)
                existing_file.delete_object()
                ctx.execute_query()
                print(f"  🗑️ Deleted existing {filename}")
            except:
                pass
            
            # Upload new file
            target_folder.upload_file(filename, file_content)
            ctx.execute_query()
            print(f"  ✅ Successfully uploaded {filename} to '{lib_name}'")
            return True
            
        except Exception as e:
            print(f"  ⚠️ Failed with library '{lib_name}': {str(e)}")
            continue
    
    print(f"  ❌ Failed to upload {filename} to any library")
    return False

def upload_direct_to_folder():
    """Alternative upload method using direct folder access"""
    try:
        print("🔄 Trying alternative upload method...")
        
        ctx = ClientContext(sharepoint_site_url).with_credentials(
            UserCredential(sharepoint_username, sharepoint_password)
        )
        
        # Try to access the web and get folder by server relative URL
        web = ctx.web
        ctx.load(web)
        ctx.execute_query()
        
        # Get the default document library folder
        default_folder = web.get_folder_by_server_relative_url(f"{web.server_relative_url}/Shared Documents")
        ctx.load(default_folder)
        ctx.execute_query()
        
        print("✅ Found default document library")
        return True
        
    except Exception as e:
        print(f"❌ Alternative method failed: {str(e)}")
        return False

def upload_with_retry(file_content, filename, max_retries=3):
    """Upload with retry mechanism"""
    for attempt in range(max_retries):
        print(f"  🔄 Upload attempt {attempt + 1}/{max_retries}")
        
        if upload_to_sharepoint(file_content, filename):
            return True
        
        if attempt < max_retries - 1:
            print(f"  ⏳ Waiting 5 seconds before retry...")
            time.sleep(5)
    
    return False

def main():
    """Upload all PECS datasets to SharePoint with improved error handling"""
    print("🚀 UPLOADING PECS DATA TO SHAREPOINT")
    print("=" * 50)
    print("📝 Using QUOTE_ALL to handle commas in datetime fields for Power BI compatibility")
    print()
    
    # Test connection first
    available_libraries = test_sharepoint_connection()
    if available_libraries is None:
        print("❌ Cannot connect to SharePoint. Please check:")
        print("   - Site URL is correct")
        print("   - Username and password are valid")
        print("   - You have access to the site")
        return
    
    # Test alternative method
    upload_direct_to_folder()
    
    successful = 0
    failed = 0
    
    for name, df in upload_dfs.items():
        if df is None or df.empty:
            print(f"⏭️ Skipping {name} (empty dataframe)")
            continue
            
        print(f"\n📊 Processing {name}")
        print(f"   Shape: {df.shape[0]:,} rows × {df.shape[1]} columns")
        
        # Add timestamp
        df_with_timestamp = df.copy()
        df_with_timestamp['Last_Updated'] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        
        # Convert to CSV with all fields quoted to handle commas in datetime columns
        filename = f"{name}.csv"
        csv_buffer = BytesIO()
        df_with_timestamp.to_csv(csv_buffer, index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
        csv_buffer.seek(0)
        
        # Upload to SharePoint with retry
        if upload_with_retry(csv_buffer.getvalue(), filename):
            successful += 1
        else:
            failed += 1
    
    # Summary
    print(f"\n" + "=" * 50)
    print(f"📊 UPLOAD SUMMARY")
    print(f"✅ Successful: {successful}")
    print(f"❌ Failed: {failed}")
    print(f"📁 SharePoint folder: {sharepoint_folder_name}")
    
    if successful > 0:
        print(f"\n🎉 Successfully uploaded {successful} datasets!")
        print(f"\n💡 Power BI Import Note:")
        print(f"   All fields are quoted to handle commas in datetime values")
        print(f"   Power BI should automatically detect and import correctly")
    elif failed > 0:
        print(f"\n💡 TROUBLESHOOTING TIPS:")
        print(f"   1. Verify the SharePoint site URL: {sharepoint_site_url}")
        print(f"   2. Check if you have upload permissions")
        print(f"   3. Try accessing the site manually in a browser")
        print(f"   4. The site might use a different document library name")

# Alternative simple upload function for testing
def simple_upload_test():
    """Simple test to upload a small file"""
    print("🧪 Running simple upload test...")
    
    try:
        # Create a simple test CSV
        test_df = pd.DataFrame({
            'test_column': ['test_value'],
            'timestamp': [datetime.datetime.now()]
        })
        
        csv_buffer = BytesIO()
        test_df.to_csv(csv_buffer, index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
        csv_buffer.seek(0)
        
        # Try upload
        ctx = ClientContext(sharepoint_site_url).with_credentials(
            UserCredential(sharepoint_username, sharepoint_password)
        )
        
        # Try different approaches
        approaches = [
            ("Shared Documents", lambda: ctx.web.lists.get_by_title("Shared Documents")),
            ("Documents", lambda: ctx.web.lists.get_by_title("Documents")),
            ("Default Library", lambda: ctx.web.default_document_library())
        ]
        
        for name, get_lib in approaches:
            try:
                print(f"  Testing {name}...")
                doc_lib = get_lib()
                ctx.load(doc_lib)
                ctx.execute_query()
                
                root_folder = doc_lib.root_folder
                root_folder.upload_file("test_upload.csv", csv_buffer.getvalue())
                ctx.execute_query()
                
                print(f"  ✅ Test upload successful with {name}!")
                return True
                
            except Exception as e:
                print(f"  ❌ {name} failed: {str(e)}")
                continue
        
        return False
        
    except Exception as e:
        print(f"❌ Test upload failed: {str(e)}")
        return False

if __name__ == "__main__":
    # Run simple test first
    if simple_upload_test():
        print("\n" + "=" * 50)
        main()
    else:
        print("\n❌ Simple test failed. Please check your SharePoint configuration.")
# Out:
# 📊 Found 14 dataframes ready for upload:
#   ✅ Census_Main: 4,363 rows × 109 columns
#   ✅ Census_Menage: 280,683 rows × 39 columns
#   ✅ Census_Random_Draws: 27,128 rows × 6 columns
#   ✅ Census_HH_Rep: 15,277 rows × 11 columns
#   ✅ Household_Main: 17,728 rows × 510 columns
#   ✅ Household_Mothers: 19,751 rows × 386 columns
#   ✅ Household_Children: 24,968 rows × 217 columns
#   ✅ Household_Group8b: 13,903 rows × 75 columns
#   ✅ Household_Group8c: 19,925 rows × 69 columns
#   ✅ Quality_Control_Main: 2,585 rows × 432 columns
#   ✅ Quality_Control_Mothers: 2,528 rows × 158 columns
#   ✅ Quality_Control_Children: 3,173 rows × 302 columns
#   ✅ Health_Workers_Main: 1,333 rows × 249 columns
#   ✅ Minister_Region_District: 491 rows × 150 columns
#
# 🧪 Running simple upload test...
#   Testing Shared Documents...
# ...

# %%
import pandas as pd
from io import BytesIO
import datetime
from office365.runtime.auth.user_credential import UserCredential
from office365.sharepoint.client_context import ClientContext
import time
import numpy as np

# SharePoint Configuration (same as your existing setup)
sharepoint_username = "rAssaf@HKI.org"
sharepoint_password = "R@ch^2627"
sharepoint_site_url = "https://hkw.sharepoint.com/teams/PBI_MER_Data"
sharepoint_folder_name = "PECS_Harmonized_Data"

# National Statistics file paths
national_stats_files = {
    'Burkina Faso': {
        'path': 'Shared Documents/PECS 2024/Burkina Fasso_2024_PECS_Tirage_Cluster.xlsx',
        'format': 'xlsx'
    },
    'Cameroon': {
        'path': 'Shared Documents/PECS 2024/CAMEROUN_2024_PECS_tirage_ZD.xlsx',
        'format': 'xlsx'
    },
    'Guinea': {
        'path': 'Shared Documents/PECS 2024/Guinea_2024_PECS_tirage_ZD.xlsx',
        'format': 'xlsx'
    },
    'Madagascar': {
        'path': 'Shared Documents/PECS 2024/Madagascar_2024_PECS_tirage_ZD.xlsx',
        'format': 'xlsx'
    },
    'Mali': {
        'path': 'Shared Documents/PECS 2024/Mali_2024_PECS_tirage_ZD.xlsx',
        'format': 'xlsx'
    },
    'Niger': {
        'path': 'Shared Documents/PECS 2024/Niger_2024_echantillon_pecs.xlsx',
        'format': 'xlsx'
    }
}

# Harmonization mapping (your NATIONAL_STATISTICS_MAPPING)
NATIONAL_STATISTICS_MAPPING = {
    # Geographic Identifiers - Region Level
    "region_code": {
        "Burkina Faso": "CODE_REGION",
        "Cameroon": "Geographical unit",
        "Guinea": "region",
        "Madagascar": "CODEREG", 
        "Mali": "REG_NEW",
        "Niger": "CodeRegion"
    },
    
    "region_name": {
        "Burkina Faso": "REGION",
        "Cameroon": "Region",
        "Guinea": "Regnad",
        "Madagascar": "REGION",
        "Mali": "LREG_NEW",
        "Niger": "Region"
    },
    
    # Province/Department Level
    "province_department_code": {
        "Burkina Faso": "CODE_PROVINCE",
        "Cameroon": None,
        "Guinea": "prefecture", 
        "Madagascar": "CODEDIST",
        "Mali": "CER2009",
        "Niger": "CodeDepartement"
    },
    
    "province_department_name": {
        "Burkina Faso": "PROVINCE",
        "Cameroon": "Departemen",
        "Guinea": "Prefecture",
        "Madagascar": "DISTRICT", 
        "Mali": "LCER2009",
        "Niger": "Departement"
    },
    
    # Commune/Arrondissement Level
    "commune_arrondissement_code": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Guinea": "sousprefecture",
        "Madagascar": "CODECOM",
        "Mali": "COM2009",
        "Niger": "CodeCommune"
    },
    
    "commune_arrondissement_name": {
        "Burkina Faso": "COMMUNE",
        "Cameroon": "Arrondisse",
        "Guinea": "S_Prefecture",
        "Madagascar": "COMMUNEARRONDISSEMENT",
        "Mali": "LCOM2009",
        "Niger": "Commune"
    },
    
    # Village/Sector Level
    "village_sector": {
        "Burkina Faso": "VILLAGE/SECTEUR",
        "Cameroon": None,
        "Guinea": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None
    },
    
    # Enumeration Area/Zone
    "enumeration_zone_code": {
        "Burkina Faso": "CODE_ZD",
        "Cameroon": "ZD",
        "Guinea": "ZD_Finale",
        "Madagascar": "numero_zd2",
        "Mali": "NumeroSE",
        "Niger": "zone"
    },
    
    "cluster_grappe": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Guinea": "cluster",
        "Madagascar": None,
        "Mali": "GRAPPE",
        "Niger": None
    },
    
    # Urban/Rural Classification
    "milieu_code": {
        "Burkina Faso": "MILIEU(1=URBAIN, 2=RURAL)",
        "Cameroon": "Milieu",
        "Guinea": "Code_Mil",
        "Madagascar": "MILIEU",
        "Mali": "MILIEU_NEW",
        "Niger": None
    },
    
    "milieu_description": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Guinea": "Milres",
        "Madagascar": None,
        "Mali": None,
        "Niger": None
    },
    
    # Population and Household Counts
    "household_count": {
        "Burkina Faso": "NOMBRE MENAG",
        "Cameroon": "Menage_E",
        "Guinea": "Menage_Finale",
        "Madagascar": "Menage",
        "Mali": "Nb_Menage",
        "Niger": None
    },
    
    "population_count": {
        "Burkina Faso": "POPULATION",
        "Cameroon": "Pop_E", 
        "Guinea": "Pop_Finale",
        "Madagascar": "Population",
        "Mali": "PopSE",
        "Niger": None
    },
    
    # Sampling and Stratification
    "strata_code": {
        "Burkina Faso": "STRATE",
        "Cameroon": None,
        "Guinea": "Strate",
        "Madagascar": None,
        "Mali": "Strate",
        "Niger": None
    },
    
    "strata_name": {
        "Burkina Faso": "NOM_STRATE",
        "Cameroon": None,
        "Guinea": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None
    },
    
    # Sampling Weights
    "inclusion_probability": {
        "Burkina Faso": "InclusionProbability_1_",
        "Cameroon": None,
        "Guinea": None,
        "Madagascar": None,
        "Mali": "InclusionProbability_1_",
        "Niger": None
    },
    
    "sample_weight": {
        "Burkina Faso": "SampleWeight_1_",
        "Cameroon": None,
        "Guinea": None,
        "Madagascar": None,
        "Mali": "SampleWeight_1_", 
        "Niger": None
    },
    
    "sample_weight_final": {
        "Burkina Faso": "SampleWeight_Final_",
        "Cameroon": None,
        "Guinea": None,
        "Madagascar": None,
        "Mali": "SampleWeight_Final_",
        "Niger": None
    },
    
    # Survey Management
    "draw_tirage": {
        "Burkina Faso": None,
        "Cameroon": "Tirage",
        "Guinea": None,
        "Madagascar": None,
        "Mali": "TYPE_GRAPPE",
        "Niger": None
    }
}

def load_sharepoint_excel_file(file_path, file_format):
    """Load Excel file from SharePoint using office365 library"""
    try:
        ctx = ClientContext(sharepoint_site_url).with_credentials(
            UserCredential(sharepoint_username, sharepoint_password)
        )
        
        # Method 1: Try with download buffer
        try:
            file_url = f"/teams/PBI_MER_Data/{file_path}"
            file_obj = ctx.web.get_file_by_server_relative_url(file_url)
            
            download_buffer = BytesIO()
            file_obj.download(download_buffer)
            ctx.execute_query()
            
            download_buffer.seek(0)
            
            if file_format == 'xlsx':
                df = pd.read_excel(download_buffer)
            elif file_format == 'xls':
                df = pd.read_excel(download_buffer, engine='xlrd')
            else:
                df = pd.read_excel(download_buffer)
            
            return df
            
        except Exception as e1:
            print(f"  ⚠️ Method 1 failed: {e1}")
            
        # Method 2: Alternative approach
        try:
            file_url = f"/teams/PBI_MER_Data/{file_path}"
            file_obj = ctx.web.get_file_by_server_relative_url(file_url)
            ctx.load(file_obj)
            ctx.execute_query()
            
            file_content = file_obj.get_content()
            ctx.execute_query()
            
            if file_format == 'xlsx':
                df = pd.read_excel(BytesIO(file_content.value))
            elif file_format == 'xls':
                df = pd.read_excel(BytesIO(file_content.value), engine='xlrd')
            else:
                df = pd.read_excel(BytesIO(file_content.value))
            
            return df
            
        except Exception as e2:
            print(f"  ⚠️ Method 2 failed: {e2}")
            return None
        
    except Exception as e:
        print(f"  ❌ General error: {e}")
        return None

def harmonize_country_data(df, country):
    """Apply harmonization mapping to a country's dataframe"""
    harmonized_df = pd.DataFrame()
    
    # Apply mapping for each harmonized field first
    for harmonized_field, country_mapping in NATIONAL_STATISTICS_MAPPING.items():
        original_column = country_mapping.get(country)
        
        if original_column and original_column in df.columns:
            harmonized_df[harmonized_field] = df[original_column].values
        else:
            # Add empty column for missing fields
            harmonized_df[harmonized_field] = pd.NA
    
    # Now add country identifier - ensuring proper length
    if len(harmonized_df) > 0:
        harmonized_df['Country'] = country
    else:
        # If no harmonized fields, create dataframe with original length
        harmonized_df = pd.DataFrame(index=range(len(df)))
        harmonized_df['Country'] = country
        
        # Add all mapping fields as empty
        for harmonized_field in NATIONAL_STATISTICS_MAPPING.keys():
            harmonized_df[harmonized_field] = pd.NA
    
    # Add processing date
    harmonized_df['Processing_Date'] = datetime.datetime.now().strftime('%Y-%m-%d')
    
    return harmonized_df

def load_all_national_stats():
    """Load all National Statistics files from SharePoint"""
    print("🔍 Loading National Statistics files from SharePoint...")
    
    country_dataframes = {}
    
    for country, file_info in national_stats_files.items():
        print(f"\n📂 Loading {country}...")
        
        df = load_sharepoint_excel_file(file_info['path'], file_info['format'])
        
        if df is not None:
            print(f"  ✅ Loaded: {df.shape[0]} rows × {df.shape[1]} columns")
            country_dataframes[country] = df
        else:
            print(f"  ❌ Failed to load {country}")
    
    return country_dataframes

def create_harmonized_dataset():
    """Create harmonized National Statistics dataset"""
    print("🔄 Starting National Statistics harmonization...")
    
    # Load all country data
    country_dataframes = load_all_national_stats()
    
    if not country_dataframes:
        print("❌ No data loaded - cannot proceed with harmonization")
        return None
    
    print(f"\n📊 Successfully loaded data from {len(country_dataframes)} countries")
    
    # Harmonize each country's data
    harmonized_datasets = []
    
    for country, df in country_dataframes.items():
        print(f"\n🔄 Harmonizing {country}...")
        
        harmonized_df = harmonize_country_data(df, country)
        
        # Ensure we have data
        if not harmonized_df.empty:
            harmonized_datasets.append(harmonized_df)
            print(f"  ✅ Harmonized: {harmonized_df.shape[0]} rows × {harmonized_df.shape[1]} columns")
        else:
            print(f"  ⚠️ No data after harmonization for {country}")
    
    # Combine all harmonized datasets
    if harmonized_datasets:
        print(f"\n🔗 Combining data from all countries...")
        combined_df = pd.concat(harmonized_datasets, ignore_index=True, sort=False)
        
        # Add final timestamp
        combined_df['Last_Updated'] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        
        print(f"✅ Final harmonized dataset: {combined_df.shape[0]} rows × {combined_df.shape[1]} columns")
        return combined_df
    else:
        print("❌ No harmonized datasets to combine")
        return None

def upload_to_sharepoint(file_content, filename, doc_lib_name="Documents"):
    """Upload file to SharePoint (same as your existing function)"""
    library_names = [doc_lib_name, "Shared Documents", "Documents", "Shared%20Documents"]
    
    for lib_name in library_names:
        try:
            print(f"  📤 Trying library '{lib_name}' for {filename}...")
            
            ctx = ClientContext(sharepoint_site_url).with_credentials(
                UserCredential(sharepoint_username, sharepoint_password)
            )
            
            doc_lib = ctx.web.lists.get_by_title(lib_name)
            ctx.load(doc_lib)
            ctx.execute_query()
            
            root_folder = doc_lib.root_folder
            ctx.load(root_folder)
            ctx.execute_query()
            
            # Create or access folder
            try:
                target_folder = root_folder.folders.get_by_url(sharepoint_folder_name)
                ctx.load(target_folder)
                ctx.execute_query()
            except:
                target_folder = root_folder.folders.add(sharepoint_folder_name)
                ctx.execute_query()
                print(f"  📁 Created folder: {sharepoint_folder_name}")
            
            # Delete existing file
            try:
                existing_file = target_folder.files.get_by_url(filename)
                existing_file.delete_object()
                ctx.execute_query()
                print(f"  🗑️ Deleted existing {filename}")
            except:
                pass
            
            # Upload new file
            target_folder.upload_file(filename, file_content)
            ctx.execute_query()
            print(f"  ✅ Successfully uploaded {filename} to '{lib_name}'")
            return True
            
        except Exception as e:
            print(f"  ⚠️ Failed with library '{lib_name}': {str(e)}")
            continue
    
    print(f"  ❌ Failed to upload {filename} to any library")
    return False

def upload_with_retry(file_content, filename, max_retries=3):
    """Upload with retry mechanism"""
    for attempt in range(max_retries):
        print(f"  🔄 Upload attempt {attempt + 1}/{max_retries}")
        
        if upload_to_sharepoint(file_content, filename):
            return True
        
        if attempt < max_retries - 1:
            print(f"  ⏳ Waiting 5 seconds before retry...")
            time.sleep(5)
    
    return False

def test_sharepoint_connection():
    """Test SharePoint connection"""
    try:
        print("🔍 Testing SharePoint connection...")
        
        ctx = ClientContext(sharepoint_site_url).with_credentials(
            UserCredential(sharepoint_username, sharepoint_password)
        )
        
        web = ctx.web
        ctx.load(web)
        ctx.execute_query()
        print(f"✅ Connected to site: {web.title}")
        return True
        
    except Exception as e:
        print(f"❌ Connection failed: {str(e)}")
        return False

def generate_summary_report(harmonized_df):
    """Generate summary report of harmonized data"""
    print("\n" + "="*60)
    print("📊 HARMONIZATION SUMMARY REPORT")
    print("="*60)
    
    # Overall statistics
    print(f"Total Records: {len(harmonized_df):,}")
    
    # Check if Country column has valid data
    if 'Country' in harmonized_df.columns:
        countries = harmonized_df['Country'].dropna().unique()
        if len(countries) > 0:
            print(f"Total Countries: {len(countries)}")
            print(f"Countries: {', '.join(sorted(countries))}")
            
            # Records per country
            print(f"\n📈 Records per Country:")
            country_counts = harmonized_df['Country'].value_counts().sort_index()
            for country, count in country_counts.items():
                print(f"  {country}: {count:,} records")
        else:
            print("⚠️ No valid country data found")
            country_counts = pd.Series()
    else:
        print("⚠️ Country column not found")
        country_counts = pd.Series()
    
    # Data completeness for key fields
    print(f"\n📋 Data Completeness (key fields):")
    key_fields = ['region_name', 'enumeration_zone_code', 'household_count']
    for field in key_fields:
        if field in harmonized_df.columns:
            non_null_count = harmonized_df[field].notna().sum()
            completeness = (non_null_count / len(harmonized_df)) * 100
            print(f"  {field}: {completeness:.1f}% complete")
    
    return country_counts

def main():
    """Main harmonization and upload process"""
    print("🚀 NATIONAL STATISTICS HARMONIZATION")
    print("=" * 60)
    
    # Test connection
    if not test_sharepoint_connection():
        print("❌ Cannot proceed without SharePoint connection")
        return None
    
    # Create harmonized dataset
    harmonized_df = create_harmonized_dataset()
    
    if harmonized_df is None or harmonized_df.empty:
        print("❌ Harmonization failed")
        return None
    
    # Generate summary report
    generate_summary_report(harmonized_df)
    
    # Upload to SharePoint
    print(f"\n📤 Uploading harmonized dataset to SharePoint...")
    
    filename = "National_Statistics_Harmonized.csv"
    csv_buffer = BytesIO()
    harmonized_df.to_csv(csv_buffer, index=False, encoding='utf-8')
    csv_buffer.seek(0)
    
    if upload_with_retry(csv_buffer.getvalue(), filename):
        print(f"\n🎉 SUCCESS! Harmonized National Statistics uploaded to SharePoint")
        print(f"📁 Location: {sharepoint_folder_name}/{filename}")
        print(f"📊 Dataset: {len(harmonized_df):,} records")
    else:
        print(f"\n❌ Upload failed - but harmonization was successful")
    
    return harmonized_df

if __name__ == "__main__":
    # Run the harmonization
    harmonized_data = main()
# Out:
# 🚀 NATIONAL STATISTICS HARMONIZATION
# ...
# 🔍 Testing SharePoint connection...
# ✅ Connected to site: PBI_MER_Data
# 🔄 Starting National Statistics harmonization...
# 🔍 Loading National Statistics files from SharePoint...
#
# 📂 Loading Burkina Faso...
#   ✅ Loaded: 110 rows × 23 columns
#
# 📂 Loading Cameroon...
#   ✅ Loaded: 10 rows × 9 columns
#
# 📂 Loading Guinea...
#   ✅ Loaded: 115 rows × 13 columns
#
# 📂 Loading Madagascar...
#   ✅ Loaded: 115 rows × 10 columns
#
# 📂 Loading Mali...
#   ✅ Loaded: 127 rows × 33 columns
#
# 📂 Loading Niger...
#   ✅ Loaded: 266 rows × 8 columns
#
# 📊 Successfully loaded data from 6 countries
#
# 🔄 Harmonizing Burkina Faso...
#   ✅ Harmonized: 110 rows × 21 columns
#
# 🔄 Harmonizing Cameroon...
#   ✅ Harmonized: 10 rows × 21 columns
#
# 🔄 Harmonizing Guinea...
#   ✅ Harmonized: 115 rows × 21 columns
#
# 🔄 Harmonizing Madagascar...
#   ✅ Harmonized: 115 rows × 21 columns
#
# 🔄 Harmonizing Mali...
#   ✅ Harmonized: 127 rows × 21 columns
#
# ...

# %%
# Analyze why enumeration_zone_code is not unique
import pandas as pd

def analyze_enumeration_zones(df):
    """
    Analyze the structure of enumeration zones to understand duplication
    """
    
    print("🔍 ANALYZING ENUMERATION ZONE STRUCTURE")
    print("=" * 50)
    
    # Check overall uniqueness
    total_rows = len(df)
    unique_ez = df['enumeration_zone_code'].nunique()
    print(f"Total rows: {total_rows}")
    print(f"Unique enumeration zones: {unique_ez}")
    print(f"Average rows per enumeration zone: {total_rows/unique_ez:.2f}")
    print()
    
    # Check uniqueness by country
    print("📊 By Country:")
    country_analysis = df.groupby('Country').agg({
        'enumeration_zone_code': ['count', 'nunique']
    })
    country_analysis.columns = ['Total_Rows', 'Unique_EZ']
    country_analysis['Rows_Per_EZ'] = country_analysis['Total_Rows'] / country_analysis['Unique_EZ']
    print(country_analysis)
    print()
    
    # Find what makes rows unique
    print("🔑 Checking potential composite keys:")
    
    # Test different combinations
    key_combinations = [
        ['Country', 'enumeration_zone_code'],
        ['Country', 'enumeration_zone_code', 'village_sector'],
        ['Country', 'enumeration_zone_code', 'cluster_grappe'],
        ['Country', 'enumeration_zone_code', 'draw_tirage'],
        ['Country', 'enumeration_zone_code', 'village_sector', 'draw_tirage']
    ]
    
    for keys in key_combinations:
        unique_count = df[keys].drop_duplicates().shape[0]
        print(f"  {' + '.join(keys)}: {unique_count} unique combinations")
        if unique_count == total_rows:
            print(f"    ✅ This combination is UNIQUE!")
    print()
    
    # Sample duplicate enumeration zones
    print("📋 Sample of duplicate enumeration zones:")
    duplicated_ez = df[df.duplicated(subset=['Country', 'enumeration_zone_code'], keep=False)]
    
    if not duplicated_ez.empty:
        # Take first enumeration zone with duplicates
        sample_country = duplicated_ez['Country'].iloc[0]
        sample_ez = duplicated_ez['enumeration_zone_code'].iloc[0]
        
        sample_data = df[(df['Country'] == sample_country) & 
                        (df['enumeration_zone_code'] == sample_ez)]
        
        print(f"\nExample: Country={sample_country}, EZ={sample_ez}")
        print(f"Number of rows: {len(sample_data)}")
        
        # Show what varies
        varying_cols = []
        for col in sample_data.columns:
            if sample_data[col].nunique() > 1:
                varying_cols.append(col)
                
        print(f"Columns that vary: {varying_cols}")
        
        # Display sample
        display_cols = ['village_sector', 'cluster_grappe', 'draw_tirage', 
                       'household_count', 'population_count']
        display_cols = [col for col in display_cols if col in sample_data.columns]
        print("\nSample rows:")
        print(sample_data[display_cols].head())
    
    return duplicated_ez

# Run analysis
duplicates_analysis = analyze_enumeration_zones(harmonized_data)

# Recommendation based on analysis
print("\n💡 RECOMMENDATION:")
print("Based on the analysis above, choose the appropriate connection strategy:")
print("- If villages within EZ: Aggregate to EZ level or use composite key with village")
print("- If multiple draws: Use composite key with draw_tirage")
print("- If both: Consider the business logic - what level should connect to Census?")
# Out:
# 🔍 ANALYZING ENUMERATION ZONE STRUCTURE
# ...
# Total rows: 743
# Unique enumeration zones: 402
# Average rows per enumeration zone: 1.85
#
# 📊 By Country:
#               Total_Rows  Unique_EZ  Rows_Per_EZ
# Country
# Burkina Faso         109        109     1.000000
# Cameroon               9          8     1.125000
# Guinea               115         58     1.982759
# Madagascar           115        115     1.000000
# Mali                 127         77     1.649351
# Niger                266        266     1.000000
#
# 🔑 Checking potential composite keys:
#   Country + enumeration_zone_code: 635 unique combinations
#   Country + enumeration_zone_code + village_sector: 635 unique combinations
#   Country + enumeration_zone_code + cluster_grappe: 691 unique combinations
#   Country + enumeration_zone_code + draw_tirage: 643 unique combinations
#   Country + enumeration_zone_code + village_sector + draw_tirage: 643 unique combinations
#
# 📋 Sample of duplicate enumeration zones:
#
# ...

# %%
import pandas as pd
from io import BytesIO
import datetime
from office365.runtime.auth.user_credential import UserCredential
from office365.sharepoint.client_context import ClientContext
import time
import numpy as np
import csv  # Add this import for QUOTE_ALL

# SharePoint Configuration (same as your existing setup)
sharepoint_username = "rAssaf@HKI.org"
sharepoint_password = "R@ch^2627"
sharepoint_site_url = "https://hkw.sharepoint.com/teams/PBI_MER_Data"
sharepoint_folder_name = "PECS_Harmonized_Data"

# National Statistics file paths
national_stats_files = {
    'Burkina Faso': {
        'path': 'Shared Documents/PECS 2024/Burkina Fasso_2024_PECS_Tirage_Cluster.xlsx',
        'format': 'xlsx'
    },
    'Cameroon': {
        'path': 'Shared Documents/PECS 2024/CAMEROUN_2024_PECS_tirage_ZD.xlsx',
        'format': 'xlsx'
    },
    'Guinea': {
        'path': 'Shared Documents/PECS 2024/Guinea_2024_PECS_tirage_ZD.xlsx',
        'format': 'xlsx'
    },
    'Madagascar': {
        'path': 'Shared Documents/PECS 2024/Madagascar_2024_PECS_tirage_ZD.xlsx',
        'format': 'xlsx'
    },
    'Mali': {
        'path': 'Shared Documents/PECS 2024/Mali_2024_PECS_tirage_ZD.xlsx',
        'format': 'xlsx'
    },
    'Niger': {
        'path': 'Shared Documents/PECS 2024/Niger_2024_echantillon_pecs.xlsx',
        'format': 'xlsx'
    }
}

# Harmonization mapping (your NATIONAL_STATISTICS_MAPPING)
NATIONAL_STATISTICS_MAPPING = {
    # Geographic Identifiers - Region Level
    "region_code": {
        "Burkina Faso": "CODE_REGION",
        "Cameroon": "Geographical unit",
        "Guinea": "region",
        "Madagascar": "CODEREG", 
        "Mali": "REG_NEW",
        "Niger": "CodeRegion"
    },
    
    "region_name": {
        "Burkina Faso": "REGION",
        "Cameroon": "Region",
        "Guinea": "Regnad",
        "Madagascar": "REGION",
        "Mali": "LREG_NEW",
        "Niger": "Region"
    },
    
    # Province/Department Level
    "province_department_code": {
        "Burkina Faso": "CODE_PROVINCE",
        "Cameroon": None,
        "Guinea": "prefecture", 
        "Madagascar": "CODEDIST",
        "Mali": "CER2009",
        "Niger": "CodeDepartement"
    },
    
    "province_department_name": {
        "Burkina Faso": "PROVINCE",
        "Cameroon": "Departemen",
        "Guinea": "Prefecture",
        "Madagascar": "DISTRICT", 
        "Mali": "LCER2009",
        "Niger": "Departement"
    },
    
    # Commune/Arrondissement Level
    "commune_arrondissement_code": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Guinea": "sousprefecture",
        "Madagascar": "CODECOM",
        "Mali": "COM2009",
        "Niger": "CodeCommune"
    },
    
    "commune_arrondissement_name": {
        "Burkina Faso": "COMMUNE",
        "Cameroon": "Arrondisse",
        "Guinea": "S_Prefecture",
        "Madagascar": "COMMUNEARRONDISSEMENT",
        "Mali": "LCOM2009",
        "Niger": "Commune"
    },
    
    # Village/Sector Level
    "village_sector": {
        "Burkina Faso": "VILLAGE/SECTEUR",
        "Cameroon": None,
        "Guinea": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None
    },
    
    # Enumeration Area/Zone
    "enumeration_zone_code": {
        "Burkina Faso": "CODE_ZD",
        "Cameroon": "ZD",
        "Guinea": "ZD_Finale",
        "Madagascar": "numero_zd2",
        "Mali": "NumeroSE",
        "Niger": "zone"
    },
    
    "cluster_grappe": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Guinea": "cluster",
        "Madagascar": None,
        "Mali": "GRAPPE",
        "Niger": None
    },
    
    # Urban/Rural Classification
    "milieu_code": {
        "Burkina Faso": "MILIEU(1=URBAIN, 2=RURAL)",
        "Cameroon": "Milieu",
        "Guinea": "Code_Mil",
        "Madagascar": "MILIEU",
        "Mali": "MILIEU_NEW",
        "Niger": None
    },
    
    "milieu_description": {
        "Burkina Faso": None,
        "Cameroon": None,
        "Guinea": "Milres",
        "Madagascar": None,
        "Mali": None,
        "Niger": None
    },
    
    # Population and Household Counts
    "household_count": {
        "Burkina Faso": "NOMBRE MENAG",
        "Cameroon": "Menage_E",
        "Guinea": "Menage_Finale",
        "Madagascar": "Menage",
        "Mali": "Nb_Menage",
        "Niger": None
    },
    
    "population_count": {
        "Burkina Faso": "POPULATION",
        "Cameroon": "Pop_E", 
        "Guinea": "Pop_Finale",
        "Madagascar": "Population",
        "Mali": "PopSE",
        "Niger": None
    },
    
    # Sampling and Stratification
    "strata_code": {
        "Burkina Faso": "STRATE",
        "Cameroon": None,
        "Guinea": "Strate",
        "Madagascar": None,
        "Mali": "Strate",
        "Niger": None
    },
    
    "strata_name": {
        "Burkina Faso": "NOM_STRATE",
        "Cameroon": None,
        "Guinea": None,
        "Madagascar": None,
        "Mali": None,
        "Niger": None
    },
    
    # Sampling Weights
    "inclusion_probability": {
        "Burkina Faso": "InclusionProbability_1_",
        "Cameroon": None,
        "Guinea": None,
        "Madagascar": None,
        "Mali": "InclusionProbability_1_",
        "Niger": None
    },
    
    "sample_weight": {
        "Burkina Faso": "SampleWeight_1_",
        "Cameroon": None,
        "Guinea": None,
        "Madagascar": None,
        "Mali": "SampleWeight_1_", 
        "Niger": None
    },
    
    "sample_weight_final": {
        "Burkina Faso": "SampleWeight_Final_",
        "Cameroon": None,
        "Guinea": None,
        "Madagascar": None,
        "Mali": "SampleWeight_Final_",
        "Niger": None
    },
    
    # Survey Management
    "draw_tirage": {
        "Burkina Faso": None,
        "Cameroon": "Tirage",
        "Guinea": None,
        "Madagascar": None,
        "Mali": "TYPE_GRAPPE",
        "Niger": None
    }
}

def load_sharepoint_excel_file(file_path, file_format):
    """Load Excel file from SharePoint using office365 library"""
    try:
        ctx = ClientContext(sharepoint_site_url).with_credentials(
            UserCredential(sharepoint_username, sharepoint_password)
        )
        
        # Method 1: Try with download buffer
        try:
            file_url = f"/teams/PBI_MER_Data/{file_path}"
            file_obj = ctx.web.get_file_by_server_relative_url(file_url)
            
            download_buffer = BytesIO()
            file_obj.download(download_buffer)
            ctx.execute_query()
            
            download_buffer.seek(0)
            
            if file_format == 'xlsx':
                df = pd.read_excel(download_buffer)
            elif file_format == 'xls':
                df = pd.read_excel(download_buffer, engine='xlrd')
            else:
                df = pd.read_excel(download_buffer)
            
            return df
            
        except Exception as e1:
            print(f"  ⚠️ Method 1 failed: {e1}")
            
        # Method 2: Alternative approach
        try:
            file_url = f"/teams/PBI_MER_Data/{file_path}"
            file_obj = ctx.web.get_file_by_server_relative_url(file_url)
            ctx.load(file_obj)
            ctx.execute_query()
            
            file_content = file_obj.get_content()
            ctx.execute_query()
            
            if file_format == 'xlsx':
                df = pd.read_excel(BytesIO(file_content.value))
            elif file_format == 'xls':
                df = pd.read_excel(BytesIO(file_content.value), engine='xlrd')
            else:
                df = pd.read_excel(BytesIO(file_content.value))
            
            return df
            
        except Exception as e2:
            print(f"  ⚠️ Method 2 failed: {e2}")
            return None
        
    except Exception as e:
        print(f"  ❌ General error: {e}")
        return None

def harmonize_country_data(df, country):
    """Apply harmonization mapping to a country's dataframe"""
    harmonized_df = pd.DataFrame()
    
    # Apply mapping for each harmonized field first
    for harmonized_field, country_mapping in NATIONAL_STATISTICS_MAPPING.items():
        original_column = country_mapping.get(country)
        
        if original_column and original_column in df.columns:
            harmonized_df[harmonized_field] = df[original_column].values
        else:
            # Add empty column for missing fields
            harmonized_df[harmonized_field] = pd.NA
    
    # Now add country identifier - ensuring proper length
    if len(harmonized_df) > 0:
        harmonized_df['Country'] = country
    else:
        # If no harmonized fields, create dataframe with original length
        harmonized_df = pd.DataFrame(index=range(len(df)))
        harmonized_df['Country'] = country
        
        # Add all mapping fields as empty
        for harmonized_field in NATIONAL_STATISTICS_MAPPING.keys():
            harmonized_df[harmonized_field] = pd.NA
    
    # Add processing date
    harmonized_df['Processing_Date'] = datetime.datetime.now().strftime('%Y-%m-%d')
    
    return harmonized_df

def load_all_national_stats():
    """Load all National Statistics files from SharePoint"""
    print("🔍 Loading National Statistics files from SharePoint...")
    
    country_dataframes = {}
    
    for country, file_info in national_stats_files.items():
        print(f"\n📂 Loading {country}...")
        
        df = load_sharepoint_excel_file(file_info['path'], file_info['format'])
        
        if df is not None:
            print(f"  ✅ Loaded: {df.shape[0]} rows × {df.shape[1]} columns")
            country_dataframes[country] = df
        else:
            print(f"  ❌ Failed to load {country}")
    
    return country_dataframes

def create_harmonized_dataset():
    """Create harmonized National Statistics dataset"""
    print("🔄 Starting National Statistics harmonization...")
    
    # Load all country data
    country_dataframes = load_all_national_stats()
    
    if not country_dataframes:
        print("❌ No data loaded - cannot proceed with harmonization")
        return None
    
    print(f"\n📊 Successfully loaded data from {len(country_dataframes)} countries")
    
    # Harmonize each country's data
    harmonized_datasets = []
    
    for country, df in country_dataframes.items():
        print(f"\n🔄 Harmonizing {country}...")
        
        harmonized_df = harmonize_country_data(df, country)
        
        # Ensure we have data
        if not harmonized_df.empty:
            harmonized_datasets.append(harmonized_df)
            print(f"  ✅ Harmonized: {harmonized_df.shape[0]} rows × {harmonized_df.shape[1]} columns")
        else:
            print(f"  ⚠️ No data after harmonization for {country}")
    
    # Combine all harmonized datasets
    if harmonized_datasets:
        print(f"\n🔗 Combining data from all countries...")
        combined_df = pd.concat(harmonized_datasets, ignore_index=True, sort=False)
        
        # Add final timestamp
        combined_df['Last_Updated'] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        
        print(f"✅ Final harmonized dataset: {combined_df.shape[0]} rows × {combined_df.shape[1]} columns")
        return combined_df
    else:
        print("❌ No harmonized datasets to combine")
        return None

def upload_to_sharepoint(file_content, filename, doc_lib_name="Documents"):
    """Upload file to SharePoint (same as your existing function)"""
    library_names = [doc_lib_name, "Shared Documents", "Documents", "Shared%20Documents"]
    
    for lib_name in library_names:
        try:
            print(f"  📤 Trying library '{lib_name}' for {filename}...")
            
            ctx = ClientContext(sharepoint_site_url).with_credentials(
                UserCredential(sharepoint_username, sharepoint_password)
            )
            
            doc_lib = ctx.web.lists.get_by_title(lib_name)
            ctx.load(doc_lib)
            ctx.execute_query()
            
            root_folder = doc_lib.root_folder
            ctx.load(root_folder)
            ctx.execute_query()
            
            # Create or access folder
            try:
                target_folder = root_folder.folders.get_by_url(sharepoint_folder_name)
                ctx.load(target_folder)
                ctx.execute_query()
            except:
                target_folder = root_folder.folders.add(sharepoint_folder_name)
                ctx.execute_query()
                print(f"  📁 Created folder: {sharepoint_folder_name}")
            
            # Delete existing file
            try:
                existing_file = target_folder.files.get_by_url(filename)
                existing_file.delete_object()
                ctx.execute_query()
                print(f"  🗑️ Deleted existing {filename}")
            except:
                pass
            
            # Upload new file
            target_folder.upload_file(filename, file_content)
            ctx.execute_query()
            print(f"  ✅ Successfully uploaded {filename} to '{lib_name}'")
            return True
            
        except Exception as e:
            print(f"  ⚠️ Failed with library '{lib_name}': {str(e)}")
            continue
    
    print(f"  ❌ Failed to upload {filename} to any library")
    return False

def upload_with_retry(file_content, filename, max_retries=3):
    """Upload with retry mechanism"""
    for attempt in range(max_retries):
        print(f"  🔄 Upload attempt {attempt + 1}/{max_retries}")
        
        if upload_to_sharepoint(file_content, filename):
            return True
        
        if attempt < max_retries - 1:
            print(f"  ⏳ Waiting 5 seconds before retry...")
            time.sleep(5)
    
    return False

def test_sharepoint_connection():
    """Test SharePoint connection"""
    try:
        print("🔍 Testing SharePoint connection...")
        
        ctx = ClientContext(sharepoint_site_url).with_credentials(
            UserCredential(sharepoint_username, sharepoint_password)
        )
        
        web = ctx.web
        ctx.load(web)
        ctx.execute_query()
        print(f"✅ Connected to site: {web.title}")
        return True
        
    except Exception as e:
        print(f"❌ Connection failed: {str(e)}")
        return False

def generate_summary_report(harmonized_df):
    """Generate summary report of harmonized data"""
    print("\n" + "="*60)
    print("📊 HARMONIZATION SUMMARY REPORT")
    print("="*60)
    
    # Overall statistics
    print(f"Total Records: {len(harmonized_df):,}")
    
    # Check if Country column has valid data
    if 'Country' in harmonized_df.columns:
        countries = harmonized_df['Country'].dropna().unique()
        if len(countries) > 0:
            print(f"Total Countries: {len(countries)}")
            print(f"Countries: {', '.join(sorted(countries))}")
            
            # Records per country
            print(f"\n📈 Records per Country:")
            country_counts = harmonized_df['Country'].value_counts().sort_index()
            for country, count in country_counts.items():
                print(f"  {country}: {count:,} records")
        else:
            print("⚠️ No valid country data found")
            country_counts = pd.Series()
    else:
        print("⚠️ Country column not found")
        country_counts = pd.Series()
    
    # Data completeness for key fields
    print(f"\n📋 Data Completeness (key fields):")
    key_fields = ['region_name', 'enumeration_zone_code', 'household_count']
    for field in key_fields:
        if field in harmonized_df.columns:
            non_null_count = harmonized_df[field].notna().sum()
            completeness = (non_null_count / len(harmonized_df)) * 100
            print(f"  {field}: {completeness:.1f}% complete")
    
    return country_counts

# NEW FUNCTION: Aggregate to Enumeration Zone Level
def aggregate_to_ez_level(df):
    """
    Aggregate National Statistics to enumeration zone level to solve duplicate issue
    """
    print("\n" + "="*60)
    print("🔧 AGGREGATING TO ENUMERATION ZONE LEVEL")
    print("="*60)
    
    # Define aggregation rules
    agg_rules = {
        # Geographic fields - take first (should be same within EZ)
        'region_code': 'first',
        'region_name': 'first',
        'province_department_code': 'first',
        'province_department_name': 'first',
        'commune_arrondissement_code': 'first',
        'commune_arrondissement_name': 'first',
        'milieu_code': 'first',
        'milieu_description': 'first',
        'strata_code': 'first',
        'strata_name': 'first',
        'cluster_grappe': 'first',
        
        # Sum population counts across draws
        'household_count': 'sum',
        'population_count': 'sum',
        
        # Average weights
        'inclusion_probability': 'mean',
        'sample_weight': 'mean',
        'sample_weight_final': 'mean',
        
        # Concatenate varying fields
        'village_sector': lambda x: '|'.join([str(v) for v in x.dropna().unique()]),
        'draw_tirage': lambda x: '|'.join([str(v) for v in x.dropna().unique()])
    }
    
    # Check current duplication status
    total_rows_before = len(df)
    unique_ez_before = df[['Country', 'enumeration_zone_code']].drop_duplicates().shape[0]
    
    print(f"Before aggregation:")
    print(f"  Total rows: {total_rows_before}")
    print(f"  Unique Country + EZ combinations: {unique_ez_before}")
    
    # Perform aggregation
    print("\n🔄 Aggregating data...")
    aggregated = df.groupby(['Country', 'enumeration_zone_code']).agg(agg_rules).reset_index()
    
    # Add metadata columns
    aggregated['Aggregation_Level'] = 'Enumeration_Zone'
    aggregated['Number_of_Draws'] = df.groupby(['Country', 'enumeration_zone_code'])['draw_tirage'].nunique().values
    aggregated['Processing_Date'] = pd.Timestamp.now().strftime('%Y-%m-%d')
    aggregated['Last_Updated'] = pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')
    
    # Summary
    print(f"\nAfter aggregation:")
    print(f"  Total rows: {len(aggregated)}")
    print(f"  Rows removed: {total_rows_before - len(aggregated)}")
    
    # Show countries with multiple draws
    multi_draw = aggregated[aggregated['Number_of_Draws'] > 1]
    if not multi_draw.empty:
        print(f"\n📍 Countries with multiple draws per EZ:")
        for country in multi_draw['Country'].unique():
            country_data = multi_draw[multi_draw['Country'] == country]
            print(f"  {country}: {len(country_data)} zones with multiple draws")
    
    # Verify uniqueness
    unique_check = aggregated[['Country', 'enumeration_zone_code']].drop_duplicates()
    if len(unique_check) == len(aggregated):
        print("\n✅ SUCCESS: Each enumeration zone is now unique!")
    else:
        print("\n⚠️ WARNING: Still have duplicates after aggregation")
    
    return aggregated

def main():
    """Main harmonization and upload process"""
    print("🚀 NATIONAL STATISTICS HARMONIZATION")
    print("=" * 60)
    
    # Test connection
    if not test_sharepoint_connection():
        print("❌ Cannot proceed without SharePoint connection")
        return None
    
    # Create harmonized dataset
    harmonized_df = create_harmonized_dataset()
    
    if harmonized_df is None or harmonized_df.empty:
        print("❌ Harmonization failed")
        return None
    
    # Generate summary report
    generate_summary_report(harmonized_df)
    
    # Upload original harmonized dataset
    print(f"\n📤 Uploading harmonized dataset to SharePoint...")
    
    filename = "National_Statistics_Harmonized.csv"
    csv_buffer = BytesIO()
    harmonized_df.to_csv(csv_buffer, index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
    csv_buffer.seek(0)
    
    if upload_with_retry(csv_buffer.getvalue(), filename):
        print(f"\n✅ Harmonized National Statistics uploaded")
        print(f"📁 Location: {sharepoint_folder_name}/{filename}")
        print(f"📊 Dataset: {len(harmonized_df):,} records")
    else:
        print(f"\n❌ Upload failed - but harmonization was successful")
    
    # NEW: Create and upload EZ-level aggregated version
    aggregated_df = aggregate_to_ez_level(harmonized_df)
    
    print(f"\n📤 Uploading EZ-level aggregated dataset to SharePoint...")
    
    filename_ez = "National_Statistics_EZ_Level.csv"
    csv_buffer_ez = BytesIO()
    aggregated_df.to_csv(csv_buffer_ez, index=False, encoding='utf-8', quoting=csv.QUOTE_ALL)
    csv_buffer_ez.seek(0)
    
    if upload_with_retry(csv_buffer_ez.getvalue(), filename_ez):
        print(f"\n✅ EZ-level aggregated dataset uploaded")
        print(f"📁 Location: {sharepoint_folder_name}/{filename_ez}")
        print(f"📊 Dataset: {len(aggregated_df):,} records (unique enumeration zones)")
        print(f"\n💡 USE THIS FILE for Power BI connection to Census_Main!")
    else:
        print(f"\n❌ EZ-level upload failed")
    
    print("\n" + "="*60)
    print("🎉 PROCESS COMPLETE!")
    print("="*60)
    print("\n📋 Files uploaded:")
    print(f"  1. {filename} - Original harmonized data ({len(harmonized_df)} rows)")
    print(f"  2. {filename_ez} - Aggregated to EZ level ({len(aggregated_df)} rows)")
    print("\n🔗 For Power BI:")
    print(f"  Connect Census_Main to {filename_ez} using enumeration_zone_code")
    
    return harmonized_df

if __name__ == "__main__":
    # Run the harmonization
    harmonized_data = main()
# Out:
# /Users/mehmetsundu/anaconda3/envs/ml/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# 🚀 NATIONAL STATISTICS HARMONIZATION
# ...
# 🔍 Testing SharePoint connection...
# ✅ Connected to site: PBI_MER_Data
# 🔄 Starting National Statistics harmonization...
# 🔍 Loading National Statistics files from SharePoint...
#
# 📂 Loading Burkina Faso...
#   ✅ Loaded: 110 rows × 23 columns
#
# 📂 Loading Cameroon...
#   ✅ Loaded: 10 rows × 9 columns
#
# 📂 Loading Guinea...
#   ✅ Loaded: 115 rows × 13 columns
#
# 📂 Loading Madagascar...
#   ✅ Loaded: 115 rows × 10 columns
#
# 📂 Loading Mali...
#   ✅ Loaded: 127 rows × 33 columns
#
# 📂 Loading Niger...
#   ✅ Loaded: 266 rows × 8 columns
#
# 📊 Successfully loaded data from 6 countries
#
# 🔄 Harmonizing Burkina Faso...
#   ✅ Harmonized: 110 rows × 21 columns
#
# 🔄 Harmonizing Cameroon...
# ...
